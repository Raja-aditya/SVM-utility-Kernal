# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Create 2 virtual GPUs with 1GB memory each
  try:
    tf.config.set_logical_device_configuration(
        gpus[0],
        [tf.config.LogicalDeviceConfiguration(memory_limit=1024),
         tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPU,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPU, 2 Logical GPUs

# %%
import numpy as np, pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import os,math,pickle
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate,cross_val_predict,StratifiedKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix,roc_auc_score
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# %%
path = 'data/'

# %%
# hyper-parameters of the utility kernel
c = 100
K_0 = 0.1
K_1 = 10
Alpha = 5

# number of PCA features by fixing the variance of 95%
NumComponents = 0.95

# number of samples of minority classes at various survival cut-offs
long_data_num_5yr = 204
long_data_num_6yr = 584
long_data_num_7yr = 187
long_data_num_8yr = 127
long_data_num_9yr = 102

# %%
# various survival cut-offs csv files
survival_file_name_5yr = 'class_5_year.csv'
survival_file_name_6yr = 'class_6_year.csv'
survival_file_name_7yr = 'class_7_year.csv'
survival_file_name_8yr = 'class_8_year.csv'
survival_file_name_9yr = 'class_9_year.csv'

# %%
#change for each survival year cutoff
long_data_num = long_data_num_9yr
survival_file_name = survival_file_name_9yr

# %%
def data_sampler(long_data,short_data):
	#subsampling the long data
	df = pd.DataFrame(long_data)
	long_data=df.sample(n = long_data_num)

	#generating balanced class data for training
	data = np.vstack((long_data,short_data))
	#print(data.shape)
	return data

# %%
#define utility kernel
def utility_kernel(X, Y):
    k_0 =K_0
    k_1 = K_1
    alpha = Alpha
    kernel_value = k_0+np.multiply(k_1,np.power((np.dot(X, Y.T)),alpha))
    return kernel_value

# %%
def my_pca(data,numComponents):
	#Applying PCA with 95% explained_variance_ratio_
	plt.style.use('ggplot')
	pca = PCA(n_components=numComponents, random_state=42)
	pca.fit(data) 
	data = pca.transform(data)
	plt.plot(np.cumsum(pca.explained_variance_ratio_))
	plt.xlabel('number of components')
	plt.ylabel('Explained variance')
	plt.savefig(os.path.join(path,'elbow_plot_multimodal.png'),dpi=100)
	return data

# %%
def ncr(n, r):
    r = min(r, n-r)
    numer = reduce(op.mul, range(n, n-r, -1), 1)
    denom = reduce(op.mul, range(1, r+1), 1)
    return numer // denom

# %%
CLN = np.loadtxt(os.path.join(path,'tcga_cln_final.csv'), delimiter=",")
WSI = np.loadtxt(os.path.join(path,'tcga_allWSIpatchfused.csv'), delimiter=",")
EXP = np.loadtxt(os.path.join(path,'tcga_exp_final.csv'), delimiter=",")
CNV = np.loadtxt(os.path.join(path,'tcga_cnv_final.csv'), delimiter=",")
CLN_EXP    = np.concatenate((CLN,EXP),axis=1)
CLN_CNV    = np.concatenate((CLN,CNV),axis=1)
CLN_WSI    = np.concatenate((CLN,WSI),axis=1)
EXP_CNV    = np.concatenate((EXP,CNV),axis=1)
EXP_WSI    = np.concatenate((EXP,WSI),axis=1)
CNV_WSI    = np.concatenate((CNV,WSI),axis=1)
CLN_EXP_CNV     = np.concatenate((CLN,EXP,CNV),axis=1)
CLN_EXP_WSI     = np.concatenate((CLN,EXP,WSI),axis=1)
EXP_CNV_WSI     = np.concatenate((EXP,CNV,WSI),axis=1)
CNV_CLN_WSI     = np.concatenate((CNV,CLN,WSI),axis=1)
multimodal     = np.concatenate((WSI,CLN,CNV,EXP),axis=1)
y_multimodal 	  = np.loadtxt(os.path.join(path, survival_file_name))

# %%
CLN.shape
# Out:
# (1068, 10)

# %%
y_multimodal.shape
# Out:
# (1068,)

# %%
import seaborn as sns
sns.countplot(x=y_multimodal)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
from sklearn.metrics import roc_auc_score, matthews_corrcoef, cohen_kappa_score, accuracy_score, precision_score, recall_score, f1_score,jaccard_score,fbeta_score

# %%
ML_Model = []
accuracy = []
roc = []
precision = []
recall = []
f1score = []
mcc = []
kappa = []
jacc = []
gmea = []

#function to call for storing the results
def storeResults(model, a,b,c,d,e,f,g,h,i):
    ML_Model.append(model)
    accuracy.append(round(a, 3))
    roc.append(round(b, 3))
    precision.append(round(c, 3))
    recall.append(round(d, 3))
    f1score.append(round(e,3))
    mcc.append(round(f,3))
    kappa.append(round(g,3))
    jacc.append(round(h,3))
    gmea.append(round(i,3))

# %% [markdown]
# # CLN

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 10), (907,), (161, 10), (161,))

# %% [markdown]
# # SVM - RBF

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_a = accuracy_score(y_pred, y_test)
svm_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_a = precision_score(y_pred, y_test)
svm_rec_a = recall_score(y_pred, y_test)
svm_f1_a = f1_score(y_pred, y_test)
svm_mcc_a = matthews_corrcoef(y_pred, y_test)
svm_kap_a = cohen_kappa_score(y_pred, y_test)
svm_jacc_a = jaccard_score(y_pred, y_test)
svm_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - rbf',svm_acc_a,svm_roc_a,svm_prec_a,svm_rec_a,svm_f1_a,svm_mcc_a,svm_kap_a,svm_jacc_a,svm_gmea_a)

# %% [markdown]
# # SVM - Poly

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_a = accuracy_score(y_pred, y_test)
svm1_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_a = precision_score(y_pred, y_test)
svm1_rec_a = recall_score(y_pred, y_test)
svm1_f1_a = f1_score(y_pred, y_test)
svm1_mcc_a = matthews_corrcoef(y_pred, y_test)
svm1_kap_a = cohen_kappa_score(y_pred, y_test)
svm1_jacc_a = jaccard_score(y_pred, y_test)
svm1_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - Poly',svm1_acc_a,svm1_roc_a,svm1_prec_a,svm1_rec_a,svm1_f1_a,svm1_mcc_a,svm1_kap_a,svm1_jacc_a,svm1_gmea_a)

# %% [markdown]
# # SVM - Utility Kerenl

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_a = accuracy_score(y_pred, y_test)
svm2_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_a = precision_score(y_pred, y_test)
svm2_rec_a = recall_score(y_pred, y_test)
svm2_f1_a = f1_score(y_pred, y_test)
svm2_mcc_a = matthews_corrcoef(y_pred, y_test)
svm2_kap_a = cohen_kappa_score(y_pred, y_test)
svm2_jacc_a = jaccard_score(y_pred, y_test)
svm2_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - Utility ',svm2_acc_a,svm2_roc_a,svm2_prec_a,svm2_rec_a,svm2_f1_a,svm2_mcc_a,svm2_kap_a,svm2_jacc_a,svm2_gmea_a)

# %% [markdown]
# # SVC - Linear

# %%
clf = SVC(kernel ='linear',probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_a = accuracy_score(y_pred, y_test)
svm3_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_a = precision_score(y_pred, y_test)
svm3_rec_a = recall_score(y_pred, y_test)
svm3_f1_a = f1_score(y_pred, y_test)
svm3_mcc_a = matthews_corrcoef(y_pred, y_test)
svm3_kap_a = cohen_kappa_score(y_pred, y_test)
svm3_jacc_a = jaccard_score(y_pred, y_test)
svm3_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - Linear ',svm3_acc_a,svm3_roc_a,svm3_prec_a,svm3_rec_a,svm3_f1_a,svm3_mcc_a,svm3_kap_a,svm3_jacc_a,svm3_gmea_a)

# %% [markdown]
# # SVC - Sigmoid

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_a = accuracy_score(y_pred, y_test)
svm4_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_a = precision_score(y_pred, y_test)
svm4_rec_a = recall_score(y_pred, y_test)
svm4_f1_a = f1_score(y_pred, y_test)
svm4_mcc_a = matthews_corrcoef(y_pred, y_test)
svm4_kap_a = cohen_kappa_score(y_pred, y_test)
svm4_jacc_a = jaccard_score(y_pred, y_test)
svm4_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - Sigmoid',svm4_acc_a,svm4_roc_a,svm4_prec_a,svm4_rec_a,svm4_f1_a,svm4_mcc_a,svm4_kap_a,svm4_jacc_a,svm4_gmea_a)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_a = accuracy_score(y_pred, y_test)
rf_roc_a = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_a = precision_score(y_pred, y_test)
rf_rec_a = recall_score(y_pred, y_test)
rf_f1_a = f1_score(y_pred, y_test)
rf_mcc_a = matthews_corrcoef(y_pred, y_test)
rf_kap_a = cohen_kappa_score(y_pred, y_test)
rf_jacc_a = jaccard_score(y_pred, y_test)
rf_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - RF',rf_acc_a,rf_roc_a,rf_prec_a,rf_rec_a,rf_f1_a,rf_mcc_a,rf_kap_a,rf_jacc_a,rf_gmea_a)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_a = accuracy_score(y_pred, y_test)
dt_roc_a = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_a = precision_score(y_pred, y_test)
dt_rec_a = recall_score(y_pred, y_test)
dt_f1_a = f1_score(y_pred, y_test)
dt_mcc_a = matthews_corrcoef(y_pred, y_test)
dt_kap_a = cohen_kappa_score(y_pred, y_test)
dt_jacc_a = jaccard_score(y_pred, y_test)
dt_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - DT',dt_acc_a,dt_roc_a,dt_prec_a,dt_rec_a,dt_f1_a,dt_mcc_a,dt_kap_a,dt_jacc_a,dt_gmea_a)

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_a = accuracy_score(y_pred, y_test)
nb_roc_a = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_a = precision_score(y_pred, y_test)
nb_rec_a = recall_score(y_pred, y_test)
nb_f1_a = f1_score(y_pred, y_test)
nb_mcc_a = matthews_corrcoef(y_pred, y_test)
nb_kap_a = cohen_kappa_score(y_pred, y_test)
nb_jacc_a = jaccard_score(y_pred, y_test)
nb_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - NB',nb_acc_a,nb_roc_a,nb_prec_a,nb_rec_a,nb_f1_a,nb_mcc_a,nb_kap_a,nb_jacc_a,nb_gmea_a)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_a = accuracy_score(y_pred, y_test)
vot_roc_a = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_a = precision_score(y_pred, y_test)
vot_rec_a = recall_score(y_pred, y_test)
vot_f1_a = f1_score(y_pred, y_test)
vot_mcc_a = matthews_corrcoef(y_pred, y_test)
vot_kap_a = cohen_kappa_score(y_pred, y_test)
vot_jacc_a = jaccard_score(y_pred, y_test)
vot_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - vot',vot_acc_a,vot_roc_a,vot_prec_a,vot_rec_a,vot_f1_a,vot_mcc_a,vot_kap_a,vot_jacc_a,vot_gmea_a)

# %% [markdown]
# # DL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %% [markdown]
# # VGGNets

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 9, 128)            384
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 4, 128)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 128)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 1026
# =================================================================
# Total params: 1,410
# Trainable params: 1,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 3s 192ms/step - loss: 0.6966 - accuracy: 0.5000 - val_loss: 0.6754 - val_accuracy: 0.8626
# Epoch 2/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6783 - accuracy: 0.8750 - val_loss: 0.6371 - val_accuracy: 0.8571
# Epoch 3/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5827 - accuracy: 1.0000 - val_loss: 0.6019 - val_accuracy: 0.8571
# Epoch 4/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.5260 - accuracy: 1.0000 - val_loss: 0.5695 - val_accuracy: 0.8571
# Epoch 5/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4787 - accuracy: 1.0000 - val_loss: 0.5402 - val_accuracy: 0.8571
# Epoch 6/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4508 - accuracy: 1.0000 - val_loss: 0.5143 - val_accuracy: 0.8571
# Epoch 7/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4892 - accuracy: 0.8750 - val_loss: 0.4927 - val_accuracy: 0.8571
# Epoch 8/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3555 - accuracy: 1.0000 - val_loss: 0.4748 - val_accuracy: 0.8571
# Epoch 9/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3373 - accuracy: 1.0000 - val_loss: 0.4598 - val_accuracy: 0.8571
# Epoch 10/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3081 - accuracy: 1.0000 - val_loss: 0.4477 - val_accuracy: 0.8571
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2562 - accuracy: 1.0000 - val_loss: 0.4386 - val_accuracy: 0.8571
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7293 - accuracy: 0.6250 - val_loss: 0.4340 - val_accuracy: 0.8571
# Epoch 13/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.2241 - accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 0.8571
# Epoch 14/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.5449 - accuracy: 0.7500 - val_loss: 0.4293 - val_accuracy: 0.8571
# Epoch 15/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1967 - accuracy: 1.0000 - val_loss: 0.4286 - val_accuracy: 0.8571
# Epoch 16/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4055 - accuracy: 0.8750 - val_loss: 0.4289 - val_accuracy: 0.8571
# Epoch 17/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1417 - accuracy: 1.0000 - val_loss: 0.4299 - val_accuracy: 0.8571
# Epoch 18/20
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1534 - accuracy: 1.0000 - val_loss: 0.4319 - val_accuracy: 0.8571
# Epoch 19/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3563 - accuracy: 0.8750 - val_loss: 0.4344 - val_accuracy: 0.8571
# Epoch 20/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3993 - accuracy: 0.8750 - val_loss: 0.4366 - val_accuracy: 0.8571

# %%
# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

# %%
cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_a = accuracy_score(y_pred, y_test)
vgg_roc_a = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_a = precision_score(y_pred, y_test)
vgg_rec_a = recall_score(y_pred, y_test)
vgg_f1_a = f1_score(y_pred, y_test)
vgg_mcc_a = matthews_corrcoef(y_pred, y_test)
vgg_kap_a = cohen_kappa_score(y_pred, y_test)
vgg_jacc_a = jaccard_score(y_pred, y_test)
vgg_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - VGGNets',vgg_acc_a,vgg_roc_a,vgg_prec_a,vgg_rec_a,vgg_f1_a,vgg_mcc_a,vgg_kap_a,vgg_jacc_a,vgg_gmea_a)
# Out:
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # ResNets

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_a = accuracy_score(y_pred, y_test)
res_roc_a = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_a = precision_score(y_pred, y_test)
res_rec_a = recall_score(y_pred, y_test)
res_f1_a = f1_score(y_pred, y_test)
res_mcc_a = matthews_corrcoef(y_pred, y_test)
res_kap_a = cohen_kappa_score(y_pred, y_test)
res_jacc_a = jaccard_score(y_pred, y_test)
res_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - ResNets',res_acc_a,res_roc_a,res_prec_a,res_rec_a,res_f1_a,res_mcc_a,res_kap_a,res_jacc_a,res_gmea_a)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 9, 128)            384
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 4, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 128)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 1,410
# Trainable params: 1,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 153ms/step - loss: 0.6418 - accuracy: 1.0000 - val_loss: 0.6384 - val_accuracy: 0.8571
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6161 - accuracy: 1.0000 - val_loss: 0.6084 - val_accuracy: 0.8571
# Epoch 3/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5817 - accuracy: 0.8750 - val_loss: 0.5823 - val_accuracy: 0.8571
# Epoch 4/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5333 - accuracy: 1.0000 - val_loss: 0.5577 - val_accuracy: 0.8571
# Epoch 5/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4852 - accuracy: 1.0000 - val_loss: 0.5347 - val_accuracy: 0.8571
# Epoch 6/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5029 - accuracy: 0.8750 - val_loss: 0.5148 - val_accuracy: 0.8571
# Epoch 7/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6572 - accuracy: 0.6250 - val_loss: 0.4992 - val_accuracy: 0.8571
# Epoch 8/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3910 - accuracy: 1.0000 - val_loss: 0.4854 - val_accuracy: 0.8571
# Epoch 9/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4661 - accuracy: 0.8750 - val_loss: 0.4727 - val_accuracy: 0.8571
# Epoch 10/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3357 - accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.8571
# Epoch 11/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4054 - accuracy: 0.8750 - val_loss: 0.4509 - val_accuracy: 0.8571
# Epoch 12/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4759 - accuracy: 0.8750 - val_loss: 0.4428 - val_accuracy: 0.8571
# Epoch 13/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.2767 - accuracy: 1.0000 - val_loss: 0.4361 - val_accuracy: 0.8571
# Epoch 14/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4464 - accuracy: 0.8750 - val_loss: 0.4310 - val_accuracy: 0.8571
# Epoch 15/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3975 - accuracy: 0.8750 - val_loss: 0.4278 - val_accuracy: 0.8571
# Epoch 16/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1888 - accuracy: 1.0000 - val_loss: 0.4255 - val_accuracy: 0.8571
# Epoch 17/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1842 - accuracy: 1.0000 - val_loss: 0.4243 - val_accuracy: 0.8571
# Epoch 18/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.6583 - accuracy: 0.7500 - val_loss: 0.4241 - val_accuracy: 0.8571
# Epoch 19/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1628 - accuracy: 1.0000 - val_loss: 0.4246 - val_accuracy: 0.8571
# Epoch 20/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1275 - accuracy: 1.0000 - val_loss: 0.4260 - val_accuracy: 0.8571
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %% [markdown]
# # DesNet

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_a = accuracy_score(y_pred, y_test)
dense_roc_a = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_a = precision_score(y_pred, y_test)
dense_rec_a = recall_score(y_pred, y_test)
dense_f1_a = f1_score(y_pred, y_test)
dense_mcc_a = matthews_corrcoef(y_pred, y_test)
dense_kap_a = cohen_kappa_score(y_pred, y_test)
dense_jacc_a = jaccard_score(y_pred, y_test)
dense_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - DenseNets',dense_acc_a,dense_roc_a,dense_prec_a,dense_rec_a,dense_f1_a,dense_mcc_a,dense_kap_a,dense_jacc_a,dense_gmea_a)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 9, 128)            384
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 4, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 128)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 1,410
# Trainable params: 1,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 148ms/step - loss: 0.6414 - accuracy: 0.8750 - val_loss: 0.6261 - val_accuracy: 0.8571
# Epoch 2/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5691 - accuracy: 1.0000 - val_loss: 0.5995 - val_accuracy: 0.8571
# Epoch 3/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6083 - accuracy: 0.8750 - val_loss: 0.5757 - val_accuracy: 0.8571
# Epoch 4/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5782 - accuracy: 0.8750 - val_loss: 0.5546 - val_accuracy: 0.8571
# Epoch 5/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5519 - accuracy: 0.8750 - val_loss: 0.5357 - val_accuracy: 0.8571
# Epoch 6/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4424 - accuracy: 1.0000 - val_loss: 0.5178 - val_accuracy: 0.8571
# Epoch 7/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4194 - accuracy: 1.0000 - val_loss: 0.5003 - val_accuracy: 0.8571
# Epoch 8/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4719 - accuracy: 0.8750 - val_loss: 0.4849 - val_accuracy: 0.8571
# Epoch 9/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3638 - accuracy: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.8571
# Epoch 10/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6221 - accuracy: 0.7500 - val_loss: 0.4593 - val_accuracy: 0.8571
# Epoch 11/20
# 2/2 [==============================] - 0s 108ms/step - loss: 0.3052 - accuracy: 1.0000 - val_loss: 0.4497 - val_accuracy: 0.8571
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4105 - accuracy: 0.8750 - val_loss: 0.4417 - val_accuracy: 0.8571
# Epoch 13/20
# 2/2 [==============================] - 0s 191ms/step - loss: 0.4217 - accuracy: 0.8750 - val_loss: 0.4351 - val_accuracy: 0.8571
# Epoch 14/20
# 2/2 [==============================] - 0s 159ms/step - loss: 0.4300 - accuracy: 0.8750 - val_loss: 0.4308 - val_accuracy: 0.8571
# Epoch 15/20
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1895 - accuracy: 1.0000 - val_loss: 0.4271 - val_accuracy: 0.8571
# Epoch 16/20
# 2/2 [==============================] - 0s 126ms/step - loss: 0.4182 - accuracy: 0.8750 - val_loss: 0.4250 - val_accuracy: 0.8571
# Epoch 17/20
# 2/2 [==============================] - 0s 121ms/step - loss: 0.1900 - accuracy: 1.0000 - val_loss: 0.4239 - val_accuracy: 0.8571
# Epoch 18/20
# 2/2 [==============================] - 0s 114ms/step - loss: 0.6774 - accuracy: 0.7500 - val_loss: 0.4239 - val_accuracy: 0.8571
# Epoch 19/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.1734 - accuracy: 1.0000 - val_loss: 0.4245 - val_accuracy: 0.8571
# Epoch 20/20
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4077 - accuracy: 0.8750 - val_loss: 0.4253 - val_accuracy: 0.8571
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 997us/step

# %% [markdown]
# # WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 800), (907,), (161, 800), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_b = accuracy_score(y_pred, y_test)
svm_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_b = precision_score(y_pred, y_test)
svm_rec_b = recall_score(y_pred, y_test)
svm_f1_b = f1_score(y_pred, y_test)
svm_mcc_b = matthews_corrcoef(y_pred, y_test)
svm_kap_b = cohen_kappa_score(y_pred, y_test)
svm_jacc_b = jaccard_score(y_pred, y_test)
svm_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - rbf',svm_acc_b,svm_roc_b,svm_prec_b,svm_rec_b,svm_f1_b,svm_mcc_b,svm_kap_b,svm_jacc_b,svm_gmea_b)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_b = accuracy_score(y_pred, y_test)
svm1_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_b = precision_score(y_pred, y_test)
svm1_rec_b = recall_score(y_pred, y_test)
svm1_f1_b = f1_score(y_pred, y_test)
svm1_mcc_b = matthews_corrcoef(y_pred, y_test)
svm1_kap_b = cohen_kappa_score(y_pred, y_test)
svm1_jacc_b = jaccard_score(y_pred, y_test)
svm1_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - Poly',svm1_acc_b,svm1_roc_b,svm1_prec_b,svm1_rec_b,svm1_f1_b,svm1_mcc_b,svm1_kap_b,svm1_jacc_b,svm1_gmea_a)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_b = accuracy_score(y_pred, y_test)
svm2_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_b = precision_score(y_pred, y_test)
svm2_rec_b = recall_score(y_pred, y_test)
svm2_f1_b = f1_score(y_pred, y_test)
svm2_mcc_b = matthews_corrcoef(y_pred, y_test)
svm2_kap_b = cohen_kappa_score(y_pred, y_test)
svm2_jacc_b = jaccard_score(y_pred, y_test)
svm2_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - Utility ',svm2_acc_b,svm2_roc_b,svm2_prec_b,svm2_rec_b,svm2_f1_b,svm2_mcc_b,svm2_kap_b,svm2_jacc_b,svm2_gmea_b)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_b =accuracy_score(y_pred, y_test)
svm3_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_b =precision_score(y_pred, y_test)
svm3_rec_b =recall_score(y_pred, y_test)
svm3_f1_b =f1_score(y_pred, y_test)
svm3_mcc_b =matthews_corrcoef(y_pred, y_test)
svm3_kap_b =cohen_kappa_score(y_pred, y_test)
svm3_jacc_b =jaccard_score(y_pred, y_test)
svm3_gmea_b =fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - Linear ',svm3_acc_b,svm3_roc_b,svm3_prec_b,svm3_rec_b,svm3_f1_b,svm3_mcc_b,svm3_kap_b,svm3_jacc_b,svm3_gmea_b)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_b = accuracy_score(y_pred, y_test)
svm4_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_b = precision_score(y_pred, y_test)
svm4_rec_b = recall_score(y_pred, y_test)
svm4_f1_b = f1_score(y_pred, y_test)
svm4_mcc_b = matthews_corrcoef(y_pred, y_test)
svm4_kap_b = cohen_kappa_score(y_pred, y_test)
svm4_jacc_b = jaccard_score(y_pred, y_test)
svm4_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - Sigmoid',svm4_acc_b,svm4_roc_b,svm4_prec_b,svm4_rec_b,svm4_f1_b,svm4_mcc_b,svm4_kap_b,svm4_jacc_b,svm4_gmea_b)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_b = accuracy_score(y_pred, y_test)
rf_roc_b = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_b = precision_score(y_pred, y_test)
rf_rec_b = recall_score(y_pred, y_test)
rf_f1_b = f1_score(y_pred, y_test)
rf_mcc_b = matthews_corrcoef(y_pred, y_test)
rf_kap_b = cohen_kappa_score(y_pred, y_test)
rf_jacc_b = jaccard_score(y_pred, y_test)
rf_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - RF',rf_acc_b,rf_roc_b,rf_prec_b,rf_rec_b,rf_f1_b,rf_mcc_b,rf_kap_b,rf_jacc_b,rf_gmea_b)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_b = accuracy_score(y_pred, y_test)
dt_roc_b = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_b = precision_score(y_pred, y_test)
dt_rec_b = recall_score(y_pred, y_test)
dt_f1_b = f1_score(y_pred, y_test)
dt_mcc_b = matthews_corrcoef(y_pred, y_test)
dt_kap_b = cohen_kappa_score(y_pred, y_test)
dt_jacc_b = jaccard_score(y_pred, y_test)
dt_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - DT',dt_acc_b,dt_roc_b,dt_prec_b,dt_rec_b,dt_f1_b,dt_mcc_b,dt_kap_b,dt_jacc_b,dt_gmea_b)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_b = accuracy_score(y_pred, y_test)
nb_roc_b = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_b = precision_score(y_pred, y_test)
nb_rec_b = recall_score(y_pred, y_test)
nb_f1_b = f1_score(y_pred, y_test)
nb_mcc_b = matthews_corrcoef(y_pred, y_test)
nb_kap_b = cohen_kappa_score(y_pred, y_test)
nb_jacc_b = jaccard_score(y_pred, y_test)
nb_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - NB',nb_acc_b,nb_roc_b,nb_prec_b,nb_rec_b,nb_f1_b,nb_mcc_b,nb_kap_b,nb_jacc_b,nb_gmea_b)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_b = accuracy_score(y_pred, y_test)
vot_roc_b = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_b = precision_score(y_pred, y_test)
vot_rec_b = recall_score(y_pred, y_test)
vot_f1_b = f1_score(y_pred, y_test)
vot_mcc_b = matthews_corrcoef(y_pred, y_test)
vot_kap_b = cohen_kappa_score(y_pred, y_test)
vot_jacc_b = jaccard_score(y_pred, y_test)
vot_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI- vot',vot_acc_b,vot_roc_b,vot_prec_b,vot_rec_b,vot_f1_b,vot_mcc_b,vot_kap_b,vot_jacc_b,vot_gmea_b)

# %% [markdown]
# # DL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)


# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_b = accuracy_score(y_pred, y_test)
vgg_roc_b = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_b = precision_score(y_pred, y_test)
vgg_rec_b = recall_score(y_pred, y_test)
vgg_f1_b = f1_score(y_pred, y_test)
vgg_mcc_b = matthews_corrcoef(y_pred, y_test)
vgg_kap_b = cohen_kappa_score(y_pred, y_test)
vgg_jacc_b = jaccard_score(y_pred, y_test)
vgg_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - VGGNets',vgg_acc_b,vgg_roc_b,vgg_prec_b,vgg_rec_b,vgg_f1_b,vgg_mcc_b,vgg_kap_b,vgg_jacc_b,vgg_gmea_b)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 799, 128)          384
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 399, 128)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 399, 128)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 51072)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 102146
# =================================================================
# Total params: 102,530
# Trainable params: 102,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 259ms/step - loss: 0.7111 - accuracy: 0.7500 - val_loss: 8.4363 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 75ms/step - loss: 16.3108 - accuracy: 0.8750 - val_loss: 9.7630 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 78ms/step - loss: 16.5157 - accuracy: 0.8750 - val_loss: 9.7141 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.8382 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.1633 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.6307 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 73ms/step - loss: 19.7546 - accuracy: 0.7500 - val_loss: 5.3428 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.5140 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.0386 - val_accuracy: 0.8956
# Epoch 10/20
# 2/2 [==============================] - 0s 85ms/step - loss: 4.0975 - accuracy: 0.8750 - val_loss: 3.2260 - val_accuracy: 0.5330
# Epoch 11/20
# 2/2 [==============================] - 0s 75ms/step - loss: 3.1585 - accuracy: 0.5000 - val_loss: 1.3278 - val_accuracy: 0.8462
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.8992 - accuracy: 0.8750 - val_loss: 1.9062 - val_accuracy: 0.8956
# Epoch 13/20
# 2/2 [==============================] - 0s 74ms/step - loss: 6.4075e-07 - accuracy: 1.0000 - val_loss: 2.6389 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 74ms/step - loss: 2.8098 - accuracy: 0.8750 - val_loss: 2.9936 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 74ms/step - loss: 4.5523 - accuracy: 0.8750 - val_loss: 2.2450 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 76ms/step - loss: 6.1095e-07 - accuracy: 1.0000 - val_loss: 1.6438 - val_accuracy: 0.8901
# Epoch 17/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 1.3061 - val_accuracy: 0.8681
# Epoch 18/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2957 - val_accuracy: 0.8297
# Epoch 19/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1172 - accuracy: 0.8750 - val_loss: 1.2758 - val_accuracy: 0.8187
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.7976 - accuracy: 0.8750 - val_loss: 1.2235 - val_accuracy: 0.8077
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_b = accuracy_score(y_pred, y_test)
res_roc_b = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_b = precision_score(y_pred, y_test)
res_rec_b = recall_score(y_pred, y_test)
res_f1_b = f1_score(y_pred, y_test)
res_mcc_b = matthews_corrcoef(y_pred, y_test)
res_kap_b = cohen_kappa_score(y_pred, y_test)
res_jacc_b = jaccard_score(y_pred, y_test)
res_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - ResNets',res_acc_b,res_roc_b,res_prec_b,res_rec_b,res_f1_b,res_mcc_b,res_kap_b,res_jacc_b,res_gmea_b)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 799, 128)          384
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 399, 128)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 399, 128)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 51072)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 102146
# =================================================================
# Total params: 102,530
# Trainable params: 102,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 161ms/step - loss: 0.3819 - accuracy: 0.7500 - val_loss: 7.8369 - val_accuracy: 0.1429
# Epoch 2/20
# 2/2 [==============================] - 0s 75ms/step - loss: 8.5182 - accuracy: 0.3750 - val_loss: 2.5744 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.1325 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 75ms/step - loss: 12.3643 - accuracy: 0.7500 - val_loss: 3.2036 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 75ms/step - loss: 5.0045 - accuracy: 0.8750 - val_loss: 2.2641 - val_accuracy: 0.8407
# Epoch 6/20
# 2/2 [==============================] - 0s 79ms/step - loss: 5.8911 - accuracy: 0.6250 - val_loss: 2.4960 - val_accuracy: 0.7967
# Epoch 7/20
# 2/2 [==============================] - 0s 79ms/step - loss: 8.3285 - accuracy: 0.5000 - val_loss: 2.3678 - val_accuracy: 0.7418
# Epoch 8/20
# 2/2 [==============================] - 0s 78ms/step - loss: 3.4062 - accuracy: 0.6250 - val_loss: 2.5511 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 85ms/step - loss: 2.9802e-08 - accuracy: 1.0000 - val_loss: 4.0293 - val_accuracy: 0.8956
# Epoch 10/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.2343 - val_accuracy: 0.8956
# Epoch 11/20
# 2/2 [==============================] - 0s 196ms/step - loss: 9.3156 - accuracy: 0.8750 - val_loss: 5.8579 - val_accuracy: 0.8956
# Epoch 12/20
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.0398 - val_accuracy: 0.8956
# Epoch 13/20
# 2/2 [==============================] - 0s 148ms/step - loss: 19.1441 - accuracy: 0.7500 - val_loss: 5.3003 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 139ms/step - loss: 6.7209 - accuracy: 0.8750 - val_loss: 4.0602 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.0563 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 115ms/step - loss: 2.9651 - accuracy: 0.8750 - val_loss: 1.9664 - val_accuracy: 0.8956
# Epoch 17/20
# 2/2 [==============================] - 0s 109ms/step - loss: 1.8249 - accuracy: 0.8750 - val_loss: 1.7048 - val_accuracy: 0.6703
# Epoch 18/20
# 2/2 [==============================] - 0s 106ms/step - loss: 6.4881 - accuracy: 0.2500 - val_loss: 2.5329 - val_accuracy: 0.5440
# Epoch 19/20
# 2/2 [==============================] - 0s 104ms/step - loss: 2.8779 - accuracy: 0.6250 - val_loss: 1.3263 - val_accuracy: 0.8901
# Epoch 20/20
# 2/2 [==============================] - 0s 97ms/step - loss: 5.7666 - accuracy: 0.6250 - val_loss: 1.6796 - val_accuracy: 0.8956
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 997us/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_b = accuracy_score(y_pred, y_test)
dense_roc_b = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_b = precision_score(y_pred, y_test)
dense_rec_b = recall_score(y_pred, y_test)
dense_f1_b = f1_score(y_pred, y_test)
dense_mcc_b = matthews_corrcoef(y_pred, y_test)
dense_kap_b = cohen_kappa_score(y_pred, y_test)
dense_jacc_b = jaccard_score(y_pred, y_test)
dense_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - DenseNets',dense_acc_b,dense_roc_b,dense_prec_b,dense_rec_b,dense_f1_b,dense_mcc_b,dense_kap_b,dense_jacc_b,dense_gmea_b)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 799, 128)          384
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 399, 128)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 399, 128)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 51072)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 102146
# =================================================================
# Total params: 102,530
# Trainable params: 102,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 157ms/step - loss: 0.3394 - accuracy: 0.7500 - val_loss: 1.6729 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 88ms/step - loss: 2.6911 - accuracy: 0.6250 - val_loss: 1.8497 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 97ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 3.8734 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.4040 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.6037 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.5633 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.3408 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 179ms/step - loss: 11.6995 - accuracy: 0.8750 - val_loss: 8.1439 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 156ms/step - loss: 11.4784 - accuracy: 0.8750 - val_loss: 5.9682 - val_accuracy: 0.8956
# Epoch 10/20
# 2/2 [==============================] - 0s 147ms/step - loss: 7.8325 - accuracy: 0.8750 - val_loss: 3.6168 - val_accuracy: 0.8956
# Epoch 11/20
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.8443 - val_accuracy: 0.7363
# Epoch 12/20
# 2/2 [==============================] - 0s 120ms/step - loss: 9.0110 - accuracy: 0.3750 - val_loss: 5.0297 - val_accuracy: 0.5220
# Epoch 13/20
# 2/2 [==============================] - 0s 113ms/step - loss: 1.0630 - accuracy: 0.7500 - val_loss: 3.0869 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.2488 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 102ms/step - loss: 6.3719 - accuracy: 0.8750 - val_loss: 6.3092 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.1731 - val_accuracy: 0.8956
# Epoch 17/20
# 2/2 [==============================] - 0s 99ms/step - loss: 8.9294 - accuracy: 0.8750 - val_loss: 7.5265 - val_accuracy: 0.8956
# Epoch 18/20
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4960 - val_accuracy: 0.8956
# Epoch 19/20
# 2/2 [==============================] - 0s 104ms/step - loss: 16.9836 - accuracy: 0.7500 - val_loss: 6.0788 - val_accuracy: 0.8956
# Epoch 20/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.9333 - val_accuracy: 0.8956
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 797us/step

# %% [markdown]
# # EXP

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(EXP, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 400), (907,), (161, 400), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_c = accuracy_score(y_pred, y_test)
svm_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_c = precision_score(y_pred, y_test)
svm_rec_c = recall_score(y_pred, y_test)
svm_f1_c = f1_score(y_pred, y_test)
svm_mcc_c = matthews_corrcoef(y_pred, y_test)
svm_kap_c = cohen_kappa_score(y_pred, y_test)
svm_jacc_c = jaccard_score(y_pred, y_test)
svm_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - rbf',svm_acc_c,svm_roc_c,svm_prec_c,svm_rec_c,svm_f1_c,svm_mcc_c,svm_kap_c,svm_jacc_c,svm_gmea_c)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_c = accuracy_score(y_pred, y_test)
svm1_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_c = precision_score(y_pred, y_test)
svm1_rec_c = recall_score(y_pred, y_test)
svm1_f1_c = f1_score(y_pred, y_test)
svm1_mcc_c = matthews_corrcoef(y_pred, y_test)
svm1_kap_c = cohen_kappa_score(y_pred, y_test)
svm1_jacc_c = jaccard_score(y_pred, y_test)
svm1_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Poly',svm1_acc_c,svm1_roc_c,svm1_prec_c,svm1_rec_c,svm1_f1_c,svm1_mcc_c,svm1_kap_c,svm1_jacc_c,svm1_gmea_c)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_c = accuracy_score(y_pred, y_test)
svm2_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_c = precision_score(y_pred, y_test)
svm2_rec_c = recall_score(y_pred, y_test)
svm2_f1_c = f1_score(y_pred, y_test)
svm2_mcc_c = matthews_corrcoef(y_pred, y_test)
svm2_kap_c = cohen_kappa_score(y_pred, y_test)
svm2_jacc_c = jaccard_score(y_pred, y_test)
svm2_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Utility ',svm2_acc_c,svm2_roc_c,svm2_prec_c,svm2_rec_c,svm2_f1_c,svm2_mcc_c,svm2_kap_c,svm2_jacc_c,svm2_gmea_c)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_c = accuracy_score(y_pred, y_test)
svm3_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_c = precision_score(y_pred, y_test)
svm3_rec_c = recall_score(y_pred, y_test)
svm3_f1_c = f1_score(y_pred, y_test)
svm3_mcc_c = matthews_corrcoef(y_pred, y_test)
svm3_kap_c = cohen_kappa_score(y_pred, y_test)
svm3_jacc_c = jaccard_score(y_pred, y_test)
svm3_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Linear ',svm3_acc_c,svm3_roc_c,svm3_prec_c,svm3_rec_c,svm3_f1_c,svm3_mcc_c,svm3_kap_c,svm3_jacc_c,svm3_gmea_c)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_c = accuracy_score(y_pred, y_test)
svm4_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_c = precision_score(y_pred, y_test)
svm4_rec_c = recall_score(y_pred, y_test)
svm4_f1_c = f1_score(y_pred, y_test)
svm4_mcc_c = matthews_corrcoef(y_pred, y_test)
svm4_kap_c = cohen_kappa_score(y_pred, y_test)
svm4_jacc_c = jaccard_score(y_pred, y_test)
svm4_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Sigmoid',svm4_acc_c,svm4_roc_c,svm4_prec_c,svm4_rec_c,svm4_f1_c,svm4_mcc_c,svm4_kap_c,svm4_jacc_c,svm4_gmea_c)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_c = accuracy_score(y_pred, y_test)
rf_roc_c = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_c = precision_score(y_pred, y_test)
rf_rec_c = recall_score(y_pred, y_test)
rf_f1_c = f1_score(y_pred, y_test)
rf_mcc_c = matthews_corrcoef(y_pred, y_test)
rf_kap_c = cohen_kappa_score(y_pred, y_test)
rf_jacc_c = jaccard_score(y_pred, y_test)
rf_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - RF',rf_acc_c,rf_roc_c,rf_prec_c,rf_rec_c,rf_f1_c,rf_mcc_c,rf_kap_c,rf_jacc_c,rf_gmea_c)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_c = accuracy_score(y_pred, y_test)
dt_roc_c = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_c = precision_score(y_pred, y_test)
dt_rec_c = recall_score(y_pred, y_test)
dt_f1_c = f1_score(y_pred, y_test)
dt_mcc_c = matthews_corrcoef(y_pred, y_test)
dt_kap_c = cohen_kappa_score(y_pred, y_test)
dt_jacc_c = jaccard_score(y_pred, y_test)
dt_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - DT',dt_acc_c,dt_roc_c,dt_prec_c,dt_rec_c,dt_f1_c,dt_mcc_c,dt_kap_c,dt_jacc_c,dt_gmea_c)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_c = accuracy_score(y_pred, y_test)
nb_roc_c = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_c = precision_score(y_pred, y_test)
nb_rec_c = recall_score(y_pred, y_test)
nb_f1_c = f1_score(y_pred, y_test)
nb_mcc_c = matthews_corrcoef(y_pred, y_test)
nb_kap_c = cohen_kappa_score(y_pred, y_test)
nb_jacc_c = jaccard_score(y_pred, y_test)
nb_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - NB',nb_acc_c,nb_roc_c,nb_prec_c,nb_rec_c,nb_f1_c,nb_mcc_c,nb_kap_c,nb_jacc_c,nb_gmea_c)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_c = accuracy_score(y_pred, y_test)
vot_roc_c = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_c = precision_score(y_pred, y_test)
vot_rec_c = recall_score(y_pred, y_test)
vot_f1_c = f1_score(y_pred, y_test)
vot_mcc_c = matthews_corrcoef(y_pred, y_test)
vot_kap_c = cohen_kappa_score(y_pred, y_test)
vot_jacc_c = jaccard_score(y_pred, y_test)
vot_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - vot',vot_acc_c,vot_roc_c,vot_prec_c,vot_rec_c,vot_f1_c,vot_mcc_c,vot_kap_c,vot_jacc_c,vot_gmea_c)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_c = accuracy_score(y_pred, y_test)
vgg_roc_c = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_c = precision_score(y_pred, y_test)
vgg_rec_c = recall_score(y_pred, y_test)
vgg_f1_c = f1_score(y_pred, y_test)
vgg_mcc_c = matthews_corrcoef(y_pred, y_test)
vgg_kap_c = cohen_kappa_score(y_pred, y_test)
vgg_jacc_c = jaccard_score(y_pred, y_test)
vgg_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - VGGNets',vgg_acc_c,vgg_roc_c,vgg_prec_c,vgg_rec_c,vgg_f1_c,vgg_mcc_c,vgg_kap_c,vgg_jacc_c,vgg_gmea_c)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 399, 128)          384
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 199, 128)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 199, 128)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 25472)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 50946
# =================================================================
# Total params: 51,330
# Trainable params: 51,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 159ms/step - loss: 0.5589 - accuracy: 0.7500 - val_loss: 0.3309 - val_accuracy: 0.9451
# Epoch 2/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4150 - accuracy: 0.8750 - val_loss: 0.2367 - val_accuracy: 0.9451
# Epoch 3/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3503 - accuracy: 0.8750 - val_loss: 0.2186 - val_accuracy: 0.9451
# Epoch 4/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5833 - accuracy: 0.8750 - val_loss: 0.2209 - val_accuracy: 0.9451
# Epoch 5/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 0.9451
# Epoch 6/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 0.2336 - val_accuracy: 0.9451
# Epoch 7/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2762 - accuracy: 0.8750 - val_loss: 0.2421 - val_accuracy: 0.9451
# Epoch 8/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8605 - accuracy: 0.8750 - val_loss: 0.2453 - val_accuracy: 0.9451
# Epoch 9/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9451
# Epoch 10/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.2470 - val_accuracy: 0.9451
# Epoch 11/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9451
# Epoch 12/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5532 - accuracy: 0.8750 - val_loss: 0.2486 - val_accuracy: 0.9451
# Epoch 13/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.9451
# Epoch 14/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.2493 - val_accuracy: 0.9451
# Epoch 15/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7367 - accuracy: 0.8750 - val_loss: 0.2476 - val_accuracy: 0.9451
# Epoch 16/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.8791 - accuracy: 0.7500 - val_loss: 0.2401 - val_accuracy: 0.9451
# Epoch 17/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.2345 - val_accuracy: 0.9451
# Epoch 18/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1282 - accuracy: 1.0000 - val_loss: 0.2330 - val_accuracy: 0.9451
# Epoch 19/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8703 - accuracy: 0.7500 - val_loss: 0.2324 - val_accuracy: 0.9451
# Epoch 20/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.6620 - accuracy: 0.7500 - val_loss: 0.2368 - val_accuracy: 0.9451
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 997us/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_c = accuracy_score(y_pred, y_test)
res_roc_c = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_c = precision_score(y_pred, y_test)
res_rec_c = recall_score(y_pred, y_test)
res_f1_c = f1_score(y_pred, y_test)
res_mcc_c = matthews_corrcoef(y_pred, y_test)
res_kap_c = cohen_kappa_score(y_pred, y_test)
res_jacc_c = jaccard_score(y_pred, y_test)
res_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - ResNets',res_acc_c,res_roc_c,res_prec_c,res_rec_c,res_f1_c,res_mcc_c,res_kap_c,res_jacc_c,res_gmea_c)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_7 (Conv1D)            (None, 399, 128)          384
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 199, 128)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 199, 128)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 25472)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 50946
# =================================================================
# Total params: 51,330
# Trainable params: 51,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.6069 - accuracy: 0.7500 - val_loss: 0.3452 - val_accuracy: 0.9451
# Epoch 2/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4161 - accuracy: 0.8750 - val_loss: 0.2522 - val_accuracy: 0.9451
# Epoch 3/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5180 - accuracy: 0.7500 - val_loss: 0.2271 - val_accuracy: 0.9451
# Epoch 4/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4097 - accuracy: 0.8750 - val_loss: 0.2220 - val_accuracy: 0.9451
# Epoch 5/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7761 - accuracy: 0.7500 - val_loss: 0.2228 - val_accuracy: 0.9451
# Epoch 6/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0422 - accuracy: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9451
# Epoch 7/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6736 - accuracy: 0.7500 - val_loss: 0.2242 - val_accuracy: 0.9451
# Epoch 8/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5375 - accuracy: 0.8750 - val_loss: 0.2253 - val_accuracy: 0.9451
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9451
# Epoch 10/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0925 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.9451
# Epoch 11/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.4814 - accuracy: 0.8750 - val_loss: 0.2270 - val_accuracy: 0.9451
# Epoch 12/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.2700 - accuracy: 0.8750 - val_loss: 0.2277 - val_accuracy: 0.9451
# Epoch 13/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6536 - accuracy: 0.8750 - val_loss: 0.2281 - val_accuracy: 0.9451
# Epoch 14/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3426 - accuracy: 0.8750 - val_loss: 0.2306 - val_accuracy: 0.9451
# Epoch 15/20
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1741 - accuracy: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.9451
# Epoch 16/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0797 - accuracy: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.9451
# Epoch 17/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0985 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9451
# Epoch 18/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8027 - accuracy: 0.7500 - val_loss: 0.2288 - val_accuracy: 0.9451
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0565 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.9451
# Epoch 20/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5042 - accuracy: 0.8750 - val_loss: 0.2295 - val_accuracy: 0.9451
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 797us/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_c = accuracy_score(y_pred, y_test)
dense_roc_c = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_c = precision_score(y_pred, y_test)
dense_rec_c = recall_score(y_pred, y_test)
dense_f1_c = f1_score(y_pred, y_test)
dense_mcc_c = matthews_corrcoef(y_pred, y_test)
dense_kap_c = cohen_kappa_score(y_pred, y_test)
dense_jacc_c = jaccard_score(y_pred, y_test)
dense_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - DenseNets',dense_acc_c,dense_roc_c,dense_prec_c,dense_rec_c,dense_f1_c,dense_mcc_c,dense_kap_c,dense_jacc_c,dense_gmea_c)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 399, 128)          384
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 199, 128)          0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 199, 128)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 25472)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 50946
# =================================================================
# Total params: 51,330
# Trainable params: 51,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 269ms/step - loss: 0.6612 - accuracy: 0.6250 - val_loss: 0.4496 - val_accuracy: 0.9451
# Epoch 2/20
# 2/2 [==============================] - 0s 157ms/step - loss: 0.5747 - accuracy: 0.8750 - val_loss: 0.2915 - val_accuracy: 0.9451
# Epoch 3/20
# 2/2 [==============================] - 0s 135ms/step - loss: 0.1771 - accuracy: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.9451
# Epoch 4/20
# 2/2 [==============================] - 0s 134ms/step - loss: 0.5216 - accuracy: 0.7500 - val_loss: 0.2246 - val_accuracy: 0.9451
# Epoch 5/20
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5677 - accuracy: 0.8750 - val_loss: 0.2248 - val_accuracy: 0.9451
# Epoch 6/20
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0436 - accuracy: 1.0000 - val_loss: 0.2257 - val_accuracy: 0.9451
# Epoch 7/20
# 2/2 [==============================] - 0s 110ms/step - loss: 0.4046 - accuracy: 0.8750 - val_loss: 0.2278 - val_accuracy: 0.9451
# Epoch 8/20
# 2/2 [==============================] - 0s 105ms/step - loss: 1.4703 - accuracy: 0.5000 - val_loss: 0.2264 - val_accuracy: 0.9451
# Epoch 9/20
# 2/2 [==============================] - 0s 110ms/step - loss: 0.9924 - accuracy: 0.7500 - val_loss: 0.2321 - val_accuracy: 0.9451
# Epoch 10/20
# 2/2 [==============================] - 0s 111ms/step - loss: 0.1284 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9451
# Epoch 11/20
# 2/2 [==============================] - 0s 107ms/step - loss: 0.4856 - accuracy: 0.8750 - val_loss: 0.2620 - val_accuracy: 0.9451
# Epoch 12/20
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0880 - accuracy: 1.0000 - val_loss: 0.2736 - val_accuracy: 0.9451
# Epoch 13/20
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3763 - accuracy: 0.8750 - val_loss: 0.2778 - val_accuracy: 0.9451
# Epoch 14/20
# 2/2 [==============================] - 0s 118ms/step - loss: 0.2271 - accuracy: 0.8750 - val_loss: 0.2783 - val_accuracy: 0.9451
# Epoch 15/20
# 2/2 [==============================] - 0s 117ms/step - loss: 0.1636 - accuracy: 1.0000 - val_loss: 0.2712 - val_accuracy: 0.9451
# Epoch 16/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6142 - accuracy: 0.8750 - val_loss: 0.2686 - val_accuracy: 0.9451
# Epoch 17/20
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1289 - accuracy: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9451
# Epoch 18/20
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1560 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.9451
# Epoch 19/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1458 - accuracy: 1.0000 - val_loss: 0.2366 - val_accuracy: 0.9451
# Epoch 20/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0770 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9451
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 797us/step

# %% [markdown]
# # CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CNV, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 200), (907,), (161, 200), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_d = accuracy_score(y_pred, y_test)
svm_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_d = precision_score(y_pred, y_test)
svm_rec_d = recall_score(y_pred, y_test)
svm_f1_d = f1_score(y_pred, y_test)
svm_mcc_d = matthews_corrcoef(y_pred, y_test)
svm_kap_d = cohen_kappa_score(y_pred, y_test)
svm_jacc_d = jaccard_score(y_pred, y_test)
svm_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - rbf',svm_acc_d,svm_roc_d,svm_prec_d,svm_rec_d,svm_f1_d,svm_mcc_d,svm_kap_d,svm_jacc_d,svm_gmea_d)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_d = accuracy_score(y_pred, y_test)
svm1_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_d = precision_score(y_pred, y_test)
svm1_rec_d = recall_score(y_pred, y_test)
svm1_f1_d = f1_score(y_pred, y_test)
svm1_mcc_d = matthews_corrcoef(y_pred, y_test)
svm1_kap_d = cohen_kappa_score(y_pred, y_test)
svm1_jacc_d = jaccard_score(y_pred, y_test)
svm1_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - Poly',svm1_acc_d,svm1_roc_d,svm1_prec_d,svm1_rec_d,svm1_f1_d,svm1_mcc_d,svm1_kap_d,svm1_jacc_d,svm1_gmea_d)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_d = accuracy_score(y_pred, y_test)
svm2_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_d = precision_score(y_pred, y_test)
svm2_rec_d = recall_score(y_pred, y_test)
svm2_f1_d = f1_score(y_pred, y_test)
svm2_mcc_d = matthews_corrcoef(y_pred, y_test)
svm2_kap_d = cohen_kappa_score(y_pred, y_test)
svm2_jacc_d = jaccard_score(y_pred, y_test)
svm2_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - Utility ',svm2_acc_d,svm2_roc_d,svm2_prec_d,svm2_rec_d,svm2_f1_d,svm2_mcc_d,svm2_kap_d,svm2_jacc_d,svm2_gmea_d)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_d = accuracy_score(y_pred, y_test)
svm3_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_d = precision_score(y_pred, y_test)
svm3_rec_d = recall_score(y_pred, y_test)
svm3_f1_d = f1_score(y_pred, y_test)
svm3_mcc_d = matthews_corrcoef(y_pred, y_test)
svm3_kap_d = cohen_kappa_score(y_pred, y_test)
svm3_jacc_d = jaccard_score(y_pred, y_test)
svm3_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - Linear ',svm3_acc_d,svm3_roc_d,svm3_prec_d,svm3_rec_d,svm3_f1_d,svm3_mcc_d,svm3_kap_d,svm3_jacc_d,svm3_gmea_d)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_d = accuracy_score(y_pred, y_test)
svm4_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_d = precision_score(y_pred, y_test)
svm4_rec_d = recall_score(y_pred, y_test)
svm4_f1_d = f1_score(y_pred, y_test)
svm4_mcc_d = matthews_corrcoef(y_pred, y_test)
svm4_kap_d = cohen_kappa_score(y_pred, y_test)
svm4_jacc_d = jaccard_score(y_pred, y_test)
svm4_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - Sigmoid',svm4_acc_d,svm4_roc_d,svm4_prec_d,svm4_rec_d,svm4_f1_d,svm4_mcc_d,svm4_kap_d,svm4_jacc_d,svm4_gmea_d)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_d = accuracy_score(y_pred, y_test)
rf_roc_d = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_d = precision_score(y_pred, y_test)
rf_rec_d = recall_score(y_pred, y_test)
rf_f1_d = f1_score(y_pred, y_test)
rf_mcc_d = matthews_corrcoef(y_pred, y_test)
rf_kap_d = cohen_kappa_score(y_pred, y_test)
rf_jacc_d = jaccard_score(y_pred, y_test)
rf_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - RF',rf_acc_d,rf_roc_d,rf_prec_d,rf_rec_d,rf_f1_d,rf_mcc_d,rf_kap_d,rf_jacc_d,rf_gmea_d)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_d = accuracy_score(y_pred, y_test)
dt_roc_d = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_d = precision_score(y_pred, y_test)
dt_rec_d = recall_score(y_pred, y_test)
dt_f1_d = f1_score(y_pred, y_test)
dt_mcc_d = matthews_corrcoef(y_pred, y_test)
dt_kap_d = cohen_kappa_score(y_pred, y_test)
dt_jacc_d = jaccard_score(y_pred, y_test)
dt_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - DT',dt_acc_d,dt_roc_d,dt_prec_d,dt_rec_d,dt_f1_d,dt_mcc_d,dt_kap_d,dt_jacc_d,dt_gmea_d)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_d = accuracy_score(y_pred, y_test)
nb_roc_d = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_d = precision_score(y_pred, y_test)
nb_rec_d = recall_score(y_pred, y_test)
nb_f1_d = f1_score(y_pred, y_test)
nb_mcc_d = matthews_corrcoef(y_pred, y_test)
nb_kap_d = cohen_kappa_score(y_pred, y_test)
nb_jacc_d = jaccard_score(y_pred, y_test)
nb_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - NB',nb_acc_d,nb_roc_d,nb_prec_d,nb_rec_d,nb_f1_d,nb_mcc_d,nb_kap_d,nb_jacc_d,nb_gmea_d)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_d = accuracy_score(y_pred, y_test)
vot_roc_d = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_d = precision_score(y_pred, y_test)
vot_rec_d = recall_score(y_pred, y_test)
vot_f1_d = f1_score(y_pred, y_test)
vot_mcc_d = matthews_corrcoef(y_pred, y_test)
vot_kap_d = cohen_kappa_score(y_pred, y_test)
vot_jacc_d = jaccard_score(y_pred, y_test)
vot_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - vot',vot_acc_d,vot_roc_d,vot_prec_d,vot_rec_d,vot_f1_d,vot_mcc_d,vot_kap_d,vot_jacc_d,vot_gmea_d)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_d = accuracy_score(y_pred, y_test)
vgg_roc_d = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_d = precision_score(y_pred, y_test)
vgg_rec_d = recall_score(y_pred, y_test)
vgg_f1_d = f1_score(y_pred, y_test)
vgg_mcc_d = matthews_corrcoef(y_pred, y_test)
vgg_kap_d = cohen_kappa_score(y_pred, y_test)
vgg_jacc_d = jaccard_score(y_pred, y_test)
vgg_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - VGGNets',vgg_acc_d,vgg_roc_d,vgg_prec_d,vgg_rec_d,vgg_f1_d,vgg_mcc_d,vgg_kap_d,vgg_jacc_d,vgg_gmea_d)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 199, 128)          384
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 99, 128)           0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 99, 128)           0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 12672)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 25346
# =================================================================
# Total params: 25,730
# Trainable params: 25,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 1s 190ms/step - loss: 0.6942 - accuracy: 0.6250 - val_loss: 0.5837 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7945 - accuracy: 0.7500 - val_loss: 0.5433 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5331 - accuracy: 1.0000 - val_loss: 0.5029 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7966 - accuracy: 0.7500 - val_loss: 0.4900 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4897 - accuracy: 0.8750 - val_loss: 0.4671 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4664 - accuracy: 0.8750 - val_loss: 0.4328 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3851 - accuracy: 0.8750 - val_loss: 0.3990 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3548 - accuracy: 1.0000 - val_loss: 0.3678 - val_accuracy: 0.9011
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3115 - accuracy: 1.0000 - val_loss: 0.3465 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4086 - accuracy: 0.8750 - val_loss: 0.3398 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4333 - accuracy: 0.8750 - val_loss: 0.3448 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6931 - accuracy: 0.8750 - val_loss: 0.3475 - val_accuracy: 0.9011
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0409 - accuracy: 1.0000 - val_loss: 0.3535 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 0.3637 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.1359 - accuracy: 0.7500 - val_loss: 0.3552 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0668 - accuracy: 1.0000 - val_loss: 0.3509 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8714 - accuracy: 0.7500 - val_loss: 0.3438 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3247 - accuracy: 0.8750 - val_loss: 0.3325 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0728 - accuracy: 1.0000 - val_loss: 0.3268 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8005 - accuracy: 0.8750 - val_loss: 0.3209 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_d = accuracy_score(y_pred, y_test)
res_roc_d = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_d = precision_score(y_pred, y_test)
res_rec_d = recall_score(y_pred, y_test)
res_f1_d = f1_score(y_pred, y_test)
res_mcc_d = matthews_corrcoef(y_pred, y_test)
res_kap_d = cohen_kappa_score(y_pred, y_test)
res_jacc_d = jaccard_score(y_pred, y_test)
res_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - ResNets',res_acc_d,res_roc_d,res_prec_d,res_rec_d,res_f1_d,res_mcc_d,res_kap_d,res_jacc_d,res_gmea_d)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 199, 128)          384
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 99, 128)           0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 99, 128)           0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 12672)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 25346
# =================================================================
# Total params: 25,730
# Trainable params: 25,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 142ms/step - loss: 0.6737 - accuracy: 0.3750 - val_loss: 0.5879 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7579 - accuracy: 0.8750 - val_loss: 0.5183 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5773 - accuracy: 0.8750 - val_loss: 0.4812 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4235 - accuracy: 1.0000 - val_loss: 0.4425 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3784 - accuracy: 1.0000 - val_loss: 0.4061 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6189 - accuracy: 0.7500 - val_loss: 0.3842 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4971 - accuracy: 0.7500 - val_loss: 0.3751 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.9545 - accuracy: 0.7500 - val_loss: 0.3725 - val_accuracy: 0.9011
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3946 - accuracy: 0.8750 - val_loss: 0.3707 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4162 - accuracy: 0.8750 - val_loss: 0.3673 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1816 - accuracy: 1.0000 - val_loss: 0.3643 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1196 - accuracy: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9011
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3213 - accuracy: 0.8750 - val_loss: 0.3668 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0776 - accuracy: 1.0000 - val_loss: 0.3737 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.9118 - accuracy: 0.7500 - val_loss: 0.3709 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5306 - accuracy: 0.8750 - val_loss: 0.3654 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0523 - accuracy: 1.0000 - val_loss: 0.3630 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.3629 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0585 - accuracy: 0.7500 - val_loss: 0.3574 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3632 - accuracy: 0.8750 - val_loss: 0.3493 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_d = accuracy_score(y_pred, y_test)
dense_roc_d = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_d = precision_score(y_pred, y_test)
dense_rec_d = recall_score(y_pred, y_test)
dense_f1_d = f1_score(y_pred, y_test)
dense_mcc_d = matthews_corrcoef(y_pred, y_test)
dense_kap_d = cohen_kappa_score(y_pred, y_test)
dense_jacc_d = jaccard_score(y_pred, y_test)
dense_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - DenseNets',dense_acc_d,dense_roc_d,dense_prec_d,dense_rec_d,dense_f1_d,dense_mcc_d,dense_kap_d,dense_jacc_d,dense_gmea_d)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_11 (Conv1D)           (None, 199, 128)          384
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 99, 128)           0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 99, 128)           0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 12672)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 25346
# =================================================================
# Total params: 25,730
# Trainable params: 25,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.6769 - accuracy: 0.5000 - val_loss: 0.5600 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7173 - accuracy: 0.6250 - val_loss: 0.5009 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4773 - accuracy: 0.8750 - val_loss: 0.4674 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6604 - accuracy: 0.7500 - val_loss: 0.4409 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4635 - accuracy: 0.8750 - val_loss: 0.4198 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3889 - accuracy: 1.0000 - val_loss: 0.3983 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6293 - accuracy: 0.8750 - val_loss: 0.3827 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2243 - accuracy: 1.0000 - val_loss: 0.3716 - val_accuracy: 0.9011
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5163 - accuracy: 0.8750 - val_loss: 0.3681 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.3710 - accuracy: 0.7500 - val_loss: 0.3615 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0856 - accuracy: 1.0000 - val_loss: 0.3562 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4790 - accuracy: 0.8750 - val_loss: 0.3513 - val_accuracy: 0.9011
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1435 - accuracy: 1.0000 - val_loss: 0.3476 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1518 - accuracy: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1281 - accuracy: 1.0000 - val_loss: 0.3484 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0867 - accuracy: 1.0000 - val_loss: 0.3558 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3144 - accuracy: 0.8750 - val_loss: 0.3652 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.2360 - accuracy: 0.6250 - val_loss: 0.3569 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6852 - accuracy: 0.8750 - val_loss: 0.3421 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 0.3342 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # CLN - EXP

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_EXP, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 410), (907,), (161, 410), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_e = accuracy_score(y_pred, y_test)
svm_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_e = precision_score(y_pred, y_test)
svm_rec_e = recall_score(y_pred, y_test)
svm_f1_e = f1_score(y_pred, y_test)
svm_mcc_e = matthews_corrcoef(y_pred, y_test)
svm_kap_e = cohen_kappa_score(y_pred, y_test)
svm_jacc_e = jaccard_score(y_pred, y_test)
svm_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - SVM - rbf',svm_acc_e,svm_roc_e,svm_prec_e,svm_rec_e,svm_f1_e,svm_mcc_e,svm_kap_e,svm_jacc_e,svm_gmea_e)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_e = accuracy_score(y_pred, y_test)
svm1_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_e = precision_score(y_pred, y_test)
svm1_rec_e = recall_score(y_pred, y_test)
svm1_f1_e = f1_score(y_pred, y_test)
svm1_mcc_e = matthews_corrcoef(y_pred, y_test)
svm1_kap_e = cohen_kappa_score(y_pred, y_test)
svm1_jacc_e = jaccard_score(y_pred, y_test)
svm1_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - SVM - Poly',svm1_acc_e,svm1_roc_e,svm1_prec_e,svm1_rec_e,svm1_f1_e,svm1_mcc_e,svm1_kap_e,svm1_jacc_e,svm1_gmea_e)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_e = accuracy_score(y_pred, y_test)
svm2_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_e = precision_score(y_pred, y_test)
svm2_rec_e = recall_score(y_pred, y_test)
svm2_f1_e = f1_score(y_pred, y_test)
svm2_mcc_e = matthews_corrcoef(y_pred, y_test)
svm2_kap_e = cohen_kappa_score(y_pred, y_test)
svm2_jacc_e = jaccard_score(y_pred, y_test)
svm2_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - SVM - Utility ',svm2_acc_e,svm2_roc_e,svm2_prec_e,svm2_rec_e,svm2_f1_e,svm2_mcc_e,svm2_kap_e,svm2_jacc_e,svm2_gmea_e)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_e = accuracy_score(y_pred, y_test)
svm3_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_e = precision_score(y_pred, y_test)
svm3_rec_e = recall_score(y_pred, y_test)
svm3_f1_e = f1_score(y_pred, y_test)
svm3_mcc_e = matthews_corrcoef(y_pred, y_test)
svm3_kap_e = cohen_kappa_score(y_pred, y_test)
svm3_jacc_e = jaccard_score(y_pred, y_test)
svm3_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - SVM - Linear ',svm3_acc_e,svm3_roc_e,svm3_prec_e,svm3_rec_e,svm3_f1_e,svm3_mcc_e,svm3_kap_e,svm3_jacc_e,svm3_gmea_e)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_e = accuracy_score(y_pred, y_test)
svm4_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_e = precision_score(y_pred, y_test)
svm4_rec_e = recall_score(y_pred, y_test)
svm4_f1_e = f1_score(y_pred, y_test)
svm4_mcc_e = matthews_corrcoef(y_pred, y_test)
svm4_kap_e = cohen_kappa_score(y_pred, y_test)
svm4_jacc_e = jaccard_score(y_pred, y_test)
svm4_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Sigmoid',svm4_acc_e,svm4_roc_e,svm4_prec_e,svm4_rec_e,svm4_f1_e,svm4_mcc_e,svm4_kap_e,svm4_jacc_e,svm4_gmea_e)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_e = accuracy_score(y_pred, y_test)
rf_roc_e = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_e = precision_score(y_pred, y_test)
rf_rec_e = recall_score(y_pred, y_test)
rf_f1_e = f1_score(y_pred, y_test)
rf_mcc_e = matthews_corrcoef(y_pred, y_test)
rf_kap_e = cohen_kappa_score(y_pred, y_test)
rf_jacc_e = jaccard_score(y_pred, y_test)
rf_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - RF',rf_acc_e,rf_roc_e,rf_prec_e,rf_rec_e,rf_f1_e,rf_mcc_e,rf_kap_e,rf_jacc_e,rf_gmea_e)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_e = accuracy_score(y_pred, y_test)
dt_roc_e = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_e = precision_score(y_pred, y_test)
dt_rec_e = recall_score(y_pred, y_test)
dt_f1_e = f1_score(y_pred, y_test)
dt_mcc_e = matthews_corrcoef(y_pred, y_test)
dt_kap_e = cohen_kappa_score(y_pred, y_test)
dt_jacc_e = jaccard_score(y_pred, y_test)
dt_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - DT',dt_acc_e,dt_roc_e,dt_prec_e,dt_rec_e,dt_f1_e,dt_mcc_e,dt_kap_e,dt_jacc_e,dt_gmea_e)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_e = accuracy_score(y_pred, y_test)
nb_roc_e = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_e = precision_score(y_pred, y_test)
nb_rec_e = recall_score(y_pred, y_test)
nb_f1_e = f1_score(y_pred, y_test)
nb_mcc_e = matthews_corrcoef(y_pred, y_test)
nb_kap_e = cohen_kappa_score(y_pred, y_test)
nb_jacc_e = jaccard_score(y_pred, y_test)
nb_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - NB',nb_acc_e,nb_roc_e,nb_prec_e,nb_rec_e,nb_f1_e,nb_mcc_e,nb_kap_e,nb_jacc_e,nb_gmea_e)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_e = accuracy_score(y_pred, y_test)
vot_roc_e = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_e = precision_score(y_pred, y_test)
vot_rec_e = recall_score(y_pred, y_test)
vot_f1_e = f1_score(y_pred, y_test)
vot_mcc_e = matthews_corrcoef(y_pred, y_test)
vot_kap_e = cohen_kappa_score(y_pred, y_test)
vot_jacc_e = jaccard_score(y_pred, y_test)
vot_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - vot',vot_acc_e,vot_roc_e,vot_prec_e,vot_rec_e,vot_f1_e,vot_mcc_e,vot_kap_e,vot_jacc_e,vot_gmea_e)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_e = accuracy_score(y_pred, y_test)
vgg_roc_e = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_e = precision_score(y_pred, y_test)
vgg_rec_e = recall_score(y_pred, y_test)
vgg_f1_e = f1_score(y_pred, y_test)
vgg_mcc_e = matthews_corrcoef(y_pred, y_test)
vgg_kap_e = cohen_kappa_score(y_pred, y_test)
vgg_jacc_e = jaccard_score(y_pred, y_test)
vgg_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - VGGNets',vgg_acc_e,vgg_roc_e,vgg_prec_e,vgg_rec_e,vgg_f1_e,vgg_mcc_e,vgg_kap_e,vgg_jacc_e,vgg_gmea_e)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_12 (Conv1D)           (None, 409, 128)          384
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 204, 128)          0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 204, 128)          0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 26112)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 52226
# =================================================================
# Total params: 52,610
# Trainable params: 52,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 151ms/step - loss: 0.6167 - accuracy: 0.6250 - val_loss: 0.4125 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5103 - accuracy: 0.8750 - val_loss: 0.3697 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3380 - accuracy: 0.8750 - val_loss: 0.3800 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1375 - accuracy: 1.0000 - val_loss: 0.4071 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 74ms/step - loss: 1.1259 - accuracy: 0.7500 - val_loss: 0.4078 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3767 - accuracy: 0.8750 - val_loss: 0.3960 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9267 - accuracy: 0.6250 - val_loss: 0.3810 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1476 - accuracy: 1.0000 - val_loss: 0.3754 - val_accuracy: 0.9011
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1411 - accuracy: 1.0000 - val_loss: 0.3745 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1852 - accuracy: 1.0000 - val_loss: 0.3754 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1643 - accuracy: 1.0000 - val_loss: 0.3795 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.9169 - accuracy: 0.7500 - val_loss: 0.3811 - val_accuracy: 0.9011
# Epoch 13/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0953 - accuracy: 1.0000 - val_loss: 0.3805 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2524 - accuracy: 0.8750 - val_loss: 0.3822 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.3866 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1041 - accuracy: 1.0000 - val_loss: 0.3942 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.4047 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4896 - accuracy: 0.8750 - val_loss: 0.4070 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3846 - accuracy: 0.8750 - val_loss: 0.4076 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5953 - accuracy: 0.8750 - val_loss: 0.4006 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_e = accuracy_score(y_pred, y_test)
res_roc_e = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_e = precision_score(y_pred, y_test)
res_rec_e = recall_score(y_pred, y_test)
res_f1_e = f1_score(y_pred, y_test)
res_mcc_e = matthews_corrcoef(y_pred, y_test)
res_kap_e = cohen_kappa_score(y_pred, y_test)
res_jacc_e = jaccard_score(y_pred, y_test)
res_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - ResNets',res_acc_e,res_roc_e,res_prec_e,res_rec_e,res_f1_e,res_mcc_e,res_kap_e,res_jacc_e,res_gmea_e)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_13 (Conv1D)           (None, 409, 128)          384
# _________________________________________________________________
# max_pooling1d_13 (MaxPooling (None, 204, 128)          0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 204, 128)          0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 26112)             0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 52226
# =================================================================
# Total params: 52,610
# Trainable params: 52,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 156ms/step - loss: 0.6158 - accuracy: 0.5000 - val_loss: 0.4051 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1762 - accuracy: 1.0000 - val_loss: 0.3887 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.3143 - accuracy: 0.8750 - val_loss: 0.4697 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6944 - accuracy: 0.8750 - val_loss: 0.5290 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.5601 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.1261 - accuracy: 0.7500 - val_loss: 0.5537 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3506 - accuracy: 0.8750 - val_loss: 0.5353 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0292 - accuracy: 0.8750 - val_loss: 0.4991 - val_accuracy: 0.9011
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3813 - accuracy: 0.8750 - val_loss: 0.4704 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0459 - accuracy: 1.0000 - val_loss: 0.4545 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0571 - accuracy: 1.0000 - val_loss: 0.4457 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9516 - accuracy: 0.7500 - val_loss: 0.4270 - val_accuracy: 0.9011
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2755 - accuracy: 0.8750 - val_loss: 0.4127 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1154 - accuracy: 1.0000 - val_loss: 0.4060 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1119 - accuracy: 1.0000 - val_loss: 0.4044 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3633 - accuracy: 0.8750 - val_loss: 0.4033 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1320 - accuracy: 1.0000 - val_loss: 0.4061 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6628 - accuracy: 0.8750 - val_loss: 0.4073 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.9457 - accuracy: 0.7500 - val_loss: 0.4006 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5245 - accuracy: 0.8750 - val_loss: 0.3925 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_e = accuracy_score(y_pred, y_test)
dense_roc_e = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_e = precision_score(y_pred, y_test)
dense_rec_e = recall_score(y_pred, y_test)
dense_f1_e = f1_score(y_pred, y_test)
dense_mcc_e = matthews_corrcoef(y_pred, y_test)
dense_kap_e = cohen_kappa_score(y_pred, y_test)
dense_jacc_e = jaccard_score(y_pred, y_test)
dense_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - DenseNets',dense_acc_e,dense_roc_e,dense_prec_e,dense_rec_e,dense_f1_e,dense_mcc_e,dense_kap_e,dense_jacc_e,dense_gmea_e)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_14 (Conv1D)           (None, 409, 128)          384
# _________________________________________________________________
# max_pooling1d_14 (MaxPooling (None, 204, 128)          0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 204, 128)          0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 26112)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 52226
# =================================================================
# Total params: 52,610
# Trainable params: 52,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 145ms/step - loss: 0.6024 - accuracy: 0.8750 - val_loss: 0.4076 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4753 - accuracy: 0.8750 - val_loss: 0.3758 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5421 - accuracy: 0.7500 - val_loss: 0.3964 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3602 - accuracy: 0.8750 - val_loss: 0.4166 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4128 - accuracy: 0.8750 - val_loss: 0.4304 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0651 - accuracy: 1.0000 - val_loss: 0.4428 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0660 - accuracy: 1.0000 - val_loss: 0.4586 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0624 - accuracy: 0.7500 - val_loss: 0.4531 - val_accuracy: 0.9011
# Epoch 9/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.5756 - accuracy: 0.8750 - val_loss: 0.4331 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.8845 - accuracy: 0.7500 - val_loss: 0.4114 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.3996 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1044 - accuracy: 1.0000 - val_loss: 0.3948 - val_accuracy: 0.9011
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4593 - accuracy: 0.8750 - val_loss: 0.3913 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7108 - accuracy: 0.7500 - val_loss: 0.3892 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1073 - accuracy: 1.0000 - val_loss: 0.3891 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1108 - accuracy: 1.0000 - val_loss: 0.3899 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1443 - accuracy: 1.0000 - val_loss: 0.3912 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7392 - accuracy: 0.7500 - val_loss: 0.3925 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2034 - accuracy: 1.0000 - val_loss: 0.3953 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3659 - accuracy: 0.8750 - val_loss: 0.3976 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # CLN-CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_CNV, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 210), (907,), (161, 210), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_f = accuracy_score(y_pred, y_test)
svm_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_f = precision_score(y_pred, y_test)
svm_rec_f = recall_score(y_pred, y_test)
svm_f1_f = f1_score(y_pred, y_test)
svm_mcc_f = matthews_corrcoef(y_pred, y_test)
svm_kap_f = cohen_kappa_score(y_pred, y_test)
svm_jacc_f = jaccard_score(y_pred, y_test)
svm_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - rbf',svm_acc_f,svm_roc_f,svm_prec_f,svm_rec_f,svm_f1_f,svm_mcc_f,svm_kap_f,svm_jacc_f,svm_gmea_f)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_f = accuracy_score(y_pred, y_test)
svm1_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_f = precision_score(y_pred, y_test)
svm1_rec_f = recall_score(y_pred, y_test)
svm1_f1_f = f1_score(y_pred, y_test)
svm1_mcc_f = matthews_corrcoef(y_pred, y_test)
svm1_kap_f = cohen_kappa_score(y_pred, y_test)
svm1_jacc_f = jaccard_score(y_pred, y_test)
svm1_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - Poly',svm1_acc_f,svm1_roc_f,svm1_prec_f,svm1_rec_f,svm1_f1_f,svm1_mcc_f,svm1_kap_f,svm1_jacc_f,svm1_gmea_f)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_f = accuracy_score(y_pred, y_test)
svm2_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_f = precision_score(y_pred, y_test)
svm2_rec_f = recall_score(y_pred, y_test)
svm2_f1_f = f1_score(y_pred, y_test)
svm2_mcc_f = matthews_corrcoef(y_pred, y_test)
svm2_kap_f = cohen_kappa_score(y_pred, y_test)
svm2_jacc_f = jaccard_score(y_pred, y_test)
svm2_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - Utility ',svm2_acc_f,svm2_roc_f,svm2_prec_f,svm2_rec_f,svm2_f1_f,svm2_mcc_f,svm2_kap_f,svm2_jacc_f,svm2_gmea_f)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_f = accuracy_score(y_pred, y_test)
svm3_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_f = precision_score(y_pred, y_test)
svm3_rec_f = recall_score(y_pred, y_test)
svm3_f1_f = f1_score(y_pred, y_test)
svm3_mcc_f = matthews_corrcoef(y_pred, y_test)
svm3_kap_f = cohen_kappa_score(y_pred, y_test)
svm3_jacc_f = jaccard_score(y_pred, y_test)
svm3_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - Linear ',svm3_acc_f,svm3_roc_f,svm3_prec_f,svm3_rec_f,svm3_f1_f,svm3_mcc_f,svm3_kap_f,svm3_jacc_f,svm3_gmea_f)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_f = accuracy_score(y_pred, y_test)
svm4_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_f = precision_score(y_pred, y_test)
svm4_rec_f = recall_score(y_pred, y_test)
svm4_f1_f = f1_score(y_pred, y_test)
svm4_mcc_f = matthews_corrcoef(y_pred, y_test)
svm4_kap_f = cohen_kappa_score(y_pred, y_test)
svm4_jacc_f = jaccard_score(y_pred, y_test)
svm4_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - Sigmoid',svm4_acc_f,svm4_roc_f,svm4_prec_f,svm4_rec_f,svm4_f1_f,svm4_mcc_f,svm4_kap_f,svm4_jacc_f,svm4_gmea_f)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_f = accuracy_score(y_pred, y_test)
rf_roc_f = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_f = precision_score(y_pred, y_test)
rf_rec_f = recall_score(y_pred, y_test)
rf_f1_f = f1_score(y_pred, y_test)
rf_mcc_f = matthews_corrcoef(y_pred, y_test)
rf_kap_f = cohen_kappa_score(y_pred, y_test)
rf_jacc_f = jaccard_score(y_pred, y_test)
rf_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - RF',rf_acc_f,rf_roc_f,rf_prec_f,rf_rec_f,rf_f1_f,rf_mcc_f,rf_kap_f,rf_jacc_f,rf_gmea_f)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_f = accuracy_score(y_pred, y_test)
dt_roc_f = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_f = precision_score(y_pred, y_test)
dt_rec_f = recall_score(y_pred, y_test)
dt_f1_f = f1_score(y_pred, y_test)
dt_mcc_f = matthews_corrcoef(y_pred, y_test)
dt_kap_f = cohen_kappa_score(y_pred, y_test)
dt_jacc_f = jaccard_score(y_pred, y_test)
dt_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - DT',dt_acc_f,dt_roc_f,dt_prec_f,dt_rec_f,dt_f1_f,dt_mcc_f,dt_kap_f,dt_jacc_f,dt_gmea_f)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_f = accuracy_score(y_pred, y_test)
nb_roc_f = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_f = precision_score(y_pred, y_test)
nb_rec_f = recall_score(y_pred, y_test)
nb_f1_f = f1_score(y_pred, y_test)
nb_mcc_f = matthews_corrcoef(y_pred, y_test)
nb_kap_f = cohen_kappa_score(y_pred, y_test)
nb_jacc_f = jaccard_score(y_pred, y_test)
nb_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - NB',nb_acc_f,nb_roc_f,nb_prec_f,nb_rec_f,nb_f1_f,nb_mcc_f,nb_kap_f,nb_jacc_f,nb_gmea_f)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_f = accuracy_score(y_pred, y_test)
vot_roc_f = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_f = precision_score(y_pred, y_test)
vot_rec_f = recall_score(y_pred, y_test)
vot_f1_f = f1_score(y_pred, y_test)
vot_mcc_f = matthews_corrcoef(y_pred, y_test)
vot_kap_f = cohen_kappa_score(y_pred, y_test)
vot_jacc_f = jaccard_score(y_pred, y_test)
vot_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - vot',vot_acc_f,vot_roc_f,vot_prec_f,vot_rec_f,vot_f1_f,vot_mcc_f,vot_kap_f,vot_jacc_f,vot_gmea_f)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_f = accuracy_score(y_pred, y_test)
vgg_roc_f = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_f = precision_score(y_pred, y_test)
vgg_rec_f = recall_score(y_pred, y_test)
vgg_f1_f = f1_score(y_pred, y_test)
vgg_mcc_f = matthews_corrcoef(y_pred, y_test)
vgg_kap_f = cohen_kappa_score(y_pred, y_test)
vgg_jacc_f = jaccard_score(y_pred, y_test)
vgg_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - VGGNets',vgg_acc_f,vgg_roc_f,vgg_prec_f,vgg_rec_f,vgg_f1_f,vgg_mcc_f,vgg_kap_f,vgg_jacc_f,vgg_gmea_f)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_15 (Conv1D)           (None, 209, 128)          384
# _________________________________________________________________
# max_pooling1d_15 (MaxPooling (None, 104, 128)          0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 104, 128)          0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 13312)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 26626
# =================================================================
# Total params: 27,010
# Trainable params: 27,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 1s 170ms/step - loss: 0.6889 - accuracy: 0.3750 - val_loss: 0.5716 - val_accuracy: 0.9066
# Epoch 2/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5173 - accuracy: 1.0000 - val_loss: 0.4852 - val_accuracy: 0.9066
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5576 - accuracy: 0.8750 - val_loss: 0.4376 - val_accuracy: 0.9066
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5339 - accuracy: 0.8750 - val_loss: 0.4031 - val_accuracy: 0.9066
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1917 - accuracy: 1.0000 - val_loss: 0.3715 - val_accuracy: 0.9066
# Epoch 6/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2291 - accuracy: 1.0000 - val_loss: 0.3485 - val_accuracy: 0.9066
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4742 - accuracy: 0.8750 - val_loss: 0.3405 - val_accuracy: 0.9066
# Epoch 8/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7085 - accuracy: 0.7500 - val_loss: 0.3398 - val_accuracy: 0.9066
# Epoch 9/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1480 - accuracy: 1.0000 - val_loss: 0.3401 - val_accuracy: 0.9066
# Epoch 10/20
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6203 - accuracy: 0.7500 - val_loss: 0.3403 - val_accuracy: 0.9066
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6255 - accuracy: 0.8750 - val_loss: 0.3394 - val_accuracy: 0.9066
# Epoch 12/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5311 - accuracy: 0.8750 - val_loss: 0.3374 - val_accuracy: 0.9066
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2766 - accuracy: 0.8750 - val_loss: 0.3365 - val_accuracy: 0.9066
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1787 - accuracy: 1.0000 - val_loss: 0.3355 - val_accuracy: 0.9066
# Epoch 15/20
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1571 - accuracy: 1.0000 - val_loss: 0.3347 - val_accuracy: 0.9066
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1008 - accuracy: 1.0000 - val_loss: 0.3360 - val_accuracy: 0.9066
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0843 - accuracy: 1.0000 - val_loss: 0.3407 - val_accuracy: 0.9066
# Epoch 18/20
# 2/2 [==============================] - 0s 60ms/step - loss: 0.3251 - accuracy: 0.8750 - val_loss: 0.3472 - val_accuracy: 0.9066
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3448 - accuracy: 0.8750 - val_loss: 0.3505 - val_accuracy: 0.9066
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0467 - accuracy: 1.0000 - val_loss: 0.3561 - val_accuracy: 0.9066
# 6/6 [==============================] - 0s 6ms/step
# 6/6 [==============================] - 0s 0s/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_f = accuracy_score(y_pred, y_test)
res_roc_f = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_f = precision_score(y_pred, y_test)
res_rec_f = recall_score(y_pred, y_test)
res_f1_f = f1_score(y_pred, y_test)
res_mcc_f = matthews_corrcoef(y_pred, y_test)
res_kap_f = cohen_kappa_score(y_pred, y_test)
res_jacc_f = jaccard_score(y_pred, y_test)
res_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - ResNets',res_acc_f,res_roc_f,res_prec_f,res_rec_f,res_f1_f,res_mcc_f,res_kap_f,res_jacc_f,res_gmea_f)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_16 (Conv1D)           (None, 209, 128)          384
# _________________________________________________________________
# max_pooling1d_16 (MaxPooling (None, 104, 128)          0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 104, 128)          0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 13312)             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 26626
# =================================================================
# Total params: 27,010
# Trainable params: 27,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.6360 - accuracy: 0.7500 - val_loss: 0.5214 - val_accuracy: 0.9066
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5002 - accuracy: 0.8750 - val_loss: 0.4343 - val_accuracy: 0.9066
# Epoch 3/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.2824 - accuracy: 1.0000 - val_loss: 0.3820 - val_accuracy: 0.9066
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5184 - accuracy: 0.8750 - val_loss: 0.3579 - val_accuracy: 0.9066
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5344 - accuracy: 0.8750 - val_loss: 0.3538 - val_accuracy: 0.9066
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0749 - accuracy: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.9066
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0936 - accuracy: 1.0000 - val_loss: 0.3762 - val_accuracy: 0.9066
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.4016 - val_accuracy: 0.9066
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.9066
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.4700 - val_accuracy: 0.9066
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.5932 - accuracy: 0.7500 - val_loss: 0.4648 - val_accuracy: 0.9066
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.4554 - val_accuracy: 0.9066
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.4509 - val_accuracy: 0.9066
# Epoch 14/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7741 - accuracy: 0.7500 - val_loss: 0.4296 - val_accuracy: 0.9066
# Epoch 15/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7674 - accuracy: 0.8750 - val_loss: 0.4100 - val_accuracy: 0.9066
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.3820 - accuracy: 0.8750 - val_loss: 0.3854 - val_accuracy: 0.9066
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5051 - accuracy: 0.8750 - val_loss: 0.3616 - val_accuracy: 0.9066
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0710 - accuracy: 1.0000 - val_loss: 0.3469 - val_accuracy: 0.9066
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4255 - accuracy: 0.8750 - val_loss: 0.3380 - val_accuracy: 0.9066
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5349 - accuracy: 0.7500 - val_loss: 0.3345 - val_accuracy: 0.9066
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_f = accuracy_score(y_pred, y_test)
dense_roc_f = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_f = precision_score(y_pred, y_test)
dense_rec_f = recall_score(y_pred, y_test)
dense_f1_f = f1_score(y_pred, y_test)
dense_mcc_f = matthews_corrcoef(y_pred, y_test)
dense_kap_f = cohen_kappa_score(y_pred, y_test)
dense_jacc_f = jaccard_score(y_pred, y_test)
dense_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - DenseNets',dense_acc_f,dense_roc_f,dense_prec_f,dense_rec_f,dense_f1_f,dense_mcc_f,dense_kap_f,dense_jacc_f,dense_gmea_f)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_17 (Conv1D)           (None, 209, 128)          384
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 104, 128)          0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 104, 128)          0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 13312)             0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 26626
# =================================================================
# Total params: 27,010
# Trainable params: 27,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 154ms/step - loss: 0.6414 - accuracy: 1.0000 - val_loss: 0.5298 - val_accuracy: 0.9066
# Epoch 2/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6998 - accuracy: 0.8750 - val_loss: 0.4475 - val_accuracy: 0.9066
# Epoch 3/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7105 - accuracy: 0.8750 - val_loss: 0.4061 - val_accuracy: 0.9066
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3845 - accuracy: 1.0000 - val_loss: 0.3759 - val_accuracy: 0.9066
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1992 - accuracy: 1.0000 - val_loss: 0.3493 - val_accuracy: 0.9066
# Epoch 6/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1508 - accuracy: 1.0000 - val_loss: 0.3332 - val_accuracy: 0.9066
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1796 - accuracy: 1.0000 - val_loss: 0.3300 - val_accuracy: 0.9066
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1180 - accuracy: 1.0000 - val_loss: 0.3411 - val_accuracy: 0.9066
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0626 - accuracy: 1.0000 - val_loss: 0.3645 - val_accuracy: 0.9066
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.9479 - accuracy: 0.7500 - val_loss: 0.3810 - val_accuracy: 0.9066
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.5630 - accuracy: 0.7500 - val_loss: 0.3636 - val_accuracy: 0.9066
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 0.3495 - val_accuracy: 0.9066
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0771 - accuracy: 1.0000 - val_loss: 0.3418 - val_accuracy: 0.9066
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8979 - accuracy: 0.7500 - val_loss: 0.3298 - val_accuracy: 0.9066
# Epoch 15/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3972 - accuracy: 0.8750 - val_loss: 0.3185 - val_accuracy: 0.9066
# Epoch 16/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0868 - accuracy: 1.0000 - val_loss: 0.3132 - val_accuracy: 0.9066
# Epoch 17/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4367 - accuracy: 0.8750 - val_loss: 0.3095 - val_accuracy: 0.9066
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0889 - accuracy: 1.0000 - val_loss: 0.3072 - val_accuracy: 0.9066
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5016 - accuracy: 0.8750 - val_loss: 0.3062 - val_accuracy: 0.9066
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1169 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 0.9066
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # CLN-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 810), (907,), (161, 810), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_g = accuracy_score(y_pred, y_test)
svm_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_g = precision_score(y_pred, y_test)
svm_rec_g = recall_score(y_pred, y_test)
svm_f1_g = f1_score(y_pred, y_test)
svm_mcc_g = matthews_corrcoef(y_pred, y_test)
svm_kap_g = cohen_kappa_score(y_pred, y_test)
svm_jacc_g = jaccard_score(y_pred, y_test)
svm_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - rbf',svm_acc_g,svm_roc_g,svm_prec_g,svm_rec_g,svm_f1_g,svm_mcc_g,svm_kap_g,svm_jacc_g,svm_gmea_g)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_g = accuracy_score(y_pred, y_test)
svm1_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_g = precision_score(y_pred, y_test)
svm1_rec_g = recall_score(y_pred, y_test)
svm1_f1_g = f1_score(y_pred, y_test)
svm1_mcc_g = matthews_corrcoef(y_pred, y_test)
svm1_kap_g = cohen_kappa_score(y_pred, y_test)
svm1_jacc_g = jaccard_score(y_pred, y_test)
svm1_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - Poly',svm1_acc_g,svm1_roc_g,svm1_prec_g,svm1_rec_g,svm1_f1_g,svm1_mcc_g,svm1_kap_g,svm1_jacc_g,svm1_gmea_g)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_g = accuracy_score(y_pred, y_test)
svm2_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_g = precision_score(y_pred, y_test)
svm2_rec_g = recall_score(y_pred, y_test)
svm2_f1_g = f1_score(y_pred, y_test)
svm2_mcc_g = matthews_corrcoef(y_pred, y_test)
svm2_kap_g = cohen_kappa_score(y_pred, y_test)
svm2_jacc_g = jaccard_score(y_pred, y_test)
svm2_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - Utility ',svm2_acc_g,svm2_roc_g,svm2_prec_g,svm2_rec_g,svm2_f1_g,svm2_mcc_g,svm2_kap_g,svm2_jacc_g,svm2_gmea_g)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_g = accuracy_score(y_pred, y_test)
svm3_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_g = precision_score(y_pred, y_test)
svm3_rec_g = recall_score(y_pred, y_test)
svm3_f1_g = f1_score(y_pred, y_test)
svm3_mcc_g = matthews_corrcoef(y_pred, y_test)
svm3_kap_g = cohen_kappa_score(y_pred, y_test)
svm3_jacc_g = jaccard_score(y_pred, y_test)
svm3_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - Linear ',svm3_acc_g,svm3_roc_g,svm3_prec_g,svm3_rec_g,svm3_f1_g,svm3_mcc_g,svm3_kap_g,svm3_jacc_g,svm3_gmea_g)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_g = accuracy_score(y_pred, y_test)
svm4_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_g = precision_score(y_pred, y_test)
svm4_rec_g = recall_score(y_pred, y_test)
svm4_f1_g = f1_score(y_pred, y_test)
svm4_mcc_g = matthews_corrcoef(y_pred, y_test)
svm4_kap_g = cohen_kappa_score(y_pred, y_test)
svm4_jacc_g = jaccard_score(y_pred, y_test)
svm4_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - Sigmoid',svm4_acc_g,svm4_roc_g,svm4_prec_g,svm4_rec_g,svm4_f1_g,svm4_mcc_g,svm4_kap_g,svm4_jacc_g,svm4_gmea_g)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_g = accuracy_score(y_pred, y_test)
rf_roc_g = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_g = precision_score(y_pred, y_test)
rf_rec_g = recall_score(y_pred, y_test)
rf_f1_g = f1_score(y_pred, y_test)
rf_mcc_g = matthews_corrcoef(y_pred, y_test)
rf_kap_g = cohen_kappa_score(y_pred, y_test)
rf_jacc_g = jaccard_score(y_pred, y_test)
rf_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - RF',rf_acc_g,rf_roc_g,rf_prec_g,rf_rec_g,rf_f1_g,rf_mcc_g,rf_kap_g,rf_jacc_g,rf_gmea_g)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_g = accuracy_score(y_pred, y_test)
dt_roc_g = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_g = precision_score(y_pred, y_test)
dt_rec_g = recall_score(y_pred, y_test)
dt_f1_g = f1_score(y_pred, y_test)
dt_mcc_g = matthews_corrcoef(y_pred, y_test)
dt_kap_g = cohen_kappa_score(y_pred, y_test)
dt_jacc_g = jaccard_score(y_pred, y_test)
dt_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - DT',dt_acc_g,dt_roc_g,dt_prec_g,dt_rec_g,dt_f1_g,dt_mcc_g,dt_kap_g,dt_jacc_g,dt_gmea_g)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_g = accuracy_score(y_pred, y_test)
nb_roc_g = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_g = precision_score(y_pred, y_test)
nb_rec_g = recall_score(y_pred, y_test)
nb_f1_g = f1_score(y_pred, y_test)
nb_mcc_g = matthews_corrcoef(y_pred, y_test)
nb_kap_g = cohen_kappa_score(y_pred, y_test)
nb_jacc_g = jaccard_score(y_pred, y_test)
nb_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - NB',nb_acc_g,nb_roc_g,nb_prec_g,nb_rec_g,nb_f1_g,nb_mcc_g,nb_kap_g,nb_jacc_g,nb_gmea_g)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_g = accuracy_score(y_pred, y_test)
vot_roc_g = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_g = precision_score(y_pred, y_test)
vot_rec_g = recall_score(y_pred, y_test)
vot_f1_g = f1_score(y_pred, y_test)
vot_mcc_g = matthews_corrcoef(y_pred, y_test)
vot_kap_g = cohen_kappa_score(y_pred, y_test)
vot_jacc_g = jaccard_score(y_pred, y_test)
vot_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - vot',vot_acc_g,vot_roc_g,vot_prec_g,vot_rec_g,vot_f1_g,vot_mcc_g,vot_kap_g,vot_jacc_g,vot_gmea_g)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_g = accuracy_score(y_pred, y_test)
vgg_roc_g = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_g = precision_score(y_pred, y_test)
vgg_rec_g = recall_score(y_pred, y_test)
vgg_f1_g = f1_score(y_pred, y_test)
vgg_mcc_g = matthews_corrcoef(y_pred, y_test)
vgg_kap_g = cohen_kappa_score(y_pred, y_test)
vgg_jacc_g = jaccard_score(y_pred, y_test)
vgg_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - VGGNets',vgg_acc_g,vgg_roc_g,vgg_prec_g,vgg_rec_g,vgg_f1_g,vgg_mcc_g,vgg_kap_g,vgg_jacc_g,vgg_gmea_g)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_18 (Conv1D)           (None, 809, 128)          384
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, 404, 128)          0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 404, 128)          0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 51712)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 2)                 103426
# =================================================================
# Total params: 103,810
# Trainable params: 103,810
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 5.3195 - accuracy: 0.3750 - val_loss: 2.8974 - val_accuracy: 0.8901
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.3099 - val_accuracy: 0.8901
# Epoch 3/20
# 2/2 [==============================] - 0s 74ms/step - loss: 5.5828 - accuracy: 0.8750 - val_loss: 11.6345 - val_accuracy: 0.8901
# Epoch 4/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 13.7064 - val_accuracy: 0.8901
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 12.7203 - accuracy: 0.8750 - val_loss: 13.9426 - val_accuracy: 0.8901
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 6.6297 - accuracy: 0.8750 - val_loss: 13.7414 - val_accuracy: 0.8901
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 13.2342 - val_accuracy: 0.8901
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 22.6523 - accuracy: 0.7500 - val_loss: 11.2849 - val_accuracy: 0.8901
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.2879 - val_accuracy: 0.8901
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 6.3909 - accuracy: 0.8750 - val_loss: 7.3300 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 9.6044 - accuracy: 0.7500 - val_loss: 5.1915 - val_accuracy: 0.8132
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.1933 - accuracy: 0.8750 - val_loss: 4.5254 - val_accuracy: 0.7418
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 3.7654 - accuracy: 0.7500 - val_loss: 8.8169 - val_accuracy: 0.4451
# Epoch 14/20
# 2/2 [==============================] - 0s 78ms/step - loss: 14.1527 - accuracy: 0.5000 - val_loss: 13.2608 - val_accuracy: 0.3407
# Epoch 15/20
# 2/2 [==============================] - 0s 72ms/step - loss: 6.1764 - accuracy: 0.6250 - val_loss: 6.0702 - val_accuracy: 0.4615
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6758 - accuracy: 0.8750 - val_loss: 3.6899 - val_accuracy: 0.8901
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.3993 - accuracy: 0.8750 - val_loss: 5.2062 - val_accuracy: 0.8901
# Epoch 18/20
# 2/2 [==============================] - 0s 81ms/step - loss: 2.6677 - accuracy: 0.8750 - val_loss: 5.8692 - val_accuracy: 0.8901
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.4080 - val_accuracy: 0.8901
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.8471 - val_accuracy: 0.8901
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 0s/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_g = accuracy_score(y_pred, y_test)
res_roc_g = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_g = precision_score(y_pred, y_test)
res_rec_g = recall_score(y_pred, y_test)
res_f1_g = f1_score(y_pred, y_test)
res_mcc_g = matthews_corrcoef(y_pred, y_test)
res_kap_g = cohen_kappa_score(y_pred, y_test)
res_jacc_g = jaccard_score(y_pred, y_test)
res_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - ResNets',res_acc_g,res_roc_g,res_prec_g,res_rec_g,res_f1_g,res_mcc_g,res_kap_g,res_jacc_g,res_gmea_g)
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_19 (Conv1D)           (None, 809, 128)          384
# _________________________________________________________________
# max_pooling1d_19 (MaxPooling (None, 404, 128)          0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 404, 128)          0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 51712)             0
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 103426
# =================================================================
# Total params: 103,810
# Trainable params: 103,810
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 146ms/step - loss: 0.6711 - accuracy: 0.6250 - val_loss: 11.2978 - val_accuracy: 0.8901
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 17.8315 - val_accuracy: 0.8901
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 22.4568 - val_accuracy: 0.8901
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 28.7562 - accuracy: 0.8750 - val_loss: 24.3885 - val_accuracy: 0.8901
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 24.4894 - val_accuracy: 0.8901
# Epoch 6/20
# 2/2 [==============================] - 0s 74ms/step - loss: 31.4728 - accuracy: 0.8750 - val_loss: 22.3599 - val_accuracy: 0.8901
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 29.8790 - accuracy: 0.8750 - val_loss: 18.9377 - val_accuracy: 0.8901
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 16.2095 - val_accuracy: 0.8901
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 14.0140 - val_accuracy: 0.8901
# Epoch 10/20
# 2/2 [==============================] - 0s 82ms/step - loss: 9.6406 - accuracy: 0.8750 - val_loss: 11.3617 - val_accuracy: 0.8901
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.2095 - val_accuracy: 0.8901
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 12.0246 - accuracy: 0.8750 - val_loss: 6.5984 - val_accuracy: 0.8901
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.9352 - accuracy: 0.8750 - val_loss: 3.4111 - val_accuracy: 0.8901
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 0.9369 - val_accuracy: 0.7912
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.2997 - accuracy: 0.7500 - val_loss: 3.3764 - val_accuracy: 0.3242
# Epoch 16/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4119 - accuracy: 0.8750 - val_loss: 1.5984 - val_accuracy: 0.8901
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.1972 - accuracy: 0.8750 - val_loss: 1.8203 - val_accuracy: 0.8791
# Epoch 18/20
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 2.0998 - val_accuracy: 0.8791
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3874 - accuracy: 0.8750 - val_loss: 1.8328 - val_accuracy: 0.8407
# Epoch 20/20
# 2/2 [==============================] - 0s 74ms/step - loss: 2.9195 - accuracy: 0.6250 - val_loss: 3.8696 - val_accuracy: 0.4341
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_g = accuracy_score(y_pred, y_test)
dense_roc_g = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_g = precision_score(y_pred, y_test)
dense_rec_g = recall_score(y_pred, y_test)
dense_f1_g = f1_score(y_pred, y_test)
dense_mcc_g = matthews_corrcoef(y_pred, y_test)
dense_kap_g = cohen_kappa_score(y_pred, y_test)
dense_jacc_g = jaccard_score(y_pred, y_test)
dense_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - DenseNets',dense_acc_g,dense_roc_g,dense_prec_g,dense_rec_g,dense_f1_g,dense_mcc_g,dense_kap_g,dense_jacc_g,dense_gmea_g)
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_20 (Conv1D)           (None, 809, 128)          384
# _________________________________________________________________
# max_pooling1d_20 (MaxPooling (None, 404, 128)          0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 404, 128)          0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 51712)             0
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 103426
# =================================================================
# Total params: 103,810
# Trainable params: 103,810
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 7.8498 - accuracy: 0.3750 - val_loss: 6.6694 - val_accuracy: 0.8901
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 21.1461 - accuracy: 0.7500 - val_loss: 6.0878 - val_accuracy: 0.8901
# Epoch 3/20
# 2/2 [==============================] - 0s 64ms/step - loss: 6.7799e-06 - accuracy: 1.0000 - val_loss: 3.7452 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.6547 - val_accuracy: 0.7857
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.9522 - accuracy: 0.6250 - val_loss: 6.6482 - val_accuracy: 0.3516
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 11.5433 - accuracy: 0.2500 - val_loss: 3.0815 - val_accuracy: 0.6429
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.2916 - accuracy: 0.7500 - val_loss: 3.2834 - val_accuracy: 0.8901
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 5.0759 - accuracy: 0.8750 - val_loss: 4.6502 - val_accuracy: 0.8901
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 6.8852 - accuracy: 0.8750 - val_loss: 4.1258 - val_accuracy: 0.8901
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 5.5528 - accuracy: 0.8750 - val_loss: 3.1789 - val_accuracy: 0.8901
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9385 - val_accuracy: 0.8901
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.7536e-04 - accuracy: 1.0000 - val_loss: 1.1695 - val_accuracy: 0.8516
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.1099 - accuracy: 0.7500 - val_loss: 1.1880 - val_accuracy: 0.8187
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0122 - accuracy: 0.7500 - val_loss: 1.4457 - val_accuracy: 0.7308
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.9468 - accuracy: 0.6250 - val_loss: 1.4620 - val_accuracy: 0.7253
# Epoch 16/20
# 2/2 [==============================] - 0s 73ms/step - loss: 1.2687 - accuracy: 0.6250 - val_loss: 2.6430 - val_accuracy: 0.8901
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 8.7097 - accuracy: 0.7500 - val_loss: 3.2258 - val_accuracy: 0.8901
# Epoch 18/20
# 2/2 [==============================] - 0s 83ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 3.5123 - val_accuracy: 0.8901
# Epoch 19/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.7471 - val_accuracy: 0.8901
# Epoch 20/20
# 2/2 [==============================] - 0s 210ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.9400 - val_accuracy: 0.8901
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # EXP-CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(EXP_CNV, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 600), (907,), (161, 600), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_h = accuracy_score(y_pred, y_test)
svm_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_h = precision_score(y_pred, y_test)
svm_rec_h = recall_score(y_pred, y_test)
svm_f1_h = f1_score(y_pred, y_test)
svm_mcc_h = matthews_corrcoef(y_pred, y_test)
svm_kap_h = cohen_kappa_score(y_pred, y_test)
svm_jacc_h = jaccard_score(y_pred, y_test)
svm_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - rbf',svm_acc_h,svm_roc_h,svm_prec_h,svm_rec_h,svm_f1_h,svm_mcc_h,svm_kap_h,svm_jacc_h,svm_gmea_h)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_h = accuracy_score(y_pred, y_test)
svm1_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_h = precision_score(y_pred, y_test)
svm1_rec_h = recall_score(y_pred, y_test)
svm1_f1_h = f1_score(y_pred, y_test)
svm1_mcc_h = matthews_corrcoef(y_pred, y_test)
svm1_kap_h = cohen_kappa_score(y_pred, y_test)
svm1_jacc_h = jaccard_score(y_pred, y_test)
svm1_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - Poly',svm1_acc_h,svm1_roc_h,svm1_prec_h,svm1_rec_h,svm1_f1_h,svm1_mcc_h,svm1_kap_h,svm1_jacc_h,svm1_gmea_h)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_h = accuracy_score(y_pred, y_test)
svm2_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_h = precision_score(y_pred, y_test)
svm2_rec_h = recall_score(y_pred, y_test)
svm2_f1_h = f1_score(y_pred, y_test)
svm2_mcc_h = matthews_corrcoef(y_pred, y_test)
svm2_kap_h = cohen_kappa_score(y_pred, y_test)
svm2_jacc_h = jaccard_score(y_pred, y_test)
svm2_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - Utility ',svm2_acc_h,svm2_roc_h,svm2_prec_h,svm2_rec_h,svm2_f1_h,svm2_mcc_h,svm2_kap_h,svm2_jacc_h,svm2_gmea_h)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_h = accuracy_score(y_pred, y_test)
svm3_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_h = precision_score(y_pred, y_test)
svm3_rec_h = recall_score(y_pred, y_test)
svm3_f1_h = f1_score(y_pred, y_test)
svm3_mcc_h = matthews_corrcoef(y_pred, y_test)
svm3_kap_h = cohen_kappa_score(y_pred, y_test)
svm3_jacc_h = jaccard_score(y_pred, y_test)
svm3_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - Linear ',svm3_acc_h,svm3_roc_h,svm3_prec_h,svm3_rec_h,svm3_f1_h,svm3_mcc_h,svm3_kap_h,svm3_jacc_h,svm3_gmea_h)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_h = accuracy_score(y_pred, y_test)
svm4_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_h = precision_score(y_pred, y_test)
svm4_rec_h = recall_score(y_pred, y_test)
svm4_f1_h = f1_score(y_pred, y_test)
svm4_mcc_h = matthews_corrcoef(y_pred, y_test)
svm4_kap_h = cohen_kappa_score(y_pred, y_test)
svm4_jacc_h = jaccard_score(y_pred, y_test)
svm4_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - Sigmoid',svm4_acc_h,svm4_roc_h,svm4_prec_h,svm4_rec_h,svm4_f1_h,svm4_mcc_h,svm4_kap_h,svm4_jacc_h,svm4_gmea_h)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_h = accuracy_score(y_pred, y_test)
rf_roc_h = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_h = precision_score(y_pred, y_test)
rf_rec_h = recall_score(y_pred, y_test)
rf_f1_h = f1_score(y_pred, y_test)
rf_mcc_h = matthews_corrcoef(y_pred, y_test)
rf_kap_h = cohen_kappa_score(y_pred, y_test)
rf_jacc_h = jaccard_score(y_pred, y_test)
rf_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - RF',rf_acc_h,rf_roc_h,rf_prec_h,rf_rec_h,rf_f1_h,rf_mcc_h,rf_kap_h,rf_jacc_h,rf_gmea_h)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_h = accuracy_score(y_pred, y_test)
dt_roc_h = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_h = precision_score(y_pred, y_test)
dt_rec_h = recall_score(y_pred, y_test)
dt_f1_h = f1_score(y_pred, y_test)
dt_mcc_h = matthews_corrcoef(y_pred, y_test)
dt_kap_h = cohen_kappa_score(y_pred, y_test)
dt_jacc_h = jaccard_score(y_pred, y_test)
dt_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - DT',dt_acc_h,dt_roc_h,dt_prec_h,dt_rec_h,dt_f1_h,dt_mcc_h,dt_kap_h,dt_jacc_h,dt_gmea_h)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_h = accuracy_score(y_pred, y_test)
nb_roc_h = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_h = precision_score(y_pred, y_test)
nb_rec_h = recall_score(y_pred, y_test)
nb_f1_h = f1_score(y_pred, y_test)
nb_mcc_h = matthews_corrcoef(y_pred, y_test)
nb_kap_h = cohen_kappa_score(y_pred, y_test)
nb_jacc_h = jaccard_score(y_pred, y_test)
nb_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - NB',nb_acc_h,nb_roc_h,nb_prec_h,nb_rec_h,nb_f1_h,nb_mcc_h,nb_kap_h,nb_jacc_h,nb_gmea_h)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_h = accuracy_score(y_pred, y_test)
vot_roc_h = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_h = precision_score(y_pred, y_test)
vot_rec_h = recall_score(y_pred, y_test)
vot_f1_h = f1_score(y_pred, y_test)
vot_mcc_h = matthews_corrcoef(y_pred, y_test)
vot_kap_h = cohen_kappa_score(y_pred, y_test)
vot_jacc_h = jaccard_score(y_pred, y_test)
vot_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - vot',vot_acc_h,vot_roc_h,vot_prec_h,vot_rec_h,vot_f1_h,vot_mcc_h,vot_kap_h,vot_jacc_h,vot_gmea_h)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_h = accuracy_score(y_pred, y_test)
vgg_roc_h = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_h = precision_score(y_pred, y_test)
vgg_rec_h = recall_score(y_pred, y_test)
vgg_f1_h = f1_score(y_pred, y_test)
vgg_mcc_h = matthews_corrcoef(y_pred, y_test)
vgg_kap_h = cohen_kappa_score(y_pred, y_test)
vgg_jacc_h = jaccard_score(y_pred, y_test)
vgg_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - VGGNets',vgg_acc_h,vgg_roc_h,vgg_prec_h,vgg_rec_h,vgg_f1_h,vgg_mcc_h,vgg_kap_h,vgg_jacc_h,vgg_gmea_h)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_21 (Conv1D)           (None, 599, 128)          384
# _________________________________________________________________
# max_pooling1d_21 (MaxPooling (None, 299, 128)          0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 299, 128)          0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 38272)             0
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 76546
# =================================================================
# Total params: 76,930
# Trainable params: 76,930
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 160ms/step - loss: 0.6387 - accuracy: 0.7500 - val_loss: 0.4017 - val_accuracy: 0.9176
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2480 - accuracy: 1.0000 - val_loss: 0.3350 - val_accuracy: 0.9176
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5662 - accuracy: 0.8750 - val_loss: 0.3838 - val_accuracy: 0.9176
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0693 - accuracy: 1.0000 - val_loss: 0.4399 - val_accuracy: 0.9176
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7896 - accuracy: 0.7500 - val_loss: 0.4592 - val_accuracy: 0.9176
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3739 - accuracy: 0.8750 - val_loss: 0.4523 - val_accuracy: 0.9176
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.4549 - val_accuracy: 0.9176
# Epoch 8/20
# 2/2 [==============================] - 0s 76ms/step - loss: 1.3396 - accuracy: 0.7500 - val_loss: 0.4217 - val_accuracy: 0.9176
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5940 - accuracy: 0.8750 - val_loss: 0.3924 - val_accuracy: 0.9176
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3902 - accuracy: 0.8750 - val_loss: 0.3725 - val_accuracy: 0.9176
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4611 - accuracy: 0.8750 - val_loss: 0.3600 - val_accuracy: 0.9176
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0398 - accuracy: 1.0000 - val_loss: 0.3517 - val_accuracy: 0.9176
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0439 - accuracy: 1.0000 - val_loss: 0.3489 - val_accuracy: 0.9176
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1326 - accuracy: 1.0000 - val_loss: 0.3492 - val_accuracy: 0.9176
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1884 - accuracy: 1.0000 - val_loss: 0.3516 - val_accuracy: 0.9176
# Epoch 16/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8464 - accuracy: 0.7500 - val_loss: 0.3513 - val_accuracy: 0.9176
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5124 - accuracy: 0.8750 - val_loss: 0.3450 - val_accuracy: 0.9176
# Epoch 18/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1196 - accuracy: 1.0000 - val_loss: 0.3422 - val_accuracy: 0.9176
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2102 - accuracy: 0.8750 - val_loss: 0.3410 - val_accuracy: 0.9176
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.9268 - accuracy: 0.7500 - val_loss: 0.3337 - val_accuracy: 0.9176
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_h = accuracy_score(y_pred, y_test)
res_roc_h = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_h = precision_score(y_pred, y_test)
res_rec_h = recall_score(y_pred, y_test)
res_f1_h = f1_score(y_pred, y_test)
res_mcc_h = matthews_corrcoef(y_pred, y_test)
res_kap_h = cohen_kappa_score(y_pred, y_test)
res_jacc_h = jaccard_score(y_pred, y_test)
res_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - ResNets',res_acc_h,res_roc_h,res_prec_h,res_rec_h,res_f1_h,res_mcc_h,res_kap_h,res_jacc_h,res_gmea_h)
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_22 (Conv1D)           (None, 599, 128)          384
# _________________________________________________________________
# max_pooling1d_22 (MaxPooling (None, 299, 128)          0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 299, 128)          0
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 38272)             0
# _________________________________________________________________
# dense_22 (Dense)             (None, 2)                 76546
# =================================================================
# Total params: 76,930
# Trainable params: 76,930
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.5831 - accuracy: 0.7500 - val_loss: 0.3606 - val_accuracy: 0.9176
# Epoch 2/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.6627 - accuracy: 0.7500 - val_loss: 0.3303 - val_accuracy: 0.9176
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3699 - accuracy: 0.8750 - val_loss: 0.3390 - val_accuracy: 0.9176
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4611 - accuracy: 0.8750 - val_loss: 0.3572 - val_accuracy: 0.9176
# Epoch 5/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.8634 - accuracy: 0.7500 - val_loss: 0.3518 - val_accuracy: 0.9176
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7482 - accuracy: 0.8750 - val_loss: 0.3482 - val_accuracy: 0.9176
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4270 - accuracy: 0.8750 - val_loss: 0.3420 - val_accuracy: 0.9176
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.6839 - accuracy: 0.7500 - val_loss: 0.3373 - val_accuracy: 0.9176
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3884 - accuracy: 0.8750 - val_loss: 0.3356 - val_accuracy: 0.9176
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1540 - accuracy: 1.0000 - val_loss: 0.3363 - val_accuracy: 0.9176
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1339 - accuracy: 1.0000 - val_loss: 0.3378 - val_accuracy: 0.9176
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3047 - accuracy: 0.8750 - val_loss: 0.3395 - val_accuracy: 0.9176
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4401 - accuracy: 0.7500 - val_loss: 0.3414 - val_accuracy: 0.9176
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1930 - accuracy: 1.0000 - val_loss: 0.3440 - val_accuracy: 0.9176
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4383 - accuracy: 0.8750 - val_loss: 0.3471 - val_accuracy: 0.9176
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0664 - accuracy: 1.0000 - val_loss: 0.3528 - val_accuracy: 0.9176
# Epoch 17/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1140 - accuracy: 1.0000 - val_loss: 0.3623 - val_accuracy: 0.9176
# Epoch 18/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1120 - accuracy: 1.0000 - val_loss: 0.3763 - val_accuracy: 0.9176
# Epoch 19/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3298 - accuracy: 0.8750 - val_loss: 0.3928 - val_accuracy: 0.9176
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.4076 - val_accuracy: 0.9176
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_h = accuracy_score(y_pred, y_test)
dense_roc_h = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_h = precision_score(y_pred, y_test)
dense_rec_h = recall_score(y_pred, y_test)
dense_f1_h = f1_score(y_pred, y_test)
dense_mcc_h = matthews_corrcoef(y_pred, y_test)
dense_kap_h = cohen_kappa_score(y_pred, y_test)
dense_jacc_h = jaccard_score(y_pred, y_test)
dense_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - DenseNets',dense_acc_h,dense_roc_h,dense_prec_h,dense_rec_h,dense_f1_h,dense_mcc_h,dense_kap_h,dense_jacc_h,dense_gmea_h)
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_23 (Conv1D)           (None, 599, 128)          384
# _________________________________________________________________
# max_pooling1d_23 (MaxPooling (None, 299, 128)          0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 299, 128)          0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 38272)             0
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 76546
# =================================================================
# Total params: 76,930
# Trainable params: 76,930
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 142ms/step - loss: 0.5274 - accuracy: 0.5000 - val_loss: 0.3483 - val_accuracy: 0.9176
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4563 - accuracy: 0.8750 - val_loss: 0.3647 - val_accuracy: 0.9176
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 0.4383 - val_accuracy: 0.9176
# Epoch 4/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.5272 - val_accuracy: 0.9176
# Epoch 5/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5857 - accuracy: 0.8750 - val_loss: 0.5672 - val_accuracy: 0.9176
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.5485 - accuracy: 0.8750 - val_loss: 0.5749 - val_accuracy: 0.9176
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.5621 - val_accuracy: 0.9176
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.5591 - val_accuracy: 0.9176
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6504 - accuracy: 0.8750 - val_loss: 0.5380 - val_accuracy: 0.9176
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.5242 - val_accuracy: 0.9176
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4973 - accuracy: 0.8750 - val_loss: 0.5074 - val_accuracy: 0.9176
# Epoch 12/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3432 - accuracy: 0.8750 - val_loss: 0.4816 - val_accuracy: 0.9176
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.3360 - accuracy: 0.7500 - val_loss: 0.4527 - val_accuracy: 0.9176
# Epoch 14/20
# 2/2 [==============================] - 0s 74ms/step - loss: 1.2392 - accuracy: 0.7500 - val_loss: 0.4074 - val_accuracy: 0.9176
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 0.3712 - val_accuracy: 0.9176
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5983 - accuracy: 0.8750 - val_loss: 0.3433 - val_accuracy: 0.9176
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0749 - accuracy: 1.0000 - val_loss: 0.3272 - val_accuracy: 0.9176
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9784 - accuracy: 0.7500 - val_loss: 0.3147 - val_accuracy: 0.9176
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6016 - accuracy: 0.7500 - val_loss: 0.3090 - val_accuracy: 0.9176
# Epoch 20/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4076 - accuracy: 0.8750 - val_loss: 0.3130 - val_accuracy: 0.9176
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # EXP-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(EXP_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1200), (907,), (161, 1200), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_i = accuracy_score(y_pred, y_test)
svm_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_i = precision_score(y_pred, y_test)
svm_rec_i = recall_score(y_pred, y_test)
svm_f1_i = f1_score(y_pred, y_test)
svm_mcc_i = matthews_corrcoef(y_pred, y_test)
svm_kap_i = cohen_kappa_score(y_pred, y_test)
svm_jacc_i = jaccard_score(y_pred, y_test)
svm_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - rbf',svm_acc_i,svm_roc_i,svm_prec_i,svm_rec_i,svm_f1_i,svm_mcc_i,svm_kap_i,svm_jacc_i,svm_gmea_i)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_i = accuracy_score(y_pred, y_test)
svm1_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_i = precision_score(y_pred, y_test)
svm1_rec_i = recall_score(y_pred, y_test)
svm1_f1_i = f1_score(y_pred, y_test)
svm1_mcc_i = matthews_corrcoef(y_pred, y_test)
svm1_kap_i = cohen_kappa_score(y_pred, y_test)
svm1_jacc_i = jaccard_score(y_pred, y_test)
svm1_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - Poly',svm1_acc_i,svm1_roc_i,svm1_prec_i,svm1_rec_i,svm1_f1_i,svm1_mcc_i,svm1_kap_i,svm1_jacc_i,svm1_gmea_i)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_i = accuracy_score(y_pred, y_test)
svm2_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_i = precision_score(y_pred, y_test)
svm2_rec_i = recall_score(y_pred, y_test)
svm2_f1_i = f1_score(y_pred, y_test)
svm2_mcc_i = matthews_corrcoef(y_pred, y_test)
svm2_kap_i = cohen_kappa_score(y_pred, y_test)
svm2_jacc_i = jaccard_score(y_pred, y_test)
svm2_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - Utility ',svm2_acc_i,svm2_roc_i,svm2_prec_i,svm2_rec_i,svm2_f1_i,svm2_mcc_i,svm2_kap_i,svm2_jacc_i,svm2_gmea_i)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_i = accuracy_score(y_pred, y_test)
svm3_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_i = precision_score(y_pred, y_test)
svm3_rec_i = recall_score(y_pred, y_test)
svm3_f1_i = f1_score(y_pred, y_test)
svm3_mcc_i = matthews_corrcoef(y_pred, y_test)
svm3_kap_i = cohen_kappa_score(y_pred, y_test)
svm3_jacc_i = jaccard_score(y_pred, y_test)
svm3_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - Linear ',svm3_acc_i,svm3_roc_i,svm3_prec_i,svm3_rec_i,svm3_f1_i,svm3_mcc_i,svm3_kap_i,svm3_jacc_i,svm3_gmea_i)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_i = accuracy_score(y_pred, y_test)
svm4_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_i = precision_score(y_pred, y_test)
svm4_rec_i = recall_score(y_pred, y_test)
svm4_f1_i = f1_score(y_pred, y_test)
svm4_mcc_i = matthews_corrcoef(y_pred, y_test)
svm4_kap_i = cohen_kappa_score(y_pred, y_test)
svm4_jacc_i = jaccard_score(y_pred, y_test)
svm4_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - Sigmoid',svm4_acc_i,svm4_roc_i,svm4_prec_i,svm4_rec_i,svm4_f1_i,svm4_mcc_i,svm4_kap_i,svm4_jacc_i,svm4_gmea_i)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_i = accuracy_score(y_pred, y_test)
rf_roc_i = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_i = precision_score(y_pred, y_test)
rf_rec_i = recall_score(y_pred, y_test)
rf_f1_i = f1_score(y_pred, y_test)
rf_mcc_i = matthews_corrcoef(y_pred, y_test)
rf_kap_i = cohen_kappa_score(y_pred, y_test)
rf_jacc_i = jaccard_score(y_pred, y_test)
rf_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - RF',rf_acc_i,rf_roc_i,rf_prec_i,rf_rec_i,rf_f1_i,rf_mcc_i,rf_kap_i,rf_jacc_i,rf_gmea_i)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_i = accuracy_score(y_pred, y_test)
dt_roc_i = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_i = precision_score(y_pred, y_test)
dt_rec_i = recall_score(y_pred, y_test)
dt_f1_i = f1_score(y_pred, y_test)
dt_mcc_i = matthews_corrcoef(y_pred, y_test)
dt_kap_i = cohen_kappa_score(y_pred, y_test)
dt_jacc_i = jaccard_score(y_pred, y_test)
dt_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - DT',dt_acc_i,dt_roc_i,dt_prec_i,dt_rec_i,dt_f1_i,dt_mcc_i,dt_kap_i,dt_jacc_i,dt_gmea_i)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_i = accuracy_score(y_pred, y_test)
nb_roc_i = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_i = precision_score(y_pred, y_test)
nb_rec_i = recall_score(y_pred, y_test)
nb_f1_i = f1_score(y_pred, y_test)
nb_mcc_i = matthews_corrcoef(y_pred, y_test)
nb_kap_i = cohen_kappa_score(y_pred, y_test)
nb_jacc_i = jaccard_score(y_pred, y_test)
nb_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - NB',nb_acc_i,nb_roc_i,nb_prec_i,nb_rec_i,nb_f1_i,nb_mcc_i,nb_kap_i,nb_jacc_i,nb_gmea_i)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_i = accuracy_score(y_pred, y_test)
vot_roc_i = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_i = precision_score(y_pred, y_test)
vot_rec_i = recall_score(y_pred, y_test)
vot_f1_i = f1_score(y_pred, y_test)
vot_mcc_i = matthews_corrcoef(y_pred, y_test)
vot_kap_i = cohen_kappa_score(y_pred, y_test)
vot_jacc_i = jaccard_score(y_pred, y_test)
vot_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - vot',vot_acc_i,vot_roc_i,vot_prec_i,vot_rec_i,vot_f1_i,vot_mcc_i,vot_kap_i,vot_jacc_i,vot_gmea_i)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_i = accuracy_score(y_pred, y_test)
vgg_roc_i = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_i = precision_score(y_pred, y_test)
vgg_rec_i = recall_score(y_pred, y_test)
vgg_f1_i = f1_score(y_pred, y_test)
vgg_mcc_i = matthews_corrcoef(y_pred, y_test)
vgg_kap_i = cohen_kappa_score(y_pred, y_test)
vgg_jacc_i = jaccard_score(y_pred, y_test)
vgg_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - VGGNets',vgg_acc_i,vgg_roc_i,vgg_prec_i,vgg_rec_i,vgg_f1_i,vgg_mcc_i,vgg_kap_i,vgg_jacc_i,vgg_gmea_i)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_24 (Conv1D)           (None, 1199, 128)         384
# _________________________________________________________________
# max_pooling1d_24 (MaxPooling (None, 599, 128)          0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 599, 128)          0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 76672)             0
# _________________________________________________________________
# dense_24 (Dense)             (None, 2)                 153346
# =================================================================
# Total params: 153,730
# Trainable params: 153,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 160ms/step - loss: 0.7916 - accuracy: 0.6250 - val_loss: 12.9104 - val_accuracy: 0.8736
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 20.2036 - val_accuracy: 0.8736
# Epoch 3/20
# 2/2 [==============================] - 0s 84ms/step - loss: 37.7634 - accuracy: 0.7500 - val_loss: 19.8014 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 19.5010 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 23.8135 - accuracy: 0.8750 - val_loss: 17.1851 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 73ms/step - loss: 15.1651 - accuracy: 0.8750 - val_loss: 14.0176 - val_accuracy: 0.8736
# Epoch 7/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 11.5040 - val_accuracy: 0.8736
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.4858 - val_accuracy: 0.8736
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 6.6671 - accuracy: 0.8750 - val_loss: 6.8861 - val_accuracy: 0.8736
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 8.8470 - accuracy: 0.8750 - val_loss: 3.4304 - val_accuracy: 0.8736
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.2517e-06 - accuracy: 1.0000 - val_loss: 1.3100 - val_accuracy: 0.7582
# Epoch 12/20
# 2/2 [==============================] - 0s 73ms/step - loss: 6.5957 - accuracy: 0.3750 - val_loss: 2.8634 - val_accuracy: 0.3846
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 8.1440 - accuracy: 0.3750 - val_loss: 2.2256 - val_accuracy: 0.8736
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.3410e-05 - accuracy: 1.0000 - val_loss: 2.9624 - val_accuracy: 0.8736
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.3615 - accuracy: 0.7500 - val_loss: 2.8659 - val_accuracy: 0.8736
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.0279e-04 - accuracy: 1.0000 - val_loss: 2.5497 - val_accuracy: 0.8736
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.7126 - accuracy: 0.8750 - val_loss: 2.2387 - val_accuracy: 0.7692
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.0829 - accuracy: 0.6250 - val_loss: 2.3954 - val_accuracy: 0.6374
# Epoch 19/20
# 2/2 [==============================] - 0s 81ms/step - loss: 1.8316 - accuracy: 0.5000 - val_loss: 1.8929 - val_accuracy: 0.7088
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2520 - accuracy: 0.8750 - val_loss: 2.7962 - val_accuracy: 0.8736
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 0s/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_i = accuracy_score(y_pred, y_test)
res_roc_i = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_i = precision_score(y_pred, y_test)
res_rec_i = recall_score(y_pred, y_test)
res_f1_i = f1_score(y_pred, y_test)
res_mcc_i = matthews_corrcoef(y_pred, y_test)
res_kap_i = cohen_kappa_score(y_pred, y_test)
res_jacc_i = jaccard_score(y_pred, y_test)
res_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - ResNets',res_acc_i,res_roc_i,res_prec_i,res_rec_i,res_f1_i,res_mcc_i,res_kap_i,res_jacc_i,res_gmea_i)
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_25 (Conv1D)           (None, 1199, 128)         384
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 599, 128)          0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 599, 128)          0
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 76672)             0
# _________________________________________________________________
# dense_25 (Dense)             (None, 2)                 153346
# =================================================================
# Total params: 153,730
# Trainable params: 153,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 11.0612 - accuracy: 0.3750 - val_loss: 9.6230 - val_accuracy: 0.8736
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 13.4413 - val_accuracy: 0.8736
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 16.0959 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 8.3734 - accuracy: 0.8750 - val_loss: 17.5120 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 14.4862 - accuracy: 0.8750 - val_loss: 16.7634 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 38.0900 - accuracy: 0.7500 - val_loss: 14.9158 - val_accuracy: 0.8736
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 11.7165 - accuracy: 0.8750 - val_loss: 11.8714 - val_accuracy: 0.8736
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 11.1884 - accuracy: 0.8750 - val_loss: 8.1174 - val_accuracy: 0.8736
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.3887 - accuracy: 0.8750 - val_loss: 4.7416 - val_accuracy: 0.8736
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 7.2994e-04 - accuracy: 1.0000 - val_loss: 2.9341 - val_accuracy: 0.5934
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.4747 - accuracy: 0.6250 - val_loss: 8.9749 - val_accuracy: 0.3516
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 7.7185 - accuracy: 0.5000 - val_loss: 7.4967 - val_accuracy: 0.3626
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 5.8405 - accuracy: 0.5000 - val_loss: 3.9384 - val_accuracy: 0.8626
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.4450 - accuracy: 0.8750 - val_loss: 6.6714 - val_accuracy: 0.8736
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.7961 - accuracy: 0.8750 - val_loss: 8.4591 - val_accuracy: 0.8736
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.9166 - val_accuracy: 0.8736
# Epoch 17/20
# 2/2 [==============================] - 0s 84ms/step - loss: 20.2652 - accuracy: 0.7500 - val_loss: 9.9910 - val_accuracy: 0.8736
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 5.1218 - accuracy: 0.8750 - val_loss: 9.4747 - val_accuracy: 0.8736
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.8478 - val_accuracy: 0.8736
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 12.5385 - accuracy: 0.7500 - val_loss: 7.2470 - val_accuracy: 0.8736
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_i = accuracy_score(y_pred, y_test)
dense_roc_i = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_i = precision_score(y_pred, y_test)
dense_rec_i = recall_score(y_pred, y_test)
dense_f1_i = f1_score(y_pred, y_test)
dense_mcc_i = matthews_corrcoef(y_pred, y_test)
dense_kap_i = cohen_kappa_score(y_pred, y_test)
dense_jacc_i = jaccard_score(y_pred, y_test)
dense_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - DenseNets',dense_acc_i,dense_roc_i,dense_prec_i,dense_rec_i,dense_f1_i,dense_mcc_i,dense_kap_i,dense_jacc_i,dense_gmea_i)
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_26 (Conv1D)           (None, 1199, 128)         384
# _________________________________________________________________
# max_pooling1d_26 (MaxPooling (None, 599, 128)          0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 599, 128)          0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 76672)             0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 153346
# =================================================================
# Total params: 153,730
# Trainable params: 153,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 4.3567 - accuracy: 0.3750 - val_loss: 11.5995 - val_accuracy: 0.8736
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 11.8682 - accuracy: 0.7500 - val_loss: 14.2013 - val_accuracy: 0.8736
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 15.2298 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 15.9876 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 16.5695 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 17.0274 - val_accuracy: 0.8736
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 26.2599 - accuracy: 0.7500 - val_loss: 15.0837 - val_accuracy: 0.8736
# Epoch 8/20
# 2/2 [==============================] - 0s 74ms/step - loss: 16.6449 - accuracy: 0.8750 - val_loss: 11.3069 - val_accuracy: 0.8736
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 10.0447 - accuracy: 0.8750 - val_loss: 7.2058 - val_accuracy: 0.8681
# Epoch 10/20
# 2/2 [==============================] - 0s 73ms/step - loss: 7.6373 - accuracy: 0.8750 - val_loss: 3.8252 - val_accuracy: 0.7967
# Epoch 11/20
# 2/2 [==============================] - 0s 82ms/step - loss: 6.7456 - accuracy: 0.6250 - val_loss: 10.3685 - val_accuracy: 0.2637
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 11.2569 - accuracy: 0.1250 - val_loss: 3.8179 - val_accuracy: 0.6044
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.5005 - accuracy: 0.7500 - val_loss: 4.6852 - val_accuracy: 0.8681
# Epoch 14/20
# 2/2 [==============================] - 0s 74ms/step - loss: 5.7786 - accuracy: 0.8750 - val_loss: 7.4044 - val_accuracy: 0.8736
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 12.7472 - accuracy: 0.7500 - val_loss: 7.9283 - val_accuracy: 0.8736
# Epoch 16/20
# 2/2 [==============================] - 0s 75ms/step - loss: 4.3380 - accuracy: 0.8750 - val_loss: 7.8505 - val_accuracy: 0.8736
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 9.1008 - accuracy: 0.8750 - val_loss: 6.6069 - val_accuracy: 0.8736
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.6062 - val_accuracy: 0.8736
# Epoch 19/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.7975 - val_accuracy: 0.8736
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.3088 - accuracy: 0.8750 - val_loss: 3.8976 - val_accuracy: 0.8736
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # CNV-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CNV_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1000), (907,), (161, 1000), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_j = accuracy_score(y_pred, y_test)
svm_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_j = precision_score(y_pred, y_test)
svm_rec_j = recall_score(y_pred, y_test)
svm_f1_j = f1_score(y_pred, y_test)
svm_mcc_j = matthews_corrcoef(y_pred, y_test)
svm_kap_j = cohen_kappa_score(y_pred, y_test)
svm_jacc_j = jaccard_score(y_pred, y_test)
svm_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - rbf',svm_acc_j,svm_roc_j,svm_prec_j,svm_rec_j,svm_f1_j,svm_mcc_j,svm_kap_j,svm_jacc_j,svm_gmea_j)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_j = accuracy_score(y_pred, y_test)
svm1_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_j = precision_score(y_pred, y_test)
svm1_rec_j = recall_score(y_pred, y_test)
svm1_f1_j = f1_score(y_pred, y_test)
svm1_mcc_j = matthews_corrcoef(y_pred, y_test)
svm1_kap_j = cohen_kappa_score(y_pred, y_test)
svm1_jacc_j = jaccard_score(y_pred, y_test)
svm1_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - Poly',svm1_acc_j,svm1_roc_j,svm1_prec_j,svm1_rec_j,svm1_f1_j,svm1_mcc_j,svm1_kap_j,svm1_jacc_j,svm1_gmea_j)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_j = accuracy_score(y_pred, y_test)
svm2_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_j = precision_score(y_pred, y_test)
svm2_rec_j = recall_score(y_pred, y_test)
svm2_f1_j = f1_score(y_pred, y_test)
svm2_mcc_j = matthews_corrcoef(y_pred, y_test)
svm2_kap_j = cohen_kappa_score(y_pred, y_test)
svm2_jacc_j = jaccard_score(y_pred, y_test)
svm2_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - Utility ',svm2_acc_j,svm2_roc_j,svm2_prec_j,svm2_rec_j,svm2_f1_j,svm2_mcc_j,svm2_kap_j,svm2_jacc_j,svm2_gmea_j)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_j = accuracy_score(y_pred, y_test)
svm3_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_j = precision_score(y_pred, y_test)
svm3_rec_j = recall_score(y_pred, y_test)
svm3_f1_j = f1_score(y_pred, y_test)
svm3_mcc_j = matthews_corrcoef(y_pred, y_test)
svm3_kap_j = cohen_kappa_score(y_pred, y_test)
svm3_jacc_j = jaccard_score(y_pred, y_test)
svm3_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - Linear ',svm3_acc_j,svm3_roc_j,svm3_prec_j,svm3_rec_j,svm3_f1_j,svm3_mcc_j,svm3_kap_j,svm3_jacc_j,svm3_gmea_j)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_j = accuracy_score(y_pred, y_test)
svm4_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_j = precision_score(y_pred, y_test)
svm4_rec_j = recall_score(y_pred, y_test)
svm4_f1_j = f1_score(y_pred, y_test)
svm4_mcc_j = matthews_corrcoef(y_pred, y_test)
svm4_kap_j = cohen_kappa_score(y_pred, y_test)
svm4_jacc_j = jaccard_score(y_pred, y_test)
svm4_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - Sigmoid',svm4_acc_j,svm4_roc_j,svm4_prec_j,svm4_rec_j,svm4_f1_j,svm4_mcc_j,svm4_kap_j,svm4_jacc_j,svm4_gmea_j)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_j = accuracy_score(y_pred, y_test)
rf_roc_j = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_j = precision_score(y_pred, y_test)
rf_rec_j = recall_score(y_pred, y_test)
rf_f1_j = f1_score(y_pred, y_test)
rf_mcc_j = matthews_corrcoef(y_pred, y_test)
rf_kap_j = cohen_kappa_score(y_pred, y_test)
rf_jacc_j = jaccard_score(y_pred, y_test)
rf_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - RF',rf_acc_j,rf_roc_j,rf_prec_j,rf_rec_j,rf_f1_j,rf_mcc_j,rf_kap_j,rf_jacc_j,rf_gmea_j)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_j = accuracy_score(y_pred, y_test)
dt_roc_j = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_j = precision_score(y_pred, y_test)
dt_rec_j = recall_score(y_pred, y_test)
dt_f1_j = f1_score(y_pred, y_test)
dt_mcc_j = matthews_corrcoef(y_pred, y_test)
dt_kap_j = cohen_kappa_score(y_pred, y_test)
dt_jacc_j = jaccard_score(y_pred, y_test)
dt_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - DT',dt_acc_j,dt_roc_j,dt_prec_j,dt_rec_j,dt_f1_j,dt_mcc_j,dt_kap_j,dt_jacc_j,dt_gmea_j)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_j = accuracy_score(y_pred, y_test)
nb_roc_j = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_j = precision_score(y_pred, y_test)
nb_rec_j = recall_score(y_pred, y_test)
nb_f1_j = f1_score(y_pred, y_test)
nb_mcc_j = matthews_corrcoef(y_pred, y_test)
nb_kap_j = cohen_kappa_score(y_pred, y_test)
nb_jacc_j = jaccard_score(y_pred, y_test)
nb_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - NB',nb_acc_j,nb_roc_j,nb_prec_j,nb_rec_j,nb_f1_j,nb_mcc_j,nb_kap_j,nb_jacc_j,nb_gmea_j)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_j = accuracy_score(y_pred, y_test)
vot_roc_j = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_j = precision_score(y_pred, y_test)
vot_rec_j = recall_score(y_pred, y_test)
vot_f1_j = f1_score(y_pred, y_test)
vot_mcc_j = matthews_corrcoef(y_pred, y_test)
vot_kap_j = cohen_kappa_score(y_pred, y_test)
vot_jacc_j = jaccard_score(y_pred, y_test)
vot_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - vot',vot_acc_j,vot_roc_j,vot_prec_j,vot_rec_j,vot_f1_j,vot_mcc_j,vot_kap_j,vot_jacc_j,vot_gmea_j)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_j = accuracy_score(y_pred, y_test)
vgg_roc_j = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_j = precision_score(y_pred, y_test)
vgg_rec_j = recall_score(y_pred, y_test)
vgg_f1_j = f1_score(y_pred, y_test)
vgg_mcc_j = matthews_corrcoef(y_pred, y_test)
vgg_kap_j = cohen_kappa_score(y_pred, y_test)
vgg_jacc_j = jaccard_score(y_pred, y_test)
vgg_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - VGGNets',vgg_acc_j,vgg_roc_j,vgg_prec_j,vgg_rec_j,vgg_f1_j,vgg_mcc_j,vgg_kap_j,vgg_jacc_j,vgg_gmea_j)
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_27 (Conv1D)           (None, 999, 128)          384
# _________________________________________________________________
# max_pooling1d_27 (MaxPooling (None, 499, 128)          0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 499, 128)          0
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 63872)             0
# _________________________________________________________________
# dense_27 (Dense)             (None, 2)                 127746
# =================================================================
# Total params: 128,130
# Trainable params: 128,130
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 152ms/step - loss: 0.2640 - accuracy: 0.8750 - val_loss: 9.3002 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 14.5884 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 18.3370 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 21.1893 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 33.9644 - accuracy: 0.8750 - val_loss: 21.9978 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 21.3617 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 20.8521 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 56.3145 - accuracy: 0.7500 - val_loss: 17.8049 - val_accuracy: 0.9011
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 63.5476 - accuracy: 0.6250 - val_loss: 12.3936 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.6994 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 11.0806 - accuracy: 0.8750 - val_loss: 3.0330 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.5912e-06 - accuracy: 1.0000 - val_loss: 6.6442 - val_accuracy: 0.1154
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 3.6083 - accuracy: 0.2500 - val_loss: 0.7141 - val_accuracy: 0.8791
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 6.3604e-05 - accuracy: 1.0000 - val_loss: 2.5333 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.0530 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.2948 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.3117 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 10.8157 - accuracy: 0.8750 - val_loss: 6.2319 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 12.2305 - accuracy: 0.8750 - val_loss: 5.2835 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.5093 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_j = accuracy_score(y_pred, y_test)
res_roc_j = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_j = precision_score(y_pred, y_test)
res_rec_j = recall_score(y_pred, y_test)
res_f1_j = f1_score(y_pred, y_test)
res_mcc_j = matthews_corrcoef(y_pred, y_test)
res_kap_j = cohen_kappa_score(y_pred, y_test)
res_jacc_j = jaccard_score(y_pred, y_test)
res_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - ResNets',res_acc_j,res_roc_j,res_prec_j,res_rec_j,res_f1_j,res_mcc_j,res_kap_j,res_jacc_j,res_gmea_j)
# Out:
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_28 (Conv1D)           (None, 999, 128)          384
# _________________________________________________________________
# max_pooling1d_28 (MaxPooling (None, 499, 128)          0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 499, 128)          0
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 63872)             0
# _________________________________________________________________
# dense_28 (Dense)             (None, 2)                 127746
# =================================================================
# Total params: 128,130
# Trainable params: 128,130
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 149ms/step - loss: 0.9295 - accuracy: 0.6250 - val_loss: 9.2231 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 36.6932 - accuracy: 0.7500 - val_loss: 12.1075 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 12.1105 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 50.0353 - accuracy: 0.6250 - val_loss: 10.5646 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 82ms/step - loss: 6.1593 - accuracy: 0.8750 - val_loss: 7.7824 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 10.2760 - accuracy: 0.8750 - val_loss: 4.9555 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.5209 - accuracy: 0.8750 - val_loss: 2.0888 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.6477 - accuracy: 0.8750 - val_loss: 6.4125 - val_accuracy: 0.2692
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 10.8659 - accuracy: 0.2500 - val_loss: 6.0019 - val_accuracy: 0.2582
# Epoch 10/20
# 2/2 [==============================] - 0s 73ms/step - loss: 3.5916 - accuracy: 0.6250 - val_loss: 1.8703 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 72ms/step - loss: 8.6665e-05 - accuracy: 1.0000 - val_loss: 3.9930 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 85ms/step - loss: 8.8611 - accuracy: 0.8750 - val_loss: 5.3710 - val_accuracy: 0.9011
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.1724 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.8287 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 73ms/step - loss: 5.1548 - accuracy: 0.8750 - val_loss: 7.1735 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 22.9672 - accuracy: 0.7500 - val_loss: 6.3468 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 6.9619 - accuracy: 0.8750 - val_loss: 4.8881 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 5.7087 - accuracy: 0.8750 - val_loss: 3.3952 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.3035e-05 - accuracy: 1.0000 - val_loss: 1.9314 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 74ms/step - loss: 1.1157 - accuracy: 0.8750 - val_loss: 1.4805 - val_accuracy: 0.7033
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_j = accuracy_score(y_pred, y_test)
dense_roc_j = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_j = precision_score(y_pred, y_test)
dense_rec_j = recall_score(y_pred, y_test)
dense_f1_j = f1_score(y_pred, y_test)
dense_mcc_j = matthews_corrcoef(y_pred, y_test)
dense_kap_j = cohen_kappa_score(y_pred, y_test)
dense_jacc_j = jaccard_score(y_pred, y_test)
dense_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - DenseNets',dense_acc_j,dense_roc_j,dense_prec_j,dense_rec_j,dense_f1_j,dense_mcc_j,dense_kap_j,dense_jacc_j,dense_gmea_j)
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_29 (Conv1D)           (None, 999, 128)          384
# _________________________________________________________________
# max_pooling1d_29 (MaxPooling (None, 499, 128)          0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 499, 128)          0
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 63872)             0
# _________________________________________________________________
# dense_29 (Dense)             (None, 2)                 127746
# =================================================================
# Total params: 128,130
# Trainable params: 128,130
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 152ms/step - loss: 1.1182 - accuracy: 0.5000 - val_loss: 6.1997 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 16.4450 - accuracy: 0.7500 - val_loss: 4.8237 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.8703 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.9761 - accuracy: 0.8750 - val_loss: 2.3726 - val_accuracy: 0.8901
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0740 - accuracy: 1.0000 - val_loss: 4.1489 - val_accuracy: 0.6429
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 8.2671 - accuracy: 0.7500 - val_loss: 2.4640 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 4.9509 - accuracy: 0.8750 - val_loss: 3.0347 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9146 - val_accuracy: 0.9011
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.3842e-07 - accuracy: 1.0000 - val_loss: 2.8166 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 75ms/step - loss: 4.0645 - accuracy: 0.8750 - val_loss: 2.2848 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.7430e-04 - accuracy: 1.0000 - val_loss: 1.4716 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 4.6244 - accuracy: 0.8750 - val_loss: 4.5331 - val_accuracy: 0.3681
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 3.7749 - accuracy: 0.5000 - val_loss: 1.4842 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.6031 - accuracy: 0.7500 - val_loss: 1.5885 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 7.1328 - accuracy: 0.7500 - val_loss: 1.4457 - val_accuracy: 0.7143
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4027 - accuracy: 0.7500 - val_loss: 6.5267 - val_accuracy: 0.3077
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.0755 - accuracy: 0.5000 - val_loss: 1.3138 - val_accuracy: 0.8571
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.8709 - accuracy: 0.8750 - val_loss: 2.5199 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.4138 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 79ms/step - loss: 5.6454 - accuracy: 0.8750 - val_loss: 3.7494 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # CLN-EXP-CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_EXP_CNV, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 610), (907,), (161, 610), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_k = accuracy_score(y_pred, y_test)
svm_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_k = precision_score(y_pred, y_test)
svm_rec_k = recall_score(y_pred, y_test)
svm_f1_k = f1_score(y_pred, y_test)
svm_mcc_k = matthews_corrcoef(y_pred, y_test)
svm_kap_k = cohen_kappa_score(y_pred, y_test)
svm_jacc_k = jaccard_score(y_pred, y_test)
svm_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - rbf',svm_acc_k,svm_roc_k,svm_prec_k,svm_rec_k,svm_f1_k,svm_mcc_k,svm_kap_k,svm_jacc_k,svm_gmea_k)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_k = accuracy_score(y_pred, y_test)
svm1_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_k = precision_score(y_pred, y_test)
svm1_rec_k = recall_score(y_pred, y_test)
svm1_f1_k = f1_score(y_pred, y_test)
svm1_mcc_k = matthews_corrcoef(y_pred, y_test)
svm1_kap_k = cohen_kappa_score(y_pred, y_test)
svm1_jacc_k = jaccard_score(y_pred, y_test)
svm1_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - Poly',svm1_acc_k,svm1_roc_k,svm1_prec_k,svm1_rec_k,svm1_f1_k,svm1_mcc_k,svm1_kap_k,svm1_jacc_k,svm1_gmea_k)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_k = accuracy_score(y_pred, y_test)
svm2_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_k = precision_score(y_pred, y_test)
svm2_rec_k = recall_score(y_pred, y_test)
svm2_f1_k = f1_score(y_pred, y_test)
svm2_mcc_k = matthews_corrcoef(y_pred, y_test)
svm2_kap_k = cohen_kappa_score(y_pred, y_test)
svm2_jacc_k = jaccard_score(y_pred, y_test)
svm2_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - Utility ',svm2_acc_k,svm2_roc_k,svm2_prec_k,svm2_rec_k,svm2_f1_k,svm2_mcc_k,svm2_kap_k,svm2_jacc_k,svm2_gmea_k)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_k = accuracy_score(y_pred, y_test)
svm3_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_k = precision_score(y_pred, y_test)
svm3_rec_k = recall_score(y_pred, y_test)
svm3_f1_k = f1_score(y_pred, y_test)
svm3_mcc_k = matthews_corrcoef(y_pred, y_test)
svm3_kap_k = cohen_kappa_score(y_pred, y_test)
svm3_jacc_k = jaccard_score(y_pred, y_test)
svm3_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - Linear ',svm3_acc_k,svm3_roc_k,svm3_prec_k,svm3_rec_k,svm3_f1_k,svm3_mcc_k,svm3_kap_k,svm3_jacc_k,svm3_gmea_k)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_k = accuracy_score(y_pred, y_test)
svm4_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_k = precision_score(y_pred, y_test)
svm4_rec_k = recall_score(y_pred, y_test)
svm4_f1_k = f1_score(y_pred, y_test)
svm4_mcc_k = matthews_corrcoef(y_pred, y_test)
svm4_kap_k = cohen_kappa_score(y_pred, y_test)
svm4_jacc_k = jaccard_score(y_pred, y_test)
svm4_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - Sigmoid',svm4_acc_k,svm4_roc_k,svm4_prec_k,svm4_rec_k,svm4_f1_k,svm4_mcc_k,svm4_kap_k,svm4_jacc_k,svm4_gmea_k)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_k = accuracy_score(y_pred, y_test)
rf_roc_k = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_k = precision_score(y_pred, y_test)
rf_rec_k = recall_score(y_pred, y_test)
rf_f1_k = f1_score(y_pred, y_test)
rf_mcc_k = matthews_corrcoef(y_pred, y_test)
rf_kap_k = cohen_kappa_score(y_pred, y_test)
rf_jacc_k = jaccard_score(y_pred, y_test)
rf_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - RF',rf_acc_k,rf_roc_k,rf_prec_k,rf_rec_k,rf_f1_k,rf_mcc_k,rf_kap_k,rf_jacc_k,rf_gmea_k)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_k = accuracy_score(y_pred, y_test)
dt_roc_k = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_k = precision_score(y_pred, y_test)
dt_rec_k = recall_score(y_pred, y_test)
dt_f1_k = f1_score(y_pred, y_test)
dt_mcc_k = matthews_corrcoef(y_pred, y_test)
dt_kap_k = cohen_kappa_score(y_pred, y_test)
dt_jacc_k = jaccard_score(y_pred, y_test)
dt_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - DT',dt_acc_k,dt_roc_k,dt_prec_k,dt_rec_k,dt_f1_k,dt_mcc_k,dt_kap_k,dt_jacc_k,dt_gmea_k)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_k = accuracy_score(y_pred, y_test)
nb_roc_k = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_k = precision_score(y_pred, y_test)
nb_rec_k = recall_score(y_pred, y_test)
nb_f1_k = f1_score(y_pred, y_test)
nb_mcc_k = matthews_corrcoef(y_pred, y_test)
nb_kap_k = cohen_kappa_score(y_pred, y_test)
nb_jacc_k = jaccard_score(y_pred, y_test)
nb_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - NB',nb_acc_k,nb_roc_k,nb_prec_k,nb_rec_k,nb_f1_k,nb_mcc_k,nb_kap_k,nb_jacc_k,nb_gmea_k)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_k = accuracy_score(y_pred, y_test)
vot_roc_k = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_k = precision_score(y_pred, y_test)
vot_rec_k = recall_score(y_pred, y_test)
vot_f1_k = f1_score(y_pred, y_test)
vot_mcc_k = matthews_corrcoef(y_pred, y_test)
vot_kap_k = cohen_kappa_score(y_pred, y_test)
vot_jacc_k = jaccard_score(y_pred, y_test)
vot_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - vot',vot_acc_k,vot_roc_k,vot_prec_k,vot_rec_k,vot_f1_k,vot_mcc_k,vot_kap_k,vot_jacc_k,vot_gmea_k)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_k = accuracy_score(y_pred, y_test)
vgg_roc_k = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_k = precision_score(y_pred, y_test)
vgg_rec_k = recall_score(y_pred, y_test)
vgg_f1_k = f1_score(y_pred, y_test)
vgg_mcc_k = matthews_corrcoef(y_pred, y_test)
vgg_kap_k = cohen_kappa_score(y_pred, y_test)
vgg_jacc_k = jaccard_score(y_pred, y_test)
vgg_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - VGGNets',vgg_acc_k,vgg_roc_k,vgg_prec_k,vgg_rec_k,vgg_f1_k,vgg_mcc_k,vgg_kap_k,vgg_jacc_k,vgg_gmea_k)
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_30 (Conv1D)           (None, 609, 128)          384
# _________________________________________________________________
# max_pooling1d_30 (MaxPooling (None, 304, 128)          0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 304, 128)          0
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 38912)             0
# _________________________________________________________________
# dense_30 (Dense)             (None, 2)                 77826
# =================================================================
# Total params: 78,210
# Trainable params: 78,210
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.5706 - accuracy: 0.8750 - val_loss: 0.4121 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2035 - accuracy: 1.0000 - val_loss: 0.4582 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.4063 - accuracy: 0.8750 - val_loss: 0.5862 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6557 - accuracy: 0.8750 - val_loss: 0.6113 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.2640 - accuracy: 0.7500 - val_loss: 0.5817 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.3367 - accuracy: 0.7500 - val_loss: 0.5215 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7240 - accuracy: 0.8750 - val_loss: 0.4638 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1070 - accuracy: 1.0000 - val_loss: 0.4348 - val_accuracy: 0.8846
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0909 - accuracy: 1.0000 - val_loss: 0.4207 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3395 - accuracy: 0.8750 - val_loss: 0.4116 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5224 - accuracy: 0.8750 - val_loss: 0.4030 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5852 - accuracy: 0.8750 - val_loss: 0.3949 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3272 - accuracy: 0.8750 - val_loss: 0.3909 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2493 - accuracy: 1.0000 - val_loss: 0.3911 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1621 - accuracy: 1.0000 - val_loss: 0.3916 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1495 - accuracy: 1.0000 - val_loss: 0.3927 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6963 - accuracy: 0.7500 - val_loss: 0.3936 - val_accuracy: 0.8846
# Epoch 18/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1797 - accuracy: 1.0000 - val_loss: 0.3936 - val_accuracy: 0.8846
# Epoch 19/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1471 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1441 - accuracy: 1.0000 - val_loss: 0.4036 - val_accuracy: 0.8846
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_k = accuracy_score(y_pred, y_test)
res_roc_k = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_k = precision_score(y_pred, y_test)
res_rec_k = recall_score(y_pred, y_test)
res_f1_k = f1_score(y_pred, y_test)
res_mcc_k = matthews_corrcoef(y_pred, y_test)
res_kap_k = cohen_kappa_score(y_pred, y_test)
res_jacc_k = jaccard_score(y_pred, y_test)
res_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - ResNets',res_acc_k,res_roc_k,res_prec_k,res_rec_k,res_f1_k,res_mcc_k,res_kap_k,res_jacc_k,res_gmea_k)
# Out:
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_31 (Conv1D)           (None, 609, 128)          384
# _________________________________________________________________
# max_pooling1d_31 (MaxPooling (None, 304, 128)          0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 304, 128)          0
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 38912)             0
# _________________________________________________________________
# dense_31 (Dense)             (None, 2)                 77826
# =================================================================
# Total params: 78,210
# Trainable params: 78,210
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 149ms/step - loss: 0.7260 - accuracy: 0.2500 - val_loss: 0.5866 - val_accuracy: 0.8736
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5406 - accuracy: 0.7500 - val_loss: 0.4472 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3227 - accuracy: 1.0000 - val_loss: 0.3870 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1060 - accuracy: 1.0000 - val_loss: 0.4282 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.6210 - accuracy: 0.6250 - val_loss: 0.4368 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4592 - accuracy: 0.8750 - val_loss: 0.4184 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.5378 - accuracy: 0.8750 - val_loss: 0.3939 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1498 - accuracy: 1.0000 - val_loss: 0.3875 - val_accuracy: 0.8846
# Epoch 9/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1334 - accuracy: 1.0000 - val_loss: 0.3874 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1155 - accuracy: 1.0000 - val_loss: 0.3925 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1388 - accuracy: 1.0000 - val_loss: 0.4059 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4920 - accuracy: 0.8750 - val_loss: 0.4211 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0643 - accuracy: 1.0000 - val_loss: 0.4341 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.4524 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9824 - accuracy: 0.7500 - val_loss: 0.4483 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4058 - accuracy: 0.8750 - val_loss: 0.4301 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1956 - accuracy: 0.8750 - val_loss: 0.4105 - val_accuracy: 0.8846
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0562 - accuracy: 1.0000 - val_loss: 0.3984 - val_accuracy: 0.8846
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4951 - accuracy: 0.7500 - val_loss: 0.3856 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7325 - accuracy: 0.7500 - val_loss: 0.3706 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 0s/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_k = accuracy_score(y_pred, y_test)
dense_roc_k = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_k = precision_score(y_pred, y_test)
dense_rec_k = recall_score(y_pred, y_test)
dense_f1_k = f1_score(y_pred, y_test)
dense_mcc_k = matthews_corrcoef(y_pred, y_test)
dense_kap_k = cohen_kappa_score(y_pred, y_test)
dense_jacc_k = jaccard_score(y_pred, y_test)
dense_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - DenseNets',dense_acc_k,dense_roc_k,dense_prec_k,dense_rec_k,dense_f1_k,dense_mcc_k,dense_kap_k,dense_jacc_k,dense_gmea_k)
# Out:
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_32 (Conv1D)           (None, 609, 128)          384
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 304, 128)          0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 304, 128)          0
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 38912)             0
# _________________________________________________________________
# dense_32 (Dense)             (None, 2)                 77826
# =================================================================
# Total params: 78,210
# Trainable params: 78,210
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 142ms/step - loss: 0.6053 - accuracy: 0.8750 - val_loss: 0.4158 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4895 - accuracy: 0.8750 - val_loss: 0.4197 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1113 - accuracy: 1.0000 - val_loss: 0.5206 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6612 - accuracy: 0.8750 - val_loss: 0.6105 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 72ms/step - loss: 1.2553 - accuracy: 0.7500 - val_loss: 0.5787 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.5503 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 0.5395 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3358 - accuracy: 0.8750 - val_loss: 0.5286 - val_accuracy: 0.8846
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.8135 - accuracy: 0.8750 - val_loss: 0.5045 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5950 - accuracy: 0.8750 - val_loss: 0.4711 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8831 - accuracy: 0.8750 - val_loss: 0.4375 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0630 - accuracy: 1.0000 - val_loss: 0.4132 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3203 - accuracy: 0.8750 - val_loss: 0.3992 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1151 - accuracy: 1.0000 - val_loss: 0.3949 - val_accuracy: 0.8791
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1298 - accuracy: 1.0000 - val_loss: 0.3957 - val_accuracy: 0.8791
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1179 - accuracy: 1.0000 - val_loss: 0.3993 - val_accuracy: 0.8791
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9906 - accuracy: 0.6250 - val_loss: 0.3989 - val_accuracy: 0.8791
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1036 - accuracy: 1.0000 - val_loss: 0.4000 - val_accuracy: 0.8791
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1221 - accuracy: 1.0000 - val_loss: 0.4048 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4121 - accuracy: 0.8750 - val_loss: 0.4063 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # CLN-EXP-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_EXP_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1210), (907,), (161, 1210), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_l = accuracy_score(y_pred, y_test)
svm_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_l = precision_score(y_pred, y_test)
svm_rec_l = recall_score(y_pred, y_test)
svm_f1_l = f1_score(y_pred, y_test)
svm_mcc_l = matthews_corrcoef(y_pred, y_test)
svm_kap_l = cohen_kappa_score(y_pred, y_test)
svm_jacc_l = jaccard_score(y_pred, y_test)
svm_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - rbf',svm_acc_l,svm_roc_l,svm_prec_l,svm_rec_l,svm_f1_l,svm_mcc_l,svm_kap_l,svm_jacc_l,svm_gmea_l)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_l = accuracy_score(y_pred, y_test)
svm1_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_l = precision_score(y_pred, y_test)
svm1_rec_l = recall_score(y_pred, y_test)
svm1_f1_l = f1_score(y_pred, y_test)
svm1_mcc_l = matthews_corrcoef(y_pred, y_test)
svm1_kap_l = cohen_kappa_score(y_pred, y_test)
svm1_jacc_l = jaccard_score(y_pred, y_test)
svm1_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - Poly',svm1_acc_l,svm1_roc_l,svm1_prec_l,svm1_rec_l,svm1_f1_l,svm1_mcc_l,svm1_kap_l,svm1_jacc_l,svm1_gmea_l)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_l = accuracy_score(y_pred, y_test)
svm2_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_l = precision_score(y_pred, y_test)
svm2_rec_l = recall_score(y_pred, y_test)
svm2_f1_l = f1_score(y_pred, y_test)
svm2_mcc_l = matthews_corrcoef(y_pred, y_test)
svm2_kap_l = cohen_kappa_score(y_pred, y_test)
svm2_jacc_l = jaccard_score(y_pred, y_test)
svm2_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - Utility ',svm2_acc_l,svm2_roc_l,svm2_prec_l,svm2_rec_l,svm2_f1_l,svm2_mcc_l,svm2_kap_l,svm2_jacc_l,svm2_gmea_l)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_l = accuracy_score(y_pred, y_test)
svm3_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_l = precision_score(y_pred, y_test)
svm3_rec_l = recall_score(y_pred, y_test)
svm3_f1_l = f1_score(y_pred, y_test)
svm3_mcc_l = matthews_corrcoef(y_pred, y_test)
svm3_kap_l = cohen_kappa_score(y_pred, y_test)
svm3_jacc_l = jaccard_score(y_pred, y_test)
svm3_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - Linear ',svm3_acc_l,svm3_roc_l,svm3_prec_l,svm3_rec_l,svm3_f1_l,svm3_mcc_l,svm3_kap_l,svm3_jacc_l,svm3_gmea_l)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_l = accuracy_score(y_pred, y_test)
svm4_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_l = precision_score(y_pred, y_test)
svm4_rec_l = recall_score(y_pred, y_test)
svm4_f1_l = f1_score(y_pred, y_test)
svm4_mcc_l = matthews_corrcoef(y_pred, y_test)
svm4_kap_l = cohen_kappa_score(y_pred, y_test)
svm4_jacc_l = jaccard_score(y_pred, y_test)
svm4_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - Sigmoid',svm4_acc_l,svm4_roc_l,svm4_prec_l,svm4_rec_l,svm4_f1_l,svm4_mcc_l,svm4_kap_l,svm4_jacc_l,svm4_gmea_l)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_l = accuracy_score(y_pred, y_test)
rf_roc_l = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_l = precision_score(y_pred, y_test)
rf_rec_l = recall_score(y_pred, y_test)
rf_f1_l = f1_score(y_pred, y_test)
rf_mcc_l = matthews_corrcoef(y_pred, y_test)
rf_kap_l = cohen_kappa_score(y_pred, y_test)
rf_jacc_l = jaccard_score(y_pred, y_test)
rf_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - RF',rf_acc_l,rf_roc_l,rf_prec_l,rf_rec_l,rf_f1_l,rf_mcc_l,rf_kap_l,rf_jacc_l,rf_gmea_l)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_l = accuracy_score(y_pred, y_test)
dt_roc_l = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_l = precision_score(y_pred, y_test)
dt_rec_l = recall_score(y_pred, y_test)
dt_f1_l = f1_score(y_pred, y_test)
dt_mcc_l = matthews_corrcoef(y_pred, y_test)
dt_kap_l = cohen_kappa_score(y_pred, y_test)
dt_jacc_l = jaccard_score(y_pred, y_test)
dt_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - DT',dt_acc_l,dt_roc_l,dt_prec_l,dt_rec_l,dt_f1_l,dt_mcc_l,dt_kap_l,dt_jacc_l,dt_gmea_l)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_l = accuracy_score(y_pred, y_test)
nb_roc_l = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_l = precision_score(y_pred, y_test)
nb_rec_l = recall_score(y_pred, y_test)
nb_f1_l = f1_score(y_pred, y_test)
nb_mcc_l = matthews_corrcoef(y_pred, y_test)
nb_kap_l = cohen_kappa_score(y_pred, y_test)
nb_jacc_l = jaccard_score(y_pred, y_test)
nb_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - NB',nb_acc_l,nb_roc_l,nb_prec_l,nb_rec_l,nb_f1_l,nb_mcc_l,nb_kap_l,nb_jacc_l,nb_gmea_l)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_l = accuracy_score(y_pred, y_test)
vot_roc_l = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_l = precision_score(y_pred, y_test)
vot_rec_l = recall_score(y_pred, y_test)
vot_f1_l = f1_score(y_pred, y_test)
vot_mcc_l = matthews_corrcoef(y_pred, y_test)
vot_kap_l = cohen_kappa_score(y_pred, y_test)
vot_jacc_l = jaccard_score(y_pred, y_test)
vot_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - vot',vot_acc_l,vot_roc_l,vot_prec_l,vot_rec_l,vot_f1_l,vot_mcc_l,vot_kap_l,vot_jacc_l,vot_gmea_l)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_l = accuracy_score(y_pred, y_test)
vgg_roc_l = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_l = precision_score(y_pred, y_test)
vgg_rec_l = recall_score(y_pred, y_test)
vgg_f1_l = f1_score(y_pred, y_test)
vgg_mcc_l = matthews_corrcoef(y_pred, y_test)
vgg_kap_l = cohen_kappa_score(y_pred, y_test)
vgg_jacc_l = jaccard_score(y_pred, y_test)
vgg_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - VGGNets',vgg_acc_l,vgg_roc_l,vgg_prec_l,vgg_rec_l,vgg_f1_l,vgg_mcc_l,vgg_kap_l,vgg_jacc_l,vgg_gmea_l)
# Out:
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_33 (Conv1D)           (None, 1209, 128)         384
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 604, 128)          0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 604, 128)          0
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 77312)             0
# _________________________________________________________________
# dense_33 (Dense)             (None, 2)                 154626
# =================================================================
# Total params: 155,010
# Trainable params: 155,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 1s 290ms/step - loss: 0.5622 - accuracy: 0.5000 - val_loss: 11.3201 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 8.3830 - accuracy: 0.8750 - val_loss: 16.5682 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 81ms/step - loss: 48.3318 - accuracy: 0.7500 - val_loss: 15.5148 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 13.7846 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 5.8354 - accuracy: 0.8750 - val_loss: 11.7614 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 11.8973 - accuracy: 0.8750 - val_loss: 9.5410 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.2145 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 14.6692 - accuracy: 0.7500 - val_loss: 3.9196 - val_accuracy: 0.8901
# Epoch 9/20
# 2/2 [==============================] - 0s 82ms/step - loss: 7.0408 - accuracy: 0.8750 - val_loss: 4.9872 - val_accuracy: 0.3626
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 5.8271 - accuracy: 0.1250 - val_loss: 1.4066 - val_accuracy: 0.7033
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.7805 - accuracy: 0.7500 - val_loss: 3.2294 - val_accuracy: 0.8956
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.1761 - accuracy: 0.8750 - val_loss: 4.8946 - val_accuracy: 0.8956
# Epoch 13/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.2536 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 9.3603 - accuracy: 0.8750 - val_loss: 6.3599 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.4452 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.5140 - val_accuracy: 0.8956
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.5697 - val_accuracy: 0.8956
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 9.1622 - accuracy: 0.8750 - val_loss: 6.1509 - val_accuracy: 0.8956
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.3889 - val_accuracy: 0.8956
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 6.7258 - accuracy: 0.8750 - val_loss: 3.9221 - val_accuracy: 0.8956
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_l = accuracy_score(y_pred, y_test)
res_roc_l = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_l = precision_score(y_pred, y_test)
res_rec_l = recall_score(y_pred, y_test)
res_f1_l = f1_score(y_pred, y_test)
res_mcc_l = matthews_corrcoef(y_pred, y_test)
res_kap_l = cohen_kappa_score(y_pred, y_test)
res_jacc_l = jaccard_score(y_pred, y_test)
res_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - ResNets',res_acc_l,res_roc_l,res_prec_l,res_rec_l,res_f1_l,res_mcc_l,res_kap_l,res_jacc_l,res_gmea_l)
# Out:
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_34 (Conv1D)           (None, 1209, 128)         384
# _________________________________________________________________
# max_pooling1d_34 (MaxPooling (None, 604, 128)          0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 604, 128)          0
# _________________________________________________________________
# flatten_34 (Flatten)         (None, 77312)             0
# _________________________________________________________________
# dense_34 (Dense)             (None, 2)                 154626
# =================================================================
# Total params: 155,010
# Trainable params: 155,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 160ms/step - loss: 10.2172 - accuracy: 0.7500 - val_loss: 7.9458 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 8.1378 - accuracy: 0.8750 - val_loss: 7.2850 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.8280 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.8464 - accuracy: 0.8750 - val_loss: 5.9518 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.8031 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.8966 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.6155 - accuracy: 0.8750 - val_loss: 2.4879 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.1386 - accuracy: 0.8750 - val_loss: 3.1447 - val_accuracy: 0.6264
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.1708 - accuracy: 0.5000 - val_loss: 3.0388 - val_accuracy: 0.6593
# Epoch 10/20
# 2/2 [==============================] - 0s 82ms/step - loss: 3.9590 - accuracy: 0.6250 - val_loss: 1.7391 - val_accuracy: 0.8571
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.2880 - accuracy: 0.7500 - val_loss: 1.5286 - val_accuracy: 0.8626
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.8346 - accuracy: 0.8750 - val_loss: 1.3921 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.0024 - accuracy: 0.8750 - val_loss: 1.0703 - val_accuracy: 0.8077
# Epoch 14/20
# 2/2 [==============================] - 0s 81ms/step - loss: 2.2438 - accuracy: 0.5000 - val_loss: 0.9426 - val_accuracy: 0.8462
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 1.8292 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.9213e-04 - accuracy: 1.0000 - val_loss: 2.7945 - val_accuracy: 0.8956
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.5416 - accuracy: 0.8750 - val_loss: 3.0484 - val_accuracy: 0.8956
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 9.8228 - accuracy: 0.7500 - val_loss: 2.3284 - val_accuracy: 0.8956
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.9831 - accuracy: 0.7500 - val_loss: 3.5653 - val_accuracy: 0.3956
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.7801 - accuracy: 0.6250 - val_loss: 10.8718 - val_accuracy: 0.1264
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_l = accuracy_score(y_pred, y_test)
dense_roc_l = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_l = precision_score(y_pred, y_test)
dense_rec_l = recall_score(y_pred, y_test)
dense_f1_l = f1_score(y_pred, y_test)
dense_mcc_l = matthews_corrcoef(y_pred, y_test)
dense_kap_l = cohen_kappa_score(y_pred, y_test)
dense_jacc_l = jaccard_score(y_pred, y_test)
dense_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - DenseNets',dense_acc_l,dense_roc_l,dense_prec_l,dense_rec_l,dense_f1_l,dense_mcc_l,dense_kap_l,dense_jacc_l,dense_gmea_l)
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_35 (Conv1D)           (None, 1209, 128)         384
# _________________________________________________________________
# max_pooling1d_35 (MaxPooling (None, 604, 128)          0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 604, 128)          0
# _________________________________________________________________
# flatten_35 (Flatten)         (None, 77312)             0
# _________________________________________________________________
# dense_35 (Dense)             (None, 2)                 154626
# =================================================================
# Total params: 155,010
# Trainable params: 155,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 152ms/step - loss: 0.4481 - accuracy: 0.7500 - val_loss: 10.8401 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 14.6604 - accuracy: 0.8750 - val_loss: 12.6962 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 20.6883 - accuracy: 0.8750 - val_loss: 11.3191 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.2977 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.5096 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.8870 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.3878 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.9834 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 22.2138 - accuracy: 0.6250 - val_loss: 5.5601 - val_accuracy: 0.8956
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.6050 - accuracy: 0.8750 - val_loss: 1.9940 - val_accuracy: 0.8956
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 6.4632 - accuracy: 0.5000 - val_loss: 6.7910 - val_accuracy: 0.2033
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.5571 - accuracy: 0.5000 - val_loss: 1.3688 - val_accuracy: 0.8681
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1191 - accuracy: 0.8750 - val_loss: 3.3893 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.9802e-08 - accuracy: 1.0000 - val_loss: 5.0805 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.4637 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.5977 - val_accuracy: 0.8956
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.5290 - val_accuracy: 0.8956
# Epoch 18/20
# 2/2 [==============================] - 0s 75ms/step - loss: 27.8530 - accuracy: 0.6250 - val_loss: 7.6437 - val_accuracy: 0.8956
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 15.4731 - accuracy: 0.7500 - val_loss: 5.2513 - val_accuracy: 0.8956
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 7.0606 - accuracy: 0.8750 - val_loss: 2.2862 - val_accuracy: 0.8956
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # EXP-CNV-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(EXP_CNV_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1400), (907,), (161, 1400), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_m = accuracy_score(y_pred, y_test)
svm_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_m = precision_score(y_pred, y_test)
svm_rec_m = recall_score(y_pred, y_test)
svm_f1_m = f1_score(y_pred, y_test)
svm_mcc_m = matthews_corrcoef(y_pred, y_test)
svm_kap_m = cohen_kappa_score(y_pred, y_test)
svm_jacc_m = jaccard_score(y_pred, y_test)
svm_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - rbf',svm_acc_m,svm_roc_m,svm_prec_m,svm_rec_m,svm_f1_m,svm_mcc_m,svm_kap_m,svm_jacc_m,svm_gmea_m)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_m = accuracy_score(y_pred, y_test)
svm1_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_m = precision_score(y_pred, y_test)
svm1_rec_m = recall_score(y_pred, y_test)
svm1_f1_m = f1_score(y_pred, y_test)
svm1_mcc_m = matthews_corrcoef(y_pred, y_test)
svm1_kap_m = cohen_kappa_score(y_pred, y_test)
svm1_jacc_m = jaccard_score(y_pred, y_test)
svm1_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - Poly',svm1_acc_m,svm1_roc_m,svm1_prec_m,svm1_rec_m,svm1_f1_m,svm1_mcc_m,svm1_kap_m,svm1_jacc_m,svm1_gmea_m)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_m = accuracy_score(y_pred, y_test)
svm2_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_m = precision_score(y_pred, y_test)
svm2_rec_m = recall_score(y_pred, y_test)
svm2_f1_m = f1_score(y_pred, y_test)
svm2_mcc_m = matthews_corrcoef(y_pred, y_test)
svm2_kap_m = cohen_kappa_score(y_pred, y_test)
svm2_jacc_m = jaccard_score(y_pred, y_test)
svm2_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - Utility ',svm2_acc_m,svm2_roc_m,svm2_prec_m,svm2_rec_m,svm2_f1_m,svm2_mcc_m,svm2_kap_m,svm2_jacc_m,svm2_gmea_m)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_m = accuracy_score(y_pred, y_test)
svm3_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_m = precision_score(y_pred, y_test)
svm3_rec_m = recall_score(y_pred, y_test)
svm3_f1_m = f1_score(y_pred, y_test)
svm3_mcc_m = matthews_corrcoef(y_pred, y_test)
svm3_kap_m = cohen_kappa_score(y_pred, y_test)
svm3_jacc_m = jaccard_score(y_pred, y_test)
svm3_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - Linear ',svm3_acc_m,svm3_roc_m,svm3_prec_m,svm3_rec_m,svm3_f1_m,svm3_mcc_m,svm3_kap_m,svm3_jacc_m,svm3_gmea_m)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_m = accuracy_score(y_pred, y_test)
svm4_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_m = precision_score(y_pred, y_test)
svm4_rec_m = recall_score(y_pred, y_test)
svm4_f1_m = f1_score(y_pred, y_test)
svm4_mcc_m = matthews_corrcoef(y_pred, y_test)
svm4_kap_m = cohen_kappa_score(y_pred, y_test)
svm4_jacc_m = jaccard_score(y_pred, y_test)
svm4_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - Sigmoid',svm4_acc_m,svm4_roc_m,svm4_prec_m,svm4_rec_m,svm4_f1_m,svm4_mcc_m,svm4_kap_m,svm4_jacc_m,svm4_gmea_m)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_m = accuracy_score(y_pred, y_test)
rf_roc_m = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_m = precision_score(y_pred, y_test)
rf_rec_m = recall_score(y_pred, y_test)
rf_f1_m = f1_score(y_pred, y_test)
rf_mcc_m = matthews_corrcoef(y_pred, y_test)
rf_kap_m = cohen_kappa_score(y_pred, y_test)
rf_jacc_m = jaccard_score(y_pred, y_test)
rf_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - RF',rf_acc_m,rf_roc_m,rf_prec_m,rf_rec_m,rf_f1_m,rf_mcc_m,rf_kap_m,rf_jacc_m,rf_gmea_m)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_m = accuracy_score(y_pred, y_test)
dt_roc_m = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_m = precision_score(y_pred, y_test)
dt_rec_m = recall_score(y_pred, y_test)
dt_f1_m = f1_score(y_pred, y_test)
dt_mcc_m = matthews_corrcoef(y_pred, y_test)
dt_kap_m = cohen_kappa_score(y_pred, y_test)
dt_jacc_m = jaccard_score(y_pred, y_test)
dt_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - DT',dt_acc_m,dt_roc_m,dt_prec_m,dt_rec_m,dt_f1_m,dt_mcc_m,dt_kap_m,dt_jacc_m,dt_gmea_m)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_m = accuracy_score(y_pred, y_test)
nb_roc_m = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_m = precision_score(y_pred, y_test)
nb_rec_m = recall_score(y_pred, y_test)
nb_f1_m = f1_score(y_pred, y_test)
nb_mcc_m = matthews_corrcoef(y_pred, y_test)
nb_kap_m = cohen_kappa_score(y_pred, y_test)
nb_jacc_m = jaccard_score(y_pred, y_test)
nb_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - NB',nb_acc_m,nb_roc_m,nb_prec_m,nb_rec_m,nb_f1_m,nb_mcc_m,nb_kap_m,nb_jacc_m,nb_gmea_m)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_m = accuracy_score(y_pred, y_test)
vot_roc_m = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_m = precision_score(y_pred, y_test)
vot_rec_m = recall_score(y_pred, y_test)
vot_f1_m = f1_score(y_pred, y_test)
vot_mcc_m = matthews_corrcoef(y_pred, y_test)
vot_kap_m = cohen_kappa_score(y_pred, y_test)
vot_jacc_m = jaccard_score(y_pred, y_test)
vot_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - vot',vot_acc_m,vot_roc_m,vot_prec_m,vot_rec_m,vot_f1_m,vot_mcc_m,vot_kap_m,vot_jacc_m,vot_gmea_m)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_m = accuracy_score(y_pred, y_test)
vgg_roc_m = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_m = precision_score(y_pred, y_test)
vgg_rec_m = recall_score(y_pred, y_test)
vgg_f1_m = f1_score(y_pred, y_test)
vgg_mcc_m = matthews_corrcoef(y_pred, y_test)
vgg_kap_m = cohen_kappa_score(y_pred, y_test)
vgg_jacc_m = jaccard_score(y_pred, y_test)
vgg_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - VGGNets',vgg_acc_m,vgg_roc_m,vgg_prec_m,vgg_rec_m,vgg_f1_m,vgg_mcc_m,vgg_kap_m,vgg_jacc_m,vgg_gmea_m)
# Out:
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_36 (Conv1D)           (None, 1399, 128)         384
# _________________________________________________________________
# max_pooling1d_36 (MaxPooling (None, 699, 128)          0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 699, 128)          0
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 89472)             0
# _________________________________________________________________
# dense_36 (Dense)             (None, 2)                 178946
# =================================================================
# Total params: 179,330
# Trainable params: 179,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 165ms/step - loss: 9.6166 - accuracy: 0.7500 - val_loss: 5.7205 - val_accuracy: 0.9231
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 10.0336 - accuracy: 0.8750 - val_loss: 3.8426 - val_accuracy: 0.9231
# Epoch 3/20
# 2/2 [==============================] - 0s 72ms/step - loss: 3.1453 - accuracy: 0.8750 - val_loss: 2.0427 - val_accuracy: 0.9231
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.6077e-06 - accuracy: 1.0000 - val_loss: 0.9922 - val_accuracy: 0.6484
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.6241 - accuracy: 0.6250 - val_loss: 0.7514 - val_accuracy: 0.9121
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.6363 - val_accuracy: 0.9231
# Epoch 7/20
# 2/2 [==============================] - 0s 74ms/step - loss: 3.9495 - accuracy: 0.8750 - val_loss: 3.7292 - val_accuracy: 0.9231
# Epoch 8/20
# 2/2 [==============================] - 0s 81ms/step - loss: 4.1951 - accuracy: 0.8750 - val_loss: 3.8190 - val_accuracy: 0.9231
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 10.7142 - accuracy: 0.7500 - val_loss: 2.0277 - val_accuracy: 0.9231
# Epoch 10/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.2594 - accuracy: 0.8750 - val_loss: 3.0231 - val_accuracy: 0.4945
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.3612 - accuracy: 0.1250 - val_loss: 1.5639 - val_accuracy: 0.8736
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1634 - accuracy: 0.8750 - val_loss: 2.6484 - val_accuracy: 0.9231
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 13.9600 - accuracy: 0.5000 - val_loss: 1.7938 - val_accuracy: 0.9231
# Epoch 14/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 1.7223 - val_accuracy: 0.6648
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.1156 - accuracy: 0.2500 - val_loss: 1.1286 - val_accuracy: 0.8791
# Epoch 16/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0962 - accuracy: 0.8750 - val_loss: 2.1176 - val_accuracy: 0.9231
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.1097 - accuracy: 0.8750 - val_loss: 2.8189 - val_accuracy: 0.9231
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.3804 - accuracy: 0.8750 - val_loss: 2.6962 - val_accuracy: 0.9231
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.8505 - accuracy: 0.8750 - val_loss: 2.0889 - val_accuracy: 0.9231
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.1109 - accuracy: 0.8750 - val_loss: 1.2550 - val_accuracy: 0.9121
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_m = accuracy_score(y_pred, y_test)
res_roc_m = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_m = precision_score(y_pred, y_test)
res_rec_m = recall_score(y_pred, y_test)
res_f1_m = f1_score(y_pred, y_test)
res_mcc_m = matthews_corrcoef(y_pred, y_test)
res_kap_m = cohen_kappa_score(y_pred, y_test)
res_jacc_m = jaccard_score(y_pred, y_test)
res_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - ResNets',res_acc_m,res_roc_m,res_prec_m,res_rec_m,res_f1_m,res_mcc_m,res_kap_m,res_jacc_m,res_gmea_m)
# Out:
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_37 (Conv1D)           (None, 1399, 128)         384
# _________________________________________________________________
# max_pooling1d_37 (MaxPooling (None, 699, 128)          0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 699, 128)          0
# _________________________________________________________________
# flatten_37 (Flatten)         (None, 89472)             0
# _________________________________________________________________
# dense_37 (Dense)             (None, 2)                 178946
# =================================================================
# Total params: 179,330
# Trainable params: 179,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 149ms/step - loss: 12.6077 - accuracy: 0.5000 - val_loss: 6.0038 - val_accuracy: 0.9231
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 11.4212 - accuracy: 0.8750 - val_loss: 6.1330 - val_accuracy: 0.9231
# Epoch 3/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.4001 - val_accuracy: 0.9231
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.8293 - accuracy: 0.8750 - val_loss: 4.0877 - val_accuracy: 0.9231
# Epoch 5/20
# 2/2 [==============================] - 0s 74ms/step - loss: 3.0941 - accuracy: 0.8750 - val_loss: 2.4308 - val_accuracy: 0.8407
# Epoch 6/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8736 - accuracy: 0.8750 - val_loss: 4.3470 - val_accuracy: 0.5385
# Epoch 7/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.2712 - accuracy: 0.7500 - val_loss: 2.8508 - val_accuracy: 0.8077
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 6.8391 - accuracy: 0.7500 - val_loss: 3.1308 - val_accuracy: 0.6703
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.0420 - accuracy: 0.7500 - val_loss: 6.3762 - val_accuracy: 0.4451
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 3.3095 - accuracy: 0.6250 - val_loss: 2.8675 - val_accuracy: 0.6648
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 4.8275 - accuracy: 0.8750 - val_loss: 2.2649 - val_accuracy: 0.8626
# Epoch 12/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 2.1256 - val_accuracy: 0.9066
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.3257 - accuracy: 0.8750 - val_loss: 1.7912 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0773 - accuracy: 1.0000 - val_loss: 1.5044 - val_accuracy: 0.8791
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 8.7131 - accuracy: 0.5000 - val_loss: 4.3591 - val_accuracy: 0.3297
# Epoch 16/20
# 2/2 [==============================] - 0s 75ms/step - loss: 3.2510 - accuracy: 0.5000 - val_loss: 1.5167 - val_accuracy: 0.9231
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 6.9594 - accuracy: 0.6250 - val_loss: 1.8198 - val_accuracy: 0.9231
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.4881 - accuracy: 0.8750 - val_loss: 1.5242 - val_accuracy: 0.9231
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.5388 - accuracy: 0.8750 - val_loss: 0.8866 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1620 - accuracy: 0.8750 - val_loss: 1.7818 - val_accuracy: 0.6044
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_m = accuracy_score(y_pred, y_test)
dense_roc_m = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_m = precision_score(y_pred, y_test)
dense_rec_m = recall_score(y_pred, y_test)
dense_f1_m = f1_score(y_pred, y_test)
dense_mcc_m = matthews_corrcoef(y_pred, y_test)
dense_kap_m = cohen_kappa_score(y_pred, y_test)
dense_jacc_m = jaccard_score(y_pred, y_test)
dense_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - DenseNets',dense_acc_m,dense_roc_m,dense_prec_m,dense_rec_m,dense_f1_m,dense_mcc_m,dense_kap_m,dense_jacc_m,dense_gmea_m)
# Out:
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_38 (Conv1D)           (None, 1399, 128)         384
# _________________________________________________________________
# max_pooling1d_38 (MaxPooling (None, 699, 128)          0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 699, 128)          0
# _________________________________________________________________
# flatten_38 (Flatten)         (None, 89472)             0
# _________________________________________________________________
# dense_38 (Dense)             (None, 2)                 178946
# =================================================================
# Total params: 179,330
# Trainable params: 179,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 148ms/step - loss: 0.3472 - accuracy: 0.7500 - val_loss: 8.7819 - val_accuracy: 0.9231
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 13.7306 - val_accuracy: 0.9231
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 17.2388 - val_accuracy: 0.9231
# Epoch 4/20
# 2/2 [==============================] - 0s 73ms/step - loss: 91.3514 - accuracy: 0.6250 - val_loss: 14.6788 - val_accuracy: 0.9231
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 12.0588 - val_accuracy: 0.9231
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.0020 - val_accuracy: 0.9231
# Epoch 7/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.3612 - val_accuracy: 0.9231
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 24.0734 - accuracy: 0.7500 - val_loss: 5.4441 - val_accuracy: 0.9231
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 5.7138 - accuracy: 0.8750 - val_loss: 2.1163 - val_accuracy: 0.9231
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.7457 - accuracy: 0.8750 - val_loss: 15.5497 - val_accuracy: 0.0769
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 10.8287 - accuracy: 0.2500 - val_loss: 9.7312 - val_accuracy: 0.1484
# Epoch 12/20
# 2/2 [==============================] - 0s 77ms/step - loss: 5.7388 - accuracy: 0.5000 - val_loss: 2.3309 - val_accuracy: 0.9231
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 11.4830 - accuracy: 0.6250 - val_loss: 3.8895 - val_accuracy: 0.9231
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.5691 - val_accuracy: 0.9231
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 8.4085 - accuracy: 0.7500 - val_loss: 4.3363 - val_accuracy: 0.9231
# Epoch 16/20
# 2/2 [==============================] - 0s 82ms/step - loss: 6.4318 - accuracy: 0.7500 - val_loss: 3.6635 - val_accuracy: 0.9231
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9260 - val_accuracy: 0.9231
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 2.8831 - val_accuracy: 0.7637
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6492 - accuracy: 0.7500 - val_loss: 3.0639 - val_accuracy: 0.7527
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.2689 - accuracy: 0.8750 - val_loss: 3.2122 - val_accuracy: 0.7637
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # CNV-CLN-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CNV_CLN_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1010), (907,), (161, 1010), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_n = accuracy_score(y_pred, y_test)
svm_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_n = precision_score(y_pred, y_test)
svm_rec_n = recall_score(y_pred, y_test)
svm_f1_n = f1_score(y_pred, y_test)
svm_mcc_n = matthews_corrcoef(y_pred, y_test)
svm_kap_n = cohen_kappa_score(y_pred, y_test)
svm_jacc_n = jaccard_score(y_pred, y_test)
svm_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - rbf',svm_acc_n,svm_roc_n,svm_prec_n,svm_rec_n,svm_f1_n,svm_mcc_n,svm_kap_n,svm_jacc_n,svm_gmea_n)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_n = accuracy_score(y_pred, y_test)
svm1_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_n = precision_score(y_pred, y_test)
svm1_rec_n = recall_score(y_pred, y_test)
svm1_f1_n = f1_score(y_pred, y_test)
svm1_mcc_n = matthews_corrcoef(y_pred, y_test)
svm1_kap_n = cohen_kappa_score(y_pred, y_test)
svm1_jacc_n = jaccard_score(y_pred, y_test)
svm1_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - Poly',svm1_acc_n,svm1_roc_n,svm1_prec_n,svm1_rec_n,svm1_f1_n,svm1_mcc_n,svm1_kap_n,svm1_jacc_n,svm1_gmea_n)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_n = accuracy_score(y_pred, y_test)
svm2_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_n = precision_score(y_pred, y_test)
svm2_rec_n = recall_score(y_pred, y_test)
svm2_f1_n = f1_score(y_pred, y_test)
svm2_mcc_n = matthews_corrcoef(y_pred, y_test)
svm2_kap_n = cohen_kappa_score(y_pred, y_test)
svm2_jacc_n = jaccard_score(y_pred, y_test)
svm2_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - Utility ',svm2_acc_n,svm2_roc_n,svm2_prec_n,svm2_rec_n,svm2_f1_n,svm2_mcc_n,svm2_kap_n,svm2_jacc_n,svm2_gmea_n)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_n = accuracy_score(y_pred, y_test)
svm3_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_n = precision_score(y_pred, y_test)
svm3_rec_n = recall_score(y_pred, y_test)
svm3_f1_n = f1_score(y_pred, y_test)
svm3_mcc_n = matthews_corrcoef(y_pred, y_test)
svm3_kap_n = cohen_kappa_score(y_pred, y_test)
svm3_jacc_n = jaccard_score(y_pred, y_test)
svm3_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - Linear ',svm3_acc_n,svm3_roc_n,svm3_prec_n,svm3_rec_n,svm3_f1_n,svm3_mcc_n,svm3_kap_n,svm3_jacc_n,svm3_gmea_n)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_n = accuracy_score(y_pred, y_test)
svm4_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_n = precision_score(y_pred, y_test)
svm4_rec_n = recall_score(y_pred, y_test)
svm4_f1_n = f1_score(y_pred, y_test)
svm4_mcc_n = matthews_corrcoef(y_pred, y_test)
svm4_kap_n = cohen_kappa_score(y_pred, y_test)
svm4_jacc_n = jaccard_score(y_pred, y_test)
svm4_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - Sigmoid',svm4_acc_n,svm4_roc_n,svm4_prec_n,svm4_rec_n,svm4_f1_n,svm4_mcc_n,svm4_kap_n,svm4_jacc_n,svm4_gmea_n)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_n = accuracy_score(y_pred, y_test)
rf_roc_n = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_n = precision_score(y_pred, y_test)
rf_rec_n = recall_score(y_pred, y_test)
rf_f1_n = f1_score(y_pred, y_test)
rf_mcc_n = matthews_corrcoef(y_pred, y_test)
rf_kap_n = cohen_kappa_score(y_pred, y_test)
rf_jacc_n = jaccard_score(y_pred, y_test)
rf_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - RF',rf_acc_n,rf_roc_n,rf_prec_n,rf_rec_n,rf_f1_n,rf_mcc_n,rf_kap_n,rf_jacc_n,rf_gmea_n)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_n = accuracy_score(y_pred, y_test)
dt_roc_n = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_n = precision_score(y_pred, y_test)
dt_rec_n = recall_score(y_pred, y_test)
dt_f1_n = f1_score(y_pred, y_test)
dt_mcc_n = matthews_corrcoef(y_pred, y_test)
dt_kap_n = cohen_kappa_score(y_pred, y_test)
dt_jacc_n = jaccard_score(y_pred, y_test)
dt_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - DT',dt_acc_n,dt_roc_n,dt_prec_n,dt_rec_n,dt_f1_n,dt_mcc_n,dt_kap_n,dt_jacc_n,dt_gmea_n)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_n = accuracy_score(y_pred, y_test)
nb_roc_n = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_n = precision_score(y_pred, y_test)
nb_rec_n = recall_score(y_pred, y_test)
nb_f1_n = f1_score(y_pred, y_test)
nb_mcc_n = matthews_corrcoef(y_pred, y_test)
nb_kap_n = cohen_kappa_score(y_pred, y_test)
nb_jacc_n = jaccard_score(y_pred, y_test)
nb_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - NB',nb_acc_n,nb_roc_n,nb_prec_n,nb_rec_n,nb_f1_n,nb_mcc_n,nb_kap_n,nb_jacc_n,nb_gmea_n)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_n = accuracy_score(y_pred, y_test)
vot_roc_n = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_n = precision_score(y_pred, y_test)
vot_rec_n = recall_score(y_pred, y_test)
vot_f1_n = f1_score(y_pred, y_test)
vot_mcc_n = matthews_corrcoef(y_pred, y_test)
vot_kap_n = cohen_kappa_score(y_pred, y_test)
vot_jacc_n = jaccard_score(y_pred, y_test)
vot_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - vot',vot_acc_n,vot_roc_n,vot_prec_n,vot_rec_n,vot_f1_n,vot_mcc_n,vot_kap_n,vot_jacc_n,vot_gmea_n)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_n = accuracy_score(y_pred, y_test)
vgg_roc_n = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_n = precision_score(y_pred, y_test)
vgg_rec_n = recall_score(y_pred, y_test)
vgg_f1_n = f1_score(y_pred, y_test)
vgg_mcc_n = matthews_corrcoef(y_pred, y_test)
vgg_kap_n = cohen_kappa_score(y_pred, y_test)
vgg_jacc_n = jaccard_score(y_pred, y_test)
vgg_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - VGGNets',vgg_acc_n,vgg_roc_n,vgg_prec_n,vgg_rec_n,vgg_f1_n,vgg_mcc_n,vgg_kap_n,vgg_jacc_n,vgg_gmea_n)
# Out:
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_39 (Conv1D)           (None, 1009, 128)         384
# _________________________________________________________________
# max_pooling1d_39 (MaxPooling (None, 504, 128)          0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 504, 128)          0
# _________________________________________________________________
# flatten_39 (Flatten)         (None, 64512)             0
# _________________________________________________________________
# dense_39 (Dense)             (None, 2)                 129026
# =================================================================
# Total params: 129,410
# Trainable params: 129,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 160ms/step - loss: 8.7662 - accuracy: 0.5000 - val_loss: 8.8542 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 11.6356 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 15.6145 - accuracy: 0.8750 - val_loss: 12.3202 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 11.7403 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 11.2912 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.9357 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.6499 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 13.2444 - accuracy: 0.7500 - val_loss: 8.8851 - val_accuracy: 0.9011
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 6.6293 - accuracy: 0.8750 - val_loss: 6.5757 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 8.7915 - accuracy: 0.8750 - val_loss: 2.9135 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 3.7036 - accuracy: 0.8750 - val_loss: 12.4081 - val_accuracy: 0.1044
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 9.5847 - accuracy: 0.1250 - val_loss: 1.8857 - val_accuracy: 0.6264
# Epoch 13/20
# 2/2 [==============================] - 0s 81ms/step - loss: 2.7049 - accuracy: 0.6250 - val_loss: 3.5888 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 69ms/step - loss: 13.4752 - accuracy: 0.7500 - val_loss: 4.4608 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.6804 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 71ms/step - loss: 1.3114 - accuracy: 0.8750 - val_loss: 4.5541 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 83ms/step - loss: 4.4703e-08 - accuracy: 1.0000 - val_loss: 4.4501 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 81ms/step - loss: 4.6273 - accuracy: 0.8750 - val_loss: 3.6607 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 11.1441 - accuracy: 0.6250 - val_loss: 1.4516 - val_accuracy: 0.9066
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.4933 - accuracy: 0.6250 - val_loss: 3.0174 - val_accuracy: 0.4286
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 0s/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_n = accuracy_score(y_pred, y_test)
res_roc_n = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_n = precision_score(y_pred, y_test)
res_rec_n = recall_score(y_pred, y_test)
res_f1_n = f1_score(y_pred, y_test)
res_mcc_n = matthews_corrcoef(y_pred, y_test)
res_kap_n = cohen_kappa_score(y_pred, y_test)
res_jacc_n = jaccard_score(y_pred, y_test)
res_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - ResNets',res_acc_n,res_roc_n,res_prec_n,res_rec_n,res_f1_n,res_mcc_n,res_kap_n,res_jacc_n,res_gmea_n)
# Out:
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_40 (Conv1D)           (None, 1009, 128)         384
# _________________________________________________________________
# max_pooling1d_40 (MaxPooling (None, 504, 128)          0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 504, 128)          0
# _________________________________________________________________
# flatten_40 (Flatten)         (None, 64512)             0
# _________________________________________________________________
# dense_40 (Dense)             (None, 2)                 129026
# =================================================================
# Total params: 129,410
# Trainable params: 129,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 140ms/step - loss: 7.5567 - accuracy: 0.6250 - val_loss: 8.3195 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.7921 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 70ms/step - loss: 22.8108 - accuracy: 0.7500 - val_loss: 9.1562 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.1231 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.5656 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.3426 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.3411e-07 - accuracy: 1.0000 - val_loss: 3.3672 - val_accuracy: 0.9011
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.7571e-05 - accuracy: 1.0000 - val_loss: 2.5964 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2043 - accuracy: 0.8750 - val_loss: 3.1396 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 7.3688 - accuracy: 0.6250 - val_loss: 2.8910 - val_accuracy: 0.4945
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.0758 - accuracy: 0.5000 - val_loss: 1.9330 - val_accuracy: 0.8187
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7006 - accuracy: 0.8750 - val_loss: 2.0915 - val_accuracy: 0.8681
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 5.9324 - accuracy: 0.6250 - val_loss: 1.9043 - val_accuracy: 0.8297
# Epoch 14/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0716 - accuracy: 1.0000 - val_loss: 1.9515 - val_accuracy: 0.6868
# Epoch 15/20
# 2/2 [==============================] - 0s 78ms/step - loss: 5.2608 - accuracy: 0.5000 - val_loss: 1.8121 - val_accuracy: 0.8901
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 3.7805e-04 - accuracy: 1.0000 - val_loss: 1.9497 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 83ms/step - loss: 7.8797 - accuracy: 0.7500 - val_loss: 0.9395 - val_accuracy: 0.8242
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 4.1453 - accuracy: 0.2500 - val_loss: 1.8736 - val_accuracy: 0.5659
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.8514 - accuracy: 0.5000 - val_loss: 0.9532 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.3857 - accuracy: 0.8750 - val_loss: 1.5927 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_n = accuracy_score(y_pred, y_test)
dense_roc_n = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_n = precision_score(y_pred, y_test)
dense_rec_n = recall_score(y_pred, y_test)
dense_f1_n = f1_score(y_pred, y_test)
dense_mcc_n = matthews_corrcoef(y_pred, y_test)
dense_kap_n = cohen_kappa_score(y_pred, y_test)
dense_jacc_n = jaccard_score(y_pred, y_test)
dense_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - DenseNets',dense_acc_n,dense_roc_n,dense_prec_n,dense_rec_n,dense_f1_n,dense_mcc_n,dense_kap_n,dense_jacc_n,dense_gmea_n)
# Out:
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_41 (Conv1D)           (None, 1009, 128)         384
# _________________________________________________________________
# max_pooling1d_41 (MaxPooling (None, 504, 128)          0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 504, 128)          0
# _________________________________________________________________
# flatten_41 (Flatten)         (None, 64512)             0
# _________________________________________________________________
# dense_41 (Dense)             (None, 2)                 129026
# =================================================================
# Total params: 129,410
# Trainable params: 129,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 151ms/step - loss: 5.9150 - accuracy: 0.8750 - val_loss: 6.9167 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.6889 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.5298 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.4101 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.5359 - accuracy: 0.8750 - val_loss: 3.8396 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 8.0745 - accuracy: 0.7500 - val_loss: 2.3560 - val_accuracy: 0.6758
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.2223 - accuracy: 0.6250 - val_loss: 1.9227 - val_accuracy: 0.7363
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.5420 - accuracy: 0.8750 - val_loss: 2.0205 - val_accuracy: 0.8516
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 5.3641 - accuracy: 0.7500 - val_loss: 1.8479 - val_accuracy: 0.8571
# Epoch 10/20
# 2/2 [==============================] - 0s 73ms/step - loss: 4.7946 - accuracy: 0.7500 - val_loss: 1.0327 - val_accuracy: 0.8626
# Epoch 11/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 1.1936 - val_accuracy: 0.8956
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.1994 - accuracy: 0.7500 - val_loss: 2.0852 - val_accuracy: 0.5824
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.7195 - accuracy: 0.8750 - val_loss: 2.8677 - val_accuracy: 0.4780
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4856 - accuracy: 0.8750 - val_loss: 1.0529 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.9244e-05 - accuracy: 1.0000 - val_loss: 2.2042 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 85ms/step - loss: 1.8021 - accuracy: 0.8750 - val_loss: 2.7552 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.7958 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 6.6668 - accuracy: 0.7500 - val_loss: 1.5426 - val_accuracy: 0.8626
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.4387 - accuracy: 0.7500 - val_loss: 7.9147 - val_accuracy: 0.2637
# Epoch 20/20
# 2/2 [==============================] - 0s 74ms/step - loss: 11.4528 - accuracy: 0.2500 - val_loss: 2.0949 - val_accuracy: 0.7088
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # CLN-WSI-EXP-CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(multimodal, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1410), (907,), (161, 1410), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_o = accuracy_score(y_pred, y_test)
svm_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_o = precision_score(y_pred, y_test)
svm_rec_o = recall_score(y_pred, y_test)
svm_f1_o = f1_score(y_pred, y_test)
svm_mcc_o = matthews_corrcoef(y_pred, y_test)
svm_kap_o = cohen_kappa_score(y_pred, y_test)
svm_jacc_o = jaccard_score(y_pred, y_test)
svm_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - rbf',svm_acc_o,svm_roc_o,svm_prec_o,svm_rec_o,svm_f1_o,svm_mcc_o,svm_kap_o,svm_jacc_o,svm_gmea_o)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_o = accuracy_score(y_pred, y_test)
svm1_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_o = precision_score(y_pred, y_test)
svm1_rec_o = recall_score(y_pred, y_test)
svm1_f1_o = f1_score(y_pred, y_test)
svm1_mcc_o = matthews_corrcoef(y_pred, y_test)
svm1_kap_o = cohen_kappa_score(y_pred, y_test)
svm1_jacc_o = jaccard_score(y_pred, y_test)
svm1_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - Poly',svm1_acc_o,svm1_roc_o,svm1_prec_o,svm1_rec_o,svm1_f1_o,svm1_mcc_o,svm1_kap_o,svm1_jacc_o,svm1_gmea_o)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_o = accuracy_score(y_pred, y_test)
svm2_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_o = precision_score(y_pred, y_test)
svm2_rec_o = recall_score(y_pred, y_test)
svm2_f1_o = f1_score(y_pred, y_test)
svm2_mcc_o = matthews_corrcoef(y_pred, y_test)
svm2_kap_o = cohen_kappa_score(y_pred, y_test)
svm2_jacc_o = jaccard_score(y_pred, y_test)
svm2_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - Utility ',svm2_acc_o,svm2_roc_o,svm2_prec_o,svm2_rec_o,svm2_f1_o,svm2_mcc_o,svm2_kap_o,svm2_jacc_o,svm2_gmea_o)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_o = accuracy_score(y_pred, y_test)
svm3_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_o = precision_score(y_pred, y_test)
svm3_rec_o = recall_score(y_pred, y_test)
svm3_f1_o = f1_score(y_pred, y_test)
svm3_mcc_o = matthews_corrcoef(y_pred, y_test)
svm3_kap_o = cohen_kappa_score(y_pred, y_test)
svm3_jacc_o = jaccard_score(y_pred, y_test)
svm3_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - Linear ',svm3_acc_o,svm3_roc_o,svm3_prec_o,svm3_rec_o,svm3_f1_o,svm3_mcc_o,svm3_kap_o,svm3_jacc_o,svm3_gmea_o)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_o = accuracy_score(y_pred, y_test)
svm4_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_o = precision_score(y_pred, y_test)
svm4_rec_o = recall_score(y_pred, y_test)
svm4_f1_o = f1_score(y_pred, y_test)
svm4_mcc_o = matthews_corrcoef(y_pred, y_test)
svm4_kap_o = cohen_kappa_score(y_pred, y_test)
svm4_jacc_o = jaccard_score(y_pred, y_test)
svm4_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - Sigmoid',svm4_acc_o,svm4_roc_o,svm4_prec_o,svm4_rec_o,svm4_f1_o,svm4_mcc_o,svm4_kap_o,svm4_jacc_o,svm4_gmea_o)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_o = accuracy_score(y_pred, y_test)
rf_roc_o = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_o = precision_score(y_pred, y_test)
rf_rec_o = recall_score(y_pred, y_test)
rf_f1_o = f1_score(y_pred, y_test)
rf_mcc_o = matthews_corrcoef(y_pred, y_test)
rf_kap_o = cohen_kappa_score(y_pred, y_test)
rf_jacc_o = jaccard_score(y_pred, y_test)
rf_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - RF',rf_acc_o,rf_roc_o,rf_prec_o,rf_rec_o,rf_f1_o,rf_mcc_o,rf_kap_o,rf_jacc_o,rf_gmea_o)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_o = accuracy_score(y_pred, y_test)
dt_roc_o = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_o = precision_score(y_pred, y_test)
dt_rec_o = recall_score(y_pred, y_test)
dt_f1_o = f1_score(y_pred, y_test)
dt_mcc_o = matthews_corrcoef(y_pred, y_test)
dt_kap_o = cohen_kappa_score(y_pred, y_test)
dt_jacc_o = jaccard_score(y_pred, y_test)
dt_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - DT',dt_acc_o,dt_roc_o,dt_prec_o,dt_rec_o,dt_f1_o,dt_mcc_o,dt_kap_o,dt_jacc_o,dt_gmea_o)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_o = accuracy_score(y_pred, y_test)
nb_roc_o = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_o = precision_score(y_pred, y_test)
nb_rec_o = recall_score(y_pred, y_test)
nb_f1_o = f1_score(y_pred, y_test)
nb_mcc_o = matthews_corrcoef(y_pred, y_test)
nb_kap_o = cohen_kappa_score(y_pred, y_test)
nb_jacc_o = jaccard_score(y_pred, y_test)
nb_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - NB',nb_acc_o,nb_roc_o,nb_prec_o,nb_rec_o,nb_f1_o,nb_mcc_o,nb_kap_o,nb_jacc_o,nb_gmea_o)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_o = accuracy_score(y_pred, y_test)
vot_roc_o = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_o = precision_score(y_pred, y_test)
vot_rec_o = recall_score(y_pred, y_test)
vot_f1_o = f1_score(y_pred, y_test)
vot_mcc_o = matthews_corrcoef(y_pred, y_test)
vot_kap_o = cohen_kappa_score(y_pred, y_test)
vot_jacc_o = jaccard_score(y_pred, y_test)
vot_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV- vot',vot_acc_o,vot_roc_o,vot_prec_o,vot_rec_o,vot_f1_o,vot_mcc_o,vot_kap_o,vot_jacc_o,vot_gmea_o)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_o = accuracy_score(y_pred, y_test)
vgg_roc_o = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_o = precision_score(y_pred, y_test)
vgg_rec_o = recall_score(y_pred, y_test)
vgg_f1_o = f1_score(y_pred, y_test)
vgg_mcc_o = matthews_corrcoef(y_pred, y_test)
vgg_kap_o = cohen_kappa_score(y_pred, y_test)
vgg_jacc_o = jaccard_score(y_pred, y_test)
vgg_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - VGGNets',vgg_acc_o,vgg_roc_o,vgg_prec_o,vgg_rec_o,vgg_f1_o,vgg_mcc_o,vgg_kap_o,vgg_jacc_o,vgg_gmea_o)
# Out:
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_42 (Conv1D)           (None, 1409, 128)         384
# _________________________________________________________________
# max_pooling1d_42 (MaxPooling (None, 704, 128)          0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 704, 128)          0
# _________________________________________________________________
# flatten_42 (Flatten)         (None, 90112)             0
# _________________________________________________________________
# dense_42 (Dense)             (None, 2)                 180226
# =================================================================
# Total params: 180,610
# Trainable params: 180,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 165ms/step - loss: 1.3026 - accuracy: 0.5000 - val_loss: 7.4609 - val_accuracy: 0.9176
# Epoch 2/20
# 2/2 [==============================] - 0s 85ms/step - loss: 8.9488 - accuracy: 0.8750 - val_loss: 10.0022 - val_accuracy: 0.9176
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 22.3382 - accuracy: 0.8750 - val_loss: 10.9661 - val_accuracy: 0.9176
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 17.2778 - accuracy: 0.7500 - val_loss: 10.0398 - val_accuracy: 0.9176
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 18.0616 - accuracy: 0.8750 - val_loss: 8.2335 - val_accuracy: 0.9176
# Epoch 6/20
# 2/2 [==============================] - 0s 81ms/step - loss: 13.7000 - accuracy: 0.8750 - val_loss: 6.4505 - val_accuracy: 0.9176
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 27.9673 - accuracy: 0.6250 - val_loss: 3.6591 - val_accuracy: 0.9176
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 5.9369 - accuracy: 0.7500 - val_loss: 1.9336 - val_accuracy: 0.6429
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 5.3738 - accuracy: 0.2500 - val_loss: 6.9557 - val_accuracy: 0.2857
# Epoch 10/20
# 2/2 [==============================] - 0s 70ms/step - loss: 4.1841 - accuracy: 0.6250 - val_loss: 1.9965 - val_accuracy: 0.5549
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.2895 - accuracy: 0.5000 - val_loss: 1.9620 - val_accuracy: 0.9176
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.1404 - accuracy: 0.7500 - val_loss: 3.0759 - val_accuracy: 0.9176
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.8737 - accuracy: 0.8750 - val_loss: 3.5123 - val_accuracy: 0.9176
# Epoch 14/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.8655 - val_accuracy: 0.9176
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.1523 - val_accuracy: 0.9176
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.3860 - val_accuracy: 0.9176
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.5770 - val_accuracy: 0.9176
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 12.1224 - accuracy: 0.7500 - val_loss: 3.9944 - val_accuracy: 0.9176
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.5192 - val_accuracy: 0.9176
# Epoch 20/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.1307 - val_accuracy: 0.9176
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_o = accuracy_score(y_pred, y_test)
res_roc_o = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_o = precision_score(y_pred, y_test)
res_rec_o = recall_score(y_pred, y_test)
res_f1_o = f1_score(y_pred, y_test)
res_mcc_o = matthews_corrcoef(y_pred, y_test)
res_kap_o = cohen_kappa_score(y_pred, y_test)
res_jacc_o = jaccard_score(y_pred, y_test)
res_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - ResNets',res_acc_o,res_roc_o,res_prec_o,res_rec_o,res_f1_o,res_mcc_o,res_kap_o,res_jacc_o,res_gmea_o)
# Out:
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_43 (Conv1D)           (None, 1409, 128)         384
# _________________________________________________________________
# max_pooling1d_43 (MaxPooling (None, 704, 128)          0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 704, 128)          0
# _________________________________________________________________
# flatten_43 (Flatten)         (None, 90112)             0
# _________________________________________________________________
# dense_43 (Dense)             (None, 2)                 180226
# =================================================================
# Total params: 180,610
# Trainable params: 180,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1460 - accuracy: 1.0000 - val_loss: 7.9697 - val_accuracy: 0.9176
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 12.4228 - val_accuracy: 0.9176
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 28.9780 - accuracy: 0.8750 - val_loss: 13.7080 - val_accuracy: 0.9176
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 10.9812 - accuracy: 0.8750 - val_loss: 11.6914 - val_accuracy: 0.9176
# Epoch 5/20
# 2/2 [==============================] - 0s 75ms/step - loss: 34.4035 - accuracy: 0.7500 - val_loss: 8.1986 - val_accuracy: 0.9176
# Epoch 6/20
# 2/2 [==============================] - 0s 74ms/step - loss: 16.6070 - accuracy: 0.8750 - val_loss: 3.9557 - val_accuracy: 0.9176
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 7.8626 - accuracy: 0.8750 - val_loss: 3.7307 - val_accuracy: 0.1978
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 6.3494 - accuracy: 0.0000e+00 - val_loss: 0.6757 - val_accuracy: 0.8187
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9096 - accuracy: 0.7500 - val_loss: 1.2653 - val_accuracy: 0.9176
# Epoch 10/20
# 2/2 [==============================] - 0s 64ms/step - loss: 5.1236 - accuracy: 0.7500 - val_loss: 0.9123 - val_accuracy: 0.9121
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.0413e-04 - accuracy: 1.0000 - val_loss: 0.9484 - val_accuracy: 0.8407
# Epoch 12/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5899 - accuracy: 0.8750 - val_loss: 2.3255 - val_accuracy: 0.5879
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 2.3316 - accuracy: 0.6250 - val_loss: 3.3791 - val_accuracy: 0.4121
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6457 - accuracy: 0.8750 - val_loss: 1.0086 - val_accuracy: 0.8297
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.6750 - accuracy: 0.7500 - val_loss: 1.0344 - val_accuracy: 0.8352
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 2.4907 - accuracy: 0.6250 - val_loss: 1.0172 - val_accuracy: 0.8022
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3765 - accuracy: 0.7500 - val_loss: 1.0969 - val_accuracy: 0.7473
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1110 - accuracy: 0.8750 - val_loss: 1.1466 - val_accuracy: 0.7198
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.0573 - accuracy: 0.7500 - val_loss: 1.1810 - val_accuracy: 0.9176
# Epoch 20/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.7444 - accuracy: 0.8750 - val_loss: 1.3413 - val_accuracy: 0.9176
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_o = accuracy_score(y_pred, y_test)
dense_roc_o = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_o = precision_score(y_pred, y_test)
dense_rec_o = recall_score(y_pred, y_test)
dense_f1_o = f1_score(y_pred, y_test)
dense_mcc_o = matthews_corrcoef(y_pred, y_test)
dense_kap_o = cohen_kappa_score(y_pred, y_test)
dense_jacc_o = jaccard_score(y_pred, y_test)
dense_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - DenseNets',dense_acc_o,dense_roc_o,dense_prec_o,dense_rec_o,dense_f1_o,dense_mcc_o,dense_kap_o,dense_jacc_o,dense_gmea_o)
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_44 (Conv1D)           (None, 1409, 128)         384
# _________________________________________________________________
# max_pooling1d_44 (MaxPooling (None, 704, 128)          0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 704, 128)          0
# _________________________________________________________________
# flatten_44 (Flatten)         (None, 90112)             0
# _________________________________________________________________
# dense_44 (Dense)             (None, 2)                 180226
# =================================================================
# Total params: 180,610
# Trainable params: 180,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.7129 - accuracy: 0.6250 - val_loss: 7.5606 - val_accuracy: 0.9176
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 11.8556 - val_accuracy: 0.9176
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 14.8970 - val_accuracy: 0.9176
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 51.2581 - accuracy: 0.7500 - val_loss: 14.5555 - val_accuracy: 0.9176
# Epoch 5/20
# 2/2 [==============================] - 0s 80ms/step - loss: 52.4366 - accuracy: 0.7500 - val_loss: 11.9467 - val_accuracy: 0.9176
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 17.6883 - accuracy: 0.8750 - val_loss: 9.5350 - val_accuracy: 0.9176
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.2907 - val_accuracy: 0.9176
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 20.9336 - accuracy: 0.7500 - val_loss: 4.8613 - val_accuracy: 0.9176
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 5.4132 - accuracy: 0.8750 - val_loss: 1.8903 - val_accuracy: 0.9176
# Epoch 10/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 6.3234 - val_accuracy: 0.0769
# Epoch 11/20
# 2/2 [==============================] - 0s 70ms/step - loss: 5.3456 - accuracy: 0.0000e+00 - val_loss: 1.1708 - val_accuracy: 0.9176
# Epoch 12/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.2415 - val_accuracy: 0.9176
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 7.8340 - accuracy: 0.8750 - val_loss: 4.6293 - val_accuracy: 0.9176
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 6.5400 - accuracy: 0.7500 - val_loss: 5.1133 - val_accuracy: 0.9176
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 21.1228 - accuracy: 0.7500 - val_loss: 4.5638 - val_accuracy: 0.9176
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 12.3916 - accuracy: 0.7500 - val_loss: 3.4632 - val_accuracy: 0.9176
# Epoch 17/20
# 2/2 [==============================] - 0s 70ms/step - loss: 15.6612 - accuracy: 0.6250 - val_loss: 1.4278 - val_accuracy: 0.8736
# Epoch 18/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7258 - accuracy: 0.6250 - val_loss: 4.1109 - val_accuracy: 0.3956
# Epoch 19/20
# 2/2 [==============================] - 0s 70ms/step - loss: 5.5162 - accuracy: 0.2500 - val_loss: 1.7770 - val_accuracy: 0.6154
# Epoch 20/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7528 - accuracy: 0.7500 - val_loss: 1.3373 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # Comparison

# %%
#creating dataframe
result = pd.DataFrame({ 'ML Model' : ML_Model,
                        'Accuracy' : accuracy,
                        'ROC score' : roc,
                        'Precision': precision,
                        'Recall'   : recall,
                        'F1-Score': f1score,
                        'MCC' : mcc,
                        'Kappa Score' : kappa,
                       'Jaccard Score' : jacc,
                       'G-Measure' : gmea
                      })

# %%
result
# Out:
#                         ML Model  Accuracy  ROC score  Precision  Recall  \
# 0                CLN - SVM - rbf     0.919      0.681      1.000   0.919
# 1               CLN - SVM - Poly     0.919      0.734      1.000   0.919
# 2           CLN - SVM - Utility      0.857      0.278      0.899   0.943
# 3            CLN - SVM - Linear      0.919      0.431      1.000   0.919
# 4            CLN - SVM - Sigmoid     0.845      0.594      0.912   0.918
# ..                           ...       ...        ...        ...     ...
# 175         CLN-WSI-EXP-CNV - NB     0.807      0.632      0.837   0.955
# 176         CLN-WSI-EXP-CNV- vot     0.950      0.420      1.000   0.950
# 177    CLN-WSI-EXP-CNV - VGGNets     0.950      0.487      1.000   0.950
# 178    CLN-WSI-EXP-CNV - ResNets     0.938      0.596      0.987   0.950
# 179  CLN-WSI-EXP-CNV - DenseNets     0.919      0.599      0.967   0.949
#
#      F1-Score    MCC  Kappa Score  Jaccard Score  G-Measure
# 0       0.958  0.000        0.000          0.919      0.983
# 1       0.958  0.000        0.000          0.919      0.983
# 2       0.920  0.234        0.227          0.853      0.907
# 3       0.958  0.000        0.000          0.919      0.983
# 4       0.915 -0.011       -0.011          0.844      0.913
# ..        ...    ...          ...            ...        ...
# 175     0.892  0.050        0.041          0.805      0.858
# 176     0.975  0.000        0.000          0.950      0.990
# 177     0.975  0.000        0.000          0.950      0.990
# 178     0.968 -0.026       -0.020          0.938      0.979
# 179     0.958 -0.041       -0.040          0.919      0.964
#
# [180 rows x 10 columns]

# %%
print(result.to_string())
# Out:
#                              ML Model  Accuracy  ROC score  Precision  Recall  F1-Score    MCC  Kappa Score  Jaccard Score  G-Measure
# 0                     CLN - SVM - rbf     0.919      0.681      1.000   0.919     0.958  0.000        0.000          0.919      0.983
# 1                    CLN - SVM - Poly     0.919      0.734      1.000   0.919     0.958  0.000        0.000          0.919      0.983
# 2                CLN - SVM - Utility      0.857      0.278      0.899   0.943     0.920  0.234        0.227          0.853      0.907
# 3                 CLN - SVM - Linear      0.919      0.431      1.000   0.919     0.958  0.000        0.000          0.919      0.983
# 4                 CLN - SVM - Sigmoid     0.845      0.594      0.912   0.918     0.915 -0.011       -0.011          0.844      0.913
# 5                            CLN - RF     0.913      0.772      0.973   0.935     0.954  0.272        0.258          0.911      0.965
# 6                            CLN - DT     0.888      0.731      0.919   0.958     0.938  0.386        0.378          0.883      0.926
# 7                            CLN - NB     0.863      0.574      0.932   0.920     0.926  0.010        0.010          0.862      0.930
# 8                           CLN - vot     0.925      0.781      0.973   0.947     0.960  0.424        0.416          0.923      0.968
# 9                       CLN - VGGNets     0.919      0.559      1.000   0.919     0.958  0.000        0.000          0.919      0.983
# 10                      CLN - ResNets     0.919      0.607      1.000   0.919     0.958  0.000        0.000          0.919      0.983
# 11                    CLN - DenseNets     0.919      0.620      1.000   0.919     0.958  0.000        0.000          0.919      0.983
# 12                    WSI - SVM - rbf     0.938      0.578      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 13                   WSI - SVM - Poly     0.938      0.652      1.000   0.938     0.968  0.000        0.000          0.938      0.983
# 14               WSI - SVM - Utility      0.919      0.416      0.980   0.937     0.958 -0.035       -0.030          0.919      0.971
# 15                WSI - SVM - Linear      0.839      0.579      0.881   0.943     0.911  0.059        0.055          0.836      0.893
# 16                WSI - SVM - Sigmoid     0.919      0.442      0.980   0.937     0.958 -0.035       -0.030          0.919      0.971
# 17                           WSI - RF     0.938      0.569      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 18                           WSI - DT     0.814      0.527      0.854   0.942     0.896  0.037        0.033          0.811      0.870
# 19                           WSI - NB     0.714      0.603      0.728   0.957     0.827  0.122        0.085          0.705      0.765
# 20                           WSI- vot     0.938      0.540      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 21                      WSI - VGGNets     0.851      0.433      0.907   0.932     0.919 -0.079       -0.078          0.851      0.912
# 22                      WSI - ResNets     0.938      0.531      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 23                    WSI - DenseNets     0.938      0.500      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 24                    EXP - SVM - rbf     0.913      0.551      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 25                   EXP - SVM - Poly     0.913      0.616      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 26               EXP - SVM - Utility      0.913      0.535      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 27                EXP - SVM - Linear      0.807      0.448      0.871   0.914     0.892  0.011        0.011          0.805      0.879
# 28                EXP - SVM - Sigmoid     0.913      0.581      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 29                           EXP - RF     0.913      0.598      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 30                           EXP - DT     0.795      0.532      0.850   0.919     0.883  0.050        0.048          0.791      0.863
# 31                           EXP - NB     0.404      0.496      0.381   0.918     0.538  0.014        0.006          0.368      0.431
# 32                          EXP - vot     0.913      0.563      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 33                      EXP - VGGNets     0.913      0.442      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 34                      EXP - ResNets     0.913      0.447      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 35                    EXP - DenseNets     0.913      0.468      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 36                    CNV - SVM - rbf     0.925      0.573      1.000   0.925     0.961  0.000        0.000          0.925      0.984
# 37                   CNV - SVM - Poly     0.901      0.582      0.966   0.929     0.947  0.069        0.065          0.900      0.959
# 38               CNV - SVM - Utility      0.814      0.448      0.866   0.928     0.896  0.025        0.023          0.811      0.878
# 39                CNV - SVM - Linear      0.925      0.629      1.000   0.925     0.961  0.000        0.000          0.925      0.984
# 40                CNV - SVM - Sigmoid     0.913      0.540      0.980   0.930     0.954  0.107        0.091          0.912      0.969
# 41                           CNV - RF     0.907      0.577      0.973   0.929     0.951  0.086        0.077          0.906      0.964
# 42                           CNV - DT     0.826      0.476      0.879   0.929     0.903  0.037        0.035          0.824      0.889
# 43                           CNV - NB     0.752      0.733      0.772   0.950     0.852  0.165        0.131          0.742      0.802
# 44                          CNV - vot     0.901      0.550      0.966   0.929     0.947  0.069        0.065          0.900      0.959
# 45                      CNV - VGGNets     0.925      0.546      1.000   0.925     0.961  0.000        0.000          0.925      0.984
# 46                      CNV - ResNets     0.925      0.539      1.000   0.925     0.961  0.000        0.000          0.925      0.984
# 47                    CNV - DenseNets     0.925      0.681      1.000   0.925     0.961  0.000        0.000          0.925      0.984
# 48                CLN-EXP - SVM - rbf     0.901      0.500      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 49               CLN-EXP - SVM - Poly     0.901      0.619      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 50           CLN-EXP - SVM - Utility      0.901      0.601      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 51            CLN-EXP - SVM - Linear      0.758      0.522      0.807   0.914     0.857  0.088        0.081          0.750      0.826
# 52                EXP - SVM - Sigmoid     0.901      0.439      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 53                       CLN-EXP - RF     0.901      0.635      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 54                       CLN-EXP - DT     0.826      0.486      0.910   0.898     0.904 -0.029       -0.029          0.825      0.908
# 55                       CLN-EXP - NB     0.547      0.588      0.538   0.929     0.681  0.098        0.060          0.517      0.587
# 56                      CLN-EXP - vot     0.901      0.553      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 57                  CLN-EXP - VGGNets     0.901      0.421      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 58                  CLN-EXP - ResNets     0.901      0.355      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 59                CLN-EXP - DenseNets     0.901      0.380      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 60                CLN-CNV - SVM - rbf     0.901      0.506      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 61               CLN-CNV - SVM - Poly     0.888      0.523      0.979   0.904     0.940  0.080        0.063          0.888      0.963
# 62           CLN-CNV - SVM - Utility      0.764      0.375      0.800   0.928     0.859  0.171        0.153          0.753      0.823
# 63            CLN-CNV - SVM - Linear      0.882      0.543      0.979   0.899     0.937 -0.046       -0.032          0.882      0.962
# 64            CLN-CNV - SVM - Sigmoid     0.845      0.508      0.931   0.900     0.915 -0.008       -0.008          0.844      0.925
# 65                       CLN-CNV - RF     0.901      0.641      0.993   0.906     0.947  0.150        0.091          0.900      0.974
# 66                       CLN-CNV - DT     0.857      0.587      0.924   0.918     0.921  0.179        0.179          0.854      0.923
# 67                       CLN-CNV - NB     0.627      0.482      0.662   0.897     0.762 -0.016       -0.012          0.615      0.699
# 68                      CLN-CNV - vot     0.907      0.624      0.993   0.911     0.950  0.261        0.185          0.906      0.976
# 69                  CLN-CNV - VGGNets     0.901      0.466      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 70                  CLN-CNV - ResNets     0.901      0.470      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 71                CLN-CNV - DenseNets     0.901      0.472      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 72                CLN-WSI - SVM - rbf     0.894      0.341      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 73               CLN-WSI - SVM - Poly     0.894      0.431      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 74           CLN-WSI - SVM - Utility      0.870      0.519      0.972   0.892     0.930 -0.055       -0.042          0.870      0.955
# 75            CLN-WSI - SVM - Linear      0.795      0.440      0.882   0.888     0.885 -0.058       -0.058          0.794      0.883
# 76            CLN-WSI - SVM - Sigmoid     0.870      0.422      0.972   0.892     0.930 -0.055       -0.042          0.870      0.955
# 77                       CLN-WSI - RF     0.894      0.603      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 78                       CLN-WSI - DT     0.814      0.507      0.896   0.896     0.896  0.013        0.013          0.811      0.896
# 79                       CLN-WSI - NB     0.571      0.394      0.611   0.871     0.718 -0.098       -0.073          0.561      0.650
# 80                      CLN-WSI - vot     0.894      0.595      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 81                  CLN-WSI - VGGNets     0.894      0.500      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 82                  CLN-WSI - ResNets     0.410      0.414      0.417   0.845     0.558 -0.143       -0.080          0.387      0.464
# 83                CLN-WSI - DenseNets     0.894      0.472      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 84                EXP-CNV - SVM - rbf     0.932      0.608      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 85               EXP-CNV - SVM - Poly     0.932      0.697      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 86           EXP-CNV - SVM - Utility      0.932      0.611      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 87            EXP-CNV - SVM - Linear      0.789      0.465      0.847   0.920     0.882 -0.111       -0.102          0.789      0.860
# 88            EXP-CNV - SVM - Sigmoid     0.932      0.499      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 89                       EXP-CNV - RF     0.932      0.683      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 90                       EXP-CNV - DT     0.807      0.518      0.853   0.934     0.892  0.025        0.023          0.805      0.868
# 91                       EXP-CNV - NB     0.584      0.655      0.580   0.956     0.722  0.110        0.062          0.565      0.630
# 92                      EXP-CNV - vot     0.925      0.685      0.993   0.931     0.961 -0.021       -0.012          0.925      0.980
# 93                  EXP-CNV - VGGNets     0.919      0.351      0.987   0.931     0.958 -0.030       -0.021          0.919      0.975
# 94                  EXP-CNV - ResNets     0.932      0.393      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 95                EXP-CNV - DenseNets     0.932      0.395      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 96                EXP-WSI - SVM - rbf     0.907      0.468      1.000   0.907     0.951  0.000        0.000          0.907      0.980
# 97               EXP-WSI - SVM - Poly     0.907      0.361      1.000   0.907     0.951  0.000        0.000          0.907      0.980
# 98           EXP-WSI - SVM - Utility      0.894      0.509      0.986   0.906     0.944 -0.036       -0.022          0.894      0.969
# 99            EXP-WSI - SVM - Linear      0.857      0.534      0.938   0.907     0.923  0.006        0.006          0.856      0.932
# 100           EXP-WSI - SVM - Sigmoid     0.894      0.520      0.986   0.906     0.944 -0.036       -0.022          0.894      0.969
# 101                      EXP-WSI - RF     0.907      0.546      1.000   0.907     0.951  0.000        0.000          0.907      0.980
# 102                      EXP-WSI - DT     0.870      0.424      0.952   0.908     0.930  0.025        0.024          0.869      0.943
# 103                      EXP-WSI - NB     0.627      0.429      0.671   0.891     0.766 -0.080       -0.062          0.620      0.706
# 104                     EXP-WSI - vot     0.907      0.603      1.000   0.907     0.951  0.000        0.000          0.907      0.980
# 105                 EXP-WSI - VGGNets     0.907      0.448      1.000   0.907     0.951  0.000        0.000          0.907      0.980
# 106                 EXP-WSI - ResNets     0.907      0.525      1.000   0.907     0.951  0.000        0.000          0.907      0.980
# 107               EXP-WSI - DenseNets     0.907      0.515      1.000   0.907     0.951  0.000        0.000          0.907      0.980
# 108               CNV-WSI - SVM - rbf     0.882      0.439      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 109              CNV-WSI - SVM - Poly     0.882      0.564      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 110          CNV-WSI - SVM - Utility      0.876      0.456      0.993   0.881     0.934 -0.029       -0.012          0.876      0.968
# 111           CNV-WSI - SVM - Linear      0.789      0.416      0.887   0.875     0.881 -0.063       -0.063          0.788      0.885
# 112           CNV-WSI - SVM - Sigmoid     0.876      0.537      0.993   0.881     0.934 -0.029       -0.012          0.876      0.968
# 113                      CNV-WSI - RF     0.882      0.590      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 114                      CNV-WSI - DT     0.839      0.543      0.923   0.897     0.910  0.148        0.146          0.834      0.917
# 115                      CNV-WSI - NB     0.727      0.717      0.761   0.915     0.831  0.171        0.151          0.711      0.787
# 116                     CNV-WSI - vot     0.882      0.587      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 117                 CNV-WSI - VGGNets     0.882      0.500      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 118                 EXP-CNV - ResNets     0.615      0.588      0.648   0.885     0.748  0.011        0.009          0.597      0.685
# 119               EXP-CNV - DenseNets     0.882      0.500      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 120           CLN-EXP-CNV - SVM - rbf     0.894      0.558      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 121          CLN-EXP-CNV - SVM - Poly     0.894      0.586      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 122      CLN-EXP-CNV - SVM - Utility      0.894      0.563      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 123       CLN-EXP-CNV - SVM - Linear      0.776      0.574      0.833   0.909     0.870  0.102        0.097          0.769      0.847
# 124       CLN-EXP-CNV - SVM - Sigmoid     0.894      0.573      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 125                  CLN-EXP-CNV - RF     0.894      0.614      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 126                  CLN-EXP-CNV - DT     0.857      0.609      0.924   0.917     0.920  0.224        0.224          0.853      0.922
# 127                  CLN-EXP-CNV - NB     0.553      0.627      0.569   0.891     0.695 -0.012       -0.008          0.532      0.614
# 128                 CLN-EXP-CNV - vot     0.888      0.651      0.986   0.899     0.940  0.102        0.071          0.888      0.967
# 129             CLN-EXP-CNV - VGGNets     0.894      0.464      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 130             CLN-EXP-CNV - ResNets     0.888      0.597      0.993   0.894     0.941 -0.027       -0.012          0.888      0.971
# 131           CLN-EXP-CNV - DenseNets     0.894      0.463      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 132           CLN-EXP-WSI - SVM - rbf     0.894      0.458      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 133          CLN-EXP-WSI - SVM - Poly     0.894      0.476      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 134      CLN-EXP-WSI - SVM - Utility      0.888      0.427      0.993   0.894     0.941 -0.027       -0.012          0.888      0.971
# 135       CLN-EXP-WSI - SVM - Linear      0.820      0.565      0.882   0.914     0.898  0.158        0.156          0.814      0.888
# 136       CLN-EXP-WSI - SVM - Sigmoid     0.901      0.535      1.000   0.900     0.947  0.230        0.101          0.900      0.978
# 137                  CLN-EXP-WSI - RF     0.894      0.387      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 138                  CLN-EXP-WSI - DT     0.801      0.552      0.868   0.906     0.887  0.091        0.089          0.796      0.875
# 139                  CLN-EXP-WSI - NB     0.677      0.473      0.722   0.897     0.800  0.011        0.009          0.667      0.751
# 140                 CLN-EXP-WSI - vot     0.894      0.406      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 141             CLN-EXP-WSI - VGGNets     0.894      0.483      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 142             CLN-EXP-WSI - ResNets     0.155      0.522      0.062   0.900     0.117  0.005        0.001          0.062      0.077
# 143           CLN-EXP-WSI - DenseNets     0.894      0.535      1.000   0.894     0.944  0.000        0.000          0.894      0.977
# 144           EXP-CNV-WSI - SVM - rbf     0.913      0.484      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 145          EXP-CNV-WSI - SVM - Poly     0.913      0.560      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 146      EXP-CNV-WSI - SVM - Utility      0.907      0.569      0.993   0.912     0.951 -0.024       -0.012          0.907      0.976
# 147       EXP-CNV-WSI - SVM - Linear      0.851      0.492      0.918   0.918     0.918  0.061        0.061          0.849      0.918
# 148       EXP-CNV-WSI - SVM - Sigmoid     0.901      0.345      0.986   0.912     0.948 -0.035       -0.022          0.901      0.971
# 149                  EXP-CNV-WSI - RF     0.913      0.549      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 150                  EXP-CNV-WSI - DT     0.795      0.468      0.864   0.907     0.885 -0.054       -0.053          0.794      0.872
# 151                  EXP-CNV-WSI - NB     0.652      0.453      0.687   0.910     0.783 -0.017       -0.013          0.643      0.722
# 152                 EXP-CNV-WSI - vot     0.913      0.527      1.000   0.913     0.955  0.000        0.000          0.913      0.981
# 153             EXP-CNV-WSI - VGGNets     0.901      0.651      0.986   0.912     0.948 -0.035       -0.022          0.901      0.971
# 154             EXP-CNV-WSI - ResNets     0.720      0.644      0.741   0.940     0.829  0.152        0.121          0.708      0.774
# 155           EXP-CNV-WSI - DenseNets     0.764      0.596      0.823   0.910     0.864 -0.025       -0.023          0.761      0.839
# 156           CNV-CLN-WSI - SVM - rbf     0.932      0.479      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 157          CNV-CLN-WSI - SVM - Poly     0.932      0.566      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 158      CNV-CLN-WSI - SVM - Utility      0.901      0.445      0.967   0.929     0.948 -0.048       -0.045          0.901      0.959
# 159       CNV-CLN-WSI - SVM - Linear      0.807      0.541      0.860   0.928     0.893 -0.036       -0.034          0.806      0.873
# 160       CNV-CLN-WSI - SVM - Sigmoid     0.932      0.475      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 161                  CNV-CLN-WSI - RF     0.932      0.480      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 162                  CNV-CLN-WSI - DT     0.870      0.509      0.927   0.933     0.930  0.017        0.017          0.869      0.928
# 163                  CNV-CLN-WSI - NB     0.727      0.707      0.740   0.957     0.835  0.160        0.117          0.716      0.775
# 164                 CNV-CLN-WSI - vot     0.932      0.430      1.000   0.932     0.965  0.000        0.000          0.932      0.986
# 165             CNV-CLN-WSI - VGGNets     0.441      0.598      0.427   0.941     0.587  0.032        0.014          0.416      0.479
# 166             CNV-CLN-WSI - ResNets     0.925      0.511      0.993   0.931     0.961 -0.021       -0.012          0.925      0.980
# 167           CNV-CLN-WSI - DenseNets     0.714      0.511      0.753   0.926     0.831 -0.038       -0.030          0.711      0.783
# 168       CLN-WSI-EXP-CNV - SVM - rbf     0.950      0.444      1.000   0.950     0.975  0.000        0.000          0.950      0.990
# 169      CLN-WSI-EXP-CNV - SVM - Poly     0.950      0.519      1.000   0.950     0.975  0.000        0.000          0.950      0.990
# 170  CLN-WSI-EXP-CNV - SVM - Utility      0.925      0.512      0.974   0.949     0.961 -0.036       -0.034          0.925      0.969
# 171   CLN-WSI-EXP-CNV - SVM - Linear      0.863      0.455      0.908   0.946     0.927 -0.071       -0.068          0.863      0.916
# 172   CLN-WSI-EXP-CNV - SVM - Sigmoid     0.938      0.656      0.987   0.950     0.968 -0.026       -0.020          0.938      0.979
# 173              CLN-WSI-EXP-CNV - RF     0.950      0.432      1.000   0.950     0.975  0.000        0.000          0.950      0.990
# 174              CLN-WSI-EXP-CNV - DT     0.882      0.583      0.922   0.953     0.937  0.037        0.036          0.881      0.928
# 175              CLN-WSI-EXP-CNV - NB     0.807      0.632      0.837   0.955     0.892  0.050        0.041          0.805      0.858
# 176              CLN-WSI-EXP-CNV- vot     0.950      0.420      1.000   0.950     0.975  0.000        0.000          0.950      0.990
# 177         CLN-WSI-EXP-CNV - VGGNets     0.950      0.487      1.000   0.950     0.975  0.000        0.000          0.950      0.990
# 178         CLN-WSI-EXP-CNV - ResNets     0.938      0.596      0.987   0.950     0.968 -0.026       -0.020          0.938      0.979
# 179       CLN-WSI-EXP-CNV - DenseNets     0.919      0.599      0.967   0.949     0.958 -0.041       -0.040          0.919      0.964

# %%
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, accuracy, align='center', alpha=0.5,color='blue')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Accuracy Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# Modelling - CLN with 10 features for frontend

# %%
X = pd.DataFrame(CLN)

# %%
y = pd.DataFrame(y_multimodal)

# %%
X.to_csv('x.csv')
y.to_csv('y.csv')

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X,y)
# Out:
# VotingClassifier(estimators=[('ab', RandomForestClassifier(random_state=0)),
#                              ('rf', SVC(probability=True)),
#                              ('dt', DecisionTreeClassifier(max_depth=30))],
#                  voting='soft')

# %%
pred = eclf1.predict(X)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred,y)
# Out:
# 0.9953183520599251

# %%
import joblib
filename = 'model_.sav'
joblib.dump(eclf1, filename)
# Out:
# ['model_.sav']
