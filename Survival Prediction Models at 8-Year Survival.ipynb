# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Create 2 virtual GPUs with 1GB memory each
  try:
    tf.config.set_logical_device_configuration(
        gpus[0],
        [tf.config.LogicalDeviceConfiguration(memory_limit=1024),
         tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPU,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPU, 2 Logical GPUs

# %%
import numpy as np, pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import os,math,pickle
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate,cross_val_predict,StratifiedKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix,roc_auc_score
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# %%
path = 'data/'

# %%
# hyper-parameters of the utility kernel
c = 100
K_0 = 0.1
K_1 = 10
Alpha = 5

# number of PCA features by fixing the variance of 95%
NumComponents = 0.95

# number of samples of minority classes at various survival cut-offs
long_data_num_5yr = 204
long_data_num_6yr = 584
long_data_num_7yr = 187
long_data_num_8yr = 127
long_data_num_9yr = 102

# %%
# various survival cut-offs csv files
survival_file_name_5yr = 'class_5_year.csv'
survival_file_name_6yr = 'class_6_year.csv'
survival_file_name_7yr = 'class_7_year.csv'
survival_file_name_8yr = 'class_8_year.csv'
survival_file_name_9yr = 'class_9_year.csv'

# %%
#change for each survival year cutoff
long_data_num = long_data_num_8yr
survival_file_name = survival_file_name_8yr

# %%
def data_sampler(long_data,short_data):
	#subsampling the long data
	df = pd.DataFrame(long_data)
	long_data=df.sample(n = long_data_num)

	#generating balanced class data for training
	data = np.vstack((long_data,short_data))
	#print(data.shape)
	return data

# %%
#define utility kernel
def utility_kernel(X, Y):
    k_0 =K_0
    k_1 = K_1
    alpha = Alpha
    kernel_value = k_0+np.multiply(k_1,np.power((np.dot(X, Y.T)),alpha))
    return kernel_value

# %%
def my_pca(data,numComponents):
	#Applying PCA with 95% explained_variance_ratio_
	plt.style.use('ggplot')
	pca = PCA(n_components=numComponents, random_state=42)
	pca.fit(data) 
	data = pca.transform(data)
	plt.plot(np.cumsum(pca.explained_variance_ratio_))
	plt.xlabel('number of components')
	plt.ylabel('Explained variance')
	plt.savefig(os.path.join(path,'elbow_plot_multimodal.png'),dpi=100)
	return data

# %%
def ncr(n, r):
    r = min(r, n-r)
    numer = reduce(op.mul, range(n, n-r, -1), 1)
    denom = reduce(op.mul, range(1, r+1), 1)
    return numer // denom

# %%
CLN = np.loadtxt(os.path.join(path,'tcga_cln_final.csv'), delimiter=",")
WSI = np.loadtxt(os.path.join(path,'tcga_allWSIpatchfused.csv'), delimiter=",")
EXP = np.loadtxt(os.path.join(path,'tcga_exp_final.csv'), delimiter=",")
CNV = np.loadtxt(os.path.join(path,'tcga_cnv_final.csv'), delimiter=",")
CLN_EXP    = np.concatenate((CLN,EXP),axis=1)
CLN_CNV    = np.concatenate((CLN,CNV),axis=1)
CLN_WSI    = np.concatenate((CLN,WSI),axis=1)
EXP_CNV    = np.concatenate((EXP,CNV),axis=1)
EXP_WSI    = np.concatenate((EXP,WSI),axis=1)
CNV_WSI    = np.concatenate((CNV,WSI),axis=1)
CLN_EXP_CNV     = np.concatenate((CLN,EXP,CNV),axis=1)
CLN_EXP_WSI     = np.concatenate((CLN,EXP,WSI),axis=1)
EXP_CNV_WSI     = np.concatenate((EXP,CNV,WSI),axis=1)
CNV_CLN_WSI     = np.concatenate((CNV,CLN,WSI),axis=1)
multimodal     = np.concatenate((WSI,CLN,CNV,EXP),axis=1)
y_multimodal 	  = np.loadtxt(os.path.join(path, survival_file_name))

# %%
y_multimodal
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
import seaborn as sns
sns.countplot(x=y_multimodal)

# %%
from sklearn.metrics import roc_auc_score, matthews_corrcoef, cohen_kappa_score, accuracy_score, precision_score, recall_score, f1_score,jaccard_score,fbeta_score

# %%
ML_Model = []
accuracy = []
roc = []
precision = []
recall = []
f1score = []
mcc = []
kappa = []
jacc = []
gmea = []

#function to call for storing the results
def storeResults(model, a,b,c,d,e,f,g,h,i):
    ML_Model.append(model)
    accuracy.append(round(a, 3))
    roc.append(round(b, 3))
    precision.append(round(c, 3))
    recall.append(round(d, 3))
    f1score.append(round(e,3))
    mcc.append(round(f,3))
    kappa.append(round(g,3))
    jacc.append(round(h,3))
    gmea.append(round(i,3))

# %% [markdown]
# # CLN

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 10), (907,), (161, 10), (161,))

# %% [markdown]
# # SVM - RBF

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_a = accuracy_score(y_pred, y_test)
svm_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_a = precision_score(y_pred, y_test)
svm_rec_a = recall_score(y_pred, y_test)
svm_f1_a = f1_score(y_pred, y_test)
svm_mcc_a = matthews_corrcoef(y_pred, y_test)
svm_kap_a = cohen_kappa_score(y_pred, y_test)
svm_jacc_a = jaccard_score(y_pred, y_test)
svm_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - rbf',svm_acc_a,svm_roc_a,svm_prec_a,svm_rec_a,svm_f1_a,svm_mcc_a,svm_kap_a,svm_jacc_a,svm_gmea_a)

# %% [markdown]
# # SVM - Poly

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_a = accuracy_score(y_pred, y_test)
svm1_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_a = precision_score(y_pred, y_test)
svm1_rec_a = recall_score(y_pred, y_test)
svm1_f1_a = f1_score(y_pred, y_test)
svm1_mcc_a = matthews_corrcoef(y_pred, y_test)
svm1_kap_a = cohen_kappa_score(y_pred, y_test)
svm1_jacc_a = jaccard_score(y_pred, y_test)
svm1_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - Poly',svm1_acc_a,svm1_roc_a,svm1_prec_a,svm1_rec_a,svm1_f1_a,svm1_mcc_a,svm1_kap_a,svm1_jacc_a,svm1_gmea_a)

# %% [markdown]
# # SVM - Utility Kerenl

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_a = accuracy_score(y_pred, y_test)
svm2_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_a = precision_score(y_pred, y_test)
svm2_rec_a = recall_score(y_pred, y_test)
svm2_f1_a = f1_score(y_pred, y_test)
svm2_mcc_a = matthews_corrcoef(y_pred, y_test)
svm2_kap_a = cohen_kappa_score(y_pred, y_test)
svm2_jacc_a = jaccard_score(y_pred, y_test)
svm2_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - Utility ',svm2_acc_a,svm2_roc_a,svm2_prec_a,svm2_rec_a,svm2_f1_a,svm2_mcc_a,svm2_kap_a,svm2_jacc_a,svm2_gmea_a)

# %% [markdown]
# # SVC - Linear

# %%
clf = SVC(kernel ='linear',probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_a = accuracy_score(y_pred, y_test)
svm3_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_a = precision_score(y_pred, y_test)
svm3_rec_a = recall_score(y_pred, y_test)
svm3_f1_a = f1_score(y_pred, y_test)
svm3_mcc_a = matthews_corrcoef(y_pred, y_test)
svm3_kap_a = cohen_kappa_score(y_pred, y_test)
svm3_jacc_a = jaccard_score(y_pred, y_test)
svm3_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - Linear ',svm3_acc_a,svm3_roc_a,svm3_prec_a,svm3_rec_a,svm3_f1_a,svm3_mcc_a,svm3_kap_a,svm3_jacc_a,svm3_gmea_a)

# %% [markdown]
# # SVC - Sigmoid

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_a = accuracy_score(y_pred, y_test)
svm4_roc_a = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_a = precision_score(y_pred, y_test)
svm4_rec_a = recall_score(y_pred, y_test)
svm4_f1_a = f1_score(y_pred, y_test)
svm4_mcc_a = matthews_corrcoef(y_pred, y_test)
svm4_kap_a = cohen_kappa_score(y_pred, y_test)
svm4_jacc_a = jaccard_score(y_pred, y_test)
svm4_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - SVM - Sigmoid',svm4_acc_a,svm4_roc_a,svm4_prec_a,svm4_rec_a,svm4_f1_a,svm4_mcc_a,svm4_kap_a,svm4_jacc_a,svm4_gmea_a)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_a = accuracy_score(y_pred, y_test)
rf_roc_a = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_a = precision_score(y_pred, y_test)
rf_rec_a = recall_score(y_pred, y_test)
rf_f1_a = f1_score(y_pred, y_test)
rf_mcc_a = matthews_corrcoef(y_pred, y_test)
rf_kap_a = cohen_kappa_score(y_pred, y_test)
rf_jacc_a = jaccard_score(y_pred, y_test)
rf_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - RF',rf_acc_a,rf_roc_a,rf_prec_a,rf_rec_a,rf_f1_a,rf_mcc_a,rf_kap_a,rf_jacc_a,rf_gmea_a)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_a = accuracy_score(y_pred, y_test)
dt_roc_a = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_a = precision_score(y_pred, y_test)
dt_rec_a = recall_score(y_pred, y_test)
dt_f1_a = f1_score(y_pred, y_test)
dt_mcc_a = matthews_corrcoef(y_pred, y_test)
dt_kap_a = cohen_kappa_score(y_pred, y_test)
dt_jacc_a = jaccard_score(y_pred, y_test)
dt_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - DT',dt_acc_a,dt_roc_a,dt_prec_a,dt_rec_a,dt_f1_a,dt_mcc_a,dt_kap_a,dt_jacc_a,dt_gmea_a)

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_a = accuracy_score(y_pred, y_test)
nb_roc_a = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_a = precision_score(y_pred, y_test)
nb_rec_a = recall_score(y_pred, y_test)
nb_f1_a = f1_score(y_pred, y_test)
nb_mcc_a = matthews_corrcoef(y_pred, y_test)
nb_kap_a = cohen_kappa_score(y_pred, y_test)
nb_jacc_a = jaccard_score(y_pred, y_test)
nb_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - NB',nb_acc_a,nb_roc_a,nb_prec_a,nb_rec_a,nb_f1_a,nb_mcc_a,nb_kap_a,nb_jacc_a,nb_gmea_a)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_a = accuracy_score(y_pred, y_test)
vot_roc_a = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_a = precision_score(y_pred, y_test)
vot_rec_a = recall_score(y_pred, y_test)
vot_f1_a = f1_score(y_pred, y_test)
vot_mcc_a = matthews_corrcoef(y_pred, y_test)
vot_kap_a = cohen_kappa_score(y_pred, y_test)
vot_jacc_a = jaccard_score(y_pred, y_test)
vot_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - vot',vot_acc_a,vot_roc_a,vot_prec_a,vot_rec_a,vot_f1_a,vot_mcc_a,vot_kap_a,vot_jacc_a,vot_gmea_a)

# %% [markdown]
# # DL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %% [markdown]
# # VGGNets

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 9, 128)            384
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 4, 128)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 128)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 1026
# =================================================================
# Total params: 1,410
# Trainable params: 1,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 3s 195ms/step - loss: 0.6878 - accuracy: 0.7500 - val_loss: 0.6627 - val_accuracy: 0.8681
# Epoch 2/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.6458 - accuracy: 0.8750 - val_loss: 0.6228 - val_accuracy: 0.8791
# Epoch 3/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.5769 - accuracy: 1.0000 - val_loss: 0.5859 - val_accuracy: 0.8791
# Epoch 4/20
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5200 - accuracy: 1.0000 - val_loss: 0.5521 - val_accuracy: 0.8791
# Epoch 5/20
# 2/2 [==============================] - 0s 151ms/step - loss: 0.5182 - accuracy: 0.8750 - val_loss: 0.5227 - val_accuracy: 0.8791
# Epoch 6/20
# 2/2 [==============================] - 0s 167ms/step - loss: 0.5059 - accuracy: 0.8750 - val_loss: 0.4967 - val_accuracy: 0.8791
# Epoch 7/20
# 2/2 [==============================] - 0s 151ms/step - loss: 0.4189 - accuracy: 1.0000 - val_loss: 0.4735 - val_accuracy: 0.8791
# Epoch 8/20
# 2/2 [==============================] - 0s 123ms/step - loss: 0.4567 - accuracy: 0.8750 - val_loss: 0.4530 - val_accuracy: 0.8791
# Epoch 9/20
# 2/2 [==============================] - 0s 108ms/step - loss: 0.3033 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.8791
# Epoch 10/20
# 2/2 [==============================] - 0s 112ms/step - loss: 0.2841 - accuracy: 1.0000 - val_loss: 0.4192 - val_accuracy: 0.8791
# Epoch 11/20
# 2/2 [==============================] - 0s 101ms/step - loss: 0.2806 - accuracy: 1.0000 - val_loss: 0.4054 - val_accuracy: 0.8791
# Epoch 12/20
# 2/2 [==============================] - 0s 97ms/step - loss: 0.5572 - accuracy: 0.7500 - val_loss: 0.3966 - val_accuracy: 0.8791
# Epoch 13/20
# 2/2 [==============================] - 0s 101ms/step - loss: 0.2059 - accuracy: 1.0000 - val_loss: 0.3889 - val_accuracy: 0.8791
# Epoch 14/20
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5661 - accuracy: 0.7500 - val_loss: 0.3837 - val_accuracy: 0.8791
# Epoch 15/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.3966 - accuracy: 0.8750 - val_loss: 0.3799 - val_accuracy: 0.8791
# Epoch 16/20
# 2/2 [==============================] - 0s 109ms/step - loss: 0.6323 - accuracy: 0.7500 - val_loss: 0.3776 - val_accuracy: 0.8791
# Epoch 17/20
# 2/2 [==============================] - 0s 109ms/step - loss: 0.4301 - accuracy: 0.8750 - val_loss: 0.3765 - val_accuracy: 0.8791
# Epoch 18/20
# 2/2 [==============================] - 0s 114ms/step - loss: 0.9816 - accuracy: 0.6250 - val_loss: 0.3767 - val_accuracy: 0.8791
# Epoch 19/20
# 2/2 [==============================] - 0s 115ms/step - loss: 0.3696 - accuracy: 0.8750 - val_loss: 0.3771 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 116ms/step - loss: 0.1701 - accuracy: 1.0000 - val_loss: 0.3767 - val_accuracy: 0.8791

# %%
# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

# %%
cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_a = accuracy_score(y_pred, y_test)
vgg_roc_a = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_a = precision_score(y_pred, y_test)
vgg_rec_a = recall_score(y_pred, y_test)
vgg_f1_a = f1_score(y_pred, y_test)
vgg_mcc_a = matthews_corrcoef(y_pred, y_test)
vgg_kap_a = cohen_kappa_score(y_pred, y_test)
vgg_jacc_a = jaccard_score(y_pred, y_test)
vgg_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - VGGNets',vgg_acc_a,vgg_roc_a,vgg_prec_a,vgg_rec_a,vgg_f1_a,vgg_mcc_a,vgg_kap_a,vgg_jacc_a,vgg_gmea_a)
# Out:
# 6/6 [==============================] - 0s 5ms/step
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # ResNets

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_a = accuracy_score(y_pred, y_test)
res_roc_a = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_a = precision_score(y_pred, y_test)
res_rec_a = recall_score(y_pred, y_test)
res_f1_a = f1_score(y_pred, y_test)
res_mcc_a = matthews_corrcoef(y_pred, y_test)
res_kap_a = cohen_kappa_score(y_pred, y_test)
res_jacc_a = jaccard_score(y_pred, y_test)
res_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - ResNets',res_acc_a,res_roc_a,res_prec_a,res_rec_a,res_f1_a,res_mcc_a,res_kap_a,res_jacc_a,res_gmea_a)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 9, 128)            384
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 4, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 128)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 1,410
# Trainable params: 1,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 247ms/step - loss: 0.6605 - accuracy: 0.7500 - val_loss: 0.6319 - val_accuracy: 0.8791
# Epoch 2/20
# 2/2 [==============================] - 0s 163ms/step - loss: 0.6375 - accuracy: 0.8750 - val_loss: 0.5986 - val_accuracy: 0.8791
# Epoch 3/20
# 2/2 [==============================] - 0s 166ms/step - loss: 0.6626 - accuracy: 0.7500 - val_loss: 0.5731 - val_accuracy: 0.8791
# Epoch 4/20
# 2/2 [==============================] - 0s 138ms/step - loss: 0.6215 - accuracy: 0.7500 - val_loss: 0.5504 - val_accuracy: 0.8791
# Epoch 5/20
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5586 - accuracy: 0.8750 - val_loss: 0.5292 - val_accuracy: 0.8791
# Epoch 6/20
# 2/2 [==============================] - 0s 109ms/step - loss: 0.4373 - accuracy: 1.0000 - val_loss: 0.5076 - val_accuracy: 0.8791
# Epoch 7/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5196 - accuracy: 0.8750 - val_loss: 0.4867 - val_accuracy: 0.8791
# Epoch 8/20
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5082 - accuracy: 0.8750 - val_loss: 0.4681 - val_accuracy: 0.8791
# Epoch 9/20
# 2/2 [==============================] - 0s 115ms/step - loss: 0.3583 - accuracy: 1.0000 - val_loss: 0.4507 - val_accuracy: 0.8791
# Epoch 10/20
# 2/2 [==============================] - 0s 113ms/step - loss: 0.4301 - accuracy: 0.8750 - val_loss: 0.4353 - val_accuracy: 0.8791
# Epoch 11/20
# 2/2 [==============================] - 0s 110ms/step - loss: 0.3459 - accuracy: 1.0000 - val_loss: 0.4207 - val_accuracy: 0.8791
# Epoch 12/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2960 - accuracy: 1.0000 - val_loss: 0.4073 - val_accuracy: 0.8791
# Epoch 13/20
# 2/2 [==============================] - 0s 62ms/step - loss: 0.4201 - accuracy: 0.8750 - val_loss: 0.3972 - val_accuracy: 0.8791
# Epoch 14/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3816 - accuracy: 0.8750 - val_loss: 0.3893 - val_accuracy: 0.8791
# Epoch 15/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5661 - accuracy: 0.7500 - val_loss: 0.3847 - val_accuracy: 0.8791
# Epoch 16/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3837 - accuracy: 0.8750 - val_loss: 0.3805 - val_accuracy: 0.8791
# Epoch 17/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1859 - accuracy: 1.0000 - val_loss: 0.3770 - val_accuracy: 0.8791
# Epoch 18/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1671 - accuracy: 1.0000 - val_loss: 0.3739 - val_accuracy: 0.8791
# Epoch 19/20
# 2/2 [==============================] - 0s 61ms/step - loss: 0.3988 - accuracy: 0.8750 - val_loss: 0.3720 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1694 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 4ms/step

# %% [markdown]
# # DesNet

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_a = accuracy_score(y_pred, y_test)
dense_roc_a = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_a = precision_score(y_pred, y_test)
dense_rec_a = recall_score(y_pred, y_test)
dense_f1_a = f1_score(y_pred, y_test)
dense_mcc_a = matthews_corrcoef(y_pred, y_test)
dense_kap_a = cohen_kappa_score(y_pred, y_test)
dense_jacc_a = jaccard_score(y_pred, y_test)
dense_gmea_a = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN - DenseNets',dense_acc_a,dense_roc_a,dense_prec_a,dense_rec_a,dense_f1_a,dense_mcc_a,dense_kap_a,dense_jacc_a,dense_gmea_a)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 9, 128)            384
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 4, 128)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 128)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 1,410
# Trainable params: 1,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 272ms/step - loss: 0.6913 - accuracy: 0.5000 - val_loss: 0.6764 - val_accuracy: 0.8022
# Epoch 2/20
# 2/2 [==============================] - 0s 152ms/step - loss: 0.6752 - accuracy: 0.6250 - val_loss: 0.6377 - val_accuracy: 0.8791
# Epoch 3/20
# 2/2 [==============================] - 0s 149ms/step - loss: 0.6281 - accuracy: 0.8750 - val_loss: 0.6036 - val_accuracy: 0.8791
# Epoch 4/20
# 2/2 [==============================] - 0s 138ms/step - loss: 0.5636 - accuracy: 1.0000 - val_loss: 0.5700 - val_accuracy: 0.8791
# Epoch 5/20
# 2/2 [==============================] - 0s 119ms/step - loss: 0.6620 - accuracy: 0.6250 - val_loss: 0.5423 - val_accuracy: 0.8791
# Epoch 6/20
# 2/2 [==============================] - 0s 113ms/step - loss: 0.6115 - accuracy: 0.7500 - val_loss: 0.5203 - val_accuracy: 0.8791
# Epoch 7/20
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5293 - accuracy: 0.8750 - val_loss: 0.4996 - val_accuracy: 0.8791
# Epoch 8/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.6166 - accuracy: 0.7500 - val_loss: 0.4832 - val_accuracy: 0.8791
# Epoch 9/20
# 2/2 [==============================] - 0s 104ms/step - loss: 0.4906 - accuracy: 0.8750 - val_loss: 0.4676 - val_accuracy: 0.8791
# Epoch 10/20
# 2/2 [==============================] - 0s 104ms/step - loss: 0.3421 - accuracy: 1.0000 - val_loss: 0.4516 - val_accuracy: 0.8791
# Epoch 11/20
# 2/2 [==============================] - 0s 110ms/step - loss: 0.3384 - accuracy: 1.0000 - val_loss: 0.4354 - val_accuracy: 0.8791
# Epoch 12/20
# 2/2 [==============================] - 0s 109ms/step - loss: 0.2919 - accuracy: 1.0000 - val_loss: 0.4200 - val_accuracy: 0.8791
# Epoch 13/20
# 2/2 [==============================] - 0s 101ms/step - loss: 0.3970 - accuracy: 0.8750 - val_loss: 0.4072 - val_accuracy: 0.8791
# Epoch 14/20
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5438 - accuracy: 0.7500 - val_loss: 0.3987 - val_accuracy: 0.8791
# Epoch 15/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4173 - accuracy: 0.8750 - val_loss: 0.3919 - val_accuracy: 0.8791
# Epoch 16/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.2239 - accuracy: 1.0000 - val_loss: 0.3854 - val_accuracy: 0.8791
# Epoch 17/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5677 - accuracy: 0.7500 - val_loss: 0.3811 - val_accuracy: 0.8791
# Epoch 18/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6084 - accuracy: 0.7500 - val_loss: 0.3792 - val_accuracy: 0.8791
# Epoch 19/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1651 - accuracy: 1.0000 - val_loss: 0.3770 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.3838 - accuracy: 0.8750 - val_loss: 0.3754 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 800), (907,), (161, 800), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_b = accuracy_score(y_pred, y_test)
svm_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_b = precision_score(y_pred, y_test)
svm_rec_b = recall_score(y_pred, y_test)
svm_f1_b = f1_score(y_pred, y_test)
svm_mcc_b = matthews_corrcoef(y_pred, y_test)
svm_kap_b = cohen_kappa_score(y_pred, y_test)
svm_jacc_b = jaccard_score(y_pred, y_test)
svm_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - rbf',svm_acc_b,svm_roc_b,svm_prec_b,svm_rec_b,svm_f1_b,svm_mcc_b,svm_kap_b,svm_jacc_b,svm_gmea_b)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_b = accuracy_score(y_pred, y_test)
svm1_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_b = precision_score(y_pred, y_test)
svm1_rec_b = recall_score(y_pred, y_test)
svm1_f1_b = f1_score(y_pred, y_test)
svm1_mcc_b = matthews_corrcoef(y_pred, y_test)
svm1_kap_b = cohen_kappa_score(y_pred, y_test)
svm1_jacc_b = jaccard_score(y_pred, y_test)
svm1_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - Poly',svm1_acc_b,svm1_roc_b,svm1_prec_b,svm1_rec_b,svm1_f1_b,svm1_mcc_b,svm1_kap_b,svm1_jacc_b,svm1_gmea_a)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_b = accuracy_score(y_pred, y_test)
svm2_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_b = precision_score(y_pred, y_test)
svm2_rec_b = recall_score(y_pred, y_test)
svm2_f1_b = f1_score(y_pred, y_test)
svm2_mcc_b = matthews_corrcoef(y_pred, y_test)
svm2_kap_b = cohen_kappa_score(y_pred, y_test)
svm2_jacc_b = jaccard_score(y_pred, y_test)
svm2_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - Utility ',svm2_acc_b,svm2_roc_b,svm2_prec_b,svm2_rec_b,svm2_f1_b,svm2_mcc_b,svm2_kap_b,svm2_jacc_b,svm2_gmea_b)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_b =accuracy_score(y_pred, y_test)
svm3_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_b =precision_score(y_pred, y_test)
svm3_rec_b =recall_score(y_pred, y_test)
svm3_f1_b =f1_score(y_pred, y_test)
svm3_mcc_b =matthews_corrcoef(y_pred, y_test)
svm3_kap_b =cohen_kappa_score(y_pred, y_test)
svm3_jacc_b =jaccard_score(y_pred, y_test)
svm3_gmea_b =fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - Linear ',svm3_acc_b,svm3_roc_b,svm3_prec_b,svm3_rec_b,svm3_f1_b,svm3_mcc_b,svm3_kap_b,svm3_jacc_b,svm3_gmea_b)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_b = accuracy_score(y_pred, y_test)
svm4_roc_b = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_b = precision_score(y_pred, y_test)
svm4_rec_b = recall_score(y_pred, y_test)
svm4_f1_b = f1_score(y_pred, y_test)
svm4_mcc_b = matthews_corrcoef(y_pred, y_test)
svm4_kap_b = cohen_kappa_score(y_pred, y_test)
svm4_jacc_b = jaccard_score(y_pred, y_test)
svm4_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - SVM - Sigmoid',svm4_acc_b,svm4_roc_b,svm4_prec_b,svm4_rec_b,svm4_f1_b,svm4_mcc_b,svm4_kap_b,svm4_jacc_b,svm4_gmea_b)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_b = accuracy_score(y_pred, y_test)
rf_roc_b = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_b = precision_score(y_pred, y_test)
rf_rec_b = recall_score(y_pred, y_test)
rf_f1_b = f1_score(y_pred, y_test)
rf_mcc_b = matthews_corrcoef(y_pred, y_test)
rf_kap_b = cohen_kappa_score(y_pred, y_test)
rf_jacc_b = jaccard_score(y_pred, y_test)
rf_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - RF',rf_acc_b,rf_roc_b,rf_prec_b,rf_rec_b,rf_f1_b,rf_mcc_b,rf_kap_b,rf_jacc_b,rf_gmea_b)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_b = accuracy_score(y_pred, y_test)
dt_roc_b = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_b = precision_score(y_pred, y_test)
dt_rec_b = recall_score(y_pred, y_test)
dt_f1_b = f1_score(y_pred, y_test)
dt_mcc_b = matthews_corrcoef(y_pred, y_test)
dt_kap_b = cohen_kappa_score(y_pred, y_test)
dt_jacc_b = jaccard_score(y_pred, y_test)
dt_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - DT',dt_acc_b,dt_roc_b,dt_prec_b,dt_rec_b,dt_f1_b,dt_mcc_b,dt_kap_b,dt_jacc_b,dt_gmea_b)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_b = accuracy_score(y_pred, y_test)
nb_roc_b = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_b = precision_score(y_pred, y_test)
nb_rec_b = recall_score(y_pred, y_test)
nb_f1_b = f1_score(y_pred, y_test)
nb_mcc_b = matthews_corrcoef(y_pred, y_test)
nb_kap_b = cohen_kappa_score(y_pred, y_test)
nb_jacc_b = jaccard_score(y_pred, y_test)
nb_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - NB',nb_acc_b,nb_roc_b,nb_prec_b,nb_rec_b,nb_f1_b,nb_mcc_b,nb_kap_b,nb_jacc_b,nb_gmea_b)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_b = accuracy_score(y_pred, y_test)
vot_roc_b = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_b = precision_score(y_pred, y_test)
vot_rec_b = recall_score(y_pred, y_test)
vot_f1_b = f1_score(y_pred, y_test)
vot_mcc_b = matthews_corrcoef(y_pred, y_test)
vot_kap_b = cohen_kappa_score(y_pred, y_test)
vot_jacc_b = jaccard_score(y_pred, y_test)
vot_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI- vot',vot_acc_b,vot_roc_b,vot_prec_b,vot_rec_b,vot_f1_b,vot_mcc_b,vot_kap_b,vot_jacc_b,vot_gmea_b)

# %% [markdown]
# # DL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)


# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_b = accuracy_score(y_pred, y_test)
vgg_roc_b = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_b = precision_score(y_pred, y_test)
vgg_rec_b = recall_score(y_pred, y_test)
vgg_f1_b = f1_score(y_pred, y_test)
vgg_mcc_b = matthews_corrcoef(y_pred, y_test)
vgg_kap_b = cohen_kappa_score(y_pred, y_test)
vgg_jacc_b = jaccard_score(y_pred, y_test)
vgg_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - VGGNets',vgg_acc_b,vgg_roc_b,vgg_prec_b,vgg_rec_b,vgg_f1_b,vgg_mcc_b,vgg_kap_b,vgg_jacc_b,vgg_gmea_b)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 799, 128)          384
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 399, 128)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 399, 128)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 51072)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 102146
# =================================================================
# Total params: 102,530
# Trainable params: 102,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 270ms/step - loss: 0.7727 - accuracy: 0.6250 - val_loss: 10.1381 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 90ms/step - loss: 52.3590 - accuracy: 0.6250 - val_loss: 10.4793 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9875 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 85ms/step - loss: 24.1963 - accuracy: 0.7500 - val_loss: 6.0536 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 91ms/step - loss: 16.2952 - accuracy: 0.7500 - val_loss: 1.7317 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 86ms/step - loss: 4.5669 - accuracy: 0.6250 - val_loss: 12.5590 - val_accuracy: 0.1154
# Epoch 7/20
# 2/2 [==============================] - 0s 92ms/step - loss: 12.5219 - accuracy: 0.1250 - val_loss: 2.0374 - val_accuracy: 0.5275
# Epoch 8/20
# 2/2 [==============================] - 0s 86ms/step - loss: 3.5636 - accuracy: 0.6250 - val_loss: 2.9214 - val_accuracy: 0.8846
# Epoch 9/20
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.9799 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 90ms/step - loss: 9.0264 - accuracy: 0.8750 - val_loss: 6.2917 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 17.4625 - accuracy: 0.7500 - val_loss: 6.4434 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 86ms/step - loss: 8.0522 - accuracy: 0.8750 - val_loss: 5.5284 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 85ms/step - loss: 8.6489 - accuracy: 0.8750 - val_loss: 4.1988 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.1211 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 81ms/step - loss: 6.1139 - accuracy: 0.7500 - val_loss: 1.4118 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0496 - accuracy: 1.0000 - val_loss: 3.0549 - val_accuracy: 0.4176
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.4226 - accuracy: 0.3750 - val_loss: 1.7150 - val_accuracy: 0.5714
# Epoch 18/20
# 2/2 [==============================] - 0s 86ms/step - loss: 1.1903 - accuracy: 0.8750 - val_loss: 1.3848 - val_accuracy: 0.8791
# Epoch 19/20
# 2/2 [==============================] - 0s 90ms/step - loss: 2.9871 - accuracy: 0.7500 - val_loss: 1.5763 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 90ms/step - loss: 0.7868 - accuracy: 0.8750 - val_loss: 1.4339 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 5ms/step
# 6/6 [==============================] - 0s 3ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_b = accuracy_score(y_pred, y_test)
res_roc_b = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_b = precision_score(y_pred, y_test)
res_rec_b = recall_score(y_pred, y_test)
res_f1_b = f1_score(y_pred, y_test)
res_mcc_b = matthews_corrcoef(y_pred, y_test)
res_kap_b = cohen_kappa_score(y_pred, y_test)
res_jacc_b = jaccard_score(y_pred, y_test)
res_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - ResNets',res_acc_b,res_roc_b,res_prec_b,res_rec_b,res_f1_b,res_mcc_b,res_kap_b,res_jacc_b,res_gmea_b)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 799, 128)          384
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 399, 128)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 399, 128)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 51072)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 102146
# =================================================================
# Total params: 102,530
# Trainable params: 102,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 250ms/step - loss: 15.2766 - accuracy: 0.6250 - val_loss: 4.9355 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 172ms/step - loss: 7.6139 - accuracy: 0.8750 - val_loss: 2.6663 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 140ms/step - loss: 3.9617e-05 - accuracy: 1.0000 - val_loss: 0.9708 - val_accuracy: 0.5824
# Epoch 4/20
# 2/2 [==============================] - 0s 122ms/step - loss: 1.1239 - accuracy: 0.7500 - val_loss: 0.8514 - val_accuracy: 0.8901
# Epoch 5/20
# 2/2 [==============================] - 0s 114ms/step - loss: 2.0275 - accuracy: 0.8750 - val_loss: 2.1676 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.6147 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 117ms/step - loss: 6.5688 - accuracy: 0.7500 - val_loss: 1.4336 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 109ms/step - loss: 3.1082 - accuracy: 0.6250 - val_loss: 6.2498 - val_accuracy: 0.1978
# Epoch 9/20
# 2/2 [==============================] - 0s 107ms/step - loss: 5.0512 - accuracy: 0.1250 - val_loss: 1.3761 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.8980 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.9534 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 112ms/step - loss: 4.6994 - accuracy: 0.8750 - val_loss: 7.4644 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.5455 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 69ms/step - loss: 13.4787 - accuracy: 0.8750 - val_loss: 9.0374 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 63ms/step - loss: 16.4707 - accuracy: 0.8750 - val_loss: 8.6799 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 65ms/step - loss: 19.2677 - accuracy: 0.7500 - val_loss: 7.1925 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 65ms/step - loss: 7.5901 - accuracy: 0.8750 - val_loss: 5.4354 - val_accuracy: 0.8846
# Epoch 18/20
# 2/2 [==============================] - 0s 64ms/step - loss: 7.6465 - accuracy: 0.8750 - val_loss: 3.4631 - val_accuracy: 0.8846
# Epoch 19/20
# 2/2 [==============================] - 0s 65ms/step - loss: 2.0835 - accuracy: 0.8750 - val_loss: 1.7149 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 66ms/step - loss: 3.1709 - accuracy: 0.7500 - val_loss: 6.0686 - val_accuracy: 0.1648
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 3ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_b = accuracy_score(y_pred, y_test)
dense_roc_b = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_b = precision_score(y_pred, y_test)
dense_rec_b = recall_score(y_pred, y_test)
dense_f1_b = f1_score(y_pred, y_test)
dense_mcc_b = matthews_corrcoef(y_pred, y_test)
dense_kap_b = cohen_kappa_score(y_pred, y_test)
dense_jacc_b = jaccard_score(y_pred, y_test)
dense_gmea_b = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('WSI - DenseNets',dense_acc_b,dense_roc_b,dense_prec_b,dense_rec_b,dense_f1_b,dense_mcc_b,dense_kap_b,dense_jacc_b,dense_gmea_b)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 799, 128)          384
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 399, 128)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 399, 128)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 51072)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 102146
# =================================================================
# Total params: 102,530
# Trainable params: 102,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 282ms/step - loss: 0.2549 - accuracy: 0.8750 - val_loss: 10.1309 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 171ms/step - loss: 34.3077 - accuracy: 0.6250 - val_loss: 8.7146 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 150ms/step - loss: 14.9272 - accuracy: 0.7500 - val_loss: 3.8852 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 126ms/step - loss: 5.7109 - accuracy: 0.8750 - val_loss: 8.9219 - val_accuracy: 0.1154
# Epoch 5/20
# 2/2 [==============================] - 0s 115ms/step - loss: 7.7215 - accuracy: 0.2500 - val_loss: 0.7878 - val_accuracy: 0.7308
# Epoch 6/20
# 2/2 [==============================] - 0s 108ms/step - loss: 3.3528 - accuracy: 0.7500 - val_loss: 2.7496 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 114ms/step - loss: 6.9023 - accuracy: 0.8750 - val_loss: 3.8842 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 104ms/step - loss: 11.9586 - accuracy: 0.7500 - val_loss: 2.9255 - val_accuracy: 0.8846
# Epoch 9/20
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 2.2264 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 110ms/step - loss: 0.1225 - accuracy: 0.8750 - val_loss: 1.6078 - val_accuracy: 0.8791
# Epoch 11/20
# 2/2 [==============================] - 0s 102ms/step - loss: 0.4667 - accuracy: 0.8750 - val_loss: 1.2822 - val_accuracy: 0.8571
# Epoch 12/20
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0493 - accuracy: 1.0000 - val_loss: 1.1718 - val_accuracy: 0.8571
# Epoch 13/20
# 2/2 [==============================] - 0s 104ms/step - loss: 1.7398 - accuracy: 0.8750 - val_loss: 0.9553 - val_accuracy: 0.8407
# Epoch 14/20
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4668 - accuracy: 0.7500 - val_loss: 0.8766 - val_accuracy: 0.8626
# Epoch 15/20
# 2/2 [==============================] - 0s 119ms/step - loss: 1.5343 - accuracy: 0.8750 - val_loss: 0.7555 - val_accuracy: 0.8242
# Epoch 16/20
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0538 - accuracy: 0.8750 - val_loss: 0.7841 - val_accuracy: 0.7473
# Epoch 17/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.2511 - accuracy: 0.8750 - val_loss: 2.5305 - val_accuracy: 0.4066
# Epoch 18/20
# 2/2 [==============================] - 0s 63ms/step - loss: 5.1027 - accuracy: 0.0000e+00 - val_loss: 1.0934 - val_accuracy: 0.6319
# Epoch 19/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3763 - accuracy: 0.8750 - val_loss: 1.4519 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 66ms/step - loss: 5.5152 - accuracy: 0.5000 - val_loss: 0.8536 - val_accuracy: 0.8407
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # EXP

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(EXP, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 400), (907,), (161, 400), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_c = accuracy_score(y_pred, y_test)
svm_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_c = precision_score(y_pred, y_test)
svm_rec_c = recall_score(y_pred, y_test)
svm_f1_c = f1_score(y_pred, y_test)
svm_mcc_c = matthews_corrcoef(y_pred, y_test)
svm_kap_c = cohen_kappa_score(y_pred, y_test)
svm_jacc_c = jaccard_score(y_pred, y_test)
svm_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - rbf',svm_acc_c,svm_roc_c,svm_prec_c,svm_rec_c,svm_f1_c,svm_mcc_c,svm_kap_c,svm_jacc_c,svm_gmea_c)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_c = accuracy_score(y_pred, y_test)
svm1_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_c = precision_score(y_pred, y_test)
svm1_rec_c = recall_score(y_pred, y_test)
svm1_f1_c = f1_score(y_pred, y_test)
svm1_mcc_c = matthews_corrcoef(y_pred, y_test)
svm1_kap_c = cohen_kappa_score(y_pred, y_test)
svm1_jacc_c = jaccard_score(y_pred, y_test)
svm1_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Poly',svm1_acc_c,svm1_roc_c,svm1_prec_c,svm1_rec_c,svm1_f1_c,svm1_mcc_c,svm1_kap_c,svm1_jacc_c,svm1_gmea_c)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_c = accuracy_score(y_pred, y_test)
svm2_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_c = precision_score(y_pred, y_test)
svm2_rec_c = recall_score(y_pred, y_test)
svm2_f1_c = f1_score(y_pred, y_test)
svm2_mcc_c = matthews_corrcoef(y_pred, y_test)
svm2_kap_c = cohen_kappa_score(y_pred, y_test)
svm2_jacc_c = jaccard_score(y_pred, y_test)
svm2_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Utility ',svm2_acc_c,svm2_roc_c,svm2_prec_c,svm2_rec_c,svm2_f1_c,svm2_mcc_c,svm2_kap_c,svm2_jacc_c,svm2_gmea_c)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_c = accuracy_score(y_pred, y_test)
svm3_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_c = precision_score(y_pred, y_test)
svm3_rec_c = recall_score(y_pred, y_test)
svm3_f1_c = f1_score(y_pred, y_test)
svm3_mcc_c = matthews_corrcoef(y_pred, y_test)
svm3_kap_c = cohen_kappa_score(y_pred, y_test)
svm3_jacc_c = jaccard_score(y_pred, y_test)
svm3_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Linear ',svm3_acc_c,svm3_roc_c,svm3_prec_c,svm3_rec_c,svm3_f1_c,svm3_mcc_c,svm3_kap_c,svm3_jacc_c,svm3_gmea_c)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_c = accuracy_score(y_pred, y_test)
svm4_roc_c = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_c = precision_score(y_pred, y_test)
svm4_rec_c = recall_score(y_pred, y_test)
svm4_f1_c = f1_score(y_pred, y_test)
svm4_mcc_c = matthews_corrcoef(y_pred, y_test)
svm4_kap_c = cohen_kappa_score(y_pred, y_test)
svm4_jacc_c = jaccard_score(y_pred, y_test)
svm4_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Sigmoid',svm4_acc_c,svm4_roc_c,svm4_prec_c,svm4_rec_c,svm4_f1_c,svm4_mcc_c,svm4_kap_c,svm4_jacc_c,svm4_gmea_c)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_c = accuracy_score(y_pred, y_test)
rf_roc_c = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_c = precision_score(y_pred, y_test)
rf_rec_c = recall_score(y_pred, y_test)
rf_f1_c = f1_score(y_pred, y_test)
rf_mcc_c = matthews_corrcoef(y_pred, y_test)
rf_kap_c = cohen_kappa_score(y_pred, y_test)
rf_jacc_c = jaccard_score(y_pred, y_test)
rf_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - RF',rf_acc_c,rf_roc_c,rf_prec_c,rf_rec_c,rf_f1_c,rf_mcc_c,rf_kap_c,rf_jacc_c,rf_gmea_c)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_c = accuracy_score(y_pred, y_test)
dt_roc_c = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_c = precision_score(y_pred, y_test)
dt_rec_c = recall_score(y_pred, y_test)
dt_f1_c = f1_score(y_pred, y_test)
dt_mcc_c = matthews_corrcoef(y_pred, y_test)
dt_kap_c = cohen_kappa_score(y_pred, y_test)
dt_jacc_c = jaccard_score(y_pred, y_test)
dt_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - DT',dt_acc_c,dt_roc_c,dt_prec_c,dt_rec_c,dt_f1_c,dt_mcc_c,dt_kap_c,dt_jacc_c,dt_gmea_c)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_c = accuracy_score(y_pred, y_test)
nb_roc_c = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_c = precision_score(y_pred, y_test)
nb_rec_c = recall_score(y_pred, y_test)
nb_f1_c = f1_score(y_pred, y_test)
nb_mcc_c = matthews_corrcoef(y_pred, y_test)
nb_kap_c = cohen_kappa_score(y_pred, y_test)
nb_jacc_c = jaccard_score(y_pred, y_test)
nb_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - NB',nb_acc_c,nb_roc_c,nb_prec_c,nb_rec_c,nb_f1_c,nb_mcc_c,nb_kap_c,nb_jacc_c,nb_gmea_c)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_c = accuracy_score(y_pred, y_test)
vot_roc_c = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_c = precision_score(y_pred, y_test)
vot_rec_c = recall_score(y_pred, y_test)
vot_f1_c = f1_score(y_pred, y_test)
vot_mcc_c = matthews_corrcoef(y_pred, y_test)
vot_kap_c = cohen_kappa_score(y_pred, y_test)
vot_jacc_c = jaccard_score(y_pred, y_test)
vot_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - vot',vot_acc_c,vot_roc_c,vot_prec_c,vot_rec_c,vot_f1_c,vot_mcc_c,vot_kap_c,vot_jacc_c,vot_gmea_c)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_c = accuracy_score(y_pred, y_test)
vgg_roc_c = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_c = precision_score(y_pred, y_test)
vgg_rec_c = recall_score(y_pred, y_test)
vgg_f1_c = f1_score(y_pred, y_test)
vgg_mcc_c = matthews_corrcoef(y_pred, y_test)
vgg_kap_c = cohen_kappa_score(y_pred, y_test)
vgg_jacc_c = jaccard_score(y_pred, y_test)
vgg_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - VGGNets',vgg_acc_c,vgg_roc_c,vgg_prec_c,vgg_rec_c,vgg_f1_c,vgg_mcc_c,vgg_kap_c,vgg_jacc_c,vgg_gmea_c)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 399, 128)          384
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 199, 128)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 199, 128)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 25472)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 50946
# =================================================================
# Total params: 51,330
# Trainable params: 51,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 160ms/step - loss: 0.7056 - accuracy: 0.3750 - val_loss: 0.5615 - val_accuracy: 0.8681
# Epoch 2/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.4652 - accuracy: 0.8750 - val_loss: 0.4479 - val_accuracy: 0.8736
# Epoch 3/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2128 - accuracy: 1.0000 - val_loss: 0.4538 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2565 - accuracy: 0.8750 - val_loss: 0.5212 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.6182 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.7218 - val_accuracy: 0.8736
# Epoch 7/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6755 - accuracy: 0.8750 - val_loss: 0.7455 - val_accuracy: 0.8736
# Epoch 8/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4372 - accuracy: 0.8750 - val_loss: 0.7370 - val_accuracy: 0.8736
# Epoch 9/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.7372 - val_accuracy: 0.8736
# Epoch 10/20
# 2/2 [==============================] - 0s 79ms/step - loss: 1.5186 - accuracy: 0.7500 - val_loss: 0.6927 - val_accuracy: 0.8736
# Epoch 11/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.6445 - val_accuracy: 0.8736
# Epoch 12/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.9517 - accuracy: 0.7500 - val_loss: 0.5847 - val_accuracy: 0.8736
# Epoch 13/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0880 - accuracy: 1.0000 - val_loss: 0.5448 - val_accuracy: 0.8736
# Epoch 14/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3471 - accuracy: 0.8750 - val_loss: 0.5131 - val_accuracy: 0.8736
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1013 - accuracy: 1.0000 - val_loss: 0.4965 - val_accuracy: 0.8736
# Epoch 16/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3609 - accuracy: 0.8750 - val_loss: 0.4847 - val_accuracy: 0.8736
# Epoch 17/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.3782 - accuracy: 0.8750 - val_loss: 0.4745 - val_accuracy: 0.8736
# Epoch 18/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.3370 - accuracy: 0.8750 - val_loss: 0.4687 - val_accuracy: 0.8736
# Epoch 19/20
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1016 - accuracy: 1.0000 - val_loss: 0.4688 - val_accuracy: 0.8736
# Epoch 20/20
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5923 - accuracy: 0.8750 - val_loss: 0.4617 - val_accuracy: 0.8736
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_c = accuracy_score(y_pred, y_test)
res_roc_c = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_c = precision_score(y_pred, y_test)
res_rec_c = recall_score(y_pred, y_test)
res_f1_c = f1_score(y_pred, y_test)
res_mcc_c = matthews_corrcoef(y_pred, y_test)
res_kap_c = cohen_kappa_score(y_pred, y_test)
res_jacc_c = jaccard_score(y_pred, y_test)
res_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - ResNets',res_acc_c,res_roc_c,res_prec_c,res_rec_c,res_f1_c,res_mcc_c,res_kap_c,res_jacc_c,res_gmea_c)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_7 (Conv1D)            (None, 399, 128)          384
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 199, 128)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 199, 128)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 25472)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 50946
# =================================================================
# Total params: 51,330
# Trainable params: 51,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 151ms/step - loss: 0.6284 - accuracy: 0.7500 - val_loss: 0.5149 - val_accuracy: 0.8736
# Epoch 2/20
# 2/2 [==============================] - 0s 87ms/step - loss: 0.3208 - accuracy: 1.0000 - val_loss: 0.4346 - val_accuracy: 0.8736
# Epoch 3/20
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1420 - accuracy: 1.0000 - val_loss: 0.5090 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.3116 - accuracy: 0.8750 - val_loss: 0.6041 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.7016 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5271 - accuracy: 0.8750 - val_loss: 0.7645 - val_accuracy: 0.8736
# Epoch 7/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.7973 - val_accuracy: 0.8736
# Epoch 8/20
# 2/2 [==============================] - 0s 112ms/step - loss: 0.6967 - accuracy: 0.8750 - val_loss: 0.7834 - val_accuracy: 0.8736
# Epoch 9/20
# 2/2 [==============================] - 0s 86ms/step - loss: 2.6175 - accuracy: 0.5000 - val_loss: 0.7040 - val_accuracy: 0.8736
# Epoch 10/20
# 2/2 [==============================] - 0s 196ms/step - loss: 1.1760 - accuracy: 0.7500 - val_loss: 0.6070 - val_accuracy: 0.8736
# Epoch 11/20
# 2/2 [==============================] - 0s 160ms/step - loss: 0.4586 - accuracy: 0.8750 - val_loss: 0.5325 - val_accuracy: 0.8736
# Epoch 12/20
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.8736
# Epoch 13/20
# 2/2 [==============================] - 0s 129ms/step - loss: 0.1574 - accuracy: 1.0000 - val_loss: 0.4712 - val_accuracy: 0.8736
# Epoch 14/20
# 2/2 [==============================] - 0s 119ms/step - loss: 0.1104 - accuracy: 1.0000 - val_loss: 0.4621 - val_accuracy: 0.8736
# Epoch 15/20
# 2/2 [==============================] - 0s 114ms/step - loss: 0.3961 - accuracy: 0.8750 - val_loss: 0.4547 - val_accuracy: 0.8736
# Epoch 16/20
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1340 - accuracy: 1.0000 - val_loss: 0.4494 - val_accuracy: 0.8736
# Epoch 17/20
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5104 - accuracy: 0.8750 - val_loss: 0.4447 - val_accuracy: 0.8736
# Epoch 18/20
# 2/2 [==============================] - 0s 112ms/step - loss: 0.6242 - accuracy: 0.7500 - val_loss: 0.4416 - val_accuracy: 0.8736
# Epoch 19/20
# 2/2 [==============================] - 0s 110ms/step - loss: 0.1577 - accuracy: 1.0000 - val_loss: 0.4395 - val_accuracy: 0.8736
# Epoch 20/20
# 2/2 [==============================] - 0s 113ms/step - loss: 0.3771 - accuracy: 0.8750 - val_loss: 0.4387 - val_accuracy: 0.8736
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_c = accuracy_score(y_pred, y_test)
dense_roc_c = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_c = precision_score(y_pred, y_test)
dense_rec_c = recall_score(y_pred, y_test)
dense_f1_c = f1_score(y_pred, y_test)
dense_mcc_c = matthews_corrcoef(y_pred, y_test)
dense_kap_c = cohen_kappa_score(y_pred, y_test)
dense_jacc_c = jaccard_score(y_pred, y_test)
dense_gmea_c = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - DenseNets',dense_acc_c,dense_roc_c,dense_prec_c,dense_rec_c,dense_f1_c,dense_mcc_c,dense_kap_c,dense_jacc_c,dense_gmea_c)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 399, 128)          384
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 199, 128)          0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 199, 128)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 25472)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 50946
# =================================================================
# Total params: 51,330
# Trainable params: 51,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 186ms/step - loss: 0.6332 - accuracy: 0.7500 - val_loss: 0.4879 - val_accuracy: 0.8736
# Epoch 2/20
# 2/2 [==============================] - 0s 99ms/step - loss: 0.6850 - accuracy: 0.7500 - val_loss: 0.4472 - val_accuracy: 0.8736
# Epoch 3/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.3461 - accuracy: 0.8750 - val_loss: 0.4550 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1259 - accuracy: 1.0000 - val_loss: 0.4787 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1000 - accuracy: 1.0000 - val_loss: 0.5204 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0615 - accuracy: 1.0000 - val_loss: 0.5805 - val_accuracy: 0.8736
# Epoch 7/20
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0910 - accuracy: 1.0000 - val_loss: 0.6571 - val_accuracy: 0.8736
# Epoch 8/20
# 2/2 [==============================] - 0s 147ms/step - loss: 0.8825 - accuracy: 0.8750 - val_loss: 0.7064 - val_accuracy: 0.8736
# Epoch 9/20
# 2/2 [==============================] - 0s 120ms/step - loss: 0.4528 - accuracy: 0.8750 - val_loss: 0.6921 - val_accuracy: 0.8736
# Epoch 10/20
# 2/2 [==============================] - 0s 121ms/step - loss: 1.3756 - accuracy: 0.7500 - val_loss: 0.6313 - val_accuracy: 0.8736
# Epoch 11/20
# 2/2 [==============================] - 0s 107ms/step - loss: 0.4121 - accuracy: 0.8750 - val_loss: 0.5851 - val_accuracy: 0.8736
# Epoch 12/20
# 2/2 [==============================] - 0s 97ms/step - loss: 0.3292 - accuracy: 0.8750 - val_loss: 0.5441 - val_accuracy: 0.8736
# Epoch 13/20
# 2/2 [==============================] - 0s 100ms/step - loss: 1.1351 - accuracy: 0.6250 - val_loss: 0.5023 - val_accuracy: 0.8736
# Epoch 14/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.4272 - accuracy: 0.8750 - val_loss: 0.4800 - val_accuracy: 0.8736
# Epoch 15/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.3362 - accuracy: 0.8750 - val_loss: 0.4717 - val_accuracy: 0.8681
# Epoch 16/20
# 2/2 [==============================] - 0s 108ms/step - loss: 0.5758 - accuracy: 0.8750 - val_loss: 0.4722 - val_accuracy: 0.8681
# Epoch 17/20
# 2/2 [==============================] - 0s 108ms/step - loss: 0.2885 - accuracy: 0.8750 - val_loss: 0.4725 - val_accuracy: 0.8681
# Epoch 18/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.4190 - accuracy: 0.8750 - val_loss: 0.4740 - val_accuracy: 0.8681
# Epoch 19/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.3235 - accuracy: 0.8750 - val_loss: 0.4732 - val_accuracy: 0.8681
# Epoch 20/20
# 2/2 [==============================] - 0s 103ms/step - loss: 0.6135 - accuracy: 0.8750 - val_loss: 0.4736 - val_accuracy: 0.8681
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 1ms/step

# %% [markdown]
# # CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CNV, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 200), (907,), (161, 200), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_d = accuracy_score(y_pred, y_test)
svm_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_d = precision_score(y_pred, y_test)
svm_rec_d = recall_score(y_pred, y_test)
svm_f1_d = f1_score(y_pred, y_test)
svm_mcc_d = matthews_corrcoef(y_pred, y_test)
svm_kap_d = cohen_kappa_score(y_pred, y_test)
svm_jacc_d = jaccard_score(y_pred, y_test)
svm_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - rbf',svm_acc_d,svm_roc_d,svm_prec_d,svm_rec_d,svm_f1_d,svm_mcc_d,svm_kap_d,svm_jacc_d,svm_gmea_d)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_d = accuracy_score(y_pred, y_test)
svm1_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_d = precision_score(y_pred, y_test)
svm1_rec_d = recall_score(y_pred, y_test)
svm1_f1_d = f1_score(y_pred, y_test)
svm1_mcc_d = matthews_corrcoef(y_pred, y_test)
svm1_kap_d = cohen_kappa_score(y_pred, y_test)
svm1_jacc_d = jaccard_score(y_pred, y_test)
svm1_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - Poly',svm1_acc_d,svm1_roc_d,svm1_prec_d,svm1_rec_d,svm1_f1_d,svm1_mcc_d,svm1_kap_d,svm1_jacc_d,svm1_gmea_d)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_d = accuracy_score(y_pred, y_test)
svm2_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_d = precision_score(y_pred, y_test)
svm2_rec_d = recall_score(y_pred, y_test)
svm2_f1_d = f1_score(y_pred, y_test)
svm2_mcc_d = matthews_corrcoef(y_pred, y_test)
svm2_kap_d = cohen_kappa_score(y_pred, y_test)
svm2_jacc_d = jaccard_score(y_pred, y_test)
svm2_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - Utility ',svm2_acc_d,svm2_roc_d,svm2_prec_d,svm2_rec_d,svm2_f1_d,svm2_mcc_d,svm2_kap_d,svm2_jacc_d,svm2_gmea_d)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_d = accuracy_score(y_pred, y_test)
svm3_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_d = precision_score(y_pred, y_test)
svm3_rec_d = recall_score(y_pred, y_test)
svm3_f1_d = f1_score(y_pred, y_test)
svm3_mcc_d = matthews_corrcoef(y_pred, y_test)
svm3_kap_d = cohen_kappa_score(y_pred, y_test)
svm3_jacc_d = jaccard_score(y_pred, y_test)
svm3_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - Linear ',svm3_acc_d,svm3_roc_d,svm3_prec_d,svm3_rec_d,svm3_f1_d,svm3_mcc_d,svm3_kap_d,svm3_jacc_d,svm3_gmea_d)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_d = accuracy_score(y_pred, y_test)
svm4_roc_d = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_d = precision_score(y_pred, y_test)
svm4_rec_d = recall_score(y_pred, y_test)
svm4_f1_d = f1_score(y_pred, y_test)
svm4_mcc_d = matthews_corrcoef(y_pred, y_test)
svm4_kap_d = cohen_kappa_score(y_pred, y_test)
svm4_jacc_d = jaccard_score(y_pred, y_test)
svm4_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - SVM - Sigmoid',svm4_acc_d,svm4_roc_d,svm4_prec_d,svm4_rec_d,svm4_f1_d,svm4_mcc_d,svm4_kap_d,svm4_jacc_d,svm4_gmea_d)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_d = accuracy_score(y_pred, y_test)
rf_roc_d = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_d = precision_score(y_pred, y_test)
rf_rec_d = recall_score(y_pred, y_test)
rf_f1_d = f1_score(y_pred, y_test)
rf_mcc_d = matthews_corrcoef(y_pred, y_test)
rf_kap_d = cohen_kappa_score(y_pred, y_test)
rf_jacc_d = jaccard_score(y_pred, y_test)
rf_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - RF',rf_acc_d,rf_roc_d,rf_prec_d,rf_rec_d,rf_f1_d,rf_mcc_d,rf_kap_d,rf_jacc_d,rf_gmea_d)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_d = accuracy_score(y_pred, y_test)
dt_roc_d = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_d = precision_score(y_pred, y_test)
dt_rec_d = recall_score(y_pred, y_test)
dt_f1_d = f1_score(y_pred, y_test)
dt_mcc_d = matthews_corrcoef(y_pred, y_test)
dt_kap_d = cohen_kappa_score(y_pred, y_test)
dt_jacc_d = jaccard_score(y_pred, y_test)
dt_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - DT',dt_acc_d,dt_roc_d,dt_prec_d,dt_rec_d,dt_f1_d,dt_mcc_d,dt_kap_d,dt_jacc_d,dt_gmea_d)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_d = accuracy_score(y_pred, y_test)
nb_roc_d = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_d = precision_score(y_pred, y_test)
nb_rec_d = recall_score(y_pred, y_test)
nb_f1_d = f1_score(y_pred, y_test)
nb_mcc_d = matthews_corrcoef(y_pred, y_test)
nb_kap_d = cohen_kappa_score(y_pred, y_test)
nb_jacc_d = jaccard_score(y_pred, y_test)
nb_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - NB',nb_acc_d,nb_roc_d,nb_prec_d,nb_rec_d,nb_f1_d,nb_mcc_d,nb_kap_d,nb_jacc_d,nb_gmea_d)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_d = accuracy_score(y_pred, y_test)
vot_roc_d = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_d = precision_score(y_pred, y_test)
vot_rec_d = recall_score(y_pred, y_test)
vot_f1_d = f1_score(y_pred, y_test)
vot_mcc_d = matthews_corrcoef(y_pred, y_test)
vot_kap_d = cohen_kappa_score(y_pred, y_test)
vot_jacc_d = jaccard_score(y_pred, y_test)
vot_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - vot',vot_acc_d,vot_roc_d,vot_prec_d,vot_rec_d,vot_f1_d,vot_mcc_d,vot_kap_d,vot_jacc_d,vot_gmea_d)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_d = accuracy_score(y_pred, y_test)
vgg_roc_d = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_d = precision_score(y_pred, y_test)
vgg_rec_d = recall_score(y_pred, y_test)
vgg_f1_d = f1_score(y_pred, y_test)
vgg_mcc_d = matthews_corrcoef(y_pred, y_test)
vgg_kap_d = cohen_kappa_score(y_pred, y_test)
vgg_jacc_d = jaccard_score(y_pred, y_test)
vgg_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - VGGNets',vgg_acc_d,vgg_roc_d,vgg_prec_d,vgg_rec_d,vgg_f1_d,vgg_mcc_d,vgg_kap_d,vgg_jacc_d,vgg_gmea_d)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 199, 128)          384
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 99, 128)           0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 99, 128)           0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 12672)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 25346
# =================================================================
# Total params: 25,730
# Trainable params: 25,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 1s 152ms/step - loss: 0.6843 - accuracy: 0.6250 - val_loss: 0.6399 - val_accuracy: 0.8352
# Epoch 2/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.7134 - accuracy: 0.6250 - val_loss: 0.5936 - val_accuracy: 0.8626
# Epoch 3/20
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5929 - accuracy: 1.0000 - val_loss: 0.5565 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5712 - accuracy: 0.7500 - val_loss: 0.5208 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5874 - accuracy: 0.8750 - val_loss: 0.4974 - val_accuracy: 0.8791
# Epoch 6/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.9208 - accuracy: 0.6250 - val_loss: 0.4855 - val_accuracy: 0.8791
# Epoch 7/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.4640 - accuracy: 0.7500 - val_loss: 0.4851 - val_accuracy: 0.8791
# Epoch 8/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5123 - accuracy: 1.0000 - val_loss: 0.4753 - val_accuracy: 0.8791
# Epoch 9/20
# 2/2 [==============================] - 0s 60ms/step - loss: 0.2518 - accuracy: 1.0000 - val_loss: 0.4621 - val_accuracy: 0.8791
# Epoch 10/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5619 - accuracy: 0.7500 - val_loss: 0.4526 - val_accuracy: 0.8791
# Epoch 11/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2440 - accuracy: 1.0000 - val_loss: 0.4454 - val_accuracy: 0.8791
# Epoch 12/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4742 - accuracy: 0.7500 - val_loss: 0.4438 - val_accuracy: 0.8791
# Epoch 13/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0999 - accuracy: 1.0000 - val_loss: 0.4469 - val_accuracy: 0.8791
# Epoch 14/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.7946 - accuracy: 0.7500 - val_loss: 0.4461 - val_accuracy: 0.8791
# Epoch 15/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1178 - accuracy: 1.0000 - val_loss: 0.4481 - val_accuracy: 0.8791
# Epoch 16/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.9127 - accuracy: 0.7500 - val_loss: 0.4449 - val_accuracy: 0.8791
# Epoch 17/20
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1748 - accuracy: 1.0000 - val_loss: 0.4427 - val_accuracy: 0.8791
# Epoch 18/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4065 - accuracy: 0.8750 - val_loss: 0.4396 - val_accuracy: 0.8791
# Epoch 19/20
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0955 - accuracy: 1.0000 - val_loss: 0.4397 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4820 - accuracy: 0.8750 - val_loss: 0.4383 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 0s/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_d = accuracy_score(y_pred, y_test)
res_roc_d = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_d = precision_score(y_pred, y_test)
res_rec_d = recall_score(y_pred, y_test)
res_f1_d = f1_score(y_pred, y_test)
res_mcc_d = matthews_corrcoef(y_pred, y_test)
res_kap_d = cohen_kappa_score(y_pred, y_test)
res_jacc_d = jaccard_score(y_pred, y_test)
res_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - ResNets',res_acc_d,res_roc_d,res_prec_d,res_rec_d,res_f1_d,res_mcc_d,res_kap_d,res_jacc_d,res_gmea_d)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 199, 128)          384
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 99, 128)           0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 99, 128)           0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 12672)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 25346
# =================================================================
# Total params: 25,730
# Trainable params: 25,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 144ms/step - loss: 0.7053 - accuracy: 0.0000e+00 - val_loss: 0.6470 - val_accuracy: 0.8571
# Epoch 2/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5975 - accuracy: 0.7500 - val_loss: 0.5813 - val_accuracy: 0.8791
# Epoch 3/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4406 - accuracy: 1.0000 - val_loss: 0.5383 - val_accuracy: 0.8791
# Epoch 4/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6387 - accuracy: 0.8750 - val_loss: 0.5111 - val_accuracy: 0.8791
# Epoch 5/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5149 - accuracy: 0.8750 - val_loss: 0.4945 - val_accuracy: 0.8791
# Epoch 6/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5118 - accuracy: 0.7500 - val_loss: 0.4916 - val_accuracy: 0.8791
# Epoch 7/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8559 - accuracy: 0.7500 - val_loss: 0.4895 - val_accuracy: 0.8791
# Epoch 8/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5643 - accuracy: 0.8750 - val_loss: 0.4835 - val_accuracy: 0.8791
# Epoch 9/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3600 - accuracy: 0.8750 - val_loss: 0.4767 - val_accuracy: 0.8791
# Epoch 10/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.0215 - accuracy: 0.6250 - val_loss: 0.4711 - val_accuracy: 0.8791
# Epoch 11/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4057 - accuracy: 0.8750 - val_loss: 0.4668 - val_accuracy: 0.8791
# Epoch 12/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5122 - accuracy: 0.7500 - val_loss: 0.4634 - val_accuracy: 0.8791
# Epoch 13/20
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5435 - accuracy: 0.8750 - val_loss: 0.4615 - val_accuracy: 0.8791
# Epoch 14/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3797 - accuracy: 0.8750 - val_loss: 0.4597 - val_accuracy: 0.8791
# Epoch 15/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4065 - accuracy: 0.8750 - val_loss: 0.4561 - val_accuracy: 0.8791
# Epoch 16/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9763 - accuracy: 0.6250 - val_loss: 0.4546 - val_accuracy: 0.8791
# Epoch 17/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.2513 - accuracy: 1.0000 - val_loss: 0.4523 - val_accuracy: 0.8791
# Epoch 18/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3122 - accuracy: 0.8750 - val_loss: 0.4481 - val_accuracy: 0.8791
# Epoch 19/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2498 - accuracy: 1.0000 - val_loss: 0.4407 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5765 - accuracy: 0.7500 - val_loss: 0.4359 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_d = accuracy_score(y_pred, y_test)
dense_roc_d = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_d = precision_score(y_pred, y_test)
dense_rec_d = recall_score(y_pred, y_test)
dense_f1_d = f1_score(y_pred, y_test)
dense_mcc_d = matthews_corrcoef(y_pred, y_test)
dense_kap_d = cohen_kappa_score(y_pred, y_test)
dense_jacc_d = jaccard_score(y_pred, y_test)
dense_gmea_d = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV - DenseNets',dense_acc_d,dense_roc_d,dense_prec_d,dense_rec_d,dense_f1_d,dense_mcc_d,dense_kap_d,dense_jacc_d,dense_gmea_d)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_11 (Conv1D)           (None, 199, 128)          384
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 99, 128)           0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 99, 128)           0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 12672)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 25346
# =================================================================
# Total params: 25,730
# Trainable params: 25,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 153ms/step - loss: 0.6600 - accuracy: 0.7500 - val_loss: 0.5813 - val_accuracy: 0.8791
# Epoch 2/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.6653 - accuracy: 0.6250 - val_loss: 0.5440 - val_accuracy: 0.8791
# Epoch 3/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3646 - accuracy: 1.0000 - val_loss: 0.5163 - val_accuracy: 0.8791
# Epoch 4/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4609 - accuracy: 1.0000 - val_loss: 0.5015 - val_accuracy: 0.8791
# Epoch 5/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3024 - accuracy: 0.8750 - val_loss: 0.5008 - val_accuracy: 0.8791
# Epoch 6/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.2031 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.8791
# Epoch 7/20
# 2/2 [==============================] - 0s 75ms/step - loss: 1.2837 - accuracy: 0.7500 - val_loss: 0.5224 - val_accuracy: 0.8791
# Epoch 8/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8633 - accuracy: 0.6250 - val_loss: 0.5199 - val_accuracy: 0.8791
# Epoch 9/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5368 - accuracy: 0.8750 - val_loss: 0.5143 - val_accuracy: 0.8791
# Epoch 10/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1308 - accuracy: 1.0000 - val_loss: 0.5095 - val_accuracy: 0.8791
# Epoch 11/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6489 - accuracy: 0.8750 - val_loss: 0.5040 - val_accuracy: 0.8791
# Epoch 12/20
# 2/2 [==============================] - 0s 69ms/step - loss: 1.8341 - accuracy: 0.5000 - val_loss: 0.4903 - val_accuracy: 0.8791
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2607 - accuracy: 1.0000 - val_loss: 0.4818 - val_accuracy: 0.8791
# Epoch 14/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7435 - accuracy: 0.7500 - val_loss: 0.4754 - val_accuracy: 0.8791
# Epoch 15/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7164 - accuracy: 0.6250 - val_loss: 0.4753 - val_accuracy: 0.8791
# Epoch 16/20
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0072 - accuracy: 0.7500 - val_loss: 0.4819 - val_accuracy: 0.8791
# Epoch 17/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7240 - accuracy: 0.6250 - val_loss: 0.4982 - val_accuracy: 0.8791
# Epoch 18/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3779 - accuracy: 1.0000 - val_loss: 0.5109 - val_accuracy: 0.8791
# Epoch 19/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4324 - accuracy: 1.0000 - val_loss: 0.5120 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4780 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # CLN - EXP

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_EXP, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 410), (907,), (161, 410), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_e = accuracy_score(y_pred, y_test)
svm_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_e = precision_score(y_pred, y_test)
svm_rec_e = recall_score(y_pred, y_test)
svm_f1_e = f1_score(y_pred, y_test)
svm_mcc_e = matthews_corrcoef(y_pred, y_test)
svm_kap_e = cohen_kappa_score(y_pred, y_test)
svm_jacc_e = jaccard_score(y_pred, y_test)
svm_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - SVM - rbf',svm_acc_e,svm_roc_e,svm_prec_e,svm_rec_e,svm_f1_e,svm_mcc_e,svm_kap_e,svm_jacc_e,svm_gmea_e)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_e = accuracy_score(y_pred, y_test)
svm1_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_e = precision_score(y_pred, y_test)
svm1_rec_e = recall_score(y_pred, y_test)
svm1_f1_e = f1_score(y_pred, y_test)
svm1_mcc_e = matthews_corrcoef(y_pred, y_test)
svm1_kap_e = cohen_kappa_score(y_pred, y_test)
svm1_jacc_e = jaccard_score(y_pred, y_test)
svm1_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - SVM - Poly',svm1_acc_e,svm1_roc_e,svm1_prec_e,svm1_rec_e,svm1_f1_e,svm1_mcc_e,svm1_kap_e,svm1_jacc_e,svm1_gmea_e)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_e = accuracy_score(y_pred, y_test)
svm2_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_e = precision_score(y_pred, y_test)
svm2_rec_e = recall_score(y_pred, y_test)
svm2_f1_e = f1_score(y_pred, y_test)
svm2_mcc_e = matthews_corrcoef(y_pred, y_test)
svm2_kap_e = cohen_kappa_score(y_pred, y_test)
svm2_jacc_e = jaccard_score(y_pred, y_test)
svm2_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - SVM - Utility ',svm2_acc_e,svm2_roc_e,svm2_prec_e,svm2_rec_e,svm2_f1_e,svm2_mcc_e,svm2_kap_e,svm2_jacc_e,svm2_gmea_e)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_e = accuracy_score(y_pred, y_test)
svm3_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_e = precision_score(y_pred, y_test)
svm3_rec_e = recall_score(y_pred, y_test)
svm3_f1_e = f1_score(y_pred, y_test)
svm3_mcc_e = matthews_corrcoef(y_pred, y_test)
svm3_kap_e = cohen_kappa_score(y_pred, y_test)
svm3_jacc_e = jaccard_score(y_pred, y_test)
svm3_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - SVM - Linear ',svm3_acc_e,svm3_roc_e,svm3_prec_e,svm3_rec_e,svm3_f1_e,svm3_mcc_e,svm3_kap_e,svm3_jacc_e,svm3_gmea_e)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_e = accuracy_score(y_pred, y_test)
svm4_roc_e = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_e = precision_score(y_pred, y_test)
svm4_rec_e = recall_score(y_pred, y_test)
svm4_f1_e = f1_score(y_pred, y_test)
svm4_mcc_e = matthews_corrcoef(y_pred, y_test)
svm4_kap_e = cohen_kappa_score(y_pred, y_test)
svm4_jacc_e = jaccard_score(y_pred, y_test)
svm4_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP - SVM - Sigmoid',svm4_acc_e,svm4_roc_e,svm4_prec_e,svm4_rec_e,svm4_f1_e,svm4_mcc_e,svm4_kap_e,svm4_jacc_e,svm4_gmea_e)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_e = accuracy_score(y_pred, y_test)
rf_roc_e = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_e = precision_score(y_pred, y_test)
rf_rec_e = recall_score(y_pred, y_test)
rf_f1_e = f1_score(y_pred, y_test)
rf_mcc_e = matthews_corrcoef(y_pred, y_test)
rf_kap_e = cohen_kappa_score(y_pred, y_test)
rf_jacc_e = jaccard_score(y_pred, y_test)
rf_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - RF',rf_acc_e,rf_roc_e,rf_prec_e,rf_rec_e,rf_f1_e,rf_mcc_e,rf_kap_e,rf_jacc_e,rf_gmea_e)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_e = accuracy_score(y_pred, y_test)
dt_roc_e = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_e = precision_score(y_pred, y_test)
dt_rec_e = recall_score(y_pred, y_test)
dt_f1_e = f1_score(y_pred, y_test)
dt_mcc_e = matthews_corrcoef(y_pred, y_test)
dt_kap_e = cohen_kappa_score(y_pred, y_test)
dt_jacc_e = jaccard_score(y_pred, y_test)
dt_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - DT',dt_acc_e,dt_roc_e,dt_prec_e,dt_rec_e,dt_f1_e,dt_mcc_e,dt_kap_e,dt_jacc_e,dt_gmea_e)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_e = accuracy_score(y_pred, y_test)
nb_roc_e = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_e = precision_score(y_pred, y_test)
nb_rec_e = recall_score(y_pred, y_test)
nb_f1_e = f1_score(y_pred, y_test)
nb_mcc_e = matthews_corrcoef(y_pred, y_test)
nb_kap_e = cohen_kappa_score(y_pred, y_test)
nb_jacc_e = jaccard_score(y_pred, y_test)
nb_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - NB',nb_acc_e,nb_roc_e,nb_prec_e,nb_rec_e,nb_f1_e,nb_mcc_e,nb_kap_e,nb_jacc_e,nb_gmea_e)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_e = accuracy_score(y_pred, y_test)
vot_roc_e = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_e = precision_score(y_pred, y_test)
vot_rec_e = recall_score(y_pred, y_test)
vot_f1_e = f1_score(y_pred, y_test)
vot_mcc_e = matthews_corrcoef(y_pred, y_test)
vot_kap_e = cohen_kappa_score(y_pred, y_test)
vot_jacc_e = jaccard_score(y_pred, y_test)
vot_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - vot',vot_acc_e,vot_roc_e,vot_prec_e,vot_rec_e,vot_f1_e,vot_mcc_e,vot_kap_e,vot_jacc_e,vot_gmea_e)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_e = accuracy_score(y_pred, y_test)
vgg_roc_e = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_e = precision_score(y_pred, y_test)
vgg_rec_e = recall_score(y_pred, y_test)
vgg_f1_e = f1_score(y_pred, y_test)
vgg_mcc_e = matthews_corrcoef(y_pred, y_test)
vgg_kap_e = cohen_kappa_score(y_pred, y_test)
vgg_jacc_e = jaccard_score(y_pred, y_test)
vgg_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - VGGNets',vgg_acc_e,vgg_roc_e,vgg_prec_e,vgg_rec_e,vgg_f1_e,vgg_mcc_e,vgg_kap_e,vgg_jacc_e,vgg_gmea_e)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_12 (Conv1D)           (None, 409, 128)          384
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 204, 128)          0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 204, 128)          0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 26112)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 52226
# =================================================================
# Total params: 52,610
# Trainable params: 52,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 157ms/step - loss: 0.6797 - accuracy: 0.6250 - val_loss: 0.4891 - val_accuracy: 0.8681
# Epoch 2/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3487 - accuracy: 1.0000 - val_loss: 0.4247 - val_accuracy: 0.8681
# Epoch 3/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3383 - accuracy: 0.8750 - val_loss: 0.4818 - val_accuracy: 0.8681
# Epoch 4/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.9276 - accuracy: 0.7500 - val_loss: 0.5180 - val_accuracy: 0.8681
# Epoch 5/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.5132 - accuracy: 0.8750 - val_loss: 0.5269 - val_accuracy: 0.8681
# Epoch 6/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.5284 - val_accuracy: 0.8681
# Epoch 7/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8505 - accuracy: 0.7500 - val_loss: 0.5106 - val_accuracy: 0.8681
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7635 - accuracy: 0.7500 - val_loss: 0.4779 - val_accuracy: 0.8681
# Epoch 9/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3518 - accuracy: 0.8750 - val_loss: 0.4610 - val_accuracy: 0.8681
# Epoch 10/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0939 - accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.8681
# Epoch 11/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0976 - accuracy: 1.0000 - val_loss: 0.4532 - val_accuracy: 0.8681
# Epoch 12/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.8814 - accuracy: 0.6250 - val_loss: 0.4454 - val_accuracy: 0.8681
# Epoch 13/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8500 - accuracy: 0.7500 - val_loss: 0.4376 - val_accuracy: 0.8681
# Epoch 14/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3443 - accuracy: 0.8750 - val_loss: 0.4340 - val_accuracy: 0.8681
# Epoch 15/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1508 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.8681
# Epoch 16/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.9159 - accuracy: 0.6250 - val_loss: 0.4366 - val_accuracy: 0.8681
# Epoch 17/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2541 - accuracy: 1.0000 - val_loss: 0.4404 - val_accuracy: 0.8681
# Epoch 18/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.2080 - accuracy: 1.0000 - val_loss: 0.4362 - val_accuracy: 0.8681
# Epoch 19/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3354 - accuracy: 0.8750 - val_loss: 0.4299 - val_accuracy: 0.8681
# Epoch 20/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1595 - accuracy: 1.0000 - val_loss: 0.4228 - val_accuracy: 0.8681
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_e = accuracy_score(y_pred, y_test)
res_roc_e = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_e = precision_score(y_pred, y_test)
res_rec_e = recall_score(y_pred, y_test)
res_f1_e = f1_score(y_pred, y_test)
res_mcc_e = matthews_corrcoef(y_pred, y_test)
res_kap_e = cohen_kappa_score(y_pred, y_test)
res_jacc_e = jaccard_score(y_pred, y_test)
res_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - ResNets',res_acc_e,res_roc_e,res_prec_e,res_rec_e,res_f1_e,res_mcc_e,res_kap_e,res_jacc_e,res_gmea_e)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_13 (Conv1D)           (None, 409, 128)          384
# _________________________________________________________________
# max_pooling1d_13 (MaxPooling (None, 204, 128)          0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 204, 128)          0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 26112)             0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 52226
# =================================================================
# Total params: 52,610
# Trainable params: 52,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 142ms/step - loss: 0.6300 - accuracy: 0.8750 - val_loss: 0.4738 - val_accuracy: 0.8681
# Epoch 2/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4662 - accuracy: 0.8750 - val_loss: 0.4239 - val_accuracy: 0.8681
# Epoch 3/20
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0120 - accuracy: 0.6250 - val_loss: 0.4384 - val_accuracy: 0.8681
# Epoch 4/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0944 - accuracy: 1.0000 - val_loss: 0.4432 - val_accuracy: 0.8681
# Epoch 5/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5177 - accuracy: 0.8750 - val_loss: 0.4410 - val_accuracy: 0.8681
# Epoch 6/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1064 - accuracy: 1.0000 - val_loss: 0.4478 - val_accuracy: 0.8681
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8915 - accuracy: 0.7500 - val_loss: 0.4479 - val_accuracy: 0.8681
# Epoch 8/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4081 - accuracy: 0.8750 - val_loss: 0.4399 - val_accuracy: 0.8681
# Epoch 9/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1313 - accuracy: 1.0000 - val_loss: 0.4364 - val_accuracy: 0.8681
# Epoch 10/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0985 - accuracy: 1.0000 - val_loss: 0.4392 - val_accuracy: 0.8681
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5434 - accuracy: 0.7500 - val_loss: 0.4409 - val_accuracy: 0.8681
# Epoch 12/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3592 - accuracy: 0.8750 - val_loss: 0.4390 - val_accuracy: 0.8681
# Epoch 13/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1475 - accuracy: 1.0000 - val_loss: 0.4434 - val_accuracy: 0.8681
# Epoch 14/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0905 - accuracy: 1.0000 - val_loss: 0.4536 - val_accuracy: 0.8681
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0761 - accuracy: 1.0000 - val_loss: 0.4691 - val_accuracy: 0.8681
# Epoch 16/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.4908 - val_accuracy: 0.8681
# Epoch 17/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5322 - accuracy: 0.8750 - val_loss: 0.4966 - val_accuracy: 0.8681
# Epoch 18/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3681 - accuracy: 0.8750 - val_loss: 0.5017 - val_accuracy: 0.8681
# Epoch 19/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8789 - accuracy: 0.7500 - val_loss: 0.4916 - val_accuracy: 0.8681
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.9148 - accuracy: 0.7500 - val_loss: 0.4556 - val_accuracy: 0.8681
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_e = accuracy_score(y_pred, y_test)
dense_roc_e = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_e = precision_score(y_pred, y_test)
dense_rec_e = recall_score(y_pred, y_test)
dense_f1_e = f1_score(y_pred, y_test)
dense_mcc_e = matthews_corrcoef(y_pred, y_test)
dense_kap_e = cohen_kappa_score(y_pred, y_test)
dense_jacc_e = jaccard_score(y_pred, y_test)
dense_gmea_e = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP - DenseNets',dense_acc_e,dense_roc_e,dense_prec_e,dense_rec_e,dense_f1_e,dense_mcc_e,dense_kap_e,dense_jacc_e,dense_gmea_e)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_14 (Conv1D)           (None, 409, 128)          384
# _________________________________________________________________
# max_pooling1d_14 (MaxPooling (None, 204, 128)          0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 204, 128)          0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 26112)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 52226
# =================================================================
# Total params: 52,610
# Trainable params: 52,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 148ms/step - loss: 0.6279 - accuracy: 0.6250 - val_loss: 0.4752 - val_accuracy: 0.8681
# Epoch 2/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.2346 - accuracy: 1.0000 - val_loss: 0.4314 - val_accuracy: 0.8681
# Epoch 3/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1171 - accuracy: 1.0000 - val_loss: 0.5279 - val_accuracy: 0.8681
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4597 - accuracy: 0.8750 - val_loss: 0.6081 - val_accuracy: 0.8681
# Epoch 5/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4952 - accuracy: 0.8750 - val_loss: 0.6447 - val_accuracy: 0.8681
# Epoch 6/20
# 2/2 [==============================] - 0s 74ms/step - loss: 1.6831 - accuracy: 0.6250 - val_loss: 0.6052 - val_accuracy: 0.8681
# Epoch 7/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.8681
# Epoch 8/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.8681
# Epoch 9/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 0.5450 - val_accuracy: 0.8681
# Epoch 10/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6896 - accuracy: 0.8750 - val_loss: 0.5340 - val_accuracy: 0.8681
# Epoch 11/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.8178 - accuracy: 0.7500 - val_loss: 0.4981 - val_accuracy: 0.8681
# Epoch 12/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0932 - accuracy: 1.0000 - val_loss: 0.4795 - val_accuracy: 0.8681
# Epoch 13/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 0.4714 - val_accuracy: 0.8681
# Epoch 14/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.7451 - accuracy: 0.8750 - val_loss: 0.4632 - val_accuracy: 0.8681
# Epoch 15/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.4155 - accuracy: 0.8750 - val_loss: 0.4494 - val_accuracy: 0.8681
# Epoch 16/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9673 - accuracy: 0.6250 - val_loss: 0.4334 - val_accuracy: 0.8681
# Epoch 17/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1169 - accuracy: 1.0000 - val_loss: 0.4293 - val_accuracy: 0.8681
# Epoch 18/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1951 - accuracy: 1.0000 - val_loss: 0.4283 - val_accuracy: 0.8681
# Epoch 19/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.2336 - accuracy: 1.0000 - val_loss: 0.4271 - val_accuracy: 0.8681
# Epoch 20/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1474 - accuracy: 1.0000 - val_loss: 0.4277 - val_accuracy: 0.8681
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # CLN-CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_CNV, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 210), (907,), (161, 210), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_f = accuracy_score(y_pred, y_test)
svm_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_f = precision_score(y_pred, y_test)
svm_rec_f = recall_score(y_pred, y_test)
svm_f1_f = f1_score(y_pred, y_test)
svm_mcc_f = matthews_corrcoef(y_pred, y_test)
svm_kap_f = cohen_kappa_score(y_pred, y_test)
svm_jacc_f = jaccard_score(y_pred, y_test)
svm_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - rbf',svm_acc_f,svm_roc_f,svm_prec_f,svm_rec_f,svm_f1_f,svm_mcc_f,svm_kap_f,svm_jacc_f,svm_gmea_f)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_f = accuracy_score(y_pred, y_test)
svm1_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_f = precision_score(y_pred, y_test)
svm1_rec_f = recall_score(y_pred, y_test)
svm1_f1_f = f1_score(y_pred, y_test)
svm1_mcc_f = matthews_corrcoef(y_pred, y_test)
svm1_kap_f = cohen_kappa_score(y_pred, y_test)
svm1_jacc_f = jaccard_score(y_pred, y_test)
svm1_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - Poly',svm1_acc_f,svm1_roc_f,svm1_prec_f,svm1_rec_f,svm1_f1_f,svm1_mcc_f,svm1_kap_f,svm1_jacc_f,svm1_gmea_f)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_f = accuracy_score(y_pred, y_test)
svm2_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_f = precision_score(y_pred, y_test)
svm2_rec_f = recall_score(y_pred, y_test)
svm2_f1_f = f1_score(y_pred, y_test)
svm2_mcc_f = matthews_corrcoef(y_pred, y_test)
svm2_kap_f = cohen_kappa_score(y_pred, y_test)
svm2_jacc_f = jaccard_score(y_pred, y_test)
svm2_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - Utility ',svm2_acc_f,svm2_roc_f,svm2_prec_f,svm2_rec_f,svm2_f1_f,svm2_mcc_f,svm2_kap_f,svm2_jacc_f,svm2_gmea_f)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_f = accuracy_score(y_pred, y_test)
svm3_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_f = precision_score(y_pred, y_test)
svm3_rec_f = recall_score(y_pred, y_test)
svm3_f1_f = f1_score(y_pred, y_test)
svm3_mcc_f = matthews_corrcoef(y_pred, y_test)
svm3_kap_f = cohen_kappa_score(y_pred, y_test)
svm3_jacc_f = jaccard_score(y_pred, y_test)
svm3_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - Linear ',svm3_acc_f,svm3_roc_f,svm3_prec_f,svm3_rec_f,svm3_f1_f,svm3_mcc_f,svm3_kap_f,svm3_jacc_f,svm3_gmea_f)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_f = accuracy_score(y_pred, y_test)
svm4_roc_f = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_f = precision_score(y_pred, y_test)
svm4_rec_f = recall_score(y_pred, y_test)
svm4_f1_f = f1_score(y_pred, y_test)
svm4_mcc_f = matthews_corrcoef(y_pred, y_test)
svm4_kap_f = cohen_kappa_score(y_pred, y_test)
svm4_jacc_f = jaccard_score(y_pred, y_test)
svm4_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - SVM - Sigmoid',svm4_acc_f,svm4_roc_f,svm4_prec_f,svm4_rec_f,svm4_f1_f,svm4_mcc_f,svm4_kap_f,svm4_jacc_f,svm4_gmea_f)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_f = accuracy_score(y_pred, y_test)
rf_roc_f = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_f = precision_score(y_pred, y_test)
rf_rec_f = recall_score(y_pred, y_test)
rf_f1_f = f1_score(y_pred, y_test)
rf_mcc_f = matthews_corrcoef(y_pred, y_test)
rf_kap_f = cohen_kappa_score(y_pred, y_test)
rf_jacc_f = jaccard_score(y_pred, y_test)
rf_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - RF',rf_acc_f,rf_roc_f,rf_prec_f,rf_rec_f,rf_f1_f,rf_mcc_f,rf_kap_f,rf_jacc_f,rf_gmea_f)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_f = accuracy_score(y_pred, y_test)
dt_roc_f = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_f = precision_score(y_pred, y_test)
dt_rec_f = recall_score(y_pred, y_test)
dt_f1_f = f1_score(y_pred, y_test)
dt_mcc_f = matthews_corrcoef(y_pred, y_test)
dt_kap_f = cohen_kappa_score(y_pred, y_test)
dt_jacc_f = jaccard_score(y_pred, y_test)
dt_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - DT',dt_acc_f,dt_roc_f,dt_prec_f,dt_rec_f,dt_f1_f,dt_mcc_f,dt_kap_f,dt_jacc_f,dt_gmea_f)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_f = accuracy_score(y_pred, y_test)
nb_roc_f = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_f = precision_score(y_pred, y_test)
nb_rec_f = recall_score(y_pred, y_test)
nb_f1_f = f1_score(y_pred, y_test)
nb_mcc_f = matthews_corrcoef(y_pred, y_test)
nb_kap_f = cohen_kappa_score(y_pred, y_test)
nb_jacc_f = jaccard_score(y_pred, y_test)
nb_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - NB',nb_acc_f,nb_roc_f,nb_prec_f,nb_rec_f,nb_f1_f,nb_mcc_f,nb_kap_f,nb_jacc_f,nb_gmea_f)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_f = accuracy_score(y_pred, y_test)
vot_roc_f = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_f = precision_score(y_pred, y_test)
vot_rec_f = recall_score(y_pred, y_test)
vot_f1_f = f1_score(y_pred, y_test)
vot_mcc_f = matthews_corrcoef(y_pred, y_test)
vot_kap_f = cohen_kappa_score(y_pred, y_test)
vot_jacc_f = jaccard_score(y_pred, y_test)
vot_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - vot',vot_acc_f,vot_roc_f,vot_prec_f,vot_rec_f,vot_f1_f,vot_mcc_f,vot_kap_f,vot_jacc_f,vot_gmea_f)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_f = accuracy_score(y_pred, y_test)
vgg_roc_f = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_f = precision_score(y_pred, y_test)
vgg_rec_f = recall_score(y_pred, y_test)
vgg_f1_f = f1_score(y_pred, y_test)
vgg_mcc_f = matthews_corrcoef(y_pred, y_test)
vgg_kap_f = cohen_kappa_score(y_pred, y_test)
vgg_jacc_f = jaccard_score(y_pred, y_test)
vgg_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - VGGNets',vgg_acc_f,vgg_roc_f,vgg_prec_f,vgg_rec_f,vgg_f1_f,vgg_mcc_f,vgg_kap_f,vgg_jacc_f,vgg_gmea_f)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_15 (Conv1D)           (None, 209, 128)          384
# _________________________________________________________________
# max_pooling1d_15 (MaxPooling (None, 104, 128)          0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 104, 128)          0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 13312)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 26626
# =================================================================
# Total params: 27,010
# Trainable params: 27,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 1s 177ms/step - loss: 0.7011 - accuracy: 0.5000 - val_loss: 0.6244 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.6531 - accuracy: 0.7500 - val_loss: 0.5453 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.4972 - accuracy: 1.0000 - val_loss: 0.4903 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4113 - accuracy: 0.8750 - val_loss: 0.4590 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4614 - accuracy: 0.8750 - val_loss: 0.4510 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6415 - accuracy: 0.8750 - val_loss: 0.4469 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4332 - accuracy: 0.8750 - val_loss: 0.4484 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.9498 - accuracy: 0.7500 - val_loss: 0.4417 - val_accuracy: 0.8846
# Epoch 9/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.9921 - accuracy: 0.6250 - val_loss: 0.4311 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6316 - accuracy: 0.8750 - val_loss: 0.4241 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.3109 - accuracy: 0.8750 - val_loss: 0.4223 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.2149 - accuracy: 1.0000 - val_loss: 0.4202 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3864 - accuracy: 0.8750 - val_loss: 0.4180 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1884 - accuracy: 1.0000 - val_loss: 0.4136 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.3423 - accuracy: 0.8750 - val_loss: 0.4116 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1172 - accuracy: 1.0000 - val_loss: 0.4136 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.3896 - accuracy: 0.8750 - val_loss: 0.4166 - val_accuracy: 0.8846
# Epoch 18/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1057 - accuracy: 1.0000 - val_loss: 0.4235 - val_accuracy: 0.8846
# Epoch 19/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 0.4359 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6093 - accuracy: 0.7500 - val_loss: 0.4436 - val_accuracy: 0.8846
# 6/6 [==============================] - 0s 5ms/step
# 6/6 [==============================] - 0s 997us/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_f = accuracy_score(y_pred, y_test)
res_roc_f = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_f = precision_score(y_pred, y_test)
res_rec_f = recall_score(y_pred, y_test)
res_f1_f = f1_score(y_pred, y_test)
res_mcc_f = matthews_corrcoef(y_pred, y_test)
res_kap_f = cohen_kappa_score(y_pred, y_test)
res_jacc_f = jaccard_score(y_pred, y_test)
res_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - ResNets',res_acc_f,res_roc_f,res_prec_f,res_rec_f,res_f1_f,res_mcc_f,res_kap_f,res_jacc_f,res_gmea_f)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_16 (Conv1D)           (None, 209, 128)          384
# _________________________________________________________________
# max_pooling1d_16 (MaxPooling (None, 104, 128)          0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 104, 128)          0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 13312)             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 26626
# =================================================================
# Total params: 27,010
# Trainable params: 27,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 145ms/step - loss: 0.7035 - accuracy: 0.6250 - val_loss: 0.6134 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5531 - accuracy: 0.8750 - val_loss: 0.5299 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4738 - accuracy: 0.8750 - val_loss: 0.4741 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4344 - accuracy: 0.8750 - val_loss: 0.4520 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3743 - accuracy: 0.8750 - val_loss: 0.4555 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1395 - accuracy: 1.0000 - val_loss: 0.4811 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0648 - accuracy: 1.0000 - val_loss: 0.5269 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.3665 - accuracy: 0.7500 - val_loss: 0.5269 - val_accuracy: 0.8846
# Epoch 9/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0632 - accuracy: 1.0000 - val_loss: 0.5318 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0205 - accuracy: 0.6250 - val_loss: 0.5174 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0791 - accuracy: 1.0000 - val_loss: 0.5078 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0085 - accuracy: 0.8750 - val_loss: 0.4887 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0548 - accuracy: 1.0000 - val_loss: 0.4771 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3293 - accuracy: 0.8750 - val_loss: 0.4686 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1317 - accuracy: 1.0000 - val_loss: 0.4638 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5479 - accuracy: 0.8750 - val_loss: 0.4562 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0775 - accuracy: 1.0000 - val_loss: 0.4530 - val_accuracy: 0.8846
# Epoch 18/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1105 - accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.8846
# Epoch 19/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2874 - accuracy: 0.8750 - val_loss: 0.4550 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0714 - accuracy: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.8846
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_f = accuracy_score(y_pred, y_test)
dense_roc_f = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_f = precision_score(y_pred, y_test)
dense_rec_f = recall_score(y_pred, y_test)
dense_f1_f = f1_score(y_pred, y_test)
dense_mcc_f = matthews_corrcoef(y_pred, y_test)
dense_kap_f = cohen_kappa_score(y_pred, y_test)
dense_jacc_f = jaccard_score(y_pred, y_test)
dense_gmea_f = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-CNV - DenseNets',dense_acc_f,dense_roc_f,dense_prec_f,dense_rec_f,dense_f1_f,dense_mcc_f,dense_kap_f,dense_jacc_f,dense_gmea_f)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_17 (Conv1D)           (None, 209, 128)          384
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 104, 128)          0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 104, 128)          0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 13312)             0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 26626
# =================================================================
# Total params: 27,010
# Trainable params: 27,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 147ms/step - loss: 0.6386 - accuracy: 0.6250 - val_loss: 0.5597 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5324 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2935 - accuracy: 1.0000 - val_loss: 0.4678 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.2992 - accuracy: 0.8750 - val_loss: 0.4723 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1848 - accuracy: 0.8750 - val_loss: 0.4910 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1405 - accuracy: 1.0000 - val_loss: 0.5162 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0990 - accuracy: 1.0000 - val_loss: 0.5501 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.6966 - accuracy: 0.8750 - val_loss: 0.5809 - val_accuracy: 0.8846
# Epoch 9/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0630 - accuracy: 1.0000 - val_loss: 0.6035 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.0043 - accuracy: 0.7500 - val_loss: 0.5997 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0768 - accuracy: 1.0000 - val_loss: 0.5967 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.5985 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.4117 - accuracy: 0.8750 - val_loss: 0.5757 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3891 - accuracy: 0.8750 - val_loss: 0.5519 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3696 - accuracy: 0.8750 - val_loss: 0.5318 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.7180 - accuracy: 0.8750 - val_loss: 0.5146 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1069 - accuracy: 1.0000 - val_loss: 0.5002 - val_accuracy: 0.8846
# Epoch 18/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0791 - accuracy: 1.0000 - val_loss: 0.4922 - val_accuracy: 0.8846
# Epoch 19/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.7353 - accuracy: 0.8750 - val_loss: 0.4827 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4911 - accuracy: 0.8750 - val_loss: 0.4695 - val_accuracy: 0.8846
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # CLN-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 810), (907,), (161, 810), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_g = accuracy_score(y_pred, y_test)
svm_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_g = precision_score(y_pred, y_test)
svm_rec_g = recall_score(y_pred, y_test)
svm_f1_g = f1_score(y_pred, y_test)
svm_mcc_g = matthews_corrcoef(y_pred, y_test)
svm_kap_g = cohen_kappa_score(y_pred, y_test)
svm_jacc_g = jaccard_score(y_pred, y_test)
svm_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - rbf',svm_acc_g,svm_roc_g,svm_prec_g,svm_rec_g,svm_f1_g,svm_mcc_g,svm_kap_g,svm_jacc_g,svm_gmea_g)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_g = accuracy_score(y_pred, y_test)
svm1_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_g = precision_score(y_pred, y_test)
svm1_rec_g = recall_score(y_pred, y_test)
svm1_f1_g = f1_score(y_pred, y_test)
svm1_mcc_g = matthews_corrcoef(y_pred, y_test)
svm1_kap_g = cohen_kappa_score(y_pred, y_test)
svm1_jacc_g = jaccard_score(y_pred, y_test)
svm1_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - Poly',svm1_acc_g,svm1_roc_g,svm1_prec_g,svm1_rec_g,svm1_f1_g,svm1_mcc_g,svm1_kap_g,svm1_jacc_g,svm1_gmea_g)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_g = accuracy_score(y_pred, y_test)
svm2_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_g = precision_score(y_pred, y_test)
svm2_rec_g = recall_score(y_pred, y_test)
svm2_f1_g = f1_score(y_pred, y_test)
svm2_mcc_g = matthews_corrcoef(y_pred, y_test)
svm2_kap_g = cohen_kappa_score(y_pred, y_test)
svm2_jacc_g = jaccard_score(y_pred, y_test)
svm2_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - Utility ',svm2_acc_g,svm2_roc_g,svm2_prec_g,svm2_rec_g,svm2_f1_g,svm2_mcc_g,svm2_kap_g,svm2_jacc_g,svm2_gmea_g)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_g = accuracy_score(y_pred, y_test)
svm3_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_g = precision_score(y_pred, y_test)
svm3_rec_g = recall_score(y_pred, y_test)
svm3_f1_g = f1_score(y_pred, y_test)
svm3_mcc_g = matthews_corrcoef(y_pred, y_test)
svm3_kap_g = cohen_kappa_score(y_pred, y_test)
svm3_jacc_g = jaccard_score(y_pred, y_test)
svm3_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - Linear ',svm3_acc_g,svm3_roc_g,svm3_prec_g,svm3_rec_g,svm3_f1_g,svm3_mcc_g,svm3_kap_g,svm3_jacc_g,svm3_gmea_g)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_g = accuracy_score(y_pred, y_test)
svm4_roc_g = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_g = precision_score(y_pred, y_test)
svm4_rec_g = recall_score(y_pred, y_test)
svm4_f1_g = f1_score(y_pred, y_test)
svm4_mcc_g = matthews_corrcoef(y_pred, y_test)
svm4_kap_g = cohen_kappa_score(y_pred, y_test)
svm4_jacc_g = jaccard_score(y_pred, y_test)
svm4_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - SVM - Sigmoid',svm4_acc_g,svm4_roc_g,svm4_prec_g,svm4_rec_g,svm4_f1_g,svm4_mcc_g,svm4_kap_g,svm4_jacc_g,svm4_gmea_g)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_g = accuracy_score(y_pred, y_test)
rf_roc_g = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_g = precision_score(y_pred, y_test)
rf_rec_g = recall_score(y_pred, y_test)
rf_f1_g = f1_score(y_pred, y_test)
rf_mcc_g = matthews_corrcoef(y_pred, y_test)
rf_kap_g = cohen_kappa_score(y_pred, y_test)
rf_jacc_g = jaccard_score(y_pred, y_test)
rf_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - RF',rf_acc_g,rf_roc_g,rf_prec_g,rf_rec_g,rf_f1_g,rf_mcc_g,rf_kap_g,rf_jacc_g,rf_gmea_g)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_g = accuracy_score(y_pred, y_test)
dt_roc_g = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_g = precision_score(y_pred, y_test)
dt_rec_g = recall_score(y_pred, y_test)
dt_f1_g = f1_score(y_pred, y_test)
dt_mcc_g = matthews_corrcoef(y_pred, y_test)
dt_kap_g = cohen_kappa_score(y_pred, y_test)
dt_jacc_g = jaccard_score(y_pred, y_test)
dt_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - DT',dt_acc_g,dt_roc_g,dt_prec_g,dt_rec_g,dt_f1_g,dt_mcc_g,dt_kap_g,dt_jacc_g,dt_gmea_g)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_g = accuracy_score(y_pred, y_test)
nb_roc_g = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_g = precision_score(y_pred, y_test)
nb_rec_g = recall_score(y_pred, y_test)
nb_f1_g = f1_score(y_pred, y_test)
nb_mcc_g = matthews_corrcoef(y_pred, y_test)
nb_kap_g = cohen_kappa_score(y_pred, y_test)
nb_jacc_g = jaccard_score(y_pred, y_test)
nb_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - NB',nb_acc_g,nb_roc_g,nb_prec_g,nb_rec_g,nb_f1_g,nb_mcc_g,nb_kap_g,nb_jacc_g,nb_gmea_g)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_g = accuracy_score(y_pred, y_test)
vot_roc_g = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_g = precision_score(y_pred, y_test)
vot_rec_g = recall_score(y_pred, y_test)
vot_f1_g = f1_score(y_pred, y_test)
vot_mcc_g = matthews_corrcoef(y_pred, y_test)
vot_kap_g = cohen_kappa_score(y_pred, y_test)
vot_jacc_g = jaccard_score(y_pred, y_test)
vot_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - vot',vot_acc_g,vot_roc_g,vot_prec_g,vot_rec_g,vot_f1_g,vot_mcc_g,vot_kap_g,vot_jacc_g,vot_gmea_g)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_g = accuracy_score(y_pred, y_test)
vgg_roc_g = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_g = precision_score(y_pred, y_test)
vgg_rec_g = recall_score(y_pred, y_test)
vgg_f1_g = f1_score(y_pred, y_test)
vgg_mcc_g = matthews_corrcoef(y_pred, y_test)
vgg_kap_g = cohen_kappa_score(y_pred, y_test)
vgg_jacc_g = jaccard_score(y_pred, y_test)
vgg_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - VGGNets',vgg_acc_g,vgg_roc_g,vgg_prec_g,vgg_rec_g,vgg_f1_g,vgg_mcc_g,vgg_kap_g,vgg_jacc_g,vgg_gmea_g)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_18 (Conv1D)           (None, 809, 128)          384
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, 404, 128)          0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 404, 128)          0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 51712)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 2)                 103426
# =================================================================
# Total params: 103,810
# Trainable params: 103,810
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 154ms/step - loss: 1.0065 - accuracy: 0.6250 - val_loss: 11.3749 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 72ms/step - loss: 12.3942 - accuracy: 0.8750 - val_loss: 16.4133 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 18.6952 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 78ms/step - loss: 20.6265 - accuracy: 0.8750 - val_loss: 19.4107 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 83ms/step - loss: 23.9407 - accuracy: 0.8750 - val_loss: 17.4024 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 72ms/step - loss: 17.2030 - accuracy: 0.7500 - val_loss: 14.6678 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 72ms/step - loss: 33.5097 - accuracy: 0.7500 - val_loss: 10.5833 - val_accuracy: 0.8846
# Epoch 8/20
# 2/2 [==============================] - 0s 79ms/step - loss: 2.5956 - accuracy: 0.8750 - val_loss: 6.5099 - val_accuracy: 0.8681
# Epoch 9/20
# 2/2 [==============================] - 0s 87ms/step - loss: 6.5729 - accuracy: 0.8750 - val_loss: 4.7200 - val_accuracy: 0.6813
# Epoch 10/20
# 2/2 [==============================] - 0s 76ms/step - loss: 18.6569 - accuracy: 0.3750 - val_loss: 11.1127 - val_accuracy: 0.3571
# Epoch 11/20
# 2/2 [==============================] - 0s 83ms/step - loss: 7.0990 - accuracy: 0.3750 - val_loss: 4.5293 - val_accuracy: 0.6813
# Epoch 12/20
# 2/2 [==============================] - 0s 78ms/step - loss: 1.3258 - accuracy: 0.8750 - val_loss: 4.7074 - val_accuracy: 0.8407
# Epoch 13/20
# 2/2 [==============================] - 0s 76ms/step - loss: 7.9908 - accuracy: 0.7500 - val_loss: 6.0451 - val_accuracy: 0.8681
# Epoch 14/20
# 2/2 [==============================] - 0s 81ms/step - loss: 1.5374 - accuracy: 0.8750 - val_loss: 6.8218 - val_accuracy: 0.8736
# Epoch 15/20
# 2/2 [==============================] - 0s 78ms/step - loss: 4.1723e-07 - accuracy: 1.0000 - val_loss: 7.5146 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 74ms/step - loss: 9.7821 - accuracy: 0.8750 - val_loss: 7.7280 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 75ms/step - loss: 23.8265 - accuracy: 0.7500 - val_loss: 6.3876 - val_accuracy: 0.8846
# Epoch 18/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.9834 - val_accuracy: 0.8736
# Epoch 19/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.8911 - val_accuracy: 0.8681
# Epoch 20/20
# 2/2 [==============================] - 0s 78ms/step - loss: 10.7235 - accuracy: 0.7500 - val_loss: 2.0817 - val_accuracy: 0.8297
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 0s/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_g = accuracy_score(y_pred, y_test)
res_roc_g = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_g = precision_score(y_pred, y_test)
res_rec_g = recall_score(y_pred, y_test)
res_f1_g = f1_score(y_pred, y_test)
res_mcc_g = matthews_corrcoef(y_pred, y_test)
res_kap_g = cohen_kappa_score(y_pred, y_test)
res_jacc_g = jaccard_score(y_pred, y_test)
res_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - ResNets',res_acc_g,res_roc_g,res_prec_g,res_rec_g,res_f1_g,res_mcc_g,res_kap_g,res_jacc_g,res_gmea_g)
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_19 (Conv1D)           (None, 809, 128)          384
# _________________________________________________________________
# max_pooling1d_19 (MaxPooling (None, 404, 128)          0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 404, 128)          0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 51712)             0
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 103426
# =================================================================
# Total params: 103,810
# Trainable params: 103,810
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 147ms/step - loss: 0.7504 - accuracy: 0.7500 - val_loss: 11.2802 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 74ms/step - loss: 25.2741 - accuracy: 0.7500 - val_loss: 13.4451 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 73ms/step - loss: 21.5456 - accuracy: 0.7500 - val_loss: 11.4139 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 83ms/step - loss: 26.0103 - accuracy: 0.7500 - val_loss: 7.1537 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 74ms/step - loss: 6.8954 - accuracy: 0.8750 - val_loss: 2.8178 - val_accuracy: 0.8791
# Epoch 6/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.2767 - accuracy: 0.8750 - val_loss: 3.4273 - val_accuracy: 0.3242
# Epoch 7/20
# 2/2 [==============================] - 0s 78ms/step - loss: 5.3561 - accuracy: 0.3750 - val_loss: 0.9706 - val_accuracy: 0.6978
# Epoch 8/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1469 - accuracy: 0.8750 - val_loss: 2.7998 - val_accuracy: 0.8846
# Epoch 9/20
# 2/2 [==============================] - 0s 74ms/step - loss: 1.1656e-04 - accuracy: 1.0000 - val_loss: 4.9086 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.6194 - val_accuracy: 0.8846
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.0141 - val_accuracy: 0.8846
# Epoch 12/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.1558 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 74ms/step - loss: 5.4313 - accuracy: 0.8750 - val_loss: 9.8190 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.1149 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 72ms/step - loss: 10.6352 - accuracy: 0.7500 - val_loss: 9.9069 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 74ms/step - loss: 23.1564 - accuracy: 0.7500 - val_loss: 7.6796 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 86ms/step - loss: 7.5444 - accuracy: 0.8750 - val_loss: 5.4346 - val_accuracy: 0.8846
# Epoch 18/20
# 2/2 [==============================] - 0s 72ms/step - loss: 6.6793 - accuracy: 0.8750 - val_loss: 2.7706 - val_accuracy: 0.8846
# Epoch 19/20
# 2/2 [==============================] - 0s 72ms/step - loss: 4.2304 - accuracy: 0.8750 - val_loss: 2.4975 - val_accuracy: 0.4670
# Epoch 20/20
# 2/2 [==============================] - 0s 79ms/step - loss: 4.3264 - accuracy: 0.2500 - val_loss: 1.8540 - val_accuracy: 0.5659
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_g = accuracy_score(y_pred, y_test)
dense_roc_g = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_g = precision_score(y_pred, y_test)
dense_rec_g = recall_score(y_pred, y_test)
dense_f1_g = f1_score(y_pred, y_test)
dense_mcc_g = matthews_corrcoef(y_pred, y_test)
dense_kap_g = cohen_kappa_score(y_pred, y_test)
dense_jacc_g = jaccard_score(y_pred, y_test)
dense_gmea_g = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI - DenseNets',dense_acc_g,dense_roc_g,dense_prec_g,dense_rec_g,dense_f1_g,dense_mcc_g,dense_kap_g,dense_jacc_g,dense_gmea_g)
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_20 (Conv1D)           (None, 809, 128)          384
# _________________________________________________________________
# max_pooling1d_20 (MaxPooling (None, 404, 128)          0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 404, 128)          0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 51712)             0
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 103426
# =================================================================
# Total params: 103,810
# Trainable params: 103,810
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 146ms/step - loss: 1.3063 - accuracy: 0.6250 - val_loss: 10.5762 - val_accuracy: 0.8846
# Epoch 2/20
# 2/2 [==============================] - 0s 73ms/step - loss: 9.7413 - accuracy: 0.8750 - val_loss: 13.6994 - val_accuracy: 0.8846
# Epoch 3/20
# 2/2 [==============================] - 0s 71ms/step - loss: 16.6427 - accuracy: 0.8750 - val_loss: 13.5961 - val_accuracy: 0.8846
# Epoch 4/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 13.5164 - val_accuracy: 0.8846
# Epoch 5/20
# 2/2 [==============================] - 0s 76ms/step - loss: 25.8413 - accuracy: 0.7500 - val_loss: 11.0573 - val_accuracy: 0.8846
# Epoch 6/20
# 2/2 [==============================] - 0s 74ms/step - loss: 17.4163 - accuracy: 0.7500 - val_loss: 7.6362 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 73ms/step - loss: 19.9951 - accuracy: 0.6250 - val_loss: 3.8930 - val_accuracy: 0.7857
# Epoch 8/20
# 2/2 [==============================] - 0s 72ms/step - loss: 2.7911 - accuracy: 0.6250 - val_loss: 7.3825 - val_accuracy: 0.4176
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.1457 - accuracy: 0.5000 - val_loss: 5.9316 - val_accuracy: 0.4890
# Epoch 10/20
# 2/2 [==============================] - 0s 71ms/step - loss: 3.1526 - accuracy: 0.8750 - val_loss: 3.6271 - val_accuracy: 0.7967
# Epoch 11/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3321 - accuracy: 0.8750 - val_loss: 5.1191 - val_accuracy: 0.8791
# Epoch 12/20
# 2/2 [==============================] - 0s 76ms/step - loss: 8.5218 - accuracy: 0.6250 - val_loss: 6.1053 - val_accuracy: 0.8846
# Epoch 13/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.2812 - val_accuracy: 0.8846
# Epoch 14/20
# 2/2 [==============================] - 0s 82ms/step - loss: 6.3426 - accuracy: 0.8750 - val_loss: 5.6649 - val_accuracy: 0.8846
# Epoch 15/20
# 2/2 [==============================] - 0s 74ms/step - loss: 6.5389 - accuracy: 0.7500 - val_loss: 4.6169 - val_accuracy: 0.8681
# Epoch 16/20
# 2/2 [==============================] - 0s 75ms/step - loss: 6.8532 - accuracy: 0.7500 - val_loss: 3.4836 - val_accuracy: 0.8132
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 11.3472 - accuracy: 0.2500 - val_loss: 6.2699 - val_accuracy: 0.4121
# Epoch 18/20
# 2/2 [==============================] - 0s 82ms/step - loss: 6.5438 - accuracy: 0.2500 - val_loss: 4.9041 - val_accuracy: 0.4615
# Epoch 19/20
# 2/2 [==============================] - 0s 206ms/step - loss: 8.2479 - accuracy: 0.1250 - val_loss: 2.4979 - val_accuracy: 0.8462
# Epoch 20/20
# 2/2 [==============================] - 0s 75ms/step - loss: 3.1137 - accuracy: 0.6250 - val_loss: 3.0422 - val_accuracy: 0.8846
# 6/6 [==============================] - 0s 984us/step
# 6/6 [==============================] - 0s 0s/step

# %% [markdown]
# # EXP-CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(EXP_CNV, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 600), (907,), (161, 600), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_h = accuracy_score(y_pred, y_test)
svm_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_h = precision_score(y_pred, y_test)
svm_rec_h = recall_score(y_pred, y_test)
svm_f1_h = f1_score(y_pred, y_test)
svm_mcc_h = matthews_corrcoef(y_pred, y_test)
svm_kap_h = cohen_kappa_score(y_pred, y_test)
svm_jacc_h = jaccard_score(y_pred, y_test)
svm_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - rbf',svm_acc_h,svm_roc_h,svm_prec_h,svm_rec_h,svm_f1_h,svm_mcc_h,svm_kap_h,svm_jacc_h,svm_gmea_h)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_h = accuracy_score(y_pred, y_test)
svm1_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_h = precision_score(y_pred, y_test)
svm1_rec_h = recall_score(y_pred, y_test)
svm1_f1_h = f1_score(y_pred, y_test)
svm1_mcc_h = matthews_corrcoef(y_pred, y_test)
svm1_kap_h = cohen_kappa_score(y_pred, y_test)
svm1_jacc_h = jaccard_score(y_pred, y_test)
svm1_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - Poly',svm1_acc_h,svm1_roc_h,svm1_prec_h,svm1_rec_h,svm1_f1_h,svm1_mcc_h,svm1_kap_h,svm1_jacc_h,svm1_gmea_h)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_h = accuracy_score(y_pred, y_test)
svm2_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_h = precision_score(y_pred, y_test)
svm2_rec_h = recall_score(y_pred, y_test)
svm2_f1_h = f1_score(y_pred, y_test)
svm2_mcc_h = matthews_corrcoef(y_pred, y_test)
svm2_kap_h = cohen_kappa_score(y_pred, y_test)
svm2_jacc_h = jaccard_score(y_pred, y_test)
svm2_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - Utility ',svm2_acc_h,svm2_roc_h,svm2_prec_h,svm2_rec_h,svm2_f1_h,svm2_mcc_h,svm2_kap_h,svm2_jacc_h,svm2_gmea_h)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_h = accuracy_score(y_pred, y_test)
svm3_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_h = precision_score(y_pred, y_test)
svm3_rec_h = recall_score(y_pred, y_test)
svm3_f1_h = f1_score(y_pred, y_test)
svm3_mcc_h = matthews_corrcoef(y_pred, y_test)
svm3_kap_h = cohen_kappa_score(y_pred, y_test)
svm3_jacc_h = jaccard_score(y_pred, y_test)
svm3_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - Linear ',svm3_acc_h,svm3_roc_h,svm3_prec_h,svm3_rec_h,svm3_f1_h,svm3_mcc_h,svm3_kap_h,svm3_jacc_h,svm3_gmea_h)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_h = accuracy_score(y_pred, y_test)
svm4_roc_h = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_h = precision_score(y_pred, y_test)
svm4_rec_h = recall_score(y_pred, y_test)
svm4_f1_h = f1_score(y_pred, y_test)
svm4_mcc_h = matthews_corrcoef(y_pred, y_test)
svm4_kap_h = cohen_kappa_score(y_pred, y_test)
svm4_jacc_h = jaccard_score(y_pred, y_test)
svm4_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - SVM - Sigmoid',svm4_acc_h,svm4_roc_h,svm4_prec_h,svm4_rec_h,svm4_f1_h,svm4_mcc_h,svm4_kap_h,svm4_jacc_h,svm4_gmea_h)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_h = accuracy_score(y_pred, y_test)
rf_roc_h = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_h = precision_score(y_pred, y_test)
rf_rec_h = recall_score(y_pred, y_test)
rf_f1_h = f1_score(y_pred, y_test)
rf_mcc_h = matthews_corrcoef(y_pred, y_test)
rf_kap_h = cohen_kappa_score(y_pred, y_test)
rf_jacc_h = jaccard_score(y_pred, y_test)
rf_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - RF',rf_acc_h,rf_roc_h,rf_prec_h,rf_rec_h,rf_f1_h,rf_mcc_h,rf_kap_h,rf_jacc_h,rf_gmea_h)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_h = accuracy_score(y_pred, y_test)
dt_roc_h = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_h = precision_score(y_pred, y_test)
dt_rec_h = recall_score(y_pred, y_test)
dt_f1_h = f1_score(y_pred, y_test)
dt_mcc_h = matthews_corrcoef(y_pred, y_test)
dt_kap_h = cohen_kappa_score(y_pred, y_test)
dt_jacc_h = jaccard_score(y_pred, y_test)
dt_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - DT',dt_acc_h,dt_roc_h,dt_prec_h,dt_rec_h,dt_f1_h,dt_mcc_h,dt_kap_h,dt_jacc_h,dt_gmea_h)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_h = accuracy_score(y_pred, y_test)
nb_roc_h = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_h = precision_score(y_pred, y_test)
nb_rec_h = recall_score(y_pred, y_test)
nb_f1_h = f1_score(y_pred, y_test)
nb_mcc_h = matthews_corrcoef(y_pred, y_test)
nb_kap_h = cohen_kappa_score(y_pred, y_test)
nb_jacc_h = jaccard_score(y_pred, y_test)
nb_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - NB',nb_acc_h,nb_roc_h,nb_prec_h,nb_rec_h,nb_f1_h,nb_mcc_h,nb_kap_h,nb_jacc_h,nb_gmea_h)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_h = accuracy_score(y_pred, y_test)
vot_roc_h = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_h = precision_score(y_pred, y_test)
vot_rec_h = recall_score(y_pred, y_test)
vot_f1_h = f1_score(y_pred, y_test)
vot_mcc_h = matthews_corrcoef(y_pred, y_test)
vot_kap_h = cohen_kappa_score(y_pred, y_test)
vot_jacc_h = jaccard_score(y_pred, y_test)
vot_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - vot',vot_acc_h,vot_roc_h,vot_prec_h,vot_rec_h,vot_f1_h,vot_mcc_h,vot_kap_h,vot_jacc_h,vot_gmea_h)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_h = accuracy_score(y_pred, y_test)
vgg_roc_h = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_h = precision_score(y_pred, y_test)
vgg_rec_h = recall_score(y_pred, y_test)
vgg_f1_h = f1_score(y_pred, y_test)
vgg_mcc_h = matthews_corrcoef(y_pred, y_test)
vgg_kap_h = cohen_kappa_score(y_pred, y_test)
vgg_jacc_h = jaccard_score(y_pred, y_test)
vgg_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - VGGNets',vgg_acc_h,vgg_roc_h,vgg_prec_h,vgg_rec_h,vgg_f1_h,vgg_mcc_h,vgg_kap_h,vgg_jacc_h,vgg_gmea_h)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_21 (Conv1D)           (None, 599, 128)          384
# _________________________________________________________________
# max_pooling1d_21 (MaxPooling (None, 299, 128)          0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 299, 128)          0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 38272)             0
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 76546
# =================================================================
# Total params: 76,930
# Trainable params: 76,930
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 156ms/step - loss: 0.6645 - accuracy: 0.7500 - val_loss: 0.4605 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5426 - accuracy: 0.8750 - val_loss: 0.3750 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.2396 - accuracy: 1.0000 - val_loss: 0.3895 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5697 - accuracy: 0.8750 - val_loss: 0.4535 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.5053 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5622 - accuracy: 0.8750 - val_loss: 0.5410 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5168 - accuracy: 0.8750 - val_loss: 0.5160 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4301 - accuracy: 0.8750 - val_loss: 0.4888 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.4648 - val_accuracy: 0.8956
# Epoch 10/20
# 2/2 [==============================] - 0s 78ms/step - loss: 1.0813 - accuracy: 0.6250 - val_loss: 0.4251 - val_accuracy: 0.8956
# Epoch 11/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 0.4034 - val_accuracy: 0.8956
# Epoch 12/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7124 - accuracy: 0.8750 - val_loss: 0.3828 - val_accuracy: 0.8956
# Epoch 13/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1709 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.9358 - accuracy: 0.6250 - val_loss: 0.3702 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.6244 - accuracy: 0.7500 - val_loss: 0.3753 - val_accuracy: 0.8901
# Epoch 16/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.2750 - accuracy: 0.8750 - val_loss: 0.3949 - val_accuracy: 0.8791
# Epoch 17/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6941 - accuracy: 0.7500 - val_loss: 0.4237 - val_accuracy: 0.8791
# Epoch 18/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4943 - accuracy: 0.7500 - val_loss: 0.4585 - val_accuracy: 0.8462
# Epoch 19/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4795 - accuracy: 0.8750 - val_loss: 0.4632 - val_accuracy: 0.8571
# Epoch 20/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.3883 - accuracy: 1.0000 - val_loss: 0.4409 - val_accuracy: 0.8681
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_h = accuracy_score(y_pred, y_test)
res_roc_h = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_h = precision_score(y_pred, y_test)
res_rec_h = recall_score(y_pred, y_test)
res_f1_h = f1_score(y_pred, y_test)
res_mcc_h = matthews_corrcoef(y_pred, y_test)
res_kap_h = cohen_kappa_score(y_pred, y_test)
res_jacc_h = jaccard_score(y_pred, y_test)
res_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - ResNets',res_acc_h,res_roc_h,res_prec_h,res_rec_h,res_f1_h,res_mcc_h,res_kap_h,res_jacc_h,res_gmea_h)
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_22 (Conv1D)           (None, 599, 128)          384
# _________________________________________________________________
# max_pooling1d_22 (MaxPooling (None, 299, 128)          0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 299, 128)          0
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 38272)             0
# _________________________________________________________________
# dense_22 (Dense)             (None, 2)                 76546
# =================================================================
# Total params: 76,930
# Trainable params: 76,930
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 145ms/step - loss: 0.5756 - accuracy: 1.0000 - val_loss: 0.3865 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3950 - accuracy: 0.8750 - val_loss: 0.3906 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0677 - accuracy: 1.0000 - val_loss: 0.4581 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6011 - accuracy: 0.8750 - val_loss: 0.4930 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5618 - accuracy: 0.8750 - val_loss: 0.5183 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0505 - accuracy: 0.8750 - val_loss: 0.5111 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7006 - accuracy: 0.8750 - val_loss: 0.4691 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3795 - accuracy: 0.8750 - val_loss: 0.4385 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3498 - accuracy: 0.8750 - val_loss: 0.4179 - val_accuracy: 0.8956
# Epoch 10/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5664 - accuracy: 0.8750 - val_loss: 0.4029 - val_accuracy: 0.8956
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8318 - accuracy: 0.7500 - val_loss: 0.3842 - val_accuracy: 0.8956
# Epoch 12/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1868 - accuracy: 1.0000 - val_loss: 0.3781 - val_accuracy: 0.8956
# Epoch 13/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.7102 - accuracy: 0.7500 - val_loss: 0.3752 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.7752 - accuracy: 0.6250 - val_loss: 0.3834 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7333 - accuracy: 0.7500 - val_loss: 0.4222 - val_accuracy: 0.8791
# Epoch 16/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5036 - accuracy: 0.7500 - val_loss: 0.4811 - val_accuracy: 0.8187
# Epoch 17/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5410 - accuracy: 0.8750 - val_loss: 0.4967 - val_accuracy: 0.8022
# Epoch 18/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5348 - accuracy: 0.8750 - val_loss: 0.4544 - val_accuracy: 0.8407
# Epoch 19/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4521 - accuracy: 0.8750 - val_loss: 0.4046 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8083 - accuracy: 0.6250 - val_loss: 0.3839 - val_accuracy: 0.8901
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_h = accuracy_score(y_pred, y_test)
dense_roc_h = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_h = precision_score(y_pred, y_test)
dense_rec_h = recall_score(y_pred, y_test)
dense_f1_h = f1_score(y_pred, y_test)
dense_mcc_h = matthews_corrcoef(y_pred, y_test)
dense_kap_h = cohen_kappa_score(y_pred, y_test)
dense_jacc_h = jaccard_score(y_pred, y_test)
dense_gmea_h = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - DenseNets',dense_acc_h,dense_roc_h,dense_prec_h,dense_rec_h,dense_f1_h,dense_mcc_h,dense_kap_h,dense_jacc_h,dense_gmea_h)
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_23 (Conv1D)           (None, 599, 128)          384
# _________________________________________________________________
# max_pooling1d_23 (MaxPooling (None, 299, 128)          0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 299, 128)          0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 38272)             0
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 76546
# =================================================================
# Total params: 76,930
# Trainable params: 76,930
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.6765 - accuracy: 0.5000 - val_loss: 0.5822 - val_accuracy: 0.8681
# Epoch 2/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5009 - accuracy: 1.0000 - val_loss: 0.4040 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5174 - accuracy: 0.7500 - val_loss: 0.3938 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4897 - accuracy: 0.8750 - val_loss: 0.4352 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0876 - accuracy: 1.0000 - val_loss: 0.4851 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.6070 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6804 - accuracy: 0.8750 - val_loss: 0.6467 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.6626 - val_accuracy: 0.8956
# Epoch 10/20
# 2/2 [==============================] - 0s 71ms/step - loss: 2.2510 - accuracy: 0.6250 - val_loss: 0.6096 - val_accuracy: 0.8956
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.5003 - accuracy: 0.7500 - val_loss: 0.5241 - val_accuracy: 0.8956
# Epoch 12/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6480 - accuracy: 0.8750 - val_loss: 0.4597 - val_accuracy: 0.8956
# Epoch 13/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1020 - accuracy: 1.0000 - val_loss: 0.4322 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1535 - accuracy: 1.0000 - val_loss: 0.4234 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4124 - accuracy: 0.8750 - val_loss: 0.4209 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8191 - accuracy: 0.6250 - val_loss: 0.4227 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7970 - accuracy: 0.8750 - val_loss: 0.4342 - val_accuracy: 0.8736
# Epoch 18/20
# 2/2 [==============================] - 0s 75ms/step - loss: 1.1236 - accuracy: 0.6250 - val_loss: 0.4725 - val_accuracy: 0.8187
# Epoch 19/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3669 - accuracy: 1.0000 - val_loss: 0.5007 - val_accuracy: 0.8022
# Epoch 20/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4280 - accuracy: 0.8750 - val_loss: 0.4809 - val_accuracy: 0.8297
# 6/6 [==============================] - 0s 997us/step
# 6/6 [==============================] - 0s 997us/step

# %% [markdown]
# # EXP-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(EXP_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1200), (907,), (161, 1200), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_i = accuracy_score(y_pred, y_test)
svm_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_i = precision_score(y_pred, y_test)
svm_rec_i = recall_score(y_pred, y_test)
svm_f1_i = f1_score(y_pred, y_test)
svm_mcc_i = matthews_corrcoef(y_pred, y_test)
svm_kap_i = cohen_kappa_score(y_pred, y_test)
svm_jacc_i = jaccard_score(y_pred, y_test)
svm_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - rbf',svm_acc_i,svm_roc_i,svm_prec_i,svm_rec_i,svm_f1_i,svm_mcc_i,svm_kap_i,svm_jacc_i,svm_gmea_i)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_i = accuracy_score(y_pred, y_test)
svm1_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_i = precision_score(y_pred, y_test)
svm1_rec_i = recall_score(y_pred, y_test)
svm1_f1_i = f1_score(y_pred, y_test)
svm1_mcc_i = matthews_corrcoef(y_pred, y_test)
svm1_kap_i = cohen_kappa_score(y_pred, y_test)
svm1_jacc_i = jaccard_score(y_pred, y_test)
svm1_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - Poly',svm1_acc_i,svm1_roc_i,svm1_prec_i,svm1_rec_i,svm1_f1_i,svm1_mcc_i,svm1_kap_i,svm1_jacc_i,svm1_gmea_i)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_i = accuracy_score(y_pred, y_test)
svm2_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_i = precision_score(y_pred, y_test)
svm2_rec_i = recall_score(y_pred, y_test)
svm2_f1_i = f1_score(y_pred, y_test)
svm2_mcc_i = matthews_corrcoef(y_pred, y_test)
svm2_kap_i = cohen_kappa_score(y_pred, y_test)
svm2_jacc_i = jaccard_score(y_pred, y_test)
svm2_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - Utility ',svm2_acc_i,svm2_roc_i,svm2_prec_i,svm2_rec_i,svm2_f1_i,svm2_mcc_i,svm2_kap_i,svm2_jacc_i,svm2_gmea_i)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_i = accuracy_score(y_pred, y_test)
svm3_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_i = precision_score(y_pred, y_test)
svm3_rec_i = recall_score(y_pred, y_test)
svm3_f1_i = f1_score(y_pred, y_test)
svm3_mcc_i = matthews_corrcoef(y_pred, y_test)
svm3_kap_i = cohen_kappa_score(y_pred, y_test)
svm3_jacc_i = jaccard_score(y_pred, y_test)
svm3_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - Linear ',svm3_acc_i,svm3_roc_i,svm3_prec_i,svm3_rec_i,svm3_f1_i,svm3_mcc_i,svm3_kap_i,svm3_jacc_i,svm3_gmea_i)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_i = accuracy_score(y_pred, y_test)
svm4_roc_i = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_i = precision_score(y_pred, y_test)
svm4_rec_i = recall_score(y_pred, y_test)
svm4_f1_i = f1_score(y_pred, y_test)
svm4_mcc_i = matthews_corrcoef(y_pred, y_test)
svm4_kap_i = cohen_kappa_score(y_pred, y_test)
svm4_jacc_i = jaccard_score(y_pred, y_test)
svm4_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - SVM - Sigmoid',svm4_acc_i,svm4_roc_i,svm4_prec_i,svm4_rec_i,svm4_f1_i,svm4_mcc_i,svm4_kap_i,svm4_jacc_i,svm4_gmea_i)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_i = accuracy_score(y_pred, y_test)
rf_roc_i = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_i = precision_score(y_pred, y_test)
rf_rec_i = recall_score(y_pred, y_test)
rf_f1_i = f1_score(y_pred, y_test)
rf_mcc_i = matthews_corrcoef(y_pred, y_test)
rf_kap_i = cohen_kappa_score(y_pred, y_test)
rf_jacc_i = jaccard_score(y_pred, y_test)
rf_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - RF',rf_acc_i,rf_roc_i,rf_prec_i,rf_rec_i,rf_f1_i,rf_mcc_i,rf_kap_i,rf_jacc_i,rf_gmea_i)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_i = accuracy_score(y_pred, y_test)
dt_roc_i = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_i = precision_score(y_pred, y_test)
dt_rec_i = recall_score(y_pred, y_test)
dt_f1_i = f1_score(y_pred, y_test)
dt_mcc_i = matthews_corrcoef(y_pred, y_test)
dt_kap_i = cohen_kappa_score(y_pred, y_test)
dt_jacc_i = jaccard_score(y_pred, y_test)
dt_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - DT',dt_acc_i,dt_roc_i,dt_prec_i,dt_rec_i,dt_f1_i,dt_mcc_i,dt_kap_i,dt_jacc_i,dt_gmea_i)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_i = accuracy_score(y_pred, y_test)
nb_roc_i = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_i = precision_score(y_pred, y_test)
nb_rec_i = recall_score(y_pred, y_test)
nb_f1_i = f1_score(y_pred, y_test)
nb_mcc_i = matthews_corrcoef(y_pred, y_test)
nb_kap_i = cohen_kappa_score(y_pred, y_test)
nb_jacc_i = jaccard_score(y_pred, y_test)
nb_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - NB',nb_acc_i,nb_roc_i,nb_prec_i,nb_rec_i,nb_f1_i,nb_mcc_i,nb_kap_i,nb_jacc_i,nb_gmea_i)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_i = accuracy_score(y_pred, y_test)
vot_roc_i = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_i = precision_score(y_pred, y_test)
vot_rec_i = recall_score(y_pred, y_test)
vot_f1_i = f1_score(y_pred, y_test)
vot_mcc_i = matthews_corrcoef(y_pred, y_test)
vot_kap_i = cohen_kappa_score(y_pred, y_test)
vot_jacc_i = jaccard_score(y_pred, y_test)
vot_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - vot',vot_acc_i,vot_roc_i,vot_prec_i,vot_rec_i,vot_f1_i,vot_mcc_i,vot_kap_i,vot_jacc_i,vot_gmea_i)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_i = accuracy_score(y_pred, y_test)
vgg_roc_i = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_i = precision_score(y_pred, y_test)
vgg_rec_i = recall_score(y_pred, y_test)
vgg_f1_i = f1_score(y_pred, y_test)
vgg_mcc_i = matthews_corrcoef(y_pred, y_test)
vgg_kap_i = cohen_kappa_score(y_pred, y_test)
vgg_jacc_i = jaccard_score(y_pred, y_test)
vgg_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - VGGNets',vgg_acc_i,vgg_roc_i,vgg_prec_i,vgg_rec_i,vgg_f1_i,vgg_mcc_i,vgg_kap_i,vgg_jacc_i,vgg_gmea_i)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_24 (Conv1D)           (None, 1199, 128)         384
# _________________________________________________________________
# max_pooling1d_24 (MaxPooling (None, 599, 128)          0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 599, 128)          0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 76672)             0
# _________________________________________________________________
# dense_24 (Dense)             (None, 2)                 153346
# =================================================================
# Total params: 153,730
# Trainable params: 153,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 160ms/step - loss: 0.4020 - accuracy: 0.6250 - val_loss: 12.7888 - val_accuracy: 0.8736
# Epoch 2/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 20.0405 - val_accuracy: 0.8736
# Epoch 3/20
# 2/2 [==============================] - 0s 72ms/step - loss: 68.6990 - accuracy: 0.5000 - val_loss: 18.4620 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 86ms/step - loss: 12.6948 - accuracy: 0.8750 - val_loss: 14.1851 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 72ms/step - loss: 24.4372 - accuracy: 0.7500 - val_loss: 8.2579 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.1928 - val_accuracy: 0.8736
# Epoch 7/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1691 - accuracy: 0.8750 - val_loss: 3.2110 - val_accuracy: 0.3736
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 3.2023 - accuracy: 0.5000 - val_loss: 1.2157 - val_accuracy: 0.8571
# Epoch 9/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.4906 - accuracy: 0.8750 - val_loss: 1.6230 - val_accuracy: 0.8736
# Epoch 10/20
# 2/2 [==============================] - 0s 74ms/step - loss: 4.1580 - accuracy: 0.8750 - val_loss: 1.3033 - val_accuracy: 0.8736
# Epoch 11/20
# 2/2 [==============================] - 0s 82ms/step - loss: 2.4791 - accuracy: 0.5000 - val_loss: 2.1679 - val_accuracy: 0.4011
# Epoch 12/20
# 2/2 [==============================] - 0s 83ms/step - loss: 2.4946 - accuracy: 0.3750 - val_loss: 0.8600 - val_accuracy: 0.8462
# Epoch 13/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.9278 - accuracy: 0.8750 - val_loss: 2.2000 - val_accuracy: 0.8736
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 6.2984 - accuracy: 0.7500 - val_loss: 2.6489 - val_accuracy: 0.8736
# Epoch 15/20
# 2/2 [==============================] - 0s 77ms/step - loss: 2.2803 - accuracy: 0.8750 - val_loss: 2.0617 - val_accuracy: 0.8681
# Epoch 16/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.9375 - val_accuracy: 0.7912
# Epoch 17/20
# 2/2 [==============================] - 0s 75ms/step - loss: 2.6487 - accuracy: 0.7500 - val_loss: 1.9978 - val_accuracy: 0.7582
# Epoch 18/20
# 2/2 [==============================] - 0s 73ms/step - loss: 1.8644 - accuracy: 0.7500 - val_loss: 1.5759 - val_accuracy: 0.8132
# Epoch 19/20
# 2/2 [==============================] - 0s 79ms/step - loss: 2.7816 - accuracy: 0.6250 - val_loss: 1.4276 - val_accuracy: 0.7857
# Epoch 20/20
# 2/2 [==============================] - 0s 75ms/step - loss: 4.8670 - accuracy: 0.7500 - val_loss: 5.1070 - val_accuracy: 0.3571
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_i = accuracy_score(y_pred, y_test)
res_roc_i = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_i = precision_score(y_pred, y_test)
res_rec_i = recall_score(y_pred, y_test)
res_f1_i = f1_score(y_pred, y_test)
res_mcc_i = matthews_corrcoef(y_pred, y_test)
res_kap_i = cohen_kappa_score(y_pred, y_test)
res_jacc_i = jaccard_score(y_pred, y_test)
res_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - ResNets',res_acc_i,res_roc_i,res_prec_i,res_rec_i,res_f1_i,res_mcc_i,res_kap_i,res_jacc_i,res_gmea_i)
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_25 (Conv1D)           (None, 1199, 128)         384
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 599, 128)          0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 599, 128)          0
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 76672)             0
# _________________________________________________________________
# dense_25 (Dense)             (None, 2)                 153346
# =================================================================
# Total params: 153,730
# Trainable params: 153,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 149ms/step - loss: 0.6280 - accuracy: 0.7500 - val_loss: 7.3435 - val_accuracy: 0.8736
# Epoch 2/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 11.4835 - val_accuracy: 0.8736
# Epoch 3/20
# 2/2 [==============================] - 0s 73ms/step - loss: 15.4812 - accuracy: 0.8750 - val_loss: 10.0562 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9912 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 82ms/step - loss: 9.7659 - accuracy: 0.8750 - val_loss: 6.7730 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 74ms/step - loss: 5.8765 - accuracy: 0.8750 - val_loss: 2.7576 - val_accuracy: 0.8407
# Epoch 7/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4407 - accuracy: 0.8750 - val_loss: 4.7784 - val_accuracy: 0.5769
# Epoch 8/20
# 2/2 [==============================] - 0s 72ms/step - loss: 3.7247 - accuracy: 0.6250 - val_loss: 2.6443 - val_accuracy: 0.7857
# Epoch 9/20
# 2/2 [==============================] - 0s 82ms/step - loss: 3.1426 - accuracy: 0.8750 - val_loss: 2.7886 - val_accuracy: 0.8571
# Epoch 10/20
# 2/2 [==============================] - 0s 78ms/step - loss: 2.2661 - accuracy: 0.8750 - val_loss: 2.3582 - val_accuracy: 0.8407
# Epoch 11/20
# 2/2 [==============================] - 0s 75ms/step - loss: 5.7303 - accuracy: 0.5000 - val_loss: 3.7862 - val_accuracy: 0.4945
# Epoch 12/20
# 2/2 [==============================] - 0s 74ms/step - loss: 7.9400 - accuracy: 0.1250 - val_loss: 2.9525 - val_accuracy: 0.4505
# Epoch 13/20
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0983 - accuracy: 0.6250 - val_loss: 2.8203 - val_accuracy: 0.8407
# Epoch 14/20
# 2/2 [==============================] - 0s 84ms/step - loss: 5.5708 - accuracy: 0.7500 - val_loss: 4.5756 - val_accuracy: 0.8681
# Epoch 15/20
# 2/2 [==============================] - 0s 82ms/step - loss: 6.3465 - accuracy: 0.8750 - val_loss: 4.4689 - val_accuracy: 0.8681
# Epoch 16/20
# 2/2 [==============================] - 0s 78ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 4.3892 - val_accuracy: 0.8681
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.3340 - val_accuracy: 0.8571
# Epoch 18/20
# 2/2 [==============================] - 0s 76ms/step - loss: 4.5868 - accuracy: 0.8750 - val_loss: 3.6395 - val_accuracy: 0.8187
# Epoch 19/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5026 - accuracy: 0.8750 - val_loss: 3.3106 - val_accuracy: 0.7527
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 4.7262 - accuracy: 0.5000 - val_loss: 3.2221 - val_accuracy: 0.6978
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_i = accuracy_score(y_pred, y_test)
dense_roc_i = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_i = precision_score(y_pred, y_test)
dense_rec_i = recall_score(y_pred, y_test)
dense_f1_i = f1_score(y_pred, y_test)
dense_mcc_i = matthews_corrcoef(y_pred, y_test)
dense_kap_i = cohen_kappa_score(y_pred, y_test)
dense_jacc_i = jaccard_score(y_pred, y_test)
dense_gmea_i = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-WSI - DenseNets',dense_acc_i,dense_roc_i,dense_prec_i,dense_rec_i,dense_f1_i,dense_mcc_i,dense_kap_i,dense_jacc_i,dense_gmea_i)
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_26 (Conv1D)           (None, 1199, 128)         384
# _________________________________________________________________
# max_pooling1d_26 (MaxPooling (None, 599, 128)          0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 599, 128)          0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 76672)             0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 153346
# =================================================================
# Total params: 153,730
# Trainable params: 153,730
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 145ms/step - loss: 5.5530 - accuracy: 0.6250 - val_loss: 10.2562 - val_accuracy: 0.8736
# Epoch 2/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 14.1066 - val_accuracy: 0.8736
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 21.9957 - accuracy: 0.8750 - val_loss: 13.7173 - val_accuracy: 0.8736
# Epoch 4/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 13.4242 - val_accuracy: 0.8736
# Epoch 5/20
# 2/2 [==============================] - 0s 83ms/step - loss: 23.7716 - accuracy: 0.7500 - val_loss: 10.8121 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.9487 - val_accuracy: 0.8736
# Epoch 7/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.6804 - val_accuracy: 0.8736
# Epoch 8/20
# 2/2 [==============================] - 0s 79ms/step - loss: 1.4594 - accuracy: 0.8750 - val_loss: 3.7545 - val_accuracy: 0.8077
# Epoch 9/20
# 2/2 [==============================] - 0s 77ms/step - loss: 8.8574 - accuracy: 0.6250 - val_loss: 10.2420 - val_accuracy: 0.2088
# Epoch 10/20
# 2/2 [==============================] - 0s 75ms/step - loss: 7.2859 - accuracy: 0.1250 - val_loss: 6.6137 - val_accuracy: 0.4341
# Epoch 11/20
# 2/2 [==============================] - 0s 76ms/step - loss: 4.3969 - accuracy: 0.5000 - val_loss: 3.5710 - val_accuracy: 0.7692
# Epoch 12/20
# 2/2 [==============================] - 0s 83ms/step - loss: 1.8170 - accuracy: 0.8750 - val_loss: 5.6813 - val_accuracy: 0.8626
# Epoch 13/20
# 2/2 [==============================] - 0s 73ms/step - loss: 8.3277 - accuracy: 0.8750 - val_loss: 7.3129 - val_accuracy: 0.8736
# Epoch 14/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 8.6179 - val_accuracy: 0.8736
# Epoch 15/20
# 2/2 [==============================] - 0s 72ms/step - loss: 21.5736 - accuracy: 0.7500 - val_loss: 7.7017 - val_accuracy: 0.8736
# Epoch 16/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.9582 - val_accuracy: 0.8736
# Epoch 17/20
# 2/2 [==============================] - 0s 71ms/step - loss: 8.7089 - accuracy: 0.7500 - val_loss: 6.0523 - val_accuracy: 0.8736
# Epoch 18/20
# 2/2 [==============================] - 0s 71ms/step - loss: 4.6584 - accuracy: 0.8750 - val_loss: 4.5491 - val_accuracy: 0.8736
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 8.0773 - accuracy: 0.7500 - val_loss: 2.5780 - val_accuracy: 0.7802
# Epoch 20/20
# 2/2 [==============================] - 0s 78ms/step - loss: 1.6867e-04 - accuracy: 1.0000 - val_loss: 6.0465 - val_accuracy: 0.4176
# 6/6 [==============================] - 0s 998us/step
# 6/6 [==============================] - 0s 1ms/step

# %% [markdown]
# # CNV-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CNV_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1000), (907,), (161, 1000), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_j = accuracy_score(y_pred, y_test)
svm_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_j = precision_score(y_pred, y_test)
svm_rec_j = recall_score(y_pred, y_test)
svm_f1_j = f1_score(y_pred, y_test)
svm_mcc_j = matthews_corrcoef(y_pred, y_test)
svm_kap_j = cohen_kappa_score(y_pred, y_test)
svm_jacc_j = jaccard_score(y_pred, y_test)
svm_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - rbf',svm_acc_j,svm_roc_j,svm_prec_j,svm_rec_j,svm_f1_j,svm_mcc_j,svm_kap_j,svm_jacc_j,svm_gmea_j)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_j = accuracy_score(y_pred, y_test)
svm1_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_j = precision_score(y_pred, y_test)
svm1_rec_j = recall_score(y_pred, y_test)
svm1_f1_j = f1_score(y_pred, y_test)
svm1_mcc_j = matthews_corrcoef(y_pred, y_test)
svm1_kap_j = cohen_kappa_score(y_pred, y_test)
svm1_jacc_j = jaccard_score(y_pred, y_test)
svm1_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - Poly',svm1_acc_j,svm1_roc_j,svm1_prec_j,svm1_rec_j,svm1_f1_j,svm1_mcc_j,svm1_kap_j,svm1_jacc_j,svm1_gmea_j)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_j = accuracy_score(y_pred, y_test)
svm2_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_j = precision_score(y_pred, y_test)
svm2_rec_j = recall_score(y_pred, y_test)
svm2_f1_j = f1_score(y_pred, y_test)
svm2_mcc_j = matthews_corrcoef(y_pred, y_test)
svm2_kap_j = cohen_kappa_score(y_pred, y_test)
svm2_jacc_j = jaccard_score(y_pred, y_test)
svm2_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - Utility ',svm2_acc_j,svm2_roc_j,svm2_prec_j,svm2_rec_j,svm2_f1_j,svm2_mcc_j,svm2_kap_j,svm2_jacc_j,svm2_gmea_j)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_j = accuracy_score(y_pred, y_test)
svm3_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_j = precision_score(y_pred, y_test)
svm3_rec_j = recall_score(y_pred, y_test)
svm3_f1_j = f1_score(y_pred, y_test)
svm3_mcc_j = matthews_corrcoef(y_pred, y_test)
svm3_kap_j = cohen_kappa_score(y_pred, y_test)
svm3_jacc_j = jaccard_score(y_pred, y_test)
svm3_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - Linear ',svm3_acc_j,svm3_roc_j,svm3_prec_j,svm3_rec_j,svm3_f1_j,svm3_mcc_j,svm3_kap_j,svm3_jacc_j,svm3_gmea_j)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_j = accuracy_score(y_pred, y_test)
svm4_roc_j = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_j = precision_score(y_pred, y_test)
svm4_rec_j = recall_score(y_pred, y_test)
svm4_f1_j = f1_score(y_pred, y_test)
svm4_mcc_j = matthews_corrcoef(y_pred, y_test)
svm4_kap_j = cohen_kappa_score(y_pred, y_test)
svm4_jacc_j = jaccard_score(y_pred, y_test)
svm4_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - SVM - Sigmoid',svm4_acc_j,svm4_roc_j,svm4_prec_j,svm4_rec_j,svm4_f1_j,svm4_mcc_j,svm4_kap_j,svm4_jacc_j,svm4_gmea_j)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_j = accuracy_score(y_pred, y_test)
rf_roc_j = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_j = precision_score(y_pred, y_test)
rf_rec_j = recall_score(y_pred, y_test)
rf_f1_j = f1_score(y_pred, y_test)
rf_mcc_j = matthews_corrcoef(y_pred, y_test)
rf_kap_j = cohen_kappa_score(y_pred, y_test)
rf_jacc_j = jaccard_score(y_pred, y_test)
rf_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - RF',rf_acc_j,rf_roc_j,rf_prec_j,rf_rec_j,rf_f1_j,rf_mcc_j,rf_kap_j,rf_jacc_j,rf_gmea_j)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_j = accuracy_score(y_pred, y_test)
dt_roc_j = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_j = precision_score(y_pred, y_test)
dt_rec_j = recall_score(y_pred, y_test)
dt_f1_j = f1_score(y_pred, y_test)
dt_mcc_j = matthews_corrcoef(y_pred, y_test)
dt_kap_j = cohen_kappa_score(y_pred, y_test)
dt_jacc_j = jaccard_score(y_pred, y_test)
dt_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - DT',dt_acc_j,dt_roc_j,dt_prec_j,dt_rec_j,dt_f1_j,dt_mcc_j,dt_kap_j,dt_jacc_j,dt_gmea_j)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_j = accuracy_score(y_pred, y_test)
nb_roc_j = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_j = precision_score(y_pred, y_test)
nb_rec_j = recall_score(y_pred, y_test)
nb_f1_j = f1_score(y_pred, y_test)
nb_mcc_j = matthews_corrcoef(y_pred, y_test)
nb_kap_j = cohen_kappa_score(y_pred, y_test)
nb_jacc_j = jaccard_score(y_pred, y_test)
nb_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - NB',nb_acc_j,nb_roc_j,nb_prec_j,nb_rec_j,nb_f1_j,nb_mcc_j,nb_kap_j,nb_jacc_j,nb_gmea_j)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_j = accuracy_score(y_pred, y_test)
vot_roc_j = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_j = precision_score(y_pred, y_test)
vot_rec_j = recall_score(y_pred, y_test)
vot_f1_j = f1_score(y_pred, y_test)
vot_mcc_j = matthews_corrcoef(y_pred, y_test)
vot_kap_j = cohen_kappa_score(y_pred, y_test)
vot_jacc_j = jaccard_score(y_pred, y_test)
vot_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - vot',vot_acc_j,vot_roc_j,vot_prec_j,vot_rec_j,vot_f1_j,vot_mcc_j,vot_kap_j,vot_jacc_j,vot_gmea_j)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_j = accuracy_score(y_pred, y_test)
vgg_roc_j = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_j = precision_score(y_pred, y_test)
vgg_rec_j = recall_score(y_pred, y_test)
vgg_f1_j = f1_score(y_pred, y_test)
vgg_mcc_j = matthews_corrcoef(y_pred, y_test)
vgg_kap_j = cohen_kappa_score(y_pred, y_test)
vgg_jacc_j = jaccard_score(y_pred, y_test)
vgg_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-WSI - VGGNets',vgg_acc_j,vgg_roc_j,vgg_prec_j,vgg_rec_j,vgg_f1_j,vgg_mcc_j,vgg_kap_j,vgg_jacc_j,vgg_gmea_j)
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_27 (Conv1D)           (None, 999, 128)          384
# _________________________________________________________________
# max_pooling1d_27 (MaxPooling (None, 499, 128)          0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 499, 128)          0
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 63872)             0
# _________________________________________________________________
# dense_27 (Dense)             (None, 2)                 127746
# =================================================================
# Total params: 128,130
# Trainable params: 128,130
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 155ms/step - loss: 0.7048 - accuracy: 0.5000 - val_loss: 5.8528 - val_accuracy: 0.9176
# Epoch 2/20
# 2/2 [==============================] - 0s 78ms/step - loss: 7.2904 - accuracy: 0.8750 - val_loss: 8.0857 - val_accuracy: 0.9176
# Epoch 3/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.7421 - val_accuracy: 0.9176
# Epoch 4/20
# 2/2 [==============================] - 0s 77ms/step - loss: 11.4079 - accuracy: 0.8750 - val_loss: 7.7477 - val_accuracy: 0.9176
# Epoch 5/20
# 2/2 [==============================] - 0s 76ms/step - loss: 10.8152 - accuracy: 0.8750 - val_loss: 5.7976 - val_accuracy: 0.9176
# Epoch 6/20
# 2/2 [==============================] - 0s 75ms/step - loss: 28.9396 - accuracy: 0.5000 - val_loss: 1.9178 - val_accuracy: 0.9121
# Epoch 7/20
# 2/2 [==============================] - 0s 73ms/step - loss: 7.0973 - accuracy: 0.6250 - val_loss: 15.9598 - val_accuracy: 0.1374
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 11.6053 - accuracy: 0.5000 - val_loss: 16.5259 - val_accuracy: 0.1264
# Epoch 9/20
# 2/2 [==============================] - 0s 74ms/step - loss: 6.8301 - accuracy: 0.3750 - val_loss: 1.5465 - val_accuracy: 0.8352
# Epoch 10/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4182 - accuracy: 0.8750 - val_loss: 4.1818 - val_accuracy: 0.9176
# Epoch 11/20
# 2/2 [==============================] - 0s 79ms/step - loss: 14.6429 - accuracy: 0.8750 - val_loss: 6.2252 - val_accuracy: 0.9176
# Epoch 12/20
# 2/2 [==============================] - 0s 78ms/step - loss: 7.3713 - accuracy: 0.8750 - val_loss: 7.3662 - val_accuracy: 0.9176
# Epoch 13/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.1037 - val_accuracy: 0.9176
# Epoch 14/20
# 2/2 [==============================] - 0s 77ms/step - loss: 12.8034 - accuracy: 0.8750 - val_loss: 8.1673 - val_accuracy: 0.9176
# Epoch 15/20
# 2/2 [==============================] - 0s 74ms/step - loss: 16.4139 - accuracy: 0.8750 - val_loss: 7.9288 - val_accuracy: 0.9176
# Epoch 16/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4772 - val_accuracy: 0.9176
# Epoch 17/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.1097 - val_accuracy: 0.9176
# Epoch 18/20
# 2/2 [==============================] - 0s 79ms/step - loss: 9.9629 - accuracy: 0.8750 - val_loss: 6.3545 - val_accuracy: 0.9176
# Epoch 19/20
# 2/2 [==============================] - 0s 83ms/step - loss: 12.8050 - accuracy: 0.8750 - val_loss: 5.2305 - val_accuracy: 0.9176
# Epoch 20/20
# 2/2 [==============================] - 0s 73ms/step - loss: 3.6556 - accuracy: 0.8750 - val_loss: 4.2090 - val_accuracy: 0.9176
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_j = accuracy_score(y_pred, y_test)
res_roc_j = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_j = precision_score(y_pred, y_test)
res_rec_j = recall_score(y_pred, y_test)
res_f1_j = f1_score(y_pred, y_test)
res_mcc_j = matthews_corrcoef(y_pred, y_test)
res_kap_j = cohen_kappa_score(y_pred, y_test)
res_jacc_j = jaccard_score(y_pred, y_test)
res_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - ResNets',res_acc_j,res_roc_j,res_prec_j,res_rec_j,res_f1_j,res_mcc_j,res_kap_j,res_jacc_j,res_gmea_j)
# Out:
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_28 (Conv1D)           (None, 999, 128)          384
# _________________________________________________________________
# max_pooling1d_28 (MaxPooling (None, 499, 128)          0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 499, 128)          0
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 63872)             0
# _________________________________________________________________
# dense_28 (Dense)             (None, 2)                 127746
# =================================================================
# Total params: 128,130
# Trainable params: 128,130
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 157ms/step - loss: 8.3066 - accuracy: 0.6250 - val_loss: 6.0472 - val_accuracy: 0.9176
# Epoch 2/20
# 2/2 [==============================] - 0s 78ms/step - loss: 17.9555 - accuracy: 0.7500 - val_loss: 4.5208 - val_accuracy: 0.9176
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 12.1011 - accuracy: 0.6250 - val_loss: 0.8194 - val_accuracy: 0.9176
# Epoch 4/20
# 2/2 [==============================] - 0s 87ms/step - loss: 8.4150 - accuracy: 0.5000 - val_loss: 16.6845 - val_accuracy: 0.0824
# Epoch 5/20
# 2/2 [==============================] - 0s 75ms/step - loss: 10.8116 - accuracy: 0.1250 - val_loss: 1.3157 - val_accuracy: 0.9176
# Epoch 6/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.1547 - accuracy: 0.8750 - val_loss: 3.5802 - val_accuracy: 0.9176
# Epoch 7/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.3688 - val_accuracy: 0.9176
# Epoch 8/20
# 2/2 [==============================] - 0s 76ms/step - loss: 6.6420 - accuracy: 0.8750 - val_loss: 6.5710 - val_accuracy: 0.9176
# Epoch 9/20
# 2/2 [==============================] - 0s 77ms/step - loss: 13.8206 - accuracy: 0.8750 - val_loss: 6.9923 - val_accuracy: 0.9176
# Epoch 10/20
# 2/2 [==============================] - 0s 87ms/step - loss: 28.2179 - accuracy: 0.7500 - val_loss: 6.0908 - val_accuracy: 0.9176
# Epoch 11/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.0854 - val_accuracy: 0.9176
# Epoch 12/20
# 2/2 [==============================] - 0s 83ms/step - loss: 14.6896 - accuracy: 0.7500 - val_loss: 3.8311 - val_accuracy: 0.9176
# Epoch 13/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.4253 - val_accuracy: 0.9176
# Epoch 14/20
# 2/2 [==============================] - 0s 81ms/step - loss: 1.2667e-04 - accuracy: 1.0000 - val_loss: 1.3004 - val_accuracy: 0.9176
# Epoch 15/20
# 2/2 [==============================] - 0s 76ms/step - loss: 2.2922 - accuracy: 0.7500 - val_loss: 2.0786 - val_accuracy: 0.4505
# Epoch 16/20
# 2/2 [==============================] - 0s 77ms/step - loss: 3.0102 - accuracy: 0.2500 - val_loss: 1.0980 - val_accuracy: 0.7473
# Epoch 17/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.9290 - accuracy: 0.7500 - val_loss: 0.9358 - val_accuracy: 0.8681
# Epoch 18/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.2280 - accuracy: 0.7500 - val_loss: 0.9645 - val_accuracy: 0.8681
# Epoch 19/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 1.0293 - val_accuracy: 0.8956
# Epoch 20/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1688 - val_accuracy: 0.9121
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_j = accuracy_score(y_pred, y_test)
dense_roc_j = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_j = precision_score(y_pred, y_test)
dense_rec_j = recall_score(y_pred, y_test)
dense_f1_j = f1_score(y_pred, y_test)
dense_mcc_j = matthews_corrcoef(y_pred, y_test)
dense_kap_j = cohen_kappa_score(y_pred, y_test)
dense_jacc_j = jaccard_score(y_pred, y_test)
dense_gmea_j = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV - DenseNets',dense_acc_j,dense_roc_j,dense_prec_j,dense_rec_j,dense_f1_j,dense_mcc_j,dense_kap_j,dense_jacc_j,dense_gmea_j)
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_29 (Conv1D)           (None, 999, 128)          384
# _________________________________________________________________
# max_pooling1d_29 (MaxPooling (None, 499, 128)          0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 499, 128)          0
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 63872)             0
# _________________________________________________________________
# dense_29 (Dense)             (None, 2)                 127746
# =================================================================
# Total params: 128,130
# Trainable params: 128,130
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 164ms/step - loss: 0.1369 - accuracy: 1.0000 - val_loss: 8.1886 - val_accuracy: 0.9176
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 22.3019 - accuracy: 0.8750 - val_loss: 10.6505 - val_accuracy: 0.9176
# Epoch 3/20
# 2/2 [==============================] - 0s 84ms/step - loss: 17.5569 - accuracy: 0.8750 - val_loss: 9.4776 - val_accuracy: 0.9176
# Epoch 4/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.6446 - val_accuracy: 0.9176
# Epoch 5/20
# 2/2 [==============================] - 0s 76ms/step - loss: 14.1729 - accuracy: 0.8750 - val_loss: 4.8590 - val_accuracy: 0.9176
# Epoch 6/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.6819 - val_accuracy: 0.9176
# Epoch 7/20
# 2/2 [==============================] - 0s 79ms/step - loss: 3.9786 - accuracy: 0.8750 - val_loss: 0.9876 - val_accuracy: 0.7418
# Epoch 8/20
# 2/2 [==============================] - 0s 69ms/step - loss: 7.7095 - accuracy: 0.5000 - val_loss: 13.6508 - val_accuracy: 0.0824
# Epoch 9/20
# 2/2 [==============================] - 0s 81ms/step - loss: 5.5518 - accuracy: 0.1250 - val_loss: 1.4827 - val_accuracy: 0.9176
# Epoch 10/20
# 2/2 [==============================] - 0s 76ms/step - loss: 4.4703e-08 - accuracy: 1.0000 - val_loss: 4.5367 - val_accuracy: 0.9176
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.0218 - val_accuracy: 0.9176
# Epoch 12/20
# 2/2 [==============================] - 0s 83ms/step - loss: 9.7243 - accuracy: 0.8750 - val_loss: 8.7926 - val_accuracy: 0.9176
# Epoch 13/20
# 2/2 [==============================] - 0s 76ms/step - loss: 15.6866 - accuracy: 0.8750 - val_loss: 9.6519 - val_accuracy: 0.9176
# Epoch 14/20
# 2/2 [==============================] - 0s 81ms/step - loss: 20.2449 - accuracy: 0.8750 - val_loss: 9.6027 - val_accuracy: 0.9176
# Epoch 15/20
# 2/2 [==============================] - 0s 85ms/step - loss: 17.1757 - accuracy: 0.8750 - val_loss: 8.5775 - val_accuracy: 0.9176
# Epoch 16/20
# 2/2 [==============================] - 0s 85ms/step - loss: 52.9541 - accuracy: 0.3750 - val_loss: 6.1982 - val_accuracy: 0.9176
# Epoch 17/20
# 2/2 [==============================] - 0s 79ms/step - loss: 9.8878 - accuracy: 0.8750 - val_loss: 3.6660 - val_accuracy: 0.9176
# Epoch 18/20
# 2/2 [==============================] - 0s 85ms/step - loss: 4.9854 - accuracy: 0.8750 - val_loss: 1.2330 - val_accuracy: 0.9231
# Epoch 19/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.6151 - accuracy: 0.8750 - val_loss: 6.7664 - val_accuracy: 0.2033
# Epoch 20/20
# 2/2 [==============================] - 0s 84ms/step - loss: 5.3831 - accuracy: 0.2500 - val_loss: 4.1388 - val_accuracy: 0.3571
# 6/6 [==============================] - 0s 991us/step
# 6/6 [==============================] - 0s 1ms/step

# %% [markdown]
# # CLN-EXP-CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_EXP_CNV, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 610), (907,), (161, 610), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_k = accuracy_score(y_pred, y_test)
svm_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_k = precision_score(y_pred, y_test)
svm_rec_k = recall_score(y_pred, y_test)
svm_f1_k = f1_score(y_pred, y_test)
svm_mcc_k = matthews_corrcoef(y_pred, y_test)
svm_kap_k = cohen_kappa_score(y_pred, y_test)
svm_jacc_k = jaccard_score(y_pred, y_test)
svm_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - rbf',svm_acc_k,svm_roc_k,svm_prec_k,svm_rec_k,svm_f1_k,svm_mcc_k,svm_kap_k,svm_jacc_k,svm_gmea_k)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_k = accuracy_score(y_pred, y_test)
svm1_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_k = precision_score(y_pred, y_test)
svm1_rec_k = recall_score(y_pred, y_test)
svm1_f1_k = f1_score(y_pred, y_test)
svm1_mcc_k = matthews_corrcoef(y_pred, y_test)
svm1_kap_k = cohen_kappa_score(y_pred, y_test)
svm1_jacc_k = jaccard_score(y_pred, y_test)
svm1_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - Poly',svm1_acc_k,svm1_roc_k,svm1_prec_k,svm1_rec_k,svm1_f1_k,svm1_mcc_k,svm1_kap_k,svm1_jacc_k,svm1_gmea_k)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_k = accuracy_score(y_pred, y_test)
svm2_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_k = precision_score(y_pred, y_test)
svm2_rec_k = recall_score(y_pred, y_test)
svm2_f1_k = f1_score(y_pred, y_test)
svm2_mcc_k = matthews_corrcoef(y_pred, y_test)
svm2_kap_k = cohen_kappa_score(y_pred, y_test)
svm2_jacc_k = jaccard_score(y_pred, y_test)
svm2_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - Utility ',svm2_acc_k,svm2_roc_k,svm2_prec_k,svm2_rec_k,svm2_f1_k,svm2_mcc_k,svm2_kap_k,svm2_jacc_k,svm2_gmea_k)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_k = accuracy_score(y_pred, y_test)
svm3_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_k = precision_score(y_pred, y_test)
svm3_rec_k = recall_score(y_pred, y_test)
svm3_f1_k = f1_score(y_pred, y_test)
svm3_mcc_k = matthews_corrcoef(y_pred, y_test)
svm3_kap_k = cohen_kappa_score(y_pred, y_test)
svm3_jacc_k = jaccard_score(y_pred, y_test)
svm3_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - Linear ',svm3_acc_k,svm3_roc_k,svm3_prec_k,svm3_rec_k,svm3_f1_k,svm3_mcc_k,svm3_kap_k,svm3_jacc_k,svm3_gmea_k)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_k = accuracy_score(y_pred, y_test)
svm4_roc_k = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_k = precision_score(y_pred, y_test)
svm4_rec_k = recall_score(y_pred, y_test)
svm4_f1_k = f1_score(y_pred, y_test)
svm4_mcc_k = matthews_corrcoef(y_pred, y_test)
svm4_kap_k = cohen_kappa_score(y_pred, y_test)
svm4_jacc_k = jaccard_score(y_pred, y_test)
svm4_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - SVM - Sigmoid',svm4_acc_k,svm4_roc_k,svm4_prec_k,svm4_rec_k,svm4_f1_k,svm4_mcc_k,svm4_kap_k,svm4_jacc_k,svm4_gmea_k)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_k = accuracy_score(y_pred, y_test)
rf_roc_k = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_k = precision_score(y_pred, y_test)
rf_rec_k = recall_score(y_pred, y_test)
rf_f1_k = f1_score(y_pred, y_test)
rf_mcc_k = matthews_corrcoef(y_pred, y_test)
rf_kap_k = cohen_kappa_score(y_pred, y_test)
rf_jacc_k = jaccard_score(y_pred, y_test)
rf_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - RF',rf_acc_k,rf_roc_k,rf_prec_k,rf_rec_k,rf_f1_k,rf_mcc_k,rf_kap_k,rf_jacc_k,rf_gmea_k)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_k = accuracy_score(y_pred, y_test)
dt_roc_k = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_k = precision_score(y_pred, y_test)
dt_rec_k = recall_score(y_pred, y_test)
dt_f1_k = f1_score(y_pred, y_test)
dt_mcc_k = matthews_corrcoef(y_pred, y_test)
dt_kap_k = cohen_kappa_score(y_pred, y_test)
dt_jacc_k = jaccard_score(y_pred, y_test)
dt_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - DT',dt_acc_k,dt_roc_k,dt_prec_k,dt_rec_k,dt_f1_k,dt_mcc_k,dt_kap_k,dt_jacc_k,dt_gmea_k)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_k = accuracy_score(y_pred, y_test)
nb_roc_k = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_k = precision_score(y_pred, y_test)
nb_rec_k = recall_score(y_pred, y_test)
nb_f1_k = f1_score(y_pred, y_test)
nb_mcc_k = matthews_corrcoef(y_pred, y_test)
nb_kap_k = cohen_kappa_score(y_pred, y_test)
nb_jacc_k = jaccard_score(y_pred, y_test)
nb_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - NB',nb_acc_k,nb_roc_k,nb_prec_k,nb_rec_k,nb_f1_k,nb_mcc_k,nb_kap_k,nb_jacc_k,nb_gmea_k)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_k = accuracy_score(y_pred, y_test)
vot_roc_k = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_k = precision_score(y_pred, y_test)
vot_rec_k = recall_score(y_pred, y_test)
vot_f1_k = f1_score(y_pred, y_test)
vot_mcc_k = matthews_corrcoef(y_pred, y_test)
vot_kap_k = cohen_kappa_score(y_pred, y_test)
vot_jacc_k = jaccard_score(y_pred, y_test)
vot_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - vot',vot_acc_k,vot_roc_k,vot_prec_k,vot_rec_k,vot_f1_k,vot_mcc_k,vot_kap_k,vot_jacc_k,vot_gmea_k)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_k = accuracy_score(y_pred, y_test)
vgg_roc_k = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_k = precision_score(y_pred, y_test)
vgg_rec_k = recall_score(y_pred, y_test)
vgg_f1_k = f1_score(y_pred, y_test)
vgg_mcc_k = matthews_corrcoef(y_pred, y_test)
vgg_kap_k = cohen_kappa_score(y_pred, y_test)
vgg_jacc_k = jaccard_score(y_pred, y_test)
vgg_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - VGGNets',vgg_acc_k,vgg_roc_k,vgg_prec_k,vgg_rec_k,vgg_f1_k,vgg_mcc_k,vgg_kap_k,vgg_jacc_k,vgg_gmea_k)
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_30 (Conv1D)           (None, 609, 128)          384
# _________________________________________________________________
# max_pooling1d_30 (MaxPooling (None, 304, 128)          0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 304, 128)          0
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 38912)             0
# _________________________________________________________________
# dense_30 (Dense)             (None, 2)                 77826
# =================================================================
# Total params: 78,210
# Trainable params: 78,210
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 161ms/step - loss: 0.5694 - accuracy: 0.7500 - val_loss: 0.3746 - val_accuracy: 0.9121
# Epoch 2/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1120 - accuracy: 1.0000 - val_loss: 0.4044 - val_accuracy: 0.9121
# Epoch 3/20
# 2/2 [==============================] - 0s 81ms/step - loss: 1.6053 - accuracy: 0.6250 - val_loss: 0.4345 - val_accuracy: 0.9121
# Epoch 4/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3176 - accuracy: 0.8750 - val_loss: 0.4316 - val_accuracy: 0.9121
# Epoch 5/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.4317 - val_accuracy: 0.9121
# Epoch 6/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3004 - accuracy: 0.8750 - val_loss: 0.4305 - val_accuracy: 0.9121
# Epoch 7/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3872 - accuracy: 0.7500 - val_loss: 0.4286 - val_accuracy: 0.9121
# Epoch 8/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0861 - accuracy: 1.0000 - val_loss: 0.4319 - val_accuracy: 0.9121
# Epoch 9/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.4387 - val_accuracy: 0.9121
# Epoch 10/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0788 - accuracy: 1.0000 - val_loss: 0.4489 - val_accuracy: 0.9121
# Epoch 11/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1388 - accuracy: 1.0000 - val_loss: 0.4638 - val_accuracy: 0.9121
# Epoch 12/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.9272 - accuracy: 0.8750 - val_loss: 0.4676 - val_accuracy: 0.9121
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0787 - accuracy: 1.0000 - val_loss: 0.4629 - val_accuracy: 0.9121
# Epoch 14/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4686 - accuracy: 0.8750 - val_loss: 0.4518 - val_accuracy: 0.9121
# Epoch 15/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.4457 - val_accuracy: 0.9121
# Epoch 16/20
# 2/2 [==============================] - 0s 69ms/step - loss: 1.2812 - accuracy: 0.6250 - val_loss: 0.4244 - val_accuracy: 0.9121
# Epoch 17/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4000 - accuracy: 0.8750 - val_loss: 0.4003 - val_accuracy: 0.9121
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2936 - accuracy: 0.8750 - val_loss: 0.3818 - val_accuracy: 0.9121
# Epoch 19/20
# 2/2 [==============================] - 0s 78ms/step - loss: 1.2568 - accuracy: 0.7500 - val_loss: 0.3557 - val_accuracy: 0.9121
# Epoch 20/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1256 - accuracy: 1.0000 - val_loss: 0.3422 - val_accuracy: 0.9121
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_k = accuracy_score(y_pred, y_test)
res_roc_k = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_k = precision_score(y_pred, y_test)
res_rec_k = recall_score(y_pred, y_test)
res_f1_k = f1_score(y_pred, y_test)
res_mcc_k = matthews_corrcoef(y_pred, y_test)
res_kap_k = cohen_kappa_score(y_pred, y_test)
res_jacc_k = jaccard_score(y_pred, y_test)
res_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - ResNets',res_acc_k,res_roc_k,res_prec_k,res_rec_k,res_f1_k,res_mcc_k,res_kap_k,res_jacc_k,res_gmea_k)
# Out:
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_31 (Conv1D)           (None, 609, 128)          384
# _________________________________________________________________
# max_pooling1d_31 (MaxPooling (None, 304, 128)          0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 304, 128)          0
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 38912)             0
# _________________________________________________________________
# dense_31 (Dense)             (None, 2)                 77826
# =================================================================
# Total params: 78,210
# Trainable params: 78,210
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 142ms/step - loss: 0.5021 - accuracy: 1.0000 - val_loss: 0.3646 - val_accuracy: 0.9121
# Epoch 2/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8257 - accuracy: 0.7500 - val_loss: 0.3997 - val_accuracy: 0.9121
# Epoch 3/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8849 - accuracy: 0.8750 - val_loss: 0.4212 - val_accuracy: 0.9121
# Epoch 4/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4566 - accuracy: 0.8750 - val_loss: 0.4195 - val_accuracy: 0.9121
# Epoch 5/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3743 - accuracy: 0.8750 - val_loss: 0.4111 - val_accuracy: 0.9121
# Epoch 6/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0898 - accuracy: 1.0000 - val_loss: 0.4065 - val_accuracy: 0.9121
# Epoch 7/20
# 2/2 [==============================] - 0s 72ms/step - loss: 1.2169 - accuracy: 0.7500 - val_loss: 0.3882 - val_accuracy: 0.9121
# Epoch 8/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.3757 - val_accuracy: 0.9121
# Epoch 9/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3948 - accuracy: 0.8750 - val_loss: 0.3667 - val_accuracy: 0.9121
# Epoch 10/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.3611 - val_accuracy: 0.9121
# Epoch 11/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.2734 - accuracy: 0.8750 - val_loss: 0.3587 - val_accuracy: 0.9121
# Epoch 12/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.7314 - accuracy: 0.7500 - val_loss: 0.3529 - val_accuracy: 0.9121
# Epoch 13/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6480 - accuracy: 0.7500 - val_loss: 0.3522 - val_accuracy: 0.9121
# Epoch 14/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5884 - accuracy: 0.8750 - val_loss: 0.3591 - val_accuracy: 0.9121
# Epoch 15/20
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4659 - accuracy: 0.8750 - val_loss: 0.3705 - val_accuracy: 0.9121
# Epoch 16/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3917 - accuracy: 0.8750 - val_loss: 0.3763 - val_accuracy: 0.9121
# Epoch 17/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8678 - accuracy: 0.6250 - val_loss: 0.4025 - val_accuracy: 0.8846
# Epoch 18/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4358 - accuracy: 0.7500 - val_loss: 0.4238 - val_accuracy: 0.8571
# Epoch 19/20
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0025 - accuracy: 0.5000 - val_loss: 0.4680 - val_accuracy: 0.8297
# Epoch 20/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7256 - accuracy: 0.6250 - val_loss: 0.5214 - val_accuracy: 0.8022
# 6/6 [==============================] - 0s 797us/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_k = accuracy_score(y_pred, y_test)
dense_roc_k = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_k = precision_score(y_pred, y_test)
dense_rec_k = recall_score(y_pred, y_test)
dense_f1_k = f1_score(y_pred, y_test)
dense_mcc_k = matthews_corrcoef(y_pred, y_test)
dense_kap_k = cohen_kappa_score(y_pred, y_test)
dense_jacc_k = jaccard_score(y_pred, y_test)
dense_gmea_k = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-CNV - DenseNets',dense_acc_k,dense_roc_k,dense_prec_k,dense_rec_k,dense_f1_k,dense_mcc_k,dense_kap_k,dense_jacc_k,dense_gmea_k)
# Out:
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_32 (Conv1D)           (None, 609, 128)          384
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 304, 128)          0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 304, 128)          0
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 38912)             0
# _________________________________________________________________
# dense_32 (Dense)             (None, 2)                 77826
# =================================================================
# Total params: 78,210
# Trainable params: 78,210
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.6396 - accuracy: 0.5000 - val_loss: 0.4210 - val_accuracy: 0.9121
# Epoch 2/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2439 - accuracy: 1.0000 - val_loss: 0.3742 - val_accuracy: 0.9121
# Epoch 3/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.3351 - accuracy: 0.8750 - val_loss: 0.4318 - val_accuracy: 0.9121
# Epoch 4/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.5032 - val_accuracy: 0.9121
# Epoch 5/20
# 2/2 [==============================] - 0s 76ms/step - loss: 2.0573 - accuracy: 0.6250 - val_loss: 0.4977 - val_accuracy: 0.9121
# Epoch 6/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 0.9121
# Epoch 7/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.9086 - accuracy: 0.8750 - val_loss: 0.4491 - val_accuracy: 0.9121
# Epoch 8/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0446 - accuracy: 1.0000 - val_loss: 0.4270 - val_accuracy: 0.9121
# Epoch 9/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.4139 - val_accuracy: 0.9121
# Epoch 10/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1230 - accuracy: 1.0000 - val_loss: 0.4078 - val_accuracy: 0.9121
# Epoch 11/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.4075 - val_accuracy: 0.9121
# Epoch 12/20
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0374 - accuracy: 0.8750 - val_loss: 0.3879 - val_accuracy: 0.9121
# Epoch 13/20
# 2/2 [==============================] - 0s 76ms/step - loss: 1.2301 - accuracy: 0.6250 - val_loss: 0.3614 - val_accuracy: 0.9121
# Epoch 14/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3768 - accuracy: 0.8750 - val_loss: 0.3455 - val_accuracy: 0.9121
# Epoch 15/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1541 - accuracy: 1.0000 - val_loss: 0.3365 - val_accuracy: 0.9121
# Epoch 16/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1353 - accuracy: 1.0000 - val_loss: 0.3314 - val_accuracy: 0.9121
# Epoch 17/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4868 - accuracy: 0.8750 - val_loss: 0.3263 - val_accuracy: 0.9121
# Epoch 18/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7304 - accuracy: 0.8750 - val_loss: 0.3201 - val_accuracy: 0.9121
# Epoch 19/20
# 2/2 [==============================] - 0s 74ms/step - loss: 1.1385 - accuracy: 0.7500 - val_loss: 0.3176 - val_accuracy: 0.9121
# Epoch 20/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1275 - accuracy: 1.0000 - val_loss: 0.3244 - val_accuracy: 0.9011
# 6/6 [==============================] - 0s 797us/step
# 6/6 [==============================] - 0s 3ms/step

# %% [markdown]
# # CLN-EXP-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CLN_EXP_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1210), (907,), (161, 1210), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_l = accuracy_score(y_pred, y_test)
svm_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_l = precision_score(y_pred, y_test)
svm_rec_l = recall_score(y_pred, y_test)
svm_f1_l = f1_score(y_pred, y_test)
svm_mcc_l = matthews_corrcoef(y_pred, y_test)
svm_kap_l = cohen_kappa_score(y_pred, y_test)
svm_jacc_l = jaccard_score(y_pred, y_test)
svm_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - rbf',svm_acc_l,svm_roc_l,svm_prec_l,svm_rec_l,svm_f1_l,svm_mcc_l,svm_kap_l,svm_jacc_l,svm_gmea_l)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_l = accuracy_score(y_pred, y_test)
svm1_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_l = precision_score(y_pred, y_test)
svm1_rec_l = recall_score(y_pred, y_test)
svm1_f1_l = f1_score(y_pred, y_test)
svm1_mcc_l = matthews_corrcoef(y_pred, y_test)
svm1_kap_l = cohen_kappa_score(y_pred, y_test)
svm1_jacc_l = jaccard_score(y_pred, y_test)
svm1_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - Poly',svm1_acc_l,svm1_roc_l,svm1_prec_l,svm1_rec_l,svm1_f1_l,svm1_mcc_l,svm1_kap_l,svm1_jacc_l,svm1_gmea_l)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_l = accuracy_score(y_pred, y_test)
svm2_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_l = precision_score(y_pred, y_test)
svm2_rec_l = recall_score(y_pred, y_test)
svm2_f1_l = f1_score(y_pred, y_test)
svm2_mcc_l = matthews_corrcoef(y_pred, y_test)
svm2_kap_l = cohen_kappa_score(y_pred, y_test)
svm2_jacc_l = jaccard_score(y_pred, y_test)
svm2_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - Utility ',svm2_acc_l,svm2_roc_l,svm2_prec_l,svm2_rec_l,svm2_f1_l,svm2_mcc_l,svm2_kap_l,svm2_jacc_l,svm2_gmea_l)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_l = accuracy_score(y_pred, y_test)
svm3_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_l = precision_score(y_pred, y_test)
svm3_rec_l = recall_score(y_pred, y_test)
svm3_f1_l = f1_score(y_pred, y_test)
svm3_mcc_l = matthews_corrcoef(y_pred, y_test)
svm3_kap_l = cohen_kappa_score(y_pred, y_test)
svm3_jacc_l = jaccard_score(y_pred, y_test)
svm3_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - Linear ',svm3_acc_l,svm3_roc_l,svm3_prec_l,svm3_rec_l,svm3_f1_l,svm3_mcc_l,svm3_kap_l,svm3_jacc_l,svm3_gmea_l)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_l = accuracy_score(y_pred, y_test)
svm4_roc_l = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_l = precision_score(y_pred, y_test)
svm4_rec_l = recall_score(y_pred, y_test)
svm4_f1_l = f1_score(y_pred, y_test)
svm4_mcc_l = matthews_corrcoef(y_pred, y_test)
svm4_kap_l = cohen_kappa_score(y_pred, y_test)
svm4_jacc_l = jaccard_score(y_pred, y_test)
svm4_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - SVM - Sigmoid',svm4_acc_l,svm4_roc_l,svm4_prec_l,svm4_rec_l,svm4_f1_l,svm4_mcc_l,svm4_kap_l,svm4_jacc_l,svm4_gmea_l)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_l = accuracy_score(y_pred, y_test)
rf_roc_l = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_l = precision_score(y_pred, y_test)
rf_rec_l = recall_score(y_pred, y_test)
rf_f1_l = f1_score(y_pred, y_test)
rf_mcc_l = matthews_corrcoef(y_pred, y_test)
rf_kap_l = cohen_kappa_score(y_pred, y_test)
rf_jacc_l = jaccard_score(y_pred, y_test)
rf_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - RF',rf_acc_l,rf_roc_l,rf_prec_l,rf_rec_l,rf_f1_l,rf_mcc_l,rf_kap_l,rf_jacc_l,rf_gmea_l)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_l = accuracy_score(y_pred, y_test)
dt_roc_l = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_l = precision_score(y_pred, y_test)
dt_rec_l = recall_score(y_pred, y_test)
dt_f1_l = f1_score(y_pred, y_test)
dt_mcc_l = matthews_corrcoef(y_pred, y_test)
dt_kap_l = cohen_kappa_score(y_pred, y_test)
dt_jacc_l = jaccard_score(y_pred, y_test)
dt_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - DT',dt_acc_l,dt_roc_l,dt_prec_l,dt_rec_l,dt_f1_l,dt_mcc_l,dt_kap_l,dt_jacc_l,dt_gmea_l)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_l = accuracy_score(y_pred, y_test)
nb_roc_l = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_l = precision_score(y_pred, y_test)
nb_rec_l = recall_score(y_pred, y_test)
nb_f1_l = f1_score(y_pred, y_test)
nb_mcc_l = matthews_corrcoef(y_pred, y_test)
nb_kap_l = cohen_kappa_score(y_pred, y_test)
nb_jacc_l = jaccard_score(y_pred, y_test)
nb_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - NB',nb_acc_l,nb_roc_l,nb_prec_l,nb_rec_l,nb_f1_l,nb_mcc_l,nb_kap_l,nb_jacc_l,nb_gmea_l)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_l = accuracy_score(y_pred, y_test)
vot_roc_l = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_l = precision_score(y_pred, y_test)
vot_rec_l = recall_score(y_pred, y_test)
vot_f1_l = f1_score(y_pred, y_test)
vot_mcc_l = matthews_corrcoef(y_pred, y_test)
vot_kap_l = cohen_kappa_score(y_pred, y_test)
vot_jacc_l = jaccard_score(y_pred, y_test)
vot_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - vot',vot_acc_l,vot_roc_l,vot_prec_l,vot_rec_l,vot_f1_l,vot_mcc_l,vot_kap_l,vot_jacc_l,vot_gmea_l)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_l = accuracy_score(y_pred, y_test)
vgg_roc_l = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_l = precision_score(y_pred, y_test)
vgg_rec_l = recall_score(y_pred, y_test)
vgg_f1_l = f1_score(y_pred, y_test)
vgg_mcc_l = matthews_corrcoef(y_pred, y_test)
vgg_kap_l = cohen_kappa_score(y_pred, y_test)
vgg_jacc_l = jaccard_score(y_pred, y_test)
vgg_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - VGGNets',vgg_acc_l,vgg_roc_l,vgg_prec_l,vgg_rec_l,vgg_f1_l,vgg_mcc_l,vgg_kap_l,vgg_jacc_l,vgg_gmea_l)
# Out:
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_33 (Conv1D)           (None, 1209, 128)         384
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 604, 128)          0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 604, 128)          0
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 77312)             0
# _________________________________________________________________
# dense_33 (Dense)             (None, 2)                 154626
# =================================================================
# Total params: 155,010
# Trainable params: 155,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 1s 284ms/step - loss: 10.3165 - accuracy: 0.6250 - val_loss: 6.7719 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.5356 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7595 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.6762 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 11.3891 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 78ms/step - loss: 35.7458 - accuracy: 0.7500 - val_loss: 9.0770 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 68ms/step - loss: 11.9344 - accuracy: 0.8750 - val_loss: 6.6482 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.1760 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.4567 - accuracy: 0.8750 - val_loss: 1.7424 - val_accuracy: 0.8846
# Epoch 10/20
# 2/2 [==============================] - 0s 76ms/step - loss: 7.7209 - accuracy: 0.3750 - val_loss: 7.2971 - val_accuracy: 0.2253
# Epoch 11/20
# 2/2 [==============================] - 0s 75ms/step - loss: 3.1147 - accuracy: 0.5000 - val_loss: 1.0131 - val_accuracy: 0.7967
# Epoch 12/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0923 - accuracy: 0.8750 - val_loss: 1.7923 - val_accuracy: 0.8956
# Epoch 13/20
# 2/2 [==============================] - 0s 73ms/step - loss: 1.6450e-05 - accuracy: 1.0000 - val_loss: 2.8054 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.6349 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 74ms/step - loss: 8.2960 - accuracy: 0.7500 - val_loss: 3.2381 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 79ms/step - loss: 4.1833 - accuracy: 0.8750 - val_loss: 2.1556 - val_accuracy: 0.8846
# Epoch 17/20
# 2/2 [==============================] - 0s 69ms/step - loss: 3.8747 - accuracy: 0.8750 - val_loss: 1.7904 - val_accuracy: 0.8022
# Epoch 18/20
# 2/2 [==============================] - 0s 80ms/step - loss: 9.1604 - accuracy: 0.5000 - val_loss: 20.9375 - val_accuracy: 0.1044
# Epoch 19/20
# 2/2 [==============================] - 0s 78ms/step - loss: 24.8485 - accuracy: 0.2500 - val_loss: 30.4914 - val_accuracy: 0.1044
# Epoch 20/20
# 2/2 [==============================] - 0s 76ms/step - loss: 25.9953 - accuracy: 0.0000e+00 - val_loss: 3.9471 - val_accuracy: 0.4396
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 3ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_l = accuracy_score(y_pred, y_test)
res_roc_l = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_l = precision_score(y_pred, y_test)
res_rec_l = recall_score(y_pred, y_test)
res_f1_l = f1_score(y_pred, y_test)
res_mcc_l = matthews_corrcoef(y_pred, y_test)
res_kap_l = cohen_kappa_score(y_pred, y_test)
res_jacc_l = jaccard_score(y_pred, y_test)
res_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - ResNets',res_acc_l,res_roc_l,res_prec_l,res_rec_l,res_f1_l,res_mcc_l,res_kap_l,res_jacc_l,res_gmea_l)
# Out:
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_34 (Conv1D)           (None, 1209, 128)         384
# _________________________________________________________________
# max_pooling1d_34 (MaxPooling (None, 604, 128)          0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 604, 128)          0
# _________________________________________________________________
# flatten_34 (Flatten)         (None, 77312)             0
# _________________________________________________________________
# dense_34 (Dense)             (None, 2)                 154626
# =================================================================
# Total params: 155,010
# Trainable params: 155,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.3825 - accuracy: 0.7500 - val_loss: 1.5515 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 77ms/step - loss: 4.9473 - accuracy: 0.6250 - val_loss: 1.3069 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 76ms/step - loss: 5.2649 - accuracy: 0.6250 - val_loss: 3.1128 - val_accuracy: 0.3956
# Epoch 4/20
# 2/2 [==============================] - 0s 72ms/step - loss: 3.0095 - accuracy: 0.5000 - val_loss: 1.7108 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 74ms/step - loss: 3.9338e-06 - accuracy: 1.0000 - val_loss: 3.8703 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 8.3880 - accuracy: 0.7500 - val_loss: 4.6340 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 81ms/step - loss: 9.4891 - accuracy: 0.7500 - val_loss: 4.1377 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.4074 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 78ms/step - loss: 7.0036 - accuracy: 0.8750 - val_loss: 2.4598 - val_accuracy: 0.8901
# Epoch 10/20
# 2/2 [==============================] - 0s 77ms/step - loss: 7.3083 - accuracy: 0.6250 - val_loss: 2.2479 - val_accuracy: 0.7143
# Epoch 11/20
# 2/2 [==============================] - 0s 74ms/step - loss: 2.0413 - accuracy: 0.8750 - val_loss: 4.7034 - val_accuracy: 0.4451
# Epoch 12/20
# 2/2 [==============================] - 0s 77ms/step - loss: 5.6171 - accuracy: 0.2500 - val_loss: 3.7027 - val_accuracy: 0.4725
# Epoch 13/20
# 2/2 [==============================] - 0s 77ms/step - loss: 5.7927 - accuracy: 0.3750 - val_loss: 2.2786 - val_accuracy: 0.5769
# Epoch 14/20
# 2/2 [==============================] - 0s 72ms/step - loss: 4.1188 - accuracy: 0.3750 - val_loss: 1.1414 - val_accuracy: 0.8626
# Epoch 15/20
# 2/2 [==============================] - 0s 72ms/step - loss: 4.1358 - accuracy: 0.7500 - val_loss: 1.1427 - val_accuracy: 0.8846
# Epoch 16/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.9913 - accuracy: 0.8750 - val_loss: 1.0561 - val_accuracy: 0.8791
# Epoch 17/20
# 2/2 [==============================] - 0s 77ms/step - loss: 5.5195 - accuracy: 0.6250 - val_loss: 1.0699 - val_accuracy: 0.7582
# Epoch 18/20
# 2/2 [==============================] - 0s 78ms/step - loss: 2.5507 - accuracy: 0.5000 - val_loss: 8.6277 - val_accuracy: 0.1868
# Epoch 19/20
# 2/2 [==============================] - 0s 73ms/step - loss: 7.4761 - accuracy: 0.2500 - val_loss: 8.7612 - val_accuracy: 0.2253
# Epoch 20/20
# 2/2 [==============================] - 0s 78ms/step - loss: 6.8634 - accuracy: 0.6250 - val_loss: 1.7960 - val_accuracy: 0.8956
# 6/6 [==============================] - 0s 995us/step
# 6/6 [==============================] - 0s 3ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_l = accuracy_score(y_pred, y_test)
dense_roc_l = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_l = precision_score(y_pred, y_test)
dense_rec_l = recall_score(y_pred, y_test)
dense_f1_l = f1_score(y_pred, y_test)
dense_mcc_l = matthews_corrcoef(y_pred, y_test)
dense_kap_l = cohen_kappa_score(y_pred, y_test)
dense_jacc_l = jaccard_score(y_pred, y_test)
dense_gmea_l = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-EXP-WSI - DenseNets',dense_acc_l,dense_roc_l,dense_prec_l,dense_rec_l,dense_f1_l,dense_mcc_l,dense_kap_l,dense_jacc_l,dense_gmea_l)
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_35 (Conv1D)           (None, 1209, 128)         384
# _________________________________________________________________
# max_pooling1d_35 (MaxPooling (None, 604, 128)          0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 604, 128)          0
# _________________________________________________________________
# flatten_35 (Flatten)         (None, 77312)             0
# _________________________________________________________________
# dense_35 (Dense)             (None, 2)                 154626
# =================================================================
# Total params: 155,010
# Trainable params: 155,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 2.0091 - accuracy: 0.6250 - val_loss: 9.4916 - val_accuracy: 0.8956
# Epoch 2/20
# 2/2 [==============================] - 0s 73ms/step - loss: 55.1910 - accuracy: 0.6250 - val_loss: 10.2604 - val_accuracy: 0.8956
# Epoch 3/20
# 2/2 [==============================] - 0s 79ms/step - loss: 14.9104 - accuracy: 0.8750 - val_loss: 8.0417 - val_accuracy: 0.8956
# Epoch 4/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.4046 - val_accuracy: 0.8956
# Epoch 5/20
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.1464 - val_accuracy: 0.8956
# Epoch 6/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.1558 - val_accuracy: 0.8956
# Epoch 7/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.3637 - val_accuracy: 0.8956
# Epoch 8/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.2070e-06 - accuracy: 1.0000 - val_loss: 2.7239 - val_accuracy: 0.8956
# Epoch 9/20
# 2/2 [==============================] - 0s 79ms/step - loss: 4.9454 - accuracy: 0.8750 - val_loss: 1.7126 - val_accuracy: 0.8956
# Epoch 10/20
# 2/2 [==============================] - 0s 77ms/step - loss: 5.8644 - accuracy: 0.5000 - val_loss: 4.1781 - val_accuracy: 0.3681
# Epoch 11/20
# 2/2 [==============================] - 0s 78ms/step - loss: 3.3449 - accuracy: 0.6250 - val_loss: 1.5783 - val_accuracy: 0.5934
# Epoch 12/20
# 2/2 [==============================] - 0s 73ms/step - loss: 2.3153 - accuracy: 0.6250 - val_loss: 1.6775 - val_accuracy: 0.8956
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 8.0466e-07 - accuracy: 1.0000 - val_loss: 2.7063 - val_accuracy: 0.8956
# Epoch 14/20
# 2/2 [==============================] - 0s 71ms/step - loss: 3.9151 - accuracy: 0.8750 - val_loss: 3.1548 - val_accuracy: 0.8956
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 5.9939 - accuracy: 0.8750 - val_loss: 2.4370 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 78ms/step - loss: 2.5319 - accuracy: 0.8750 - val_loss: 1.4947 - val_accuracy: 0.8956
# Epoch 17/20
# 2/2 [==============================] - 0s 79ms/step - loss: 3.4473 - accuracy: 0.8750 - val_loss: 4.8254 - val_accuracy: 0.2692
# Epoch 18/20
# 2/2 [==============================] - 0s 68ms/step - loss: 5.8039 - accuracy: 0.5000 - val_loss: 2.7483 - val_accuracy: 0.4670
# Epoch 19/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 1.5765 - val_accuracy: 0.8956
# Epoch 20/20
# 2/2 [==============================] - 0s 79ms/step - loss: 2.3539 - accuracy: 0.8750 - val_loss: 2.3150 - val_accuracy: 0.8956
# 6/6 [==============================] - 0s 998us/step
# 6/6 [==============================] - 0s 994us/step

# %% [markdown]
# # EXP-CNV-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(EXP_CNV_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1400), (907,), (161, 1400), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_m = accuracy_score(y_pred, y_test)
svm_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_m = precision_score(y_pred, y_test)
svm_rec_m = recall_score(y_pred, y_test)
svm_f1_m = f1_score(y_pred, y_test)
svm_mcc_m = matthews_corrcoef(y_pred, y_test)
svm_kap_m = cohen_kappa_score(y_pred, y_test)
svm_jacc_m = jaccard_score(y_pred, y_test)
svm_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - rbf',svm_acc_m,svm_roc_m,svm_prec_m,svm_rec_m,svm_f1_m,svm_mcc_m,svm_kap_m,svm_jacc_m,svm_gmea_m)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_m = accuracy_score(y_pred, y_test)
svm1_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_m = precision_score(y_pred, y_test)
svm1_rec_m = recall_score(y_pred, y_test)
svm1_f1_m = f1_score(y_pred, y_test)
svm1_mcc_m = matthews_corrcoef(y_pred, y_test)
svm1_kap_m = cohen_kappa_score(y_pred, y_test)
svm1_jacc_m = jaccard_score(y_pred, y_test)
svm1_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - Poly',svm1_acc_m,svm1_roc_m,svm1_prec_m,svm1_rec_m,svm1_f1_m,svm1_mcc_m,svm1_kap_m,svm1_jacc_m,svm1_gmea_m)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_m = accuracy_score(y_pred, y_test)
svm2_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_m = precision_score(y_pred, y_test)
svm2_rec_m = recall_score(y_pred, y_test)
svm2_f1_m = f1_score(y_pred, y_test)
svm2_mcc_m = matthews_corrcoef(y_pred, y_test)
svm2_kap_m = cohen_kappa_score(y_pred, y_test)
svm2_jacc_m = jaccard_score(y_pred, y_test)
svm2_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - Utility ',svm2_acc_m,svm2_roc_m,svm2_prec_m,svm2_rec_m,svm2_f1_m,svm2_mcc_m,svm2_kap_m,svm2_jacc_m,svm2_gmea_m)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_m = accuracy_score(y_pred, y_test)
svm3_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_m = precision_score(y_pred, y_test)
svm3_rec_m = recall_score(y_pred, y_test)
svm3_f1_m = f1_score(y_pred, y_test)
svm3_mcc_m = matthews_corrcoef(y_pred, y_test)
svm3_kap_m = cohen_kappa_score(y_pred, y_test)
svm3_jacc_m = jaccard_score(y_pred, y_test)
svm3_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - Linear ',svm3_acc_m,svm3_roc_m,svm3_prec_m,svm3_rec_m,svm3_f1_m,svm3_mcc_m,svm3_kap_m,svm3_jacc_m,svm3_gmea_m)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_m = accuracy_score(y_pred, y_test)
svm4_roc_m = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_m = precision_score(y_pred, y_test)
svm4_rec_m = recall_score(y_pred, y_test)
svm4_f1_m = f1_score(y_pred, y_test)
svm4_mcc_m = matthews_corrcoef(y_pred, y_test)
svm4_kap_m = cohen_kappa_score(y_pred, y_test)
svm4_jacc_m = jaccard_score(y_pred, y_test)
svm4_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - SVM - Sigmoid',svm4_acc_m,svm4_roc_m,svm4_prec_m,svm4_rec_m,svm4_f1_m,svm4_mcc_m,svm4_kap_m,svm4_jacc_m,svm4_gmea_m)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_m = accuracy_score(y_pred, y_test)
rf_roc_m = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_m = precision_score(y_pred, y_test)
rf_rec_m = recall_score(y_pred, y_test)
rf_f1_m = f1_score(y_pred, y_test)
rf_mcc_m = matthews_corrcoef(y_pred, y_test)
rf_kap_m = cohen_kappa_score(y_pred, y_test)
rf_jacc_m = jaccard_score(y_pred, y_test)
rf_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - RF',rf_acc_m,rf_roc_m,rf_prec_m,rf_rec_m,rf_f1_m,rf_mcc_m,rf_kap_m,rf_jacc_m,rf_gmea_m)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_m = accuracy_score(y_pred, y_test)
dt_roc_m = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_m = precision_score(y_pred, y_test)
dt_rec_m = recall_score(y_pred, y_test)
dt_f1_m = f1_score(y_pred, y_test)
dt_mcc_m = matthews_corrcoef(y_pred, y_test)
dt_kap_m = cohen_kappa_score(y_pred, y_test)
dt_jacc_m = jaccard_score(y_pred, y_test)
dt_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - DT',dt_acc_m,dt_roc_m,dt_prec_m,dt_rec_m,dt_f1_m,dt_mcc_m,dt_kap_m,dt_jacc_m,dt_gmea_m)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_m = accuracy_score(y_pred, y_test)
nb_roc_m = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_m = precision_score(y_pred, y_test)
nb_rec_m = recall_score(y_pred, y_test)
nb_f1_m = f1_score(y_pred, y_test)
nb_mcc_m = matthews_corrcoef(y_pred, y_test)
nb_kap_m = cohen_kappa_score(y_pred, y_test)
nb_jacc_m = jaccard_score(y_pred, y_test)
nb_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - NB',nb_acc_m,nb_roc_m,nb_prec_m,nb_rec_m,nb_f1_m,nb_mcc_m,nb_kap_m,nb_jacc_m,nb_gmea_m)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_m = accuracy_score(y_pred, y_test)
vot_roc_m = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_m = precision_score(y_pred, y_test)
vot_rec_m = recall_score(y_pred, y_test)
vot_f1_m = f1_score(y_pred, y_test)
vot_mcc_m = matthews_corrcoef(y_pred, y_test)
vot_kap_m = cohen_kappa_score(y_pred, y_test)
vot_jacc_m = jaccard_score(y_pred, y_test)
vot_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - vot',vot_acc_m,vot_roc_m,vot_prec_m,vot_rec_m,vot_f1_m,vot_mcc_m,vot_kap_m,vot_jacc_m,vot_gmea_m)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_m = accuracy_score(y_pred, y_test)
vgg_roc_m = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_m = precision_score(y_pred, y_test)
vgg_rec_m = recall_score(y_pred, y_test)
vgg_f1_m = f1_score(y_pred, y_test)
vgg_mcc_m = matthews_corrcoef(y_pred, y_test)
vgg_kap_m = cohen_kappa_score(y_pred, y_test)
vgg_jacc_m = jaccard_score(y_pred, y_test)
vgg_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - VGGNets',vgg_acc_m,vgg_roc_m,vgg_prec_m,vgg_rec_m,vgg_f1_m,vgg_mcc_m,vgg_kap_m,vgg_jacc_m,vgg_gmea_m)
# Out:
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_36 (Conv1D)           (None, 1399, 128)         384
# _________________________________________________________________
# max_pooling1d_36 (MaxPooling (None, 699, 128)          0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 699, 128)          0
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 89472)             0
# _________________________________________________________________
# dense_36 (Dense)             (None, 2)                 178946
# =================================================================
# Total params: 179,330
# Trainable params: 179,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 162ms/step - loss: 0.9344 - accuracy: 0.8750 - val_loss: 7.0252 - val_accuracy: 0.9341
# Epoch 2/20
# 2/2 [==============================] - 0s 69ms/step - loss: 18.2220 - accuracy: 0.8750 - val_loss: 8.0720 - val_accuracy: 0.9341
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 19.8026 - accuracy: 0.8750 - val_loss: 7.9343 - val_accuracy: 0.9341
# Epoch 4/20
# 2/2 [==============================] - 0s 68ms/step - loss: 23.7386 - accuracy: 0.7500 - val_loss: 5.5656 - val_accuracy: 0.9341
# Epoch 5/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.7558 - val_accuracy: 0.9341
# Epoch 6/20
# 2/2 [==============================] - 0s 70ms/step - loss: 10.3963 - accuracy: 0.8750 - val_loss: 1.5332 - val_accuracy: 0.9341
# Epoch 7/20
# 2/2 [==============================] - 0s 71ms/step - loss: 5.2526 - accuracy: 0.6250 - val_loss: 12.5347 - val_accuracy: 0.0659
# Epoch 8/20
# 2/2 [==============================] - 0s 71ms/step - loss: 13.0187 - accuracy: 0.0000e+00 - val_loss: 4.8105 - val_accuracy: 0.1538
# Epoch 9/20
# 2/2 [==============================] - 0s 72ms/step - loss: 2.5479 - accuracy: 0.5000 - val_loss: 1.8398 - val_accuracy: 0.9341
# Epoch 10/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.6922 - val_accuracy: 0.9341
# Epoch 11/20
# 2/2 [==============================] - 0s 77ms/step - loss: 6.7717 - accuracy: 0.8750 - val_loss: 4.8304 - val_accuracy: 0.9341
# Epoch 12/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.7559 - val_accuracy: 0.9341
# Epoch 13/20
# 2/2 [==============================] - 0s 85ms/step - loss: 9.7977 - accuracy: 0.8750 - val_loss: 6.1635 - val_accuracy: 0.9341
# Epoch 14/20
# 2/2 [==============================] - 0s 72ms/step - loss: 33.4654 - accuracy: 0.7500 - val_loss: 6.0287 - val_accuracy: 0.9341
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 28.5887 - accuracy: 0.7500 - val_loss: 4.7201 - val_accuracy: 0.9341
# Epoch 16/20
# 2/2 [==============================] - 0s 71ms/step - loss: 8.5407 - accuracy: 0.8750 - val_loss: 3.3688 - val_accuracy: 0.9341
# Epoch 17/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.2813 - val_accuracy: 0.9341
# Epoch 18/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.4024 - val_accuracy: 0.9341
# Epoch 19/20
# 2/2 [==============================] - 0s 69ms/step - loss: 4.2353 - accuracy: 0.7500 - val_loss: 0.6155 - val_accuracy: 0.8846
# Epoch 20/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.7422 - accuracy: 0.6250 - val_loss: 4.2373 - val_accuracy: 0.3352
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_m = accuracy_score(y_pred, y_test)
res_roc_m = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_m = precision_score(y_pred, y_test)
res_rec_m = recall_score(y_pred, y_test)
res_f1_m = f1_score(y_pred, y_test)
res_mcc_m = matthews_corrcoef(y_pred, y_test)
res_kap_m = cohen_kappa_score(y_pred, y_test)
res_jacc_m = jaccard_score(y_pred, y_test)
res_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - ResNets',res_acc_m,res_roc_m,res_prec_m,res_rec_m,res_f1_m,res_mcc_m,res_kap_m,res_jacc_m,res_gmea_m)
# Out:
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_37 (Conv1D)           (None, 1399, 128)         384
# _________________________________________________________________
# max_pooling1d_37 (MaxPooling (None, 699, 128)          0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 699, 128)          0
# _________________________________________________________________
# flatten_37 (Flatten)         (None, 89472)             0
# _________________________________________________________________
# dense_37 (Dense)             (None, 2)                 178946
# =================================================================
# Total params: 179,330
# Trainable params: 179,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 1.1356 - accuracy: 0.5000 - val_loss: 6.3521 - val_accuracy: 0.9341
# Epoch 2/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.0031 - val_accuracy: 0.9341
# Epoch 3/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 12.5885 - val_accuracy: 0.9341
# Epoch 4/20
# 2/2 [==============================] - 0s 77ms/step - loss: 47.0849 - accuracy: 0.7500 - val_loss: 12.4058 - val_accuracy: 0.9341
# Epoch 5/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 11.8502 - val_accuracy: 0.9341
# Epoch 6/20
# 2/2 [==============================] - 0s 77ms/step - loss: 25.9348 - accuracy: 0.8750 - val_loss: 10.4681 - val_accuracy: 0.9341
# Epoch 7/20
# 2/2 [==============================] - 0s 75ms/step - loss: 9.3027 - accuracy: 0.8750 - val_loss: 9.1660 - val_accuracy: 0.9341
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.9386 - val_accuracy: 0.9341
# Epoch 9/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.9502 - val_accuracy: 0.9341
# Epoch 10/20
# 2/2 [==============================] - 0s 81ms/step - loss: 28.4035 - accuracy: 0.7500 - val_loss: 5.0308 - val_accuracy: 0.9341
# Epoch 11/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.1483 - val_accuracy: 0.9341
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.6904 - val_accuracy: 0.9286
# Epoch 13/20
# 2/2 [==============================] - 0s 79ms/step - loss: 2.8656 - accuracy: 0.7500 - val_loss: 2.0787 - val_accuracy: 0.7033
# Epoch 14/20
# 2/2 [==============================] - 0s 72ms/step - loss: 3.0111 - accuracy: 0.6250 - val_loss: 1.4543 - val_accuracy: 0.7363
# Epoch 15/20
# 2/2 [==============================] - 0s 75ms/step - loss: 1.6094 - accuracy: 0.8750 - val_loss: 1.0392 - val_accuracy: 0.9286
# Epoch 16/20
# 2/2 [==============================] - 0s 76ms/step - loss: 4.0978e-06 - accuracy: 1.0000 - val_loss: 1.5698 - val_accuracy: 0.9341
# Epoch 17/20
# 2/2 [==============================] - 0s 78ms/step - loss: 5.0215 - accuracy: 0.7500 - val_loss: 0.9577 - val_accuracy: 0.9341
# Epoch 18/20
# 2/2 [==============================] - 0s 73ms/step - loss: 3.2347e-05 - accuracy: 1.0000 - val_loss: 0.6669 - val_accuracy: 0.8736
# Epoch 19/20
# 2/2 [==============================] - 0s 88ms/step - loss: 1.1233 - accuracy: 0.7500 - val_loss: 0.7222 - val_accuracy: 0.8791
# Epoch 20/20
# 2/2 [==============================] - 0s 78ms/step - loss: 8.0056 - accuracy: 0.6250 - val_loss: 0.6727 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_m = accuracy_score(y_pred, y_test)
dense_roc_m = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_m = precision_score(y_pred, y_test)
dense_rec_m = recall_score(y_pred, y_test)
dense_f1_m = f1_score(y_pred, y_test)
dense_mcc_m = matthews_corrcoef(y_pred, y_test)
dense_kap_m = cohen_kappa_score(y_pred, y_test)
dense_jacc_m = jaccard_score(y_pred, y_test)
dense_gmea_m = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('EXP-CNV-WSI - DenseNets',dense_acc_m,dense_roc_m,dense_prec_m,dense_rec_m,dense_f1_m,dense_mcc_m,dense_kap_m,dense_jacc_m,dense_gmea_m)
# Out:
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_38 (Conv1D)           (None, 1399, 128)         384
# _________________________________________________________________
# max_pooling1d_38 (MaxPooling (None, 699, 128)          0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 699, 128)          0
# _________________________________________________________________
# flatten_38 (Flatten)         (None, 89472)             0
# _________________________________________________________________
# dense_38 (Dense)             (None, 2)                 178946
# =================================================================
# Total params: 179,330
# Trainable params: 179,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 149ms/step - loss: 0.3032 - accuracy: 0.7500 - val_loss: 5.4504 - val_accuracy: 0.9341
# Epoch 2/20
# 2/2 [==============================] - 0s 67ms/step - loss: 13.7955 - accuracy: 0.8750 - val_loss: 5.6146 - val_accuracy: 0.9341
# Epoch 3/20
# 2/2 [==============================] - 0s 80ms/step - loss: 35.1615 - accuracy: 0.5000 - val_loss: 2.2429 - val_accuracy: 0.9341
# Epoch 4/20
# 2/2 [==============================] - 0s 79ms/step - loss: 2.4810 - accuracy: 0.7500 - val_loss: 8.9890 - val_accuracy: 0.2527
# Epoch 5/20
# 2/2 [==============================] - 0s 78ms/step - loss: 7.3307 - accuracy: 0.6250 - val_loss: 9.0153 - val_accuracy: 0.1099
# Epoch 6/20
# 2/2 [==============================] - 0s 75ms/step - loss: 6.8903 - accuracy: 0.6250 - val_loss: 1.3846 - val_accuracy: 0.9341
# Epoch 7/20
# 2/2 [==============================] - 0s 74ms/step - loss: 8.9316 - accuracy: 0.7500 - val_loss: 2.4406 - val_accuracy: 0.9341
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 9.7567 - accuracy: 0.8750 - val_loss: 2.4698 - val_accuracy: 0.9341
# Epoch 9/20
# 2/2 [==============================] - 0s 78ms/step - loss: 3.0278 - accuracy: 0.8750 - val_loss: 2.0653 - val_accuracy: 0.9341
# Epoch 10/20
# 2/2 [==============================] - 0s 76ms/step - loss: 3.2931e-06 - accuracy: 1.0000 - val_loss: 1.6235 - val_accuracy: 0.9176
# Epoch 11/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.4998 - val_accuracy: 0.8516
# Epoch 12/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.7609 - val_accuracy: 0.7418
# Epoch 13/20
# 2/2 [==============================] - 0s 71ms/step - loss: 8.6864 - accuracy: 0.6250 - val_loss: 5.2797 - val_accuracy: 0.3901
# Epoch 14/20
# 2/2 [==============================] - 0s 79ms/step - loss: 9.9179 - accuracy: 0.1250 - val_loss: 2.8638 - val_accuracy: 0.5000
# Epoch 15/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.4918 - accuracy: 0.6250 - val_loss: 0.9028 - val_accuracy: 0.8956
# Epoch 16/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.6737 - accuracy: 0.8750 - val_loss: 1.3526 - val_accuracy: 0.9341
# Epoch 17/20
# 2/2 [==============================] - 0s 78ms/step - loss: 7.3024e-05 - accuracy: 1.0000 - val_loss: 1.6470 - val_accuracy: 0.9341
# Epoch 18/20
# 2/2 [==============================] - 0s 77ms/step - loss: 3.4724 - accuracy: 0.8750 - val_loss: 1.4832 - val_accuracy: 0.9341
# Epoch 19/20
# 2/2 [==============================] - 0s 78ms/step - loss: 2.7090 - accuracy: 0.8750 - val_loss: 1.0448 - val_accuracy: 0.9286
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 3.7800 - accuracy: 0.7500 - val_loss: 3.3467 - val_accuracy: 0.5110
# 6/6 [==============================] - 0s 448us/step
# 6/6 [==============================] - 0s 3ms/step

# %% [markdown]
# # CNV-CLN-WSI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(CNV_CLN_WSI, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1010), (907,), (161, 1010), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_n = accuracy_score(y_pred, y_test)
svm_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_n = precision_score(y_pred, y_test)
svm_rec_n = recall_score(y_pred, y_test)
svm_f1_n = f1_score(y_pred, y_test)
svm_mcc_n = matthews_corrcoef(y_pred, y_test)
svm_kap_n = cohen_kappa_score(y_pred, y_test)
svm_jacc_n = jaccard_score(y_pred, y_test)
svm_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - rbf',svm_acc_n,svm_roc_n,svm_prec_n,svm_rec_n,svm_f1_n,svm_mcc_n,svm_kap_n,svm_jacc_n,svm_gmea_n)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_n = accuracy_score(y_pred, y_test)
svm1_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_n = precision_score(y_pred, y_test)
svm1_rec_n = recall_score(y_pred, y_test)
svm1_f1_n = f1_score(y_pred, y_test)
svm1_mcc_n = matthews_corrcoef(y_pred, y_test)
svm1_kap_n = cohen_kappa_score(y_pred, y_test)
svm1_jacc_n = jaccard_score(y_pred, y_test)
svm1_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - Poly',svm1_acc_n,svm1_roc_n,svm1_prec_n,svm1_rec_n,svm1_f1_n,svm1_mcc_n,svm1_kap_n,svm1_jacc_n,svm1_gmea_n)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_n = accuracy_score(y_pred, y_test)
svm2_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_n = precision_score(y_pred, y_test)
svm2_rec_n = recall_score(y_pred, y_test)
svm2_f1_n = f1_score(y_pred, y_test)
svm2_mcc_n = matthews_corrcoef(y_pred, y_test)
svm2_kap_n = cohen_kappa_score(y_pred, y_test)
svm2_jacc_n = jaccard_score(y_pred, y_test)
svm2_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - Utility ',svm2_acc_n,svm2_roc_n,svm2_prec_n,svm2_rec_n,svm2_f1_n,svm2_mcc_n,svm2_kap_n,svm2_jacc_n,svm2_gmea_n)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_n = accuracy_score(y_pred, y_test)
svm3_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_n = precision_score(y_pred, y_test)
svm3_rec_n = recall_score(y_pred, y_test)
svm3_f1_n = f1_score(y_pred, y_test)
svm3_mcc_n = matthews_corrcoef(y_pred, y_test)
svm3_kap_n = cohen_kappa_score(y_pred, y_test)
svm3_jacc_n = jaccard_score(y_pred, y_test)
svm3_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - Linear ',svm3_acc_n,svm3_roc_n,svm3_prec_n,svm3_rec_n,svm3_f1_n,svm3_mcc_n,svm3_kap_n,svm3_jacc_n,svm3_gmea_n)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_n = accuracy_score(y_pred, y_test)
svm4_roc_n = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_n = precision_score(y_pred, y_test)
svm4_rec_n = recall_score(y_pred, y_test)
svm4_f1_n = f1_score(y_pred, y_test)
svm4_mcc_n = matthews_corrcoef(y_pred, y_test)
svm4_kap_n = cohen_kappa_score(y_pred, y_test)
svm4_jacc_n = jaccard_score(y_pred, y_test)
svm4_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - SVM - Sigmoid',svm4_acc_n,svm4_roc_n,svm4_prec_n,svm4_rec_n,svm4_f1_n,svm4_mcc_n,svm4_kap_n,svm4_jacc_n,svm4_gmea_n)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_n = accuracy_score(y_pred, y_test)
rf_roc_n = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_n = precision_score(y_pred, y_test)
rf_rec_n = recall_score(y_pred, y_test)
rf_f1_n = f1_score(y_pred, y_test)
rf_mcc_n = matthews_corrcoef(y_pred, y_test)
rf_kap_n = cohen_kappa_score(y_pred, y_test)
rf_jacc_n = jaccard_score(y_pred, y_test)
rf_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - RF',rf_acc_n,rf_roc_n,rf_prec_n,rf_rec_n,rf_f1_n,rf_mcc_n,rf_kap_n,rf_jacc_n,rf_gmea_n)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_n = accuracy_score(y_pred, y_test)
dt_roc_n = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_n = precision_score(y_pred, y_test)
dt_rec_n = recall_score(y_pred, y_test)
dt_f1_n = f1_score(y_pred, y_test)
dt_mcc_n = matthews_corrcoef(y_pred, y_test)
dt_kap_n = cohen_kappa_score(y_pred, y_test)
dt_jacc_n = jaccard_score(y_pred, y_test)
dt_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - DT',dt_acc_n,dt_roc_n,dt_prec_n,dt_rec_n,dt_f1_n,dt_mcc_n,dt_kap_n,dt_jacc_n,dt_gmea_n)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_n = accuracy_score(y_pred, y_test)
nb_roc_n = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_n = precision_score(y_pred, y_test)
nb_rec_n = recall_score(y_pred, y_test)
nb_f1_n = f1_score(y_pred, y_test)
nb_mcc_n = matthews_corrcoef(y_pred, y_test)
nb_kap_n = cohen_kappa_score(y_pred, y_test)
nb_jacc_n = jaccard_score(y_pred, y_test)
nb_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - NB',nb_acc_n,nb_roc_n,nb_prec_n,nb_rec_n,nb_f1_n,nb_mcc_n,nb_kap_n,nb_jacc_n,nb_gmea_n)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_n = accuracy_score(y_pred, y_test)
vot_roc_n = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_n = precision_score(y_pred, y_test)
vot_rec_n = recall_score(y_pred, y_test)
vot_f1_n = f1_score(y_pred, y_test)
vot_mcc_n = matthews_corrcoef(y_pred, y_test)
vot_kap_n = cohen_kappa_score(y_pred, y_test)
vot_jacc_n = jaccard_score(y_pred, y_test)
vot_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - vot',vot_acc_n,vot_roc_n,vot_prec_n,vot_rec_n,vot_f1_n,vot_mcc_n,vot_kap_n,vot_jacc_n,vot_gmea_n)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_n = accuracy_score(y_pred, y_test)
vgg_roc_n = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_n = precision_score(y_pred, y_test)
vgg_rec_n = recall_score(y_pred, y_test)
vgg_f1_n = f1_score(y_pred, y_test)
vgg_mcc_n = matthews_corrcoef(y_pred, y_test)
vgg_kap_n = cohen_kappa_score(y_pred, y_test)
vgg_jacc_n = jaccard_score(y_pred, y_test)
vgg_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - VGGNets',vgg_acc_n,vgg_roc_n,vgg_prec_n,vgg_rec_n,vgg_f1_n,vgg_mcc_n,vgg_kap_n,vgg_jacc_n,vgg_gmea_n)
# Out:
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_39 (Conv1D)           (None, 1009, 128)         384
# _________________________________________________________________
# max_pooling1d_39 (MaxPooling (None, 504, 128)          0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 504, 128)          0
# _________________________________________________________________
# flatten_39 (Flatten)         (None, 64512)             0
# _________________________________________________________________
# dense_39 (Dense)             (None, 2)                 129026
# =================================================================
# Total params: 129,410
# Trainable params: 129,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 159ms/step - loss: 0.6286 - accuracy: 0.6250 - val_loss: 14.4608 - val_accuracy: 0.8571
# Epoch 2/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 22.6460 - val_accuracy: 0.8571
# Epoch 3/20
# 2/2 [==============================] - 0s 78ms/step - loss: 36.0776 - accuracy: 0.7500 - val_loss: 23.3717 - val_accuracy: 0.8571
# Epoch 4/20
# 2/2 [==============================] - 0s 83ms/step - loss: 10.5029 - accuracy: 0.8750 - val_loss: 21.6675 - val_accuracy: 0.8571
# Epoch 5/20
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 19.6585 - val_accuracy: 0.8571
# Epoch 6/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 18.0814 - val_accuracy: 0.8571
# Epoch 7/20
# 2/2 [==============================] - 0s 84ms/step - loss: 17.7582 - accuracy: 0.8750 - val_loss: 15.7092 - val_accuracy: 0.8571
# Epoch 8/20
# 2/2 [==============================] - 0s 74ms/step - loss: 7.8563 - accuracy: 0.8750 - val_loss: 12.1366 - val_accuracy: 0.8571
# Epoch 9/20
# 2/2 [==============================] - 0s 77ms/step - loss: 11.5073 - accuracy: 0.8750 - val_loss: 7.8614 - val_accuracy: 0.8516
# Epoch 10/20
# 2/2 [==============================] - 0s 87ms/step - loss: 8.4499 - accuracy: 0.8750 - val_loss: 3.9186 - val_accuracy: 0.7418
# Epoch 11/20
# 2/2 [==============================] - 0s 77ms/step - loss: 8.0769 - accuracy: 0.6250 - val_loss: 14.0361 - val_accuracy: 0.1593
# Epoch 12/20
# 2/2 [==============================] - 0s 78ms/step - loss: 11.2202 - accuracy: 0.1250 - val_loss: 3.7826 - val_accuracy: 0.5934
# Epoch 13/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1402 - accuracy: 0.8750 - val_loss: 4.9353 - val_accuracy: 0.8297
# Epoch 14/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0864 - accuracy: 1.0000 - val_loss: 8.3759 - val_accuracy: 0.8571
# Epoch 15/20
# 2/2 [==============================] - 0s 75ms/step - loss: 13.4296 - accuracy: 0.8750 - val_loss: 10.7753 - val_accuracy: 0.8571
# Epoch 16/20
# 2/2 [==============================] - 0s 85ms/step - loss: 22.8168 - accuracy: 0.7500 - val_loss: 10.6173 - val_accuracy: 0.8571
# Epoch 17/20
# 2/2 [==============================] - 0s 79ms/step - loss: 1.8494 - accuracy: 0.8750 - val_loss: 9.7254 - val_accuracy: 0.8571
# Epoch 18/20
# 2/2 [==============================] - 0s 83ms/step - loss: 10.1699 - accuracy: 0.7500 - val_loss: 8.1877 - val_accuracy: 0.8571
# Epoch 19/20
# 2/2 [==============================] - 0s 83ms/step - loss: 1.5258e-05 - accuracy: 1.0000 - val_loss: 6.3984 - val_accuracy: 0.8516
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 8.9186e-04 - accuracy: 1.0000 - val_loss: 4.9933 - val_accuracy: 0.8516
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_n = accuracy_score(y_pred, y_test)
res_roc_n = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_n = precision_score(y_pred, y_test)
res_rec_n = recall_score(y_pred, y_test)
res_f1_n = f1_score(y_pred, y_test)
res_mcc_n = matthews_corrcoef(y_pred, y_test)
res_kap_n = cohen_kappa_score(y_pred, y_test)
res_jacc_n = jaccard_score(y_pred, y_test)
res_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - ResNets',res_acc_n,res_roc_n,res_prec_n,res_rec_n,res_f1_n,res_mcc_n,res_kap_n,res_jacc_n,res_gmea_n)
# Out:
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_40 (Conv1D)           (None, 1009, 128)         384
# _________________________________________________________________
# max_pooling1d_40 (MaxPooling (None, 504, 128)          0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 504, 128)          0
# _________________________________________________________________
# flatten_40 (Flatten)         (None, 64512)             0
# _________________________________________________________________
# dense_40 (Dense)             (None, 2)                 129026
# =================================================================
# Total params: 129,410
# Trainable params: 129,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 0.2422 - accuracy: 0.8750 - val_loss: 14.7791 - val_accuracy: 0.8571
# Epoch 2/20
# 2/2 [==============================] - 0s 76ms/step - loss: 6.1656 - accuracy: 0.8750 - val_loss: 18.9474 - val_accuracy: 0.8571
# Epoch 3/20
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 21.8434 - val_accuracy: 0.8571
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 24.0144 - val_accuracy: 0.8571
# Epoch 5/20
# 2/2 [==============================] - 0s 68ms/step - loss: 21.7626 - accuracy: 0.8750 - val_loss: 23.9005 - val_accuracy: 0.8571
# Epoch 6/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 22.2087 - val_accuracy: 0.8571
# Epoch 7/20
# 2/2 [==============================] - 0s 73ms/step - loss: 24.7084 - accuracy: 0.8750 - val_loss: 19.3812 - val_accuracy: 0.8571
# Epoch 8/20
# 2/2 [==============================] - 0s 73ms/step - loss: 19.5421 - accuracy: 0.8750 - val_loss: 13.7282 - val_accuracy: 0.8571
# Epoch 9/20
# 2/2 [==============================] - 0s 77ms/step - loss: 14.5272 - accuracy: 0.7500 - val_loss: 7.3764 - val_accuracy: 0.8571
# Epoch 10/20
# 2/2 [==============================] - 0s 75ms/step - loss: 2.3910 - accuracy: 0.8750 - val_loss: 1.3699 - val_accuracy: 0.7637
# Epoch 11/20
# 2/2 [==============================] - 0s 82ms/step - loss: 7.3762 - accuracy: 0.5000 - val_loss: 9.0438 - val_accuracy: 0.1648
# Epoch 12/20
# 2/2 [==============================] - 0s 70ms/step - loss: 5.2721 - accuracy: 0.2500 - val_loss: 3.9045 - val_accuracy: 0.8516
# Epoch 13/20
# 2/2 [==============================] - 0s 72ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 9.0663 - val_accuracy: 0.8571
# Epoch 14/20
# 2/2 [==============================] - 0s 72ms/step - loss: 11.7028 - accuracy: 0.8750 - val_loss: 12.6579 - val_accuracy: 0.8571
# Epoch 15/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 15.0218 - val_accuracy: 0.8571
# Epoch 16/20
# 2/2 [==============================] - 0s 76ms/step - loss: 10.2544 - accuracy: 0.8750 - val_loss: 16.5140 - val_accuracy: 0.8571
# Epoch 17/20
# 2/2 [==============================] - 0s 77ms/step - loss: 14.0171 - accuracy: 0.8750 - val_loss: 16.8208 - val_accuracy: 0.8571
# Epoch 18/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 16.6021 - val_accuracy: 0.8571
# Epoch 19/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 16.4210 - val_accuracy: 0.8571
# Epoch 20/20
# 2/2 [==============================] - 0s 76ms/step - loss: 18.5424 - accuracy: 0.7500 - val_loss: 15.5855 - val_accuracy: 0.8571
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_n = accuracy_score(y_pred, y_test)
dense_roc_n = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_n = precision_score(y_pred, y_test)
dense_rec_n = recall_score(y_pred, y_test)
dense_f1_n = f1_score(y_pred, y_test)
dense_mcc_n = matthews_corrcoef(y_pred, y_test)
dense_kap_n = cohen_kappa_score(y_pred, y_test)
dense_jacc_n = jaccard_score(y_pred, y_test)
dense_gmea_n = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CNV-CLN-WSI - DenseNets',dense_acc_n,dense_roc_n,dense_prec_n,dense_rec_n,dense_f1_n,dense_mcc_n,dense_kap_n,dense_jacc_n,dense_gmea_n)
# Out:
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_41 (Conv1D)           (None, 1009, 128)         384
# _________________________________________________________________
# max_pooling1d_41 (MaxPooling (None, 504, 128)          0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 504, 128)          0
# _________________________________________________________________
# flatten_41 (Flatten)         (None, 64512)             0
# _________________________________________________________________
# dense_41 (Dense)             (None, 2)                 129026
# =================================================================
# Total params: 129,410
# Trainable params: 129,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 150ms/step - loss: 8.7932 - accuracy: 0.8750 - val_loss: 9.8803 - val_accuracy: 0.8571
# Epoch 2/20
# 2/2 [==============================] - 0s 71ms/step - loss: 4.5619 - accuracy: 0.8750 - val_loss: 9.0265 - val_accuracy: 0.8571
# Epoch 3/20
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.8469 - val_accuracy: 0.8571
# Epoch 4/20
# 2/2 [==============================] - 0s 73ms/step - loss: 1.7128e-04 - accuracy: 1.0000 - val_loss: 5.2662 - val_accuracy: 0.8571
# Epoch 5/20
# 2/2 [==============================] - 0s 74ms/step - loss: 11.4797 - accuracy: 0.8750 - val_loss: 3.3698 - val_accuracy: 0.6758
# Epoch 6/20
# 2/2 [==============================] - 0s 74ms/step - loss: 2.7114 - accuracy: 0.5000 - val_loss: 3.4733 - val_accuracy: 0.8407
# Epoch 7/20
# 2/2 [==============================] - 0s 74ms/step - loss: 6.3878 - accuracy: 0.6250 - val_loss: 3.2190 - val_accuracy: 0.8571
# Epoch 8/20
# 2/2 [==============================] - 0s 71ms/step - loss: 3.2722 - accuracy: 0.8750 - val_loss: 2.3981 - val_accuracy: 0.8626
# Epoch 9/20
# 2/2 [==============================] - 0s 72ms/step - loss: 1.7254 - accuracy: 0.8750 - val_loss: 1.5772 - val_accuracy: 0.6374
# Epoch 10/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.7401 - accuracy: 0.7500 - val_loss: 1.1107 - val_accuracy: 0.8132
# Epoch 11/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.3519 - accuracy: 0.8750 - val_loss: 1.7755 - val_accuracy: 0.8571
# Epoch 12/20
# 2/2 [==============================] - 0s 73ms/step - loss: 3.3883e-05 - accuracy: 1.0000 - val_loss: 2.2305 - val_accuracy: 0.8571
# Epoch 13/20
# 2/2 [==============================] - 0s 72ms/step - loss: 1.5793 - accuracy: 0.8750 - val_loss: 1.6201 - val_accuracy: 0.8516
# Epoch 14/20
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3421 - accuracy: 0.8750 - val_loss: 1.7282 - val_accuracy: 0.8462
# Epoch 15/20
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5593 - accuracy: 0.8750 - val_loss: 2.9814 - val_accuracy: 0.8571
# Epoch 16/20
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0928 - accuracy: 0.8750 - val_loss: 3.9925 - val_accuracy: 0.8571
# Epoch 17/20
# 2/2 [==============================] - 0s 84ms/step - loss: 3.2697 - accuracy: 0.8750 - val_loss: 3.6393 - val_accuracy: 0.8571
# Epoch 18/20
# 2/2 [==============================] - 0s 77ms/step - loss: 3.2558 - accuracy: 0.8750 - val_loss: 2.0442 - val_accuracy: 0.8407
# Epoch 19/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1803 - accuracy: 0.8750 - val_loss: 1.8443 - val_accuracy: 0.6923
# Epoch 20/20
# 2/2 [==============================] - 0s 77ms/step - loss: 2.0085 - accuracy: 0.6250 - val_loss: 1.8653 - val_accuracy: 0.7912
# 6/6 [==============================] - 0s 296us/step
# 6/6 [==============================] - 0s 3ms/step

# %% [markdown]
# # CLN-WSI-EXP-CNV

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(multimodal, y_multimodal, test_size = 0.15)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((907, 1410), (907,), (161, 1410), (161,))

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm_acc_o = accuracy_score(y_pred, y_test)
svm_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm_prec_o = precision_score(y_pred, y_test)
svm_rec_o = recall_score(y_pred, y_test)
svm_f1_o = f1_score(y_pred, y_test)
svm_mcc_o = matthews_corrcoef(y_pred, y_test)
svm_kap_o = cohen_kappa_score(y_pred, y_test)
svm_jacc_o = jaccard_score(y_pred, y_test)
svm_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - rbf',svm_acc_o,svm_roc_o,svm_prec_o,svm_rec_o,svm_f1_o,svm_mcc_o,svm_kap_o,svm_jacc_o,svm_gmea_o)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_prob = clf.predict_proba(X_test)

svm1_acc_o = accuracy_score(y_pred, y_test)
svm1_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm1_prec_o = precision_score(y_pred, y_test)
svm1_rec_o = recall_score(y_pred, y_test)
svm1_f1_o = f1_score(y_pred, y_test)
svm1_mcc_o = matthews_corrcoef(y_pred, y_test)
svm1_kap_o = cohen_kappa_score(y_pred, y_test)
svm1_jacc_o = jaccard_score(y_pred, y_test)
svm1_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - Poly',svm1_acc_o,svm1_roc_o,svm1_prec_o,svm1_rec_o,svm1_f1_o,svm1_mcc_o,svm1_kap_o,svm1_jacc_o,svm1_gmea_o)

# %%
clf = SVC(C=c,kernel=utility_kernel, probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm2_acc_o = accuracy_score(y_pred, y_test)
svm2_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm2_prec_o = precision_score(y_pred, y_test)
svm2_rec_o = recall_score(y_pred, y_test)
svm2_f1_o = f1_score(y_pred, y_test)
svm2_mcc_o = matthews_corrcoef(y_pred, y_test)
svm2_kap_o = cohen_kappa_score(y_pred, y_test)
svm2_jacc_o = jaccard_score(y_pred, y_test)
svm2_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - Utility ',svm2_acc_o,svm2_roc_o,svm2_prec_o,svm2_rec_o,svm2_f1_o,svm2_mcc_o,svm2_kap_o,svm2_jacc_o,svm2_gmea_o)

# %%
clf = SVC(kernel ='linear', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm3_acc_o = accuracy_score(y_pred, y_test)
svm3_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm3_prec_o = precision_score(y_pred, y_test)
svm3_rec_o = recall_score(y_pred, y_test)
svm3_f1_o = f1_score(y_pred, y_test)
svm3_mcc_o = matthews_corrcoef(y_pred, y_test)
svm3_kap_o = cohen_kappa_score(y_pred, y_test)
svm3_jacc_o = jaccard_score(y_pred, y_test)
svm3_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - Linear ',svm3_acc_o,svm3_roc_o,svm3_prec_o,svm3_rec_o,svm3_f1_o,svm3_mcc_o,svm3_kap_o,svm3_jacc_o,svm3_gmea_o)

# %%
clf = SVC(kernel ='sigmoid', probability=True)

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

svm4_acc_o = accuracy_score(y_pred, y_test)
svm4_roc_o = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
svm4_prec_o = precision_score(y_pred, y_test)
svm4_rec_o = recall_score(y_pred, y_test)
svm4_f1_o = f1_score(y_pred, y_test)
svm4_mcc_o = matthews_corrcoef(y_pred, y_test)
svm4_kap_o = cohen_kappa_score(y_pred, y_test)
svm4_jacc_o = jaccard_score(y_pred, y_test)
svm4_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - SVM - Sigmoid',svm4_acc_o,svm4_roc_o,svm4_prec_o,svm4_rec_o,svm4_f1_o,svm4_mcc_o,svm4_kap_o,svm4_jacc_o,svm4_gmea_o)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the model 
rf = RandomForestClassifier(n_estimators=100, random_state=0)


# fit the model 
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

rf_acc_o = accuracy_score(y_pred, y_test)
rf_roc_o = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
rf_prec_o = precision_score(y_pred, y_test)
rf_rec_o = recall_score(y_pred, y_test)
rf_f1_o = f1_score(y_pred, y_test)
rf_mcc_o = matthews_corrcoef(y_pred, y_test)
rf_kap_o = cohen_kappa_score(y_pred, y_test)
rf_jacc_o = jaccard_score(y_pred, y_test)
rf_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - RF',rf_acc_o,rf_roc_o,rf_prec_o,rf_rec_o,rf_f1_o,rf_mcc_o,rf_kap_o,rf_jacc_o,rf_gmea_o)

# %%
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth=30)

# fit the model 
tree.fit(X_train, y_train)

y_pred = tree.predict(X_test)
y_prob = tree.predict_proba(X_test)

dt_acc_o = accuracy_score(y_pred, y_test)
dt_roc_o = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
dt_prec_o = precision_score(y_pred, y_test)
dt_rec_o = recall_score(y_pred, y_test)
dt_f1_o = f1_score(y_pred, y_test)
dt_mcc_o = matthews_corrcoef(y_pred, y_test)
dt_kap_o = cohen_kappa_score(y_pred, y_test)
dt_jacc_o = jaccard_score(y_pred, y_test)
dt_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - DT',dt_acc_o,dt_roc_o,dt_prec_o,dt_rec_o,dt_f1_o,dt_mcc_o,dt_kap_o,dt_jacc_o,dt_gmea_o)

# %%
from sklearn.naive_bayes import GaussianNB
#from sklearn.pipeline import Pipeline

# instantiate the model
nb=  GaussianNB()

# fit the model 
nb.fit(X_train, y_train)

y_pred = nb.predict(X_test)
y_prob = nb.predict_proba(X_test)

nb_acc_o = accuracy_score(y_pred, y_test)
nb_roc_o = roc_auc_score(y_test, nb.predict_proba(X_test)[:, 1])
nb_prec_o = precision_score(y_pred, y_test)
nb_rec_o = recall_score(y_pred, y_test)
nb_f1_o = f1_score(y_pred, y_test)
nb_mcc_o = matthews_corrcoef(y_pred, y_test)
nb_kap_o = cohen_kappa_score(y_pred, y_test)
nb_jacc_o = jaccard_score(y_pred, y_test)
nb_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - NB',nb_acc_o,nb_roc_o,nb_prec_o,nb_rec_o,nb_f1_o,nb_mcc_o,nb_kap_o,nb_jacc_o,nb_gmea_o)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
clf1 = RandomForestClassifier(n_estimators=100, random_state=0)
clf2 = SVC(probability=True)
clf3 = DecisionTreeClassifier(max_depth=30)

eclf1 = VotingClassifier(estimators=[('ab', clf1), ('rf', clf2), ('dt', clf3)], voting='soft')
eclf1.fit(X_train, y_train)

y_pred = eclf1.predict(X_test)
y_prob = eclf1.predict_proba(X_test)

vot_acc_o = accuracy_score(y_pred, y_test)
vot_roc_o = roc_auc_score(y_test, eclf1.predict_proba(X_test)[:, 1])
vot_prec_o = precision_score(y_pred, y_test)
vot_rec_o = recall_score(y_pred, y_test)
vot_f1_o = f1_score(y_pred, y_test)
vot_mcc_o = matthews_corrcoef(y_pred, y_test)
vot_kap_o = cohen_kappa_score(y_pred, y_test)
vot_jacc_o = jaccard_score(y_pred, y_test)
vot_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV- vot',vot_acc_o,vot_roc_o,vot_prec_o,vot_rec_o,vot_f1_o,vot_mcc_o,vot_kap_o,vot_jacc_o,vot_gmea_o)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

X_train=X_train
X_test=X_test

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 4
activationFunction='relu'

def VGGNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = VGGNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

vgg_acc_o = accuracy_score(y_pred, y_test)
vgg_roc_o = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
vgg_prec_o = precision_score(y_pred, y_test)
vgg_rec_o = recall_score(y_pred, y_test)
vgg_f1_o = f1_score(y_pred, y_test)
vgg_mcc_o = matthews_corrcoef(y_pred, y_test)
vgg_kap_o = cohen_kappa_score(y_pred, y_test)
vgg_jacc_o = jaccard_score(y_pred, y_test)
vgg_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - VGGNets',vgg_acc_o,vgg_roc_o,vgg_prec_o,vgg_rec_o,vgg_f1_o,vgg_mcc_o,vgg_kap_o,vgg_jacc_o,vgg_gmea_o)
# Out:
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_42 (Conv1D)           (None, 1409, 128)         384
# _________________________________________________________________
# max_pooling1d_42 (MaxPooling (None, 704, 128)          0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 704, 128)          0
# _________________________________________________________________
# flatten_42 (Flatten)         (None, 90112)             0
# _________________________________________________________________
# dense_42 (Dense)             (None, 2)                 180226
# =================================================================
# Total params: 180,610
# Trainable params: 180,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 1s 289ms/step - loss: 0.8307 - accuracy: 0.5000 - val_loss: 9.2682 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 79ms/step - loss: 17.8232 - accuracy: 0.7500 - val_loss: 11.3881 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 78ms/step - loss: 31.0662 - accuracy: 0.7500 - val_loss: 9.8538 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 78ms/step - loss: 7.2251 - accuracy: 0.8750 - val_loss: 8.0677 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 71ms/step - loss: 14.1858 - accuracy: 0.8750 - val_loss: 5.6987 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 71ms/step - loss: 3.6519 - accuracy: 0.8750 - val_loss: 3.5250 - val_accuracy: 0.9011
# Epoch 7/20
# 2/2 [==============================] - 0s 71ms/step - loss: 2.9802e-08 - accuracy: 1.0000 - val_loss: 2.3476 - val_accuracy: 0.6648
# Epoch 8/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4181 - accuracy: 0.7500 - val_loss: 3.3826 - val_accuracy: 0.5110
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 1.7212 - accuracy: 0.6250 - val_loss: 2.1204 - val_accuracy: 0.7582
# Epoch 10/20
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 2.7464 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 79ms/step - loss: 6.6240e-04 - accuracy: 1.0000 - val_loss: 3.5630 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 79ms/step - loss: 3.7389 - accuracy: 0.8750 - val_loss: 3.4644 - val_accuracy: 0.9011
# Epoch 13/20
# 2/2 [==============================] - 0s 68ms/step - loss: 3.2264 - accuracy: 0.8750 - val_loss: 2.6867 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.0828 - val_accuracy: 0.8901
# Epoch 15/20
# 2/2 [==============================] - 0s 77ms/step - loss: 1.3951 - accuracy: 0.7500 - val_loss: 1.7425 - val_accuracy: 0.7308
# Epoch 16/20
# 2/2 [==============================] - 0s 77ms/step - loss: 2.5816 - accuracy: 0.8750 - val_loss: 5.6269 - val_accuracy: 0.2637
# Epoch 17/20
# 2/2 [==============================] - 0s 80ms/step - loss: 4.5362 - accuracy: 0.1250 - val_loss: 1.4550 - val_accuracy: 0.7363
# Epoch 18/20
# 2/2 [==============================] - 0s 77ms/step - loss: 2.8516 - accuracy: 0.6250 - val_loss: 1.5020 - val_accuracy: 0.8956
# Epoch 19/20
# 2/2 [==============================] - 0s 72ms/step - loss: 1.4824 - accuracy: 0.8750 - val_loss: 1.5583 - val_accuracy: 0.8956
# Epoch 20/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7877 - accuracy: 0.8750 - val_loss: 1.3065 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step

# %%
def ResNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = ResNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

res_acc_o = accuracy_score(y_pred, y_test)
res_roc_o = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
res_prec_o = precision_score(y_pred, y_test)
res_rec_o = recall_score(y_pred, y_test)
res_f1_o = f1_score(y_pred, y_test)
res_mcc_o = matthews_corrcoef(y_pred, y_test)
res_kap_o = cohen_kappa_score(y_pred, y_test)
res_jacc_o = jaccard_score(y_pred, y_test)
res_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - ResNets',res_acc_o,res_roc_o,res_prec_o,res_rec_o,res_f1_o,res_mcc_o,res_kap_o,res_jacc_o,res_gmea_o)
# Out:
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_43 (Conv1D)           (None, 1409, 128)         384
# _________________________________________________________________
# max_pooling1d_43 (MaxPooling (None, 704, 128)          0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 704, 128)          0
# _________________________________________________________________
# flatten_43 (Flatten)         (None, 90112)             0
# _________________________________________________________________
# dense_43 (Dense)             (None, 2)                 180226
# =================================================================
# Total params: 180,610
# Trainable params: 180,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 149ms/step - loss: 0.2800 - accuracy: 0.7500 - val_loss: 10.2678 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 77ms/step - loss: 4.9972 - accuracy: 0.8750 - val_loss: 13.1011 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 77ms/step - loss: 29.5689 - accuracy: 0.7500 - val_loss: 12.8279 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 73ms/step - loss: 12.4589 - accuracy: 0.8750 - val_loss: 9.2158 - val_accuracy: 0.9011
# Epoch 5/20
# 2/2 [==============================] - 0s 79ms/step - loss: 23.2526 - accuracy: 0.7500 - val_loss: 5.2341 - val_accuracy: 0.9011
# Epoch 6/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1200 - val_accuracy: 0.8846
# Epoch 7/20
# 2/2 [==============================] - 0s 72ms/step - loss: 8.4475 - accuracy: 0.2500 - val_loss: 13.9208 - val_accuracy: 0.0989
# Epoch 8/20
# 2/2 [==============================] - 0s 70ms/step - loss: 9.4161 - accuracy: 0.1250 - val_loss: 1.6337 - val_accuracy: 0.8901
# Epoch 9/20
# 2/2 [==============================] - 0s 80ms/step - loss: 3.0694 - accuracy: 0.8750 - val_loss: 4.0950 - val_accuracy: 0.9011
# Epoch 10/20
# 2/2 [==============================] - 0s 77ms/step - loss: 8.4826 - accuracy: 0.8750 - val_loss: 5.6789 - val_accuracy: 0.9011
# Epoch 11/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.5859 - val_accuracy: 0.9011
# Epoch 12/20
# 2/2 [==============================] - 0s 78ms/step - loss: 11.9626 - accuracy: 0.8750 - val_loss: 6.9212 - val_accuracy: 0.9011
# Epoch 13/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.8311 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 73ms/step - loss: 8.7141 - accuracy: 0.8750 - val_loss: 6.4583 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.8851 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.4169 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 75ms/step - loss: 13.3524 - accuracy: 0.7500 - val_loss: 4.3697 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9190 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 72ms/step - loss: 1.9468 - accuracy: 0.8750 - val_loss: 1.4980 - val_accuracy: 0.8956
# Epoch 20/20
# 2/2 [==============================] - 0s 71ms/step - loss: 6.5863e-06 - accuracy: 1.0000 - val_loss: 1.5046 - val_accuracy: 0.7198
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
def DenseNets():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = DenseNets()

modelhistory= cnnmodel.fit(X_train, Y_train, epochs=20,steps_per_epoch=2, verbose=verbose, validation_split=0.2, batch_size = batch_size)

# Plot training & validation loss values
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

cnnpredictions = cnnmodel.predict(X_test, verbose=1)
cnn_predict=np.argmax(cnnpredictions,axis=1)

y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dense_acc_o = accuracy_score(y_pred, y_test)
dense_roc_o = roc_auc_score(y_test, cnnmodel.predict_proba(X_test)[:, 1])
dense_prec_o = precision_score(y_pred, y_test)
dense_rec_o = recall_score(y_pred, y_test)
dense_f1_o = f1_score(y_pred, y_test)
dense_mcc_o = matthews_corrcoef(y_pred, y_test)
dense_kap_o = cohen_kappa_score(y_pred, y_test)
dense_jacc_o = jaccard_score(y_pred, y_test)
dense_gmea_o = fbeta_score(y_pred, y_test, beta=0.5)

storeResults('CLN-WSI-EXP-CNV - DenseNets',dense_acc_o,dense_roc_o,dense_prec_o,dense_rec_o,dense_f1_o,dense_mcc_o,dense_kap_o,dense_jacc_o,dense_gmea_o)
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_44 (Conv1D)           (None, 1409, 128)         384
# _________________________________________________________________
# max_pooling1d_44 (MaxPooling (None, 704, 128)          0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 704, 128)          0
# _________________________________________________________________
# flatten_44 (Flatten)         (None, 90112)             0
# _________________________________________________________________
# dense_44 (Dense)             (None, 2)                 180226
# =================================================================
# Total params: 180,610
# Trainable params: 180,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 146ms/step - loss: 2.8852 - accuracy: 0.3750 - val_loss: 4.5747 - val_accuracy: 0.9011
# Epoch 2/20
# 2/2 [==============================] - 0s 73ms/step - loss: 6.4441 - accuracy: 0.8750 - val_loss: 3.1821 - val_accuracy: 0.9011
# Epoch 3/20
# 2/2 [==============================] - 0s 72ms/step - loss: 5.9339 - accuracy: 0.7500 - val_loss: 0.8959 - val_accuracy: 0.9011
# Epoch 4/20
# 2/2 [==============================] - 0s 71ms/step - loss: 1.9062 - accuracy: 0.5000 - val_loss: 0.6610 - val_accuracy: 0.8681
# Epoch 5/20
# 2/2 [==============================] - 0s 71ms/step - loss: 1.2401 - accuracy: 0.7500 - val_loss: 0.7907 - val_accuracy: 0.8736
# Epoch 6/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3075 - accuracy: 0.8750 - val_loss: 1.0771 - val_accuracy: 0.8901
# Epoch 7/20
# 2/2 [==============================] - 0s 78ms/step - loss: 3.5217 - accuracy: 0.7500 - val_loss: 2.5310 - val_accuracy: 0.4066
# Epoch 8/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.7926 - accuracy: 0.7500 - val_loss: 1.4857 - val_accuracy: 0.5989
# Epoch 9/20
# 2/2 [==============================] - 0s 71ms/step - loss: 2.0755 - accuracy: 0.7500 - val_loss: 0.8309 - val_accuracy: 0.8242
# Epoch 10/20
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0602 - accuracy: 1.0000 - val_loss: 1.0435 - val_accuracy: 0.8901
# Epoch 11/20
# 2/2 [==============================] - 0s 76ms/step - loss: 4.1780 - accuracy: 0.7500 - val_loss: 0.9452 - val_accuracy: 0.7857
# Epoch 12/20
# 2/2 [==============================] - 0s 74ms/step - loss: 2.7114 - accuracy: 0.5000 - val_loss: 2.9587 - val_accuracy: 0.4780
# Epoch 13/20
# 2/2 [==============================] - 0s 76ms/step - loss: 3.6703 - accuracy: 0.6250 - val_loss: 1.3940 - val_accuracy: 0.9011
# Epoch 14/20
# 2/2 [==============================] - 0s 75ms/step - loss: 1.2904e-05 - accuracy: 1.0000 - val_loss: 2.7392 - val_accuracy: 0.9011
# Epoch 15/20
# 2/2 [==============================] - 0s 74ms/step - loss: 7.2242 - accuracy: 0.7500 - val_loss: 2.7937 - val_accuracy: 0.9011
# Epoch 16/20
# 2/2 [==============================] - 0s 83ms/step - loss: 1.7881e-07 - accuracy: 1.0000 - val_loss: 2.8378 - val_accuracy: 0.9011
# Epoch 17/20
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.8739 - val_accuracy: 0.9011
# Epoch 18/20
# 2/2 [==============================] - 0s 79ms/step - loss: 5.1298 - accuracy: 0.8750 - val_loss: 2.5026 - val_accuracy: 0.9011
# Epoch 19/20
# 2/2 [==============================] - 0s 78ms/step - loss: 2.1068e-05 - accuracy: 1.0000 - val_loss: 1.8398 - val_accuracy: 0.9011
# Epoch 20/20
# 2/2 [==============================] - 0s 79ms/step - loss: 7.9428e-04 - accuracy: 1.0000 - val_loss: 1.3889 - val_accuracy: 0.8791
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 3ms/step

# %% [markdown]
# # Comparison

# %%
#creating dataframe
result = pd.DataFrame({ 'ML Model' : ML_Model,
                        'Accuracy' : accuracy,
                        'ROC score' : roc,
                        'Precision': precision,
                        'Recall'   : recall,
                        'F1-Score': f1score,
                        'MCC' : mcc,
                        'Kappa Score' : kappa,
                       'Jaccard Score' : jacc,
                       'G-Measure' : gmea
                      })

# %%
result
# Out:
#                         ML Model  Accuracy  ROC score  Precision  Recall  \
# 0                CLN - SVM - rbf     0.888      0.783      1.000   0.888
# 1               CLN - SVM - Poly     0.888      0.680      1.000   0.888
# 2           CLN - SVM - Utility      0.882      0.606      0.944   0.925
# 3            CLN - SVM - Linear      0.888      0.356      1.000   0.888
# 4            CLN - SVM - Sigmoid     0.851      0.382      0.951   0.889
# ..                           ...       ...        ...        ...     ...
# 175         CLN-WSI-EXP-CNV - NB     0.720      0.591      0.788   0.871
# 176         CLN-WSI-EXP-CNV- vot     0.851      0.399      1.000   0.851
# 177    CLN-WSI-EXP-CNV - VGGNets     0.845      0.526      0.993   0.850
# 178    CLN-WSI-EXP-CNV - ResNets     0.652      0.531      0.730   0.840
# 179  CLN-WSI-EXP-CNV - DenseNets     0.839      0.519      0.985   0.849
#
#      F1-Score    MCC  Kappa Score  Jaccard Score  G-Measure
# 0       0.941  0.000        0.000          0.888      0.975
# 1       0.941  0.000        0.000          0.888      0.975
# 2       0.934  0.361        0.359          0.877      0.940
# 3       0.941  0.000        0.000          0.888      0.975
# 4       0.919  0.010        0.009          0.850      0.938
# ..        ...    ...          ...            ...        ...
# 175     0.828  0.103        0.099          0.706      0.804
# 176     0.919  0.000        0.000          0.851      0.966
# 177     0.916 -0.033       -0.012          0.845      0.960
# 178     0.781 -0.050       -0.047          0.641      0.750
# 179     0.912 -0.047       -0.023          0.839      0.955
#
# [180 rows x 10 columns]

# %%
print(result.to_string())
# Out:
#                              ML Model  Accuracy  ROC score  Precision  Recall  F1-Score    MCC  Kappa Score  Jaccard Score  G-Measure
# 0                     CLN - SVM - rbf     0.888      0.783      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 1                    CLN - SVM - Poly     0.888      0.680      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 2                CLN - SVM - Utility      0.882      0.606      0.944   0.925     0.934  0.361        0.359          0.877      0.940
# 3                 CLN - SVM - Linear      0.888      0.356      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 4                 CLN - SVM - Sigmoid     0.851      0.382      0.951   0.889     0.919  0.010        0.009          0.850      0.938
# 5                            CLN - RF     0.876      0.685      0.951   0.913     0.932  0.275        0.268          0.872      0.943
# 6                            CLN - DT     0.863      0.678      0.916   0.929     0.923  0.344        0.344          0.856      0.919
# 7                            CLN - NB     0.776      0.621      0.867   0.879     0.873 -0.074       -0.074          0.775      0.870
# 8                           CLN - vot     0.882      0.705      0.951   0.919     0.935  0.329        0.324          0.877      0.944
# 9                       CLN - VGGNets     0.888      0.449      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 10                      CLN - ResNets     0.888      0.442      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 11                    CLN - DenseNets     0.888      0.434      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 12                    WSI - SVM - rbf     0.901      0.502      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 13                   WSI - SVM - Poly     0.901      0.469      1.000   0.901     0.948  0.000        0.000          0.901      0.975
# 14               WSI - SVM - Utility      0.826      0.484      0.917   0.893     0.905 -0.094       -0.093          0.826      0.912
# 15                WSI - SVM - Linear      0.770      0.486      0.834   0.903     0.867  0.018        0.017          0.766      0.847
# 16                WSI - SVM - Sigmoid     0.888      0.461      0.986   0.899     0.941 -0.037       -0.023          0.888      0.968
# 17                           WSI - RF     0.901      0.516      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 18                           WSI - DT     0.820      0.473      0.903   0.897     0.900 -0.035       -0.035          0.819      0.902
# 19                           WSI - NB     0.739      0.525      0.800   0.899     0.847 -0.009       -0.009          0.734      0.818
# 20                           WSI- vot     0.901      0.501      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 21                      WSI - VGGNets     0.894      0.435      0.993   0.900     0.944 -0.026       -0.012          0.894      0.973
# 22                      WSI - ResNets     0.180      0.568      0.090   1.000     0.165  0.098        0.019          0.090      0.110
# 23                    WSI - DenseNets     0.870      0.533      0.966   0.897     0.930 -0.059       -0.050          0.870      0.951
# 24                    EXP - SVM - rbf     0.882      0.572      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 25                   EXP - SVM - Poly     0.882      0.564      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 26               EXP - SVM - Utility      0.882      0.513      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 27                EXP - SVM - Linear      0.764      0.543      0.838   0.888     0.862  0.042        0.041          0.758      0.848
# 28                EXP - SVM - Sigmoid     0.882      0.559      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 29                           EXP - RF     0.882      0.601      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 30                           EXP - DT     0.733      0.507      0.803   0.884     0.841  0.011        0.010          0.726      0.818
# 31                           EXP - NB     0.398      0.540      0.366   0.881     0.517 -0.001       -0.001          0.349      0.415
# 32                          EXP - vot     0.870      0.572      0.979   0.885     0.930  0.065        0.048          0.869      0.959
# 33                      EXP - VGGNets     0.882      0.466      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 34                      EXP - ResNets     0.882      0.475      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 35                    EXP - DenseNets     0.882      0.469      1.000   0.882     0.937  0.000        0.000          0.882      0.974
# 36                    CNV - SVM - rbf     0.938      0.519      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 37                   CNV - SVM - Poly     0.882      0.574      0.940   0.934     0.937 -0.063       -0.063          0.882      0.939
# 38               CNV - SVM - Utility      0.789      0.407      0.828   0.940     0.880  0.018        0.015          0.786      0.848
# 39                CNV - SVM - Linear      0.938      0.283      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 40                CNV - SVM - Sigmoid     0.894      0.497      0.954   0.935     0.944 -0.055       -0.054          0.894      0.950
# 41                           CNV - RF     0.907      0.506      0.960   0.942     0.951  0.071        0.070          0.906      0.956
# 42                           CNV - DT     0.826      0.639      0.861   0.949     0.903  0.109        0.097          0.823      0.877
# 43                           CNV - NB     0.720      0.571      0.742   0.949     0.833  0.077        0.056          0.713      0.776
# 44                          CNV - vot     0.919      0.525      0.967   0.948     0.957  0.198        0.194          0.918      0.963
# 45                      CNV - VGGNets     0.938      0.583      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 46                      CNV - ResNets     0.938      0.516      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 47                    CNV - DenseNets     0.938      0.523      1.000   0.938     0.968  0.000        0.000          0.938      0.987
# 48                CLN-EXP - SVM - rbf     0.851      0.556      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 49               CLN-EXP - SVM - Poly     0.851      0.511      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 50           CLN-EXP - SVM - Utility      0.851      0.600      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 51            CLN-EXP - SVM - Linear      0.745      0.540      0.854   0.848     0.851 -0.021       -0.021          0.741      0.853
# 52                EXP - SVM - Sigmoid     0.851      0.645      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 53                       CLN-EXP - RF     0.851      0.620      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 54                       CLN-EXP - DT     0.776      0.542      0.876   0.863     0.870  0.087        0.087          0.769      0.873
# 55                       CLN-EXP - NB     0.547      0.613      0.555   0.864     0.676  0.039        0.030          0.510      0.597
# 56                      CLN-EXP - vot     0.851      0.611      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 57                  CLN-EXP - VGGNets     0.851      0.564      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 58                  CLN-EXP - ResNets     0.851      0.573      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 59                CLN-EXP - DenseNets     0.851      0.573      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 60                CLN-CNV - SVM - rbf     0.888      0.599      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 61               CLN-CNV - SVM - Poly     0.888      0.576      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 62           CLN-CNV - SVM - Utility      0.708      0.557      0.783   0.875     0.827 -0.082       -0.077          0.704      0.800
# 63            CLN-CNV - SVM - Linear      0.882      0.643      0.993   0.888     0.937 -0.028       -0.012          0.882      0.970
# 64            CLN-CNV - SVM - Sigmoid     0.845      0.494      0.944   0.888     0.915 -0.001       -0.000          0.844      0.932
# 65                       CLN-CNV - RF     0.876      0.847      0.986   0.887     0.934 -0.040       -0.023          0.876      0.964
# 66                       CLN-CNV - DT     0.826      0.659      0.874   0.926     0.899  0.273        0.267          0.817      0.884
# 67                       CLN-CNV - NB     0.696      0.647      0.720   0.920     0.808  0.151        0.126          0.678      0.753
# 68                      CLN-CNV - vot     0.882      0.805      0.972   0.903     0.936  0.214        0.189          0.880      0.957
# 69                  CLN-CNV - VGGNets     0.888      0.368      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 70                  CLN-CNV - ResNets     0.888      0.364      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 71                CLN-CNV - DenseNets     0.888      0.363      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 72                CLN-WSI - SVM - rbf     0.901      0.417      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 73               CLN-WSI - SVM - Poly     0.901      0.537      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 74           CLN-WSI - SVM - Utility      0.888      0.437      0.986   0.899     0.941 -0.037       -0.023          0.888      0.968
# 75            CLN-WSI - SVM - Linear      0.807      0.572      0.869   0.913     0.890  0.102        0.100          0.803      0.877
# 76            CLN-WSI - SVM - Sigmoid     0.894      0.478      0.993   0.900     0.944 -0.026       -0.012          0.894      0.973
# 77                       CLN-WSI - RF     0.901      0.628      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 78                       CLN-WSI - DT     0.832      0.657      0.876   0.934     0.904  0.259        0.251          0.825      0.887
# 79                       CLN-WSI - NB     0.689      0.483      0.745   0.893     0.812 -0.047       -0.041          0.684      0.770
# 80                      CLN-WSI - vot     0.901      0.761      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 81                  CLN-WSI - VGGNets     0.845      0.473      0.938   0.895     0.916 -0.081       -0.077          0.845      0.929
# 82                  CLN-WSI - ResNets     0.540      0.395      0.579   0.866     0.694 -0.143       -0.100          0.532      0.620
# 83                CLN-WSI - DenseNets     0.901      0.452      1.000   0.901     0.948  0.000        0.000          0.901      0.978
# 84                EXP-CNV - SVM - rbf     0.876      0.550      1.000   0.876     0.934  0.000        0.000          0.876      0.972
# 85               EXP-CNV - SVM - Poly     0.876      0.540      1.000   0.876     0.934  0.000        0.000          0.876      0.972
# 86           EXP-CNV - SVM - Utility      0.876      0.552      1.000   0.876     0.934  0.000        0.000          0.876      0.972
# 87            EXP-CNV - SVM - Linear      0.745      0.540      0.823   0.879     0.850  0.019        0.019          0.739      0.833
# 88            EXP-CNV - SVM - Sigmoid     0.876      0.549      1.000   0.876     0.934  0.000        0.000          0.876      0.972
# 89                       EXP-CNV - RF     0.876      0.570      1.000   0.876     0.934  0.000        0.000          0.876      0.972
# 90                       EXP-CNV - DT     0.820      0.554      0.908   0.889     0.898  0.116        0.115          0.815      0.904
# 91                       EXP-CNV - NB     0.484      0.516      0.482   0.872     0.621 -0.012       -0.008          0.450      0.530
# 92                      EXP-CNV - vot     0.888      0.534      1.000   0.887     0.940  0.298        0.163          0.887      0.975
# 93                  EXP-CNV - VGGNets     0.857      0.574      0.965   0.883     0.922  0.104        0.090          0.855      0.947
# 94                  EXP-CNV - ResNets     0.857      0.611      0.979   0.873     0.923 -0.052       -0.033          0.857      0.956
# 95                EXP-CNV - DenseNets     0.820      0.502      0.915   0.884     0.899  0.074        0.073          0.816      0.908
# 96                EXP-WSI - SVM - rbf     0.888      0.428      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 97               EXP-WSI - SVM - Poly     0.888      0.476      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 98           EXP-WSI - SVM - Utility      0.826      0.449      0.930   0.881     0.905 -0.091       -0.087          0.826      0.920
# 99            EXP-WSI - SVM - Linear      0.832      0.575      0.902   0.908     0.905  0.176        0.176          0.827      0.903
# 100           EXP-WSI - SVM - Sigmoid     0.832      0.479      0.937   0.882     0.908 -0.086       -0.081          0.832      0.925
# 101                      EXP-WSI - RF     0.888      0.559      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 102                      EXP-WSI - DT     0.851      0.625      0.916   0.916     0.916  0.249        0.249          0.845      0.916
# 103                      EXP-WSI - NB     0.615      0.494      0.643   0.893     0.748  0.021        0.016          0.597      0.681
# 104                     EXP-WSI - vot     0.888      0.588      1.000   0.888     0.941  0.000        0.000          0.888      0.975
# 105                 EXP-WSI - VGGNets     0.360      0.485      0.315   0.900     0.466  0.025        0.011          0.304      0.362
# 106                 EXP-WSI - ResNets     0.696      0.488      0.755   0.885     0.815 -0.017       -0.015          0.688      0.778
# 107               EXP-WSI - DenseNets     0.373      0.426      0.364   0.839     0.507 -0.124       -0.065          0.340      0.410
# 108               CNV-WSI - SVM - rbf     0.870      0.490      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 109              CNV-WSI - SVM - Poly     0.870      0.504      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 110          CNV-WSI - SVM - Utility      0.832      0.398      0.950   0.869     0.908 -0.004       -0.003          0.831      0.933
# 111           CNV-WSI - SVM - Linear      0.789      0.585      0.879   0.879     0.879  0.069        0.069          0.783      0.879
# 112           CNV-WSI - SVM - Sigmoid     0.857      0.446      0.986   0.868     0.923 -0.043       -0.023          0.857      0.960
# 113                      CNV-WSI - RF     0.870      0.546      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 114                      CNV-WSI - DT     0.745      0.449      0.850   0.856     0.853 -0.100       -0.100          0.744      0.851
# 115                      CNV-WSI - NB     0.758      0.742      0.793   0.917     0.851  0.247        0.229          0.740      0.815
# 116                     CNV-WSI - vot     0.870      0.488      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 117                 CNV-WSI - VGGNets     0.870      0.500      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 118                 EXP-CNV - ResNets     0.863      0.596      0.993   0.869     0.927 -0.031       -0.012          0.863      0.965
# 119               EXP-CNV - DenseNets     0.292      0.447      0.236   0.825     0.367 -0.076       -0.032          0.224      0.275
# 120           CLN-EXP-CNV - SVM - rbf     0.870      0.572      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 121          CLN-EXP-CNV - SVM - Poly     0.870      0.615      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 122      CLN-EXP-CNV - SVM - Utility      0.870      0.594      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 123       CLN-EXP-CNV - SVM - Linear      0.770      0.535      0.850   0.881     0.865  0.081        0.080          0.763      0.856
# 124       CLN-EXP-CNV - SVM - Sigmoid     0.870      0.544      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 125                  CLN-EXP-CNV - RF     0.870      0.713      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 126                  CLN-EXP-CNV - DT     0.826      0.596      0.907   0.894     0.901  0.201        0.201          0.819      0.905
# 127                  CLN-EXP-CNV - NB     0.665      0.554      0.707   0.884     0.786  0.064        0.056          0.647      0.737
# 128                 CLN-EXP-CNV - vot     0.851      0.661      0.979   0.867     0.919 -0.053       -0.034          0.851      0.954
# 129             CLN-EXP-CNV - VGGNets     0.870      0.519      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 130             CLN-EXP-CNV - ResNets     0.776      0.569      0.843   0.894     0.868  0.154        0.152          0.766      0.853
# 131           CLN-EXP-CNV - DenseNets     0.870      0.532      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 132           CLN-EXP-WSI - SVM - rbf     0.870      0.473      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 133          CLN-EXP-WSI - SVM - Poly     0.870      0.511      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 134      CLN-EXP-WSI - SVM - Utility      0.820      0.478      0.929   0.872     0.900  0.031        0.029          0.818      0.917
# 135       CLN-EXP-WSI - SVM - Linear      0.727      0.527      0.829   0.853     0.841 -0.115       -0.115          0.725      0.833
# 136       CLN-EXP-WSI - SVM - Sigmoid     0.839      0.532      0.957   0.870     0.912  0.008        0.007          0.838      0.938
# 137                  CLN-EXP-WSI - RF     0.870      0.389      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 138                  CLN-EXP-WSI - DT     0.795      0.457      0.907   0.864     0.885 -0.054       -0.053          0.794      0.898
# 139                  CLN-EXP-WSI - NB     0.578      0.525      0.607   0.867     0.714 -0.008       -0.006          0.556      0.646
# 140                 CLN-EXP-WSI - vot     0.870      0.357      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 141             CLN-EXP-WSI - VGGNets     0.453      0.638      0.421   0.894     0.573  0.060        0.035          0.401      0.471
# 142             CLN-EXP-WSI - ResNets     0.870      0.437      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 143           CLN-EXP-WSI - DenseNets     0.870      0.466      1.000   0.870     0.930  0.000        0.000          0.870      0.971
# 144           EXP-CNV-WSI - SVM - rbf     0.851      0.509      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 145          EXP-CNV-WSI - SVM - Poly     0.851      0.492      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 146      EXP-CNV-WSI - SVM - Utility      0.820      0.453      0.942   0.860     0.899  0.094        0.086          0.816      0.924
# 147       EXP-CNV-WSI - SVM - Linear      0.770      0.525      0.883   0.852     0.867  0.009        0.009          0.766      0.877
# 148       EXP-CNV-WSI - SVM - Sigmoid     0.863      0.486      1.000   0.862     0.926  0.268        0.134          0.862      0.969
# 149                  EXP-CNV-WSI - RF     0.851      0.480      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 150                  EXP-CNV-WSI - DT     0.758      0.505      0.869   0.850     0.859 -0.007       -0.007          0.753      0.865
# 151                  EXP-CNV-WSI - NB     0.683      0.590      0.730   0.877     0.797  0.115        0.105          0.662      0.755
# 152                 EXP-CNV-WSI - vot     0.851      0.500      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 153             EXP-CNV-WSI - VGGNets     0.379      0.472      0.336   0.836     0.479 -0.029       -0.016          0.315      0.381
# 154             EXP-CNV-WSI - ResNets     0.820      0.584      0.949   0.855     0.900  0.050        0.043          0.818      0.929
# 155           EXP-CNV-WSI - DenseNets     0.553      0.566      0.540   0.892     0.673  0.118        0.086          0.507      0.586
# 156           CNV-CLN-WSI - SVM - rbf     0.857      0.474      1.000   0.857     0.923  0.000        0.000          0.857      0.968
# 157          CNV-CLN-WSI - SVM - Poly     0.857      0.466      1.000   0.857     0.923  0.000        0.000          0.857      0.968
# 158      CNV-CLN-WSI - SVM - Utility      0.814      0.547      0.928   0.865     0.895  0.074        0.071          0.810      0.914
# 159       CNV-CLN-WSI - SVM - Linear      0.739      0.514      0.833   0.858     0.846  0.007        0.007          0.732      0.838
# 160       CNV-CLN-WSI - SVM - Sigmoid     0.845      0.492      0.986   0.855     0.916 -0.046       -0.023          0.845      0.956
# 161                  CNV-CLN-WSI - RF     0.857      0.498      1.000   0.857     0.923  0.000        0.000          0.857      0.968
# 162                  CNV-CLN-WSI - DT     0.764      0.457      0.884   0.847     0.865 -0.083       -0.081          0.762      0.876
# 163                  CNV-CLN-WSI - NB     0.627      0.546      0.681   0.855     0.758 -0.011       -0.010          0.610      0.710
# 164                 CNV-CLN-WSI - vot     0.857      0.466      1.000   0.857     0.923  0.000        0.000          0.857      0.968
# 165             CNV-CLN-WSI - VGGNets     0.832      0.466      0.964   0.858     0.908  0.013        0.010          0.831      0.941
# 166             CNV-CLN-WSI - ResNets     0.857      0.500      1.000   0.857     0.923  0.000        0.000          0.857      0.968
# 167           CNV-CLN-WSI - DenseNets     0.702      0.425      0.804   0.841     0.822 -0.099       -0.098          0.698      0.811
# 168       CLN-WSI-EXP-CNV - SVM - rbf     0.851      0.434      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 169      CLN-WSI-EXP-CNV - SVM - Poly     0.851      0.589      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 170  CLN-WSI-EXP-CNV - SVM - Utility      0.839      0.478      0.964   0.863     0.910  0.145        0.122          0.835      0.942
# 171   CLN-WSI-EXP-CNV - SVM - Linear      0.807      0.563      0.905   0.873     0.889  0.171        0.170          0.800      0.899
# 172   CLN-WSI-EXP-CNV - SVM - Sigmoid     0.863      0.526      1.000   0.862     0.926  0.268        0.134          0.862      0.969
# 173              CLN-WSI-EXP-CNV - RF     0.851      0.431      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 174              CLN-WSI-EXP-CNV - DT     0.727      0.461      0.839   0.839     0.839 -0.077       -0.077          0.723      0.839
# 175              CLN-WSI-EXP-CNV - NB     0.720      0.591      0.788   0.871     0.828  0.103        0.099          0.706      0.804
# 176              CLN-WSI-EXP-CNV- vot     0.851      0.399      1.000   0.851     0.919  0.000        0.000          0.851      0.966
# 177         CLN-WSI-EXP-CNV - VGGNets     0.845      0.526      0.993   0.850     0.916 -0.033       -0.012          0.845      0.960
# 178         CLN-WSI-EXP-CNV - ResNets     0.652      0.531      0.730   0.840     0.781 -0.050       -0.047          0.641      0.750
# 179       CLN-WSI-EXP-CNV - DenseNets     0.839      0.519      0.985   0.849     0.912 -0.047       -0.023          0.839      0.955

# %%
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, accuracy, align='center', alpha=0.5,color='blue')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Accuracy Score')
plt2.title('Classification Performance')
plt2.show()
